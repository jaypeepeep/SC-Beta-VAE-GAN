# %%
# Cell 1
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import io
import os
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import random
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model
from keras.utils import custom_object_scope
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense

# %%
# Cell 2
# Updated function
# Updated function without saving data inside
def upload_and_process_files(directory, num_files_to_use=None):
    svc_files = [f for f in os.listdir(directory) if f.endswith('.svc')]
    
    # If num_files_to_use is specified, only take that many files sequentially
    if num_files_to_use:
        svc_files = svc_files[:num_files_to_use]  # Take the first num_files_to_use files

    data_frames = []  # Processed data after scaling
    original_data_frames = []  # Save the original unscaled data
    scalers = []
    input_filenames = []  # List to store input filenames

    num_files = len(svc_files)
    

    for i, filename in enumerate(svc_files):
        file_path = os.path.join(directory, filename)
        input_filenames.append(filename)  # Store the filename
        df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
        df.columns = ['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude']
        
        # Modify timestamp to start from 0
        df['timestamp'] = (df['timestamp'] - df['timestamp'].min()).round().astype(int)
        
        # Keep a copy of the original data before scaling
        original_data_frames.append(df.copy())  # Save the original unmodified data
        
        # Process the data for use in the model
        df = df.iloc[:, [0, 1, 2, 3, 4, 5, 6]] 
        data_frames.append(df)
        scaler = MinMaxScaler()
        normalized_data = scaler.fit_transform(df[['x', 'y', 'timestamp']])
        scalers.append(scaler)


    processed_data = [np.column_stack((scaler.transform(df[['x', 'y', 'timestamp']]), df['pen_status'].values)) 
                      for df, scaler in zip(data_frames, scalers)]
    avg_data_points = int(np.mean([df.shape[0] for df in data_frames]))

    return data_frames, processed_data, scalers, avg_data_points, input_filenames, original_data_frames  # Return original data

# Save data outside the function
def save_original_data(data_frames, input_filenames, output_folder='original_absolute'):
    os.makedirs(output_folder, exist_ok=True)
    for df, filename in zip(data_frames, input_filenames):
        save_path = os.path.join(output_folder, filename)
        df.to_csv(save_path, sep=' ', index=False, header=False)

directory = '../../all_datasets/emothaw'  # Directory where the .svc files are stored
num_files_to_use = 903
data_frames, processed_data, scalers, avg_data_points, input_filenames, original_data_frames = upload_and_process_files(directory, num_files_to_use)

# Save the original data after processing
save_original_data(original_data_frames, input_filenames)

# Store the name of the first file for use in Cell 4
input_filename = input_filenames[0] if input_filenames else 'processed_data'
print(f"Number of processed files: {len(processed_data)}")
print(f"Average number of data points: {avg_data_points}")
# Out:
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# ...
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\annek\AppData\Local\Temp\ipykernel_11440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# Number of processed files: 903
# Average number of data points: 2939

# %%
# Cell 3
# Process each DataFrame instead of just the first one
for df_idx in range(len(data_frames)):
    df = data_frames[df_idx]  # Using each DataFrame in the list

    # Convert the 'timestamp' column to numeric for calculations (if not already done)
    df['timestamp'] = pd.to_numeric(df['timestamp'])

    # Sort the DataFrame by timestamp (should already be sorted in the function)
    df.sort_values('timestamp', inplace=True)

    # Calculate the differences between consecutive timestamps (optional for gap finding)
    df['time_diff'] = df['timestamp'].diff()

    # Identify the indices where the time difference is greater than 30,000 milliseconds
    gap_indices = df.index[df['time_diff'] > 8].tolist()

    # Create an empty list to hold the new rows
    new_rows = []

    # Fill in the gaps with 70 milliseconds intervals
    for idx in gap_indices:
        # Check if the next index is valid
        if idx + 1 < len(df):
            # Get the current and next timestamps
            current_timestamp = df.at[idx, 'timestamp']
            next_timestamp = df.at[idx + 1, 'timestamp']

            # Calculate how many entries we need to fill in
            num_fill_entries = (next_timestamp - current_timestamp) // 7

            # Generate the timestamps to fill the gap
            for i in range(1, num_fill_entries + 1):
                new_timestamp = current_timestamp + i * 7

                # Create a new row to fill in with NaN for x and y
                new_row = {
                    'x': np.nan,  # Set x to NaN
                    'y': np.nan,  # Set y to NaN
                    'timestamp': new_timestamp,
                    'pen_status': 0,        # You can set this to your desired value
                    'azimuth': df.at[idx, 'azimuth'],   # Use the current azimuth value
                    'altitude': df.at[idx, 'altitude'], # Use the current altitude value
                    'pressure': df.at[idx, 'pressure']  # Use the current pressure value
                }

                # Append the new row to the list of new rows
                new_rows.append(new_row)

    # Create a DataFrame from the new rows
    new_rows_df = pd.DataFrame(new_rows)

    # Concatenate the original DataFrame with the new rows DataFrame
    df = pd.concat([df, new_rows_df], ignore_index=True)

    # Sort the DataFrame by timestamp to maintain order
    df.sort_values('timestamp', inplace=True)

    # Reset index after sorting
    df.reset_index(drop=True, inplace=True)


    # Check for NaN entries before interpolation
    if df[['x', 'y']].isnull().any().any():
        df[['x', 'y']] = df[['x', 'y']].interpolate(method='linear')

    # Drop the 'time_diff' column after processing
    df.drop(columns=['time_diff'], inplace=True)

    # Update the processed data
    data_frames[df_idx] = df

# Update processed data for all DataFrames
processed_data = [np.column_stack((scaler.transform(df[['x', 'y', 'timestamp']]), df['pen_status'].values)) 
                  for df, scaler in zip(data_frames, scalers)]
avg_data_points = int(np.mean([df.shape[0] for df in data_frames]))

# Cell 4
##### Start
# Create the 'imputed' folder if it doesn't exist
imputed_folder = 'imputed'
os.makedirs(imputed_folder, exist_ok=True)
##### End
processed_dataframes = []

for input_filename, df in zip(input_filenames, data_frames):
    # Convert all numeric columns to integers
    df[['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude']] = df[['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude']].astype(int)

    #########Start
    # Save the processed DataFrame to the 'imputed' folder with the same input filename
    save_path = os.path.join(imputed_folder, input_filename)
    df.to_csv(save_path, sep=' ', index=False, header=False)  # Save without header and index
    ##########Emd
    # Append the processed DataFrame to the list
    processed_dataframes.append(df)

    print(f"Processed DataFrame saved as: {input_filename}")
# Cell 5 (modified)
def process_dataframes(dataframes, num_files_to_use=None):
    if num_files_to_use:
        dataframes = dataframes[:num_files_to_use]

    data_frames = []
    scalers = []

    for i, df in enumerate(dataframes):
        # Modify timestamp to start from 0
        df['timestamp'] = (df['timestamp'] - df['timestamp'].min()).round().astype(int)
        
        data_frames.append(df)
        scaler = MinMaxScaler()
        scaler.fit(df[['x', 'y', 'timestamp']])  # Fit the scaler
        scalers.append(scaler)

        # Print the first few rows of the timestamp column
        # print(f"Modified timestamps for DataFrame {i + 1}:")
        # print(df['timestamp'].head())
        # print("\n")

    processed_data = [np.column_stack((scaler.transform(df[['x', 'y', 'timestamp']]), df['pen_status'].values)) 
                      for df, scaler in zip(data_frames, scalers)]
    avg_data_points = int(np.mean([df.shape[0] for df in data_frames]))

    return data_frames, processed_data, scalers, avg_data_points, [f"DataFrame_{i+1}" for i in range(len(dataframes))]

# Use the processed_dataframes directly 
data_frames, processed_data, scalers, avg_data_points, original_filenames = process_dataframes(processed_dataframes, num_files_to_use)
print(f"Number of processed files: {len(processed_data)}")
print(f"Average number of data points: {avg_data_points}")
# Out:
# Processed DataFrame saved as: collection1u00001s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00001s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00001s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00001s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00001s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00001s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00001s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00002s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00002s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00002s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00002s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00002s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00002s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00002s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00003s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00003s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00003s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00003s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00003s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00003s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00003s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00004s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00004s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00004s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00004s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00004s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00004s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00004s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00005s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00005s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00005s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00005s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00005s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00005s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00005s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00006s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00006s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00006s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00006s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00006s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00006s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00006s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00007s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00007s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00007s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00007s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00007s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00007s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00007s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00008s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00008s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00008s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00008s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00008s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00008s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00008s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00009s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00009s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00009s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00009s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00009s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00009s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00009s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00010s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00010s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00010s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00010s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00010s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00010s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00010s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00011s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00011s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00011s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00011s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00011s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00011s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00011s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00012s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00012s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00012s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00012s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00012s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00012s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00012s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00013s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00013s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00013s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00013s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00013s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00013s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00013s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00014s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00014s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00014s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00014s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00014s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00014s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00014s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00015s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00015s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00015s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00015s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00015s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00015s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00015s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00016s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00016s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00016s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00016s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00016s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00016s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00016s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00017s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00017s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00017s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00017s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00017s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00017s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00017s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00018s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00018s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00018s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00018s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00018s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00018s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00018s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00019s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00019s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00019s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00019s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00019s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00019s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00019s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00020s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00020s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00020s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00020s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00020s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00020s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00020s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00021s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00021s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00021s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00021s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00021s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00021s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00021s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00022s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00022s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00022s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00022s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00022s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00022s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00022s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00023s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00023s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00023s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00023s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00023s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00023s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00023s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00024s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00024s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00024s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00024s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00024s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00024s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00024s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00025s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00025s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00025s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00025s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00025s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00025s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00025s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00026s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00026s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00026s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00026s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00026s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00026s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00026s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00027s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00027s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00027s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00027s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00027s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00027s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00027s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00028s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00028s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00028s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00028s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00028s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00028s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00028s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00029s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00029s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00029s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00029s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00029s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00029s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00029s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00030s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00030s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00030s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00030s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00030s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00030s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00030s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00031s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00031s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00031s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00031s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00031s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00031s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00031s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00032s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00032s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00032s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00032s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00032s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00032s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00032s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00033s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00033s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00033s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00033s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00033s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00033s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00033s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00034s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00034s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00034s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00034s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00034s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00034s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00034s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00035s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00035s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00035s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00035s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00035s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00035s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00035s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00036s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00036s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00036s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00036s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00036s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00036s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00036s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00037s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00037s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00037s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00037s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00037s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00037s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00037s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00038s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00038s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00038s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00038s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00038s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00038s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00038s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00039s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00039s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00039s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00039s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00039s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00039s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00039s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00040s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00040s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00040s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00040s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00040s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00040s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00040s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00041s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00041s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00041s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00041s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00041s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00041s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00041s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00042s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00042s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00042s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00042s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00042s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00042s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00042s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00043s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00043s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00043s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00043s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00043s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00043s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00043s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00044s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00044s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00044s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00044s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00044s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00044s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00044s00001_hw00007.svc
# Processed DataFrame saved as: collection1u00045s00001_hw00001.svc
# Processed DataFrame saved as: collection1u00045s00001_hw00002.svc
# Processed DataFrame saved as: collection1u00045s00001_hw00003.svc
# Processed DataFrame saved as: collection1u00045s00001_hw00004.svc
# Processed DataFrame saved as: collection1u00045s00001_hw00005.svc
# Processed DataFrame saved as: collection1u00045s00001_hw00006.svc
# Processed DataFrame saved as: collection1u00045s00001_hw00007.svc
# Processed DataFrame saved as: u00001s00001_hw00001.svc
# Processed DataFrame saved as: u00001s00001_hw00002.svc
# Processed DataFrame saved as: u00001s00001_hw00003.svc
# Processed DataFrame saved as: u00001s00001_hw00004.svc
# Processed DataFrame saved as: u00001s00001_hw00005.svc
# Processed DataFrame saved as: u00001s00001_hw00006.svc
# Processed DataFrame saved as: u00001s00001_hw00007.svc
# Processed DataFrame saved as: u00002s00001_hw00001.svc
# Processed DataFrame saved as: u00002s00001_hw00002.svc
# Processed DataFrame saved as: u00002s00001_hw00003.svc
# Processed DataFrame saved as: u00002s00001_hw00004.svc
# Processed DataFrame saved as: u00002s00001_hw00005.svc
# Processed DataFrame saved as: u00002s00001_hw00006.svc
# Processed DataFrame saved as: u00002s00001_hw00007.svc
# Processed DataFrame saved as: u00003s00001_hw00001.svc
# Processed DataFrame saved as: u00003s00001_hw00002.svc
# Processed DataFrame saved as: u00003s00001_hw00003.svc
# Processed DataFrame saved as: u00003s00001_hw00004.svc
# Processed DataFrame saved as: u00003s00001_hw00005.svc
# Processed DataFrame saved as: u00003s00001_hw00006.svc
# Processed DataFrame saved as: u00003s00001_hw00007.svc
# Processed DataFrame saved as: u00004s00001_hw00001.svc
# Processed DataFrame saved as: u00004s00001_hw00002.svc
# Processed DataFrame saved as: u00004s00001_hw00003.svc
# Processed DataFrame saved as: u00004s00001_hw00004.svc
# Processed DataFrame saved as: u00004s00001_hw00005.svc
# Processed DataFrame saved as: u00004s00001_hw00006.svc
# Processed DataFrame saved as: u00004s00001_hw00007.svc
# Processed DataFrame saved as: u00005s00001_hw00001.svc
# Processed DataFrame saved as: u00005s00001_hw00002.svc
# Processed DataFrame saved as: u00005s00001_hw00003.svc
# Processed DataFrame saved as: u00005s00001_hw00004.svc
# Processed DataFrame saved as: u00005s00001_hw00005.svc
# Processed DataFrame saved as: u00005s00001_hw00006.svc
# Processed DataFrame saved as: u00005s00001_hw00007.svc
# Processed DataFrame saved as: u00006s00001_hw00001.svc
# Processed DataFrame saved as: u00006s00001_hw00002.svc
# Processed DataFrame saved as: u00006s00001_hw00003.svc
# Processed DataFrame saved as: u00006s00001_hw00004.svc
# Processed DataFrame saved as: u00006s00001_hw00005.svc
# Processed DataFrame saved as: u00006s00001_hw00006.svc
# Processed DataFrame saved as: u00006s00001_hw00007.svc
# Processed DataFrame saved as: u00007s00001_hw00001.svc
# Processed DataFrame saved as: u00007s00001_hw00002.svc
# Processed DataFrame saved as: u00007s00001_hw00003.svc
# Processed DataFrame saved as: u00007s00001_hw00004.svc
# Processed DataFrame saved as: u00007s00001_hw00005.svc
# Processed DataFrame saved as: u00007s00001_hw00006.svc
# Processed DataFrame saved as: u00007s00001_hw00007.svc
# Processed DataFrame saved as: u00008s00001_hw00001.svc
# Processed DataFrame saved as: u00008s00001_hw00002.svc
# Processed DataFrame saved as: u00008s00001_hw00003.svc
# Processed DataFrame saved as: u00008s00001_hw00004.svc
# Processed DataFrame saved as: u00008s00001_hw00005.svc
# Processed DataFrame saved as: u00008s00001_hw00006.svc
# Processed DataFrame saved as: u00008s00001_hw00007.svc
# Processed DataFrame saved as: u00009s00001_hw00001.svc
# Processed DataFrame saved as: u00009s00001_hw00002.svc
# Processed DataFrame saved as: u00009s00001_hw00003.svc
# Processed DataFrame saved as: u00009s00001_hw00004.svc
# Processed DataFrame saved as: u00009s00001_hw00005.svc
# Processed DataFrame saved as: u00009s00001_hw00006.svc
# Processed DataFrame saved as: u00009s00001_hw00007.svc
# Processed DataFrame saved as: u00010s00001_hw00001.svc
# Processed DataFrame saved as: u00010s00001_hw00002.svc
# Processed DataFrame saved as: u00010s00001_hw00003.svc
# Processed DataFrame saved as: u00010s00001_hw00004.svc
# Processed DataFrame saved as: u00010s00001_hw00005.svc
# Processed DataFrame saved as: u00010s00001_hw00006.svc
# Processed DataFrame saved as: u00010s00001_hw00007.svc
# Processed DataFrame saved as: u00011s00001_hw00001.svc
# Processed DataFrame saved as: u00011s00001_hw00002.svc
# Processed DataFrame saved as: u00011s00001_hw00003.svc
# Processed DataFrame saved as: u00011s00001_hw00004.svc
# Processed DataFrame saved as: u00011s00001_hw00005.svc
# Processed DataFrame saved as: u00011s00001_hw00006.svc
# Processed DataFrame saved as: u00011s00001_hw00007.svc
# Processed DataFrame saved as: u00012s00001_hw00001.svc
# Processed DataFrame saved as: u00012s00001_hw00002.svc
# Processed DataFrame saved as: u00012s00001_hw00003.svc
# Processed DataFrame saved as: u00012s00001_hw00004.svc
# Processed DataFrame saved as: u00012s00001_hw00005.svc
# Processed DataFrame saved as: u00012s00001_hw00006.svc
# Processed DataFrame saved as: u00012s00001_hw00007.svc
# Processed DataFrame saved as: u00013s00001_hw00001.svc
# Processed DataFrame saved as: u00013s00001_hw00002.svc
# Processed DataFrame saved as: u00013s00001_hw00003.svc
# Processed DataFrame saved as: u00013s00001_hw00004.svc
# Processed DataFrame saved as: u00013s00001_hw00005.svc
# Processed DataFrame saved as: u00013s00001_hw00006.svc
# Processed DataFrame saved as: u00013s00001_hw00007.svc
# Processed DataFrame saved as: u00014s00001_hw00001.svc
# Processed DataFrame saved as: u00014s00001_hw00002.svc
# Processed DataFrame saved as: u00014s00001_hw00003.svc
# Processed DataFrame saved as: u00014s00001_hw00004.svc
# Processed DataFrame saved as: u00014s00001_hw00005.svc
# Processed DataFrame saved as: u00014s00001_hw00006.svc
# Processed DataFrame saved as: u00014s00001_hw00007.svc
# Processed DataFrame saved as: u00015s00001_hw00001.svc
# Processed DataFrame saved as: u00015s00001_hw00002.svc
# Processed DataFrame saved as: u00015s00001_hw00003.svc
# Processed DataFrame saved as: u00015s00001_hw00004.svc
# Processed DataFrame saved as: u00015s00001_hw00005.svc
# Processed DataFrame saved as: u00015s00001_hw00006.svc
# Processed DataFrame saved as: u00015s00001_hw00007.svc
# Processed DataFrame saved as: u00016s00001_hw00001.svc
# Processed DataFrame saved as: u00016s00001_hw00002.svc
# Processed DataFrame saved as: u00016s00001_hw00003.svc
# Processed DataFrame saved as: u00016s00001_hw00004.svc
# Processed DataFrame saved as: u00016s00001_hw00005.svc
# Processed DataFrame saved as: u00016s00001_hw00006.svc
# Processed DataFrame saved as: u00016s00001_hw00007.svc
# Processed DataFrame saved as: u00017s00001_hw00001.svc
# Processed DataFrame saved as: u00017s00001_hw00002.svc
# Processed DataFrame saved as: u00017s00001_hw00003.svc
# Processed DataFrame saved as: u00017s00001_hw00004.svc
# Processed DataFrame saved as: u00017s00001_hw00005.svc
# Processed DataFrame saved as: u00017s00001_hw00006.svc
# Processed DataFrame saved as: u00017s00001_hw00007.svc
# Processed DataFrame saved as: u00018s00001_hw00001.svc
# Processed DataFrame saved as: u00018s00001_hw00002.svc
# Processed DataFrame saved as: u00018s00001_hw00003.svc
# Processed DataFrame saved as: u00018s00001_hw00004.svc
# Processed DataFrame saved as: u00018s00001_hw00005.svc
# Processed DataFrame saved as: u00018s00001_hw00006.svc
# Processed DataFrame saved as: u00018s00001_hw00007.svc
# Processed DataFrame saved as: u00019s00001_hw00001.svc
# Processed DataFrame saved as: u00019s00001_hw00002.svc
# Processed DataFrame saved as: u00019s00001_hw00003.svc
# Processed DataFrame saved as: u00019s00001_hw00004.svc
# Processed DataFrame saved as: u00019s00001_hw00005.svc
# Processed DataFrame saved as: u00019s00001_hw00006.svc
# Processed DataFrame saved as: u00019s00001_hw00007.svc
# Processed DataFrame saved as: u00020s00001_hw00001.svc
# Processed DataFrame saved as: u00020s00001_hw00002.svc
# Processed DataFrame saved as: u00020s00001_hw00003.svc
# Processed DataFrame saved as: u00020s00001_hw00004.svc
# Processed DataFrame saved as: u00020s00001_hw00005.svc
# Processed DataFrame saved as: u00020s00001_hw00006.svc
# Processed DataFrame saved as: u00020s00001_hw00007.svc
# Processed DataFrame saved as: u00021s00001_hw00001.svc
# Processed DataFrame saved as: u00021s00001_hw00002.svc
# Processed DataFrame saved as: u00021s00001_hw00003.svc
# Processed DataFrame saved as: u00021s00001_hw00004.svc
# Processed DataFrame saved as: u00021s00001_hw00005.svc
# Processed DataFrame saved as: u00021s00001_hw00006.svc
# Processed DataFrame saved as: u00021s00001_hw00007.svc
# Processed DataFrame saved as: u00022s00001_hw00001.svc
# Processed DataFrame saved as: u00022s00001_hw00002.svc
# Processed DataFrame saved as: u00022s00001_hw00003.svc
# Processed DataFrame saved as: u00022s00001_hw00004.svc
# Processed DataFrame saved as: u00022s00001_hw00005.svc
# Processed DataFrame saved as: u00022s00001_hw00006.svc
# Processed DataFrame saved as: u00022s00001_hw00007.svc
# Processed DataFrame saved as: u00023s00001_hw00001.svc
# Processed DataFrame saved as: u00023s00001_hw00002.svc
# Processed DataFrame saved as: u00023s00001_hw00003.svc
# Processed DataFrame saved as: u00023s00001_hw00004.svc
# Processed DataFrame saved as: u00023s00001_hw00005.svc
# Processed DataFrame saved as: u00023s00001_hw00006.svc
# Processed DataFrame saved as: u00023s00001_hw00007.svc
# Processed DataFrame saved as: u00024s00001_hw00001.svc
# Processed DataFrame saved as: u00024s00001_hw00002.svc
# Processed DataFrame saved as: u00024s00001_hw00003.svc
# Processed DataFrame saved as: u00024s00001_hw00004.svc
# Processed DataFrame saved as: u00024s00001_hw00005.svc
# Processed DataFrame saved as: u00024s00001_hw00006.svc
# Processed DataFrame saved as: u00024s00001_hw00007.svc
# Processed DataFrame saved as: u00025s00001_hw00001.svc
# Processed DataFrame saved as: u00025s00001_hw00002.svc
# Processed DataFrame saved as: u00025s00001_hw00003.svc
# Processed DataFrame saved as: u00025s00001_hw00004.svc
# Processed DataFrame saved as: u00025s00001_hw00005.svc
# Processed DataFrame saved as: u00025s00001_hw00006.svc
# Processed DataFrame saved as: u00025s00001_hw00007.svc
# Processed DataFrame saved as: u00026s00001_hw00001.svc
# Processed DataFrame saved as: u00026s00001_hw00002.svc
# Processed DataFrame saved as: u00026s00001_hw00003.svc
# Processed DataFrame saved as: u00026s00001_hw00004.svc
# Processed DataFrame saved as: u00026s00001_hw00005.svc
# Processed DataFrame saved as: u00026s00001_hw00006.svc
# Processed DataFrame saved as: u00026s00001_hw00007.svc
# Processed DataFrame saved as: u00027s00001_hw00001.svc
# Processed DataFrame saved as: u00027s00001_hw00002.svc
# Processed DataFrame saved as: u00027s00001_hw00003.svc
# Processed DataFrame saved as: u00027s00001_hw00004.svc
# Processed DataFrame saved as: u00027s00001_hw00005.svc
# Processed DataFrame saved as: u00027s00001_hw00006.svc
# Processed DataFrame saved as: u00027s00001_hw00007.svc
# Processed DataFrame saved as: u00028s00001_hw00001.svc
# Processed DataFrame saved as: u00028s00001_hw00002.svc
# Processed DataFrame saved as: u00028s00001_hw00003.svc
# Processed DataFrame saved as: u00028s00001_hw00004.svc
# Processed DataFrame saved as: u00028s00001_hw00005.svc
# Processed DataFrame saved as: u00028s00001_hw00006.svc
# Processed DataFrame saved as: u00028s00001_hw00007.svc
# Processed DataFrame saved as: u00029s00001_hw00001.svc
# Processed DataFrame saved as: u00029s00001_hw00002.svc
# Processed DataFrame saved as: u00029s00001_hw00003.svc
# Processed DataFrame saved as: u00029s00001_hw00004.svc
# Processed DataFrame saved as: u00029s00001_hw00005.svc
# Processed DataFrame saved as: u00029s00001_hw00006.svc
# Processed DataFrame saved as: u00029s00001_hw00007.svc
# Processed DataFrame saved as: u00030s00001_hw00001.svc
# Processed DataFrame saved as: u00030s00001_hw00002.svc
# Processed DataFrame saved as: u00030s00001_hw00003.svc
# Processed DataFrame saved as: u00030s00001_hw00004.svc
# Processed DataFrame saved as: u00030s00001_hw00005.svc
# Processed DataFrame saved as: u00030s00001_hw00006.svc
# Processed DataFrame saved as: u00030s00001_hw00007.svc
# Processed DataFrame saved as: u00031s00001_hw00001.svc
# Processed DataFrame saved as: u00031s00001_hw00002.svc
# Processed DataFrame saved as: u00031s00001_hw00003.svc
# Processed DataFrame saved as: u00031s00001_hw00004.svc
# Processed DataFrame saved as: u00031s00001_hw00005.svc
# Processed DataFrame saved as: u00031s00001_hw00006.svc
# Processed DataFrame saved as: u00031s00001_hw00007.svc
# Processed DataFrame saved as: u00032s00001_hw00001.svc
# Processed DataFrame saved as: u00032s00001_hw00002.svc
# Processed DataFrame saved as: u00032s00001_hw00003.svc
# Processed DataFrame saved as: u00032s00001_hw00004.svc
# Processed DataFrame saved as: u00032s00001_hw00005.svc
# Processed DataFrame saved as: u00032s00001_hw00006.svc
# Processed DataFrame saved as: u00032s00001_hw00007.svc
# Processed DataFrame saved as: u00033s00001_hw00001.svc
# Processed DataFrame saved as: u00033s00001_hw00002.svc
# Processed DataFrame saved as: u00033s00001_hw00003.svc
# Processed DataFrame saved as: u00033s00001_hw00004.svc
# Processed DataFrame saved as: u00033s00001_hw00005.svc
# Processed DataFrame saved as: u00033s00001_hw00006.svc
# Processed DataFrame saved as: u00033s00001_hw00007.svc
# Processed DataFrame saved as: u00034s00001_hw00001.svc
# Processed DataFrame saved as: u00034s00001_hw00002.svc
# Processed DataFrame saved as: u00034s00001_hw00003.svc
# Processed DataFrame saved as: u00034s00001_hw00004.svc
# Processed DataFrame saved as: u00034s00001_hw00005.svc
# Processed DataFrame saved as: u00034s00001_hw00006.svc
# Processed DataFrame saved as: u00034s00001_hw00007.svc
# Processed DataFrame saved as: u00035s00001_hw00001.svc
# Processed DataFrame saved as: u00035s00001_hw00002.svc
# Processed DataFrame saved as: u00035s00001_hw00003.svc
# Processed DataFrame saved as: u00035s00001_hw00004.svc
# Processed DataFrame saved as: u00035s00001_hw00005.svc
# Processed DataFrame saved as: u00035s00001_hw00006.svc
# Processed DataFrame saved as: u00035s00001_hw00007.svc
# Processed DataFrame saved as: u00036s00001_hw00001.svc
# Processed DataFrame saved as: u00036s00001_hw00002.svc
# Processed DataFrame saved as: u00036s00001_hw00003.svc
# Processed DataFrame saved as: u00036s00001_hw00004.svc
# Processed DataFrame saved as: u00036s00001_hw00005.svc
# Processed DataFrame saved as: u00036s00001_hw00006.svc
# Processed DataFrame saved as: u00036s00001_hw00007.svc
# Processed DataFrame saved as: u00037s00001_hw00001.svc
# Processed DataFrame saved as: u00037s00001_hw00002.svc
# Processed DataFrame saved as: u00037s00001_hw00003.svc
# Processed DataFrame saved as: u00037s00001_hw00004.svc
# Processed DataFrame saved as: u00037s00001_hw00005.svc
# Processed DataFrame saved as: u00037s00001_hw00006.svc
# Processed DataFrame saved as: u00037s00001_hw00007.svc
# Processed DataFrame saved as: u00038s00001_hw00001.svc
# Processed DataFrame saved as: u00038s00001_hw00002.svc
# Processed DataFrame saved as: u00038s00001_hw00003.svc
# Processed DataFrame saved as: u00038s00001_hw00004.svc
# Processed DataFrame saved as: u00038s00001_hw00005.svc
# Processed DataFrame saved as: u00038s00001_hw00006.svc
# Processed DataFrame saved as: u00038s00001_hw00007.svc
# Processed DataFrame saved as: u00039s00001_hw00001.svc
# Processed DataFrame saved as: u00039s00001_hw00002.svc
# Processed DataFrame saved as: u00039s00001_hw00003.svc
# Processed DataFrame saved as: u00039s00001_hw00004.svc
# Processed DataFrame saved as: u00039s00001_hw00005.svc
# Processed DataFrame saved as: u00039s00001_hw00006.svc
# Processed DataFrame saved as: u00039s00001_hw00007.svc
# Processed DataFrame saved as: u00040s00001_hw00001.svc
# Processed DataFrame saved as: u00040s00001_hw00002.svc
# Processed DataFrame saved as: u00040s00001_hw00003.svc
# Processed DataFrame saved as: u00040s00001_hw00004.svc
# Processed DataFrame saved as: u00040s00001_hw00005.svc
# Processed DataFrame saved as: u00040s00001_hw00006.svc
# Processed DataFrame saved as: u00040s00001_hw00007.svc
# Processed DataFrame saved as: u00041s00001_hw00001.svc
# Processed DataFrame saved as: u00041s00001_hw00002.svc
# Processed DataFrame saved as: u00041s00001_hw00003.svc
# Processed DataFrame saved as: u00041s00001_hw00004.svc
# Processed DataFrame saved as: u00041s00001_hw00005.svc
# Processed DataFrame saved as: u00041s00001_hw00006.svc
# Processed DataFrame saved as: u00041s00001_hw00007.svc
# Processed DataFrame saved as: u00042s00001_hw00001.svc
# Processed DataFrame saved as: u00042s00001_hw00002.svc
# Processed DataFrame saved as: u00042s00001_hw00003.svc
# Processed DataFrame saved as: u00042s00001_hw00004.svc
# Processed DataFrame saved as: u00042s00001_hw00005.svc
# Processed DataFrame saved as: u00042s00001_hw00006.svc
# Processed DataFrame saved as: u00042s00001_hw00007.svc
# Processed DataFrame saved as: u00043s00001_hw00001.svc
# Processed DataFrame saved as: u00043s00001_hw00002.svc
# Processed DataFrame saved as: u00043s00001_hw00003.svc
# Processed DataFrame saved as: u00043s00001_hw00004.svc
# Processed DataFrame saved as: u00043s00001_hw00005.svc
# Processed DataFrame saved as: u00043s00001_hw00006.svc
# Processed DataFrame saved as: u00043s00001_hw00007.svc
# Processed DataFrame saved as: u00044s00001_hw00001.svc
# Processed DataFrame saved as: u00044s00001_hw00002.svc
# Processed DataFrame saved as: u00044s00001_hw00003.svc
# Processed DataFrame saved as: u00044s00001_hw00004.svc
# Processed DataFrame saved as: u00044s00001_hw00005.svc
# Processed DataFrame saved as: u00044s00001_hw00006.svc
# Processed DataFrame saved as: u00044s00001_hw00007.svc
# Processed DataFrame saved as: u00045s00001_hw00001.svc
# Processed DataFrame saved as: u00045s00001_hw00002.svc
# Processed DataFrame saved as: u00045s00001_hw00003.svc
# Processed DataFrame saved as: u00045s00001_hw00004.svc
# Processed DataFrame saved as: u00045s00001_hw00005.svc
# Processed DataFrame saved as: u00045s00001_hw00006.svc
# Processed DataFrame saved as: u00045s00001_hw00007.svc
# Processed DataFrame saved as: u00046s00001_hw00001.svc
# Processed DataFrame saved as: u00046s00001_hw00002.svc
# Processed DataFrame saved as: u00046s00001_hw00003.svc
# Processed DataFrame saved as: u00046s00001_hw00004.svc
# Processed DataFrame saved as: u00046s00001_hw00005.svc
# Processed DataFrame saved as: u00046s00001_hw00006.svc
# Processed DataFrame saved as: u00046s00001_hw00007.svc
# Processed DataFrame saved as: u00047s00001_hw00001.svc
# Processed DataFrame saved as: u00047s00001_hw00002.svc
# Processed DataFrame saved as: u00047s00001_hw00003.svc
# Processed DataFrame saved as: u00047s00001_hw00004.svc
# Processed DataFrame saved as: u00047s00001_hw00005.svc
# Processed DataFrame saved as: u00047s00001_hw00006.svc
# Processed DataFrame saved as: u00047s00001_hw00007.svc
# Processed DataFrame saved as: u00048s00001_hw00001.svc
# Processed DataFrame saved as: u00048s00001_hw00002.svc
# Processed DataFrame saved as: u00048s00001_hw00003.svc
# Processed DataFrame saved as: u00048s00001_hw00004.svc
# Processed DataFrame saved as: u00048s00001_hw00005.svc
# Processed DataFrame saved as: u00048s00001_hw00006.svc
# Processed DataFrame saved as: u00048s00001_hw00007.svc
# Processed DataFrame saved as: u00049s00001_hw00001.svc
# Processed DataFrame saved as: u00049s00001_hw00002.svc
# Processed DataFrame saved as: u00049s00001_hw00003.svc
# Processed DataFrame saved as: u00049s00001_hw00004.svc
# Processed DataFrame saved as: u00049s00001_hw00005.svc
# Processed DataFrame saved as: u00049s00001_hw00006.svc
# Processed DataFrame saved as: u00049s00001_hw00007.svc
# Processed DataFrame saved as: u00050s00001_hw00001.svc
# Processed DataFrame saved as: u00050s00001_hw00002.svc
# Processed DataFrame saved as: u00050s00001_hw00003.svc
# Processed DataFrame saved as: u00050s00001_hw00004.svc
# Processed DataFrame saved as: u00050s00001_hw00005.svc
# Processed DataFrame saved as: u00050s00001_hw00006.svc
# Processed DataFrame saved as: u00050s00001_hw00007.svc
# Processed DataFrame saved as: u00051s00001_hw00001.svc
# Processed DataFrame saved as: u00051s00001_hw00002.svc
# Processed DataFrame saved as: u00051s00001_hw00003.svc
# Processed DataFrame saved as: u00051s00001_hw00004.svc
# Processed DataFrame saved as: u00051s00001_hw00005.svc
# Processed DataFrame saved as: u00051s00001_hw00006.svc
# Processed DataFrame saved as: u00051s00001_hw00007.svc
# Processed DataFrame saved as: u00052s00001_hw00001.svc
# Processed DataFrame saved as: u00052s00001_hw00002.svc
# Processed DataFrame saved as: u00052s00001_hw00003.svc
# Processed DataFrame saved as: u00052s00001_hw00004.svc
# Processed DataFrame saved as: u00052s00001_hw00005.svc
# Processed DataFrame saved as: u00052s00001_hw00006.svc
# Processed DataFrame saved as: u00052s00001_hw00007.svc
# Processed DataFrame saved as: u00053s00001_hw00001.svc
# Processed DataFrame saved as: u00053s00001_hw00002.svc
# Processed DataFrame saved as: u00053s00001_hw00003.svc
# Processed DataFrame saved as: u00053s00001_hw00004.svc
# Processed DataFrame saved as: u00053s00001_hw00005.svc
# Processed DataFrame saved as: u00053s00001_hw00006.svc
# Processed DataFrame saved as: u00053s00001_hw00007.svc
# Processed DataFrame saved as: u00054s00001_hw00001.svc
# Processed DataFrame saved as: u00054s00001_hw00002.svc
# Processed DataFrame saved as: u00054s00001_hw00003.svc
# Processed DataFrame saved as: u00054s00001_hw00004.svc
# Processed DataFrame saved as: u00054s00001_hw00005.svc
# Processed DataFrame saved as: u00054s00001_hw00006.svc
# Processed DataFrame saved as: u00054s00001_hw00007.svc
# Processed DataFrame saved as: u00055s00001_hw00001.svc
# Processed DataFrame saved as: u00055s00001_hw00002.svc
# Processed DataFrame saved as: u00055s00001_hw00003.svc
# Processed DataFrame saved as: u00055s00001_hw00004.svc
# Processed DataFrame saved as: u00055s00001_hw00005.svc
# Processed DataFrame saved as: u00055s00001_hw00006.svc
# Processed DataFrame saved as: u00055s00001_hw00007.svc
# Processed DataFrame saved as: u00056s00001_hw00001.svc
# Processed DataFrame saved as: u00056s00001_hw00002.svc
# Processed DataFrame saved as: u00056s00001_hw00003.svc
# Processed DataFrame saved as: u00056s00001_hw00004.svc
# Processed DataFrame saved as: u00056s00001_hw00005.svc
# Processed DataFrame saved as: u00056s00001_hw00006.svc
# Processed DataFrame saved as: u00056s00001_hw00007.svc
# Processed DataFrame saved as: u00057s00001_hw00001.svc
# Processed DataFrame saved as: u00057s00001_hw00002.svc
# Processed DataFrame saved as: u00057s00001_hw00003.svc
# Processed DataFrame saved as: u00057s00001_hw00004.svc
# Processed DataFrame saved as: u00057s00001_hw00005.svc
# Processed DataFrame saved as: u00057s00001_hw00006.svc
# Processed DataFrame saved as: u00057s00001_hw00007.svc
# Processed DataFrame saved as: u00058s00001_hw00001.svc
# Processed DataFrame saved as: u00058s00001_hw00002.svc
# Processed DataFrame saved as: u00058s00001_hw00003.svc
# Processed DataFrame saved as: u00058s00001_hw00004.svc
# Processed DataFrame saved as: u00058s00001_hw00005.svc
# Processed DataFrame saved as: u00058s00001_hw00006.svc
# Processed DataFrame saved as: u00058s00001_hw00007.svc
# Processed DataFrame saved as: u00059s00001_hw00001.svc
# Processed DataFrame saved as: u00059s00001_hw00002.svc
# Processed DataFrame saved as: u00059s00001_hw00003.svc
# Processed DataFrame saved as: u00059s00001_hw00004.svc
# Processed DataFrame saved as: u00059s00001_hw00005.svc
# Processed DataFrame saved as: u00059s00001_hw00006.svc
# Processed DataFrame saved as: u00059s00001_hw00007.svc
# Processed DataFrame saved as: u00060s00001_hw00001.svc
# Processed DataFrame saved as: u00060s00001_hw00002.svc
# Processed DataFrame saved as: u00060s00001_hw00003.svc
# Processed DataFrame saved as: u00060s00001_hw00004.svc
# Processed DataFrame saved as: u00060s00001_hw00005.svc
# Processed DataFrame saved as: u00060s00001_hw00006.svc
# Processed DataFrame saved as: u00060s00001_hw00007.svc
# Processed DataFrame saved as: u00061s00001_hw00001.svc
# Processed DataFrame saved as: u00061s00001_hw00002.svc
# Processed DataFrame saved as: u00061s00001_hw00003.svc
# Processed DataFrame saved as: u00061s00001_hw00004.svc
# Processed DataFrame saved as: u00061s00001_hw00005.svc
# Processed DataFrame saved as: u00061s00001_hw00006.svc
# Processed DataFrame saved as: u00061s00001_hw00007.svc
# Processed DataFrame saved as: u00062s00001_hw00001.svc
# Processed DataFrame saved as: u00062s00001_hw00002.svc
# Processed DataFrame saved as: u00062s00001_hw00003.svc
# Processed DataFrame saved as: u00062s00001_hw00004.svc
# Processed DataFrame saved as: u00062s00001_hw00005.svc
# Processed DataFrame saved as: u00062s00001_hw00006.svc
# Processed DataFrame saved as: u00062s00001_hw00007.svc
# Processed DataFrame saved as: u00063s00001_hw00001.svc
# Processed DataFrame saved as: u00063s00001_hw00002.svc
# Processed DataFrame saved as: u00063s00001_hw00003.svc
# Processed DataFrame saved as: u00063s00001_hw00004.svc
# Processed DataFrame saved as: u00063s00001_hw00005.svc
# Processed DataFrame saved as: u00063s00001_hw00006.svc
# Processed DataFrame saved as: u00063s00001_hw00007.svc
# Processed DataFrame saved as: u00064s00001_hw00001.svc
# Processed DataFrame saved as: u00064s00001_hw00002.svc
# Processed DataFrame saved as: u00064s00001_hw00003.svc
# Processed DataFrame saved as: u00064s00001_hw00004.svc
# Processed DataFrame saved as: u00064s00001_hw00005.svc
# Processed DataFrame saved as: u00064s00001_hw00006.svc
# Processed DataFrame saved as: u00064s00001_hw00007.svc
# Processed DataFrame saved as: u00065s00001_hw00001.svc
# Processed DataFrame saved as: u00065s00001_hw00002.svc
# Processed DataFrame saved as: u00065s00001_hw00003.svc
# Processed DataFrame saved as: u00065s00001_hw00004.svc
# Processed DataFrame saved as: u00065s00001_hw00005.svc
# Processed DataFrame saved as: u00065s00001_hw00006.svc
# Processed DataFrame saved as: u00065s00001_hw00007.svc
# Processed DataFrame saved as: u00066s00001_hw00001.svc
# Processed DataFrame saved as: u00066s00001_hw00002.svc
# Processed DataFrame saved as: u00066s00001_hw00003.svc
# Processed DataFrame saved as: u00066s00001_hw00004.svc
# Processed DataFrame saved as: u00066s00001_hw00005.svc
# Processed DataFrame saved as: u00066s00001_hw00006.svc
# Processed DataFrame saved as: u00066s00001_hw00007.svc
# Processed DataFrame saved as: u00067s00001_hw00001.svc
# Processed DataFrame saved as: u00067s00001_hw00002.svc
# Processed DataFrame saved as: u00067s00001_hw00003.svc
# Processed DataFrame saved as: u00067s00001_hw00004.svc
# Processed DataFrame saved as: u00067s00001_hw00005.svc
# Processed DataFrame saved as: u00067s00001_hw00006.svc
# Processed DataFrame saved as: u00067s00001_hw00007.svc
# Processed DataFrame saved as: u00068s00001_hw00001.svc
# Processed DataFrame saved as: u00068s00001_hw00002.svc
# Processed DataFrame saved as: u00068s00001_hw00003.svc
# Processed DataFrame saved as: u00068s00001_hw00004.svc
# Processed DataFrame saved as: u00068s00001_hw00005.svc
# Processed DataFrame saved as: u00068s00001_hw00006.svc
# Processed DataFrame saved as: u00068s00001_hw00007.svc
# Processed DataFrame saved as: u00069s00001_hw00001.svc
# Processed DataFrame saved as: u00069s00001_hw00002.svc
# Processed DataFrame saved as: u00069s00001_hw00003.svc
# Processed DataFrame saved as: u00069s00001_hw00004.svc
# Processed DataFrame saved as: u00069s00001_hw00005.svc
# Processed DataFrame saved as: u00069s00001_hw00006.svc
# Processed DataFrame saved as: u00069s00001_hw00007.svc
# Processed DataFrame saved as: u00070s00001_hw00001.svc
# Processed DataFrame saved as: u00070s00001_hw00002.svc
# Processed DataFrame saved as: u00070s00001_hw00003.svc
# Processed DataFrame saved as: u00070s00001_hw00004.svc
# Processed DataFrame saved as: u00070s00001_hw00005.svc
# Processed DataFrame saved as: u00070s00001_hw00006.svc
# Processed DataFrame saved as: u00070s00001_hw00007.svc
# Processed DataFrame saved as: u00071s00001_hw00001.svc
# Processed DataFrame saved as: u00071s00001_hw00002.svc
# Processed DataFrame saved as: u00071s00001_hw00003.svc
# Processed DataFrame saved as: u00071s00001_hw00004.svc
# Processed DataFrame saved as: u00071s00001_hw00005.svc
# Processed DataFrame saved as: u00071s00001_hw00006.svc
# Processed DataFrame saved as: u00071s00001_hw00007.svc
# Processed DataFrame saved as: u00072s00001_hw00001.svc
# Processed DataFrame saved as: u00072s00001_hw00002.svc
# Processed DataFrame saved as: u00072s00001_hw00003.svc
# Processed DataFrame saved as: u00072s00001_hw00004.svc
# Processed DataFrame saved as: u00072s00001_hw00005.svc
# Processed DataFrame saved as: u00072s00001_hw00006.svc
# Processed DataFrame saved as: u00072s00001_hw00007.svc
# Processed DataFrame saved as: u00073s00001_hw00001.svc
# Processed DataFrame saved as: u00073s00001_hw00002.svc
# Processed DataFrame saved as: u00073s00001_hw00003.svc
# Processed DataFrame saved as: u00073s00001_hw00004.svc
# Processed DataFrame saved as: u00073s00001_hw00005.svc
# Processed DataFrame saved as: u00073s00001_hw00006.svc
# Processed DataFrame saved as: u00073s00001_hw00007.svc
# Processed DataFrame saved as: u00074s00001_hw00001.svc
# Processed DataFrame saved as: u00074s00001_hw00002.svc
# Processed DataFrame saved as: u00074s00001_hw00003.svc
# Processed DataFrame saved as: u00074s00001_hw00004.svc
# Processed DataFrame saved as: u00074s00001_hw00005.svc
# Processed DataFrame saved as: u00074s00001_hw00006.svc
# Processed DataFrame saved as: u00074s00001_hw00007.svc
# Processed DataFrame saved as: u00075s00001_hw00001.svc
# Processed DataFrame saved as: u00075s00001_hw00002.svc
# Processed DataFrame saved as: u00075s00001_hw00003.svc
# Processed DataFrame saved as: u00075s00001_hw00004.svc
# Processed DataFrame saved as: u00075s00001_hw00005.svc
# Processed DataFrame saved as: u00075s00001_hw00006.svc
# Processed DataFrame saved as: u00075s00001_hw00007.svc
# Processed DataFrame saved as: u00076s00001_hw00001.svc
# Processed DataFrame saved as: u00076s00001_hw00002.svc
# Processed DataFrame saved as: u00076s00001_hw00003.svc
# Processed DataFrame saved as: u00076s00001_hw00004.svc
# Processed DataFrame saved as: u00076s00001_hw00005.svc
# Processed DataFrame saved as: u00076s00001_hw00006.svc
# Processed DataFrame saved as: u00076s00001_hw00007.svc
# Processed DataFrame saved as: u00077s00001_hw00001.svc
# Processed DataFrame saved as: u00077s00001_hw00002.svc
# Processed DataFrame saved as: u00077s00001_hw00003.svc
# Processed DataFrame saved as: u00077s00001_hw00004.svc
# Processed DataFrame saved as: u00077s00001_hw00005.svc
# Processed DataFrame saved as: u00077s00001_hw00006.svc
# Processed DataFrame saved as: u00077s00001_hw00007.svc
# Processed DataFrame saved as: u00078s00001_hw00001.svc
# Processed DataFrame saved as: u00078s00001_hw00002.svc
# Processed DataFrame saved as: u00078s00001_hw00003.svc
# Processed DataFrame saved as: u00078s00001_hw00004.svc
# Processed DataFrame saved as: u00078s00001_hw00005.svc
# Processed DataFrame saved as: u00078s00001_hw00006.svc
# Processed DataFrame saved as: u00078s00001_hw00007.svc
# Processed DataFrame saved as: u00079s00001_hw00001.svc
# Processed DataFrame saved as: u00079s00001_hw00002.svc
# Processed DataFrame saved as: u00079s00001_hw00003.svc
# Processed DataFrame saved as: u00079s00001_hw00004.svc
# Processed DataFrame saved as: u00079s00001_hw00005.svc
# Processed DataFrame saved as: u00079s00001_hw00006.svc
# Processed DataFrame saved as: u00079s00001_hw00007.svc
# Processed DataFrame saved as: u00080s00001_hw00001.svc
# Processed DataFrame saved as: u00080s00001_hw00002.svc
# Processed DataFrame saved as: u00080s00001_hw00003.svc
# Processed DataFrame saved as: u00080s00001_hw00004.svc
# Processed DataFrame saved as: u00080s00001_hw00005.svc
# Processed DataFrame saved as: u00080s00001_hw00006.svc
# Processed DataFrame saved as: u00080s00001_hw00007.svc
# Processed DataFrame saved as: u00081s00001_hw00001.svc
# Processed DataFrame saved as: u00081s00001_hw00002.svc
# Processed DataFrame saved as: u00081s00001_hw00003.svc
# Processed DataFrame saved as: u00081s00001_hw00004.svc
# Processed DataFrame saved as: u00081s00001_hw00005.svc
# Processed DataFrame saved as: u00081s00001_hw00006.svc
# Processed DataFrame saved as: u00081s00001_hw00007.svc
# Processed DataFrame saved as: u00082s00001_hw00001.svc
# Processed DataFrame saved as: u00082s00001_hw00002.svc
# Processed DataFrame saved as: u00082s00001_hw00003.svc
# Processed DataFrame saved as: u00082s00001_hw00004.svc
# Processed DataFrame saved as: u00082s00001_hw00005.svc
# Processed DataFrame saved as: u00082s00001_hw00006.svc
# Processed DataFrame saved as: u00082s00001_hw00007.svc
# Processed DataFrame saved as: u00083s00001_hw00001.svc
# Processed DataFrame saved as: u00083s00001_hw00002.svc
# Processed DataFrame saved as: u00083s00001_hw00003.svc
# Processed DataFrame saved as: u00083s00001_hw00004.svc
# Processed DataFrame saved as: u00083s00001_hw00005.svc
# Processed DataFrame saved as: u00083s00001_hw00006.svc
# Processed DataFrame saved as: u00083s00001_hw00007.svc
# Processed DataFrame saved as: u00084s00001_hw00001.svc
# Processed DataFrame saved as: u00084s00001_hw00002.svc
# Processed DataFrame saved as: u00084s00001_hw00003.svc
# Processed DataFrame saved as: u00084s00001_hw00004.svc
# Processed DataFrame saved as: u00084s00001_hw00005.svc
# Processed DataFrame saved as: u00084s00001_hw00006.svc
# Processed DataFrame saved as: u00084s00001_hw00007.svc
# Number of processed files: 903
# Average number of data points: 3124

# %%
from glob import glob
import os
import re
import numpy as np
import pandas as pd

def read_svc_file(file_path):
    return pd.read_csv(file_path, sep=' ', header=None, 
                       names=['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude'])

def calculate_nrmse(original, predicted):
    if original.shape != predicted.shape:
        raise ValueError("The shapes of the original and predicted datasets must match.")
    mse = np.mean((original - predicted) ** 2)
    rmse = np.sqrt(mse)
    nrmse = rmse / (np.max(original) - np.min(original))
    return nrmse

def get_matching_augmented_files(original_file, augmented_folder):
    base_name = os.path.basename(original_file)
    base_name_without_ext = os.path.splitext(base_name)[0]
    pattern = os.path.join(augmented_folder, f"synthetic_{base_name_without_ext}*.svc")
    matching_files = glob(pattern)
    
    def sort_key(filename):
        match = re.search(r'\((\d+)\)', filename)
        return int(match.group(1)) if match else -1

    return sorted(matching_files, key=sort_key)

def process_files(original_folder, augmented_folder, input_filenames):
    nrmse_results = {}

    input_filenames_set = {os.path.splitext(os.path.basename(filename))[0] for filename in input_filenames}

    for original_file in glob(os.path.join(original_folder, "*.svc")):
        base_name = os.path.splitext(os.path.basename(original_file))[0]
        
        if base_name not in input_filenames_set:
            continue

        original_data = read_svc_file(original_file)
        matching_augmented_files = get_matching_augmented_files(original_file, augmented_folder)
        
        file_nrmse = []
        for augmented_file in matching_augmented_files:
            augmented_data = read_svc_file(augmented_file)
            
            min_length = min(len(original_data), len(augmented_data))
            original_array = original_data.iloc[:min_length].values
            augmented_array = augmented_data.iloc[:min_length].values

            nrmse = calculate_nrmse(original_array, augmented_array)
            file_nrmse.append(nrmse)

        nrmse_results[os.path.basename(original_file)] = file_nrmse

    return nrmse_results

def save_results_to_log(results, output_path):
    with open(output_path, 'w') as log_file:
        for original_file, nrmse_values in results.items():
            avg_nrmse = None
            if len(nrmse_values) > 1:
                avg_nrmse = np.mean(nrmse_values)

            nrmse_values_str = ", ".join([f"{nrmse:.4f}" for nrmse in nrmse_values])
            log_line = f"{original_file}: NRMSE = {nrmse_values_str}"
            if avg_nrmse is not None:
                log_line += f", Avg NRMSE: {avg_nrmse:.4f}"

            log_file.write(log_line + '\n')
            print(log_line)

original_folder = "imputed"
augmented_folder = "../../all_datasets/timegan_augmented" #Directory ng augmented data
output_log_file = "nrmse_results_log.txt"

# Process files and save results
results = process_files(original_folder, augmented_folder, input_filenames)
save_results_to_log(results, output_log_file)

# Calculate overall average NRMSE and standard deviation
all_nrmse_values = [nrmse for nrmse_list in results.values() for nrmse in nrmse_list]
overall_avg_nrmse = np.mean(all_nrmse_values) if all_nrmse_values else None
overall_std_nrmse = np.std(all_nrmse_values) if all_nrmse_values else None

# Print and save the overall average NRMSE and standard deviation
with open(output_log_file, 'a') as log_file:
    if overall_avg_nrmse is not None and overall_std_nrmse is not None:
        log_line = f"\nOverall Average NRMSE: {overall_avg_nrmse:.4f}, Standard Deviation: {overall_std_nrmse:.4f}"
    else:
        log_line = "No NRMSE values calculated."

    log_file.write(log_line + '\n')
    print(log_line)
# Out:
# collection1u00001s00001_hw00001.svc: NRMSE = 0.0152
# collection1u00001s00001_hw00002.svc: NRMSE = 0.0123
# collection1u00001s00001_hw00003.svc: NRMSE = 0.0269
# collection1u00001s00001_hw00004.svc: NRMSE = 0.0480
# collection1u00001s00001_hw00005.svc: NRMSE = 0.0048
# collection1u00001s00001_hw00006.svc: NRMSE = 0.0247
# collection1u00001s00001_hw00007.svc: NRMSE = 0.0202
# collection1u00002s00001_hw00001.svc: NRMSE = 0.0111
# collection1u00002s00001_hw00002.svc: NRMSE = 0.0182
# collection1u00002s00001_hw00003.svc: NRMSE = 0.0355
# collection1u00002s00001_hw00004.svc: NRMSE = 0.0028
# collection1u00002s00001_hw00005.svc: NRMSE = 0.0030
# collection1u00002s00001_hw00006.svc: NRMSE = 0.0230
# collection1u00002s00001_hw00007.svc: NRMSE = 0.0150
# collection1u00003s00001_hw00001.svc: NRMSE = 0.0144
# collection1u00003s00001_hw00002.svc: NRMSE = 0.0176
# collection1u00003s00001_hw00003.svc: NRMSE = 0.0469
# collection1u00003s00001_hw00004.svc: NRMSE = 0.0016
# collection1u00003s00001_hw00005.svc: NRMSE = 0.0018
# collection1u00003s00001_hw00006.svc: NRMSE = 0.0502
# collection1u00003s00001_hw00007.svc: NRMSE = 0.0270
# collection1u00004s00001_hw00001.svc: NRMSE = 0.0032
# collection1u00004s00001_hw00002.svc: NRMSE = 0.0058
# collection1u00004s00001_hw00003.svc: NRMSE = 0.0235
# collection1u00004s00001_hw00004.svc: NRMSE = 0.0117
# collection1u00004s00001_hw00005.svc: NRMSE = 0.0025
# collection1u00004s00001_hw00006.svc: NRMSE = 0.0158
# collection1u00004s00001_hw00007.svc: NRMSE = 0.0261
# collection1u00005s00001_hw00001.svc: NRMSE = 0.0155
# collection1u00005s00001_hw00002.svc: NRMSE = 0.0174
# collection1u00005s00001_hw00003.svc: NRMSE = 0.0418
# collection1u00005s00001_hw00004.svc: NRMSE = 0.0031
# collection1u00005s00001_hw00005.svc: NRMSE = 0.0034
# collection1u00005s00001_hw00006.svc: NRMSE = 0.0592
# collection1u00005s00001_hw00007.svc: NRMSE = 0.0414
# collection1u00006s00001_hw00001.svc: NRMSE = 0.0049
# collection1u00006s00001_hw00002.svc: NRMSE = 0.0144
# collection1u00006s00001_hw00003.svc: NRMSE = 0.0337
# collection1u00006s00001_hw00004.svc: NRMSE = 0.0014
# collection1u00006s00001_hw00005.svc: NRMSE = 0.0156
# collection1u00006s00001_hw00006.svc: NRMSE = 0.0227
# collection1u00006s00001_hw00007.svc: NRMSE = 0.0316
# collection1u00007s00001_hw00001.svc: NRMSE = 0.0242
# collection1u00007s00001_hw00002.svc: NRMSE = 0.0196
# collection1u00007s00001_hw00003.svc: NRMSE = 0.0489
# collection1u00007s00001_hw00004.svc: NRMSE = 0.0038
# collection1u00007s00001_hw00005.svc: NRMSE = 0.0046
# collection1u00007s00001_hw00006.svc: NRMSE = 0.0465
# collection1u00007s00001_hw00007.svc: NRMSE = 0.0233
# collection1u00008s00001_hw00001.svc: NRMSE = 0.0113
# collection1u00008s00001_hw00002.svc: NRMSE = 0.0146
# collection1u00008s00001_hw00003.svc: NRMSE = 0.0283
# collection1u00008s00001_hw00004.svc: NRMSE = 0.0018
# collection1u00008s00001_hw00005.svc: NRMSE = 0.0014
# collection1u00008s00001_hw00006.svc: NRMSE = 0.0164
# collection1u00008s00001_hw00007.svc: NRMSE = 0.0190
# collection1u00009s00001_hw00001.svc: NRMSE = 0.0048
# collection1u00009s00001_hw00002.svc: NRMSE = 0.0116
# collection1u00009s00001_hw00003.svc: NRMSE = 0.0433
# collection1u00009s00001_hw00004.svc: NRMSE = 0.0018
# collection1u00009s00001_hw00005.svc: NRMSE = 0.0013
# collection1u00009s00001_hw00006.svc: NRMSE = 0.0321
# collection1u00009s00001_hw00007.svc: NRMSE = 0.0210
# collection1u00010s00001_hw00001.svc: NRMSE = 0.0175
# collection1u00010s00001_hw00002.svc: NRMSE = 0.0200
# collection1u00010s00001_hw00003.svc: NRMSE = 0.0317
# collection1u00010s00001_hw00004.svc: NRMSE = 0.0037
# collection1u00010s00001_hw00005.svc: NRMSE = 0.0029
# collection1u00010s00001_hw00006.svc: NRMSE = 0.0239
# collection1u00010s00001_hw00007.svc: NRMSE = 0.0135
# collection1u00011s00001_hw00001.svc: NRMSE = 0.0121
# collection1u00011s00001_hw00002.svc: NRMSE = 0.0230
# collection1u00011s00001_hw00003.svc: NRMSE = 0.0438
# collection1u00011s00001_hw00004.svc: NRMSE = 0.0188
# collection1u00011s00001_hw00005.svc: NRMSE = 0.0021
# collection1u00011s00001_hw00006.svc: NRMSE = 0.0113
# collection1u00011s00001_hw00007.svc: NRMSE = 0.0249
# collection1u00012s00001_hw00001.svc: NRMSE = 0.0047
# collection1u00012s00001_hw00002.svc: NRMSE = 0.0112
# collection1u00012s00001_hw00003.svc: NRMSE = 0.0280
# collection1u00012s00001_hw00004.svc: NRMSE = 0.0016
# collection1u00012s00001_hw00005.svc: NRMSE = 0.0015
# collection1u00012s00001_hw00006.svc: NRMSE = 0.0171
# collection1u00012s00001_hw00007.svc: NRMSE = 0.0136
# collection1u00013s00001_hw00001.svc: NRMSE = 0.0077
# collection1u00013s00001_hw00002.svc: NRMSE = 0.0138
# collection1u00013s00001_hw00003.svc: NRMSE = 0.0237
# collection1u00013s00001_hw00004.svc: NRMSE = 0.0021
# collection1u00013s00001_hw00005.svc: NRMSE = 0.0015
# collection1u00013s00001_hw00006.svc: NRMSE = 0.0192
# collection1u00013s00001_hw00007.svc: NRMSE = 0.0130
# collection1u00014s00001_hw00001.svc: NRMSE = 0.0081
# collection1u00014s00001_hw00002.svc: NRMSE = 0.0128
# collection1u00014s00001_hw00003.svc: NRMSE = 0.0312
# collection1u00014s00001_hw00004.svc: NRMSE = 0.0023
# collection1u00014s00001_hw00005.svc: NRMSE = 0.0021
# collection1u00014s00001_hw00006.svc: NRMSE = 0.0119
# collection1u00014s00001_hw00007.svc: NRMSE = 0.0263
# collection1u00015s00001_hw00001.svc: NRMSE = 0.0137
# collection1u00015s00001_hw00002.svc: NRMSE = 0.0218
# collection1u00015s00001_hw00003.svc: NRMSE = 0.0290
# collection1u00015s00001_hw00004.svc: NRMSE = 0.0026
# collection1u00015s00001_hw00005.svc: NRMSE = 0.0023
# collection1u00015s00001_hw00006.svc: NRMSE = 0.0251
# collection1u00015s00001_hw00007.svc: NRMSE = 0.0319
# collection1u00016s00001_hw00001.svc: NRMSE = 0.0052
# collection1u00016s00001_hw00002.svc: NRMSE = 0.0099
# collection1u00016s00001_hw00003.svc: NRMSE = 0.0186
# collection1u00016s00001_hw00004.svc: NRMSE = 0.0044
# collection1u00016s00001_hw00005.svc: NRMSE = 0.0045
# collection1u00016s00001_hw00006.svc: NRMSE = 0.0162
# collection1u00016s00001_hw00007.svc: NRMSE = 0.0149
# collection1u00017s00001_hw00001.svc: NRMSE = 0.0146
# collection1u00017s00001_hw00002.svc: NRMSE = 0.0106
# collection1u00017s00001_hw00003.svc: NRMSE = 0.0409
# collection1u00017s00001_hw00004.svc: NRMSE = 0.0023
# collection1u00017s00001_hw00005.svc: NRMSE = 0.0024
# collection1u00017s00001_hw00006.svc: NRMSE = 0.0186
# collection1u00017s00001_hw00007.svc: NRMSE = 0.0223
# collection1u00018s00001_hw00001.svc: NRMSE = 0.0062
# collection1u00018s00001_hw00002.svc: NRMSE = 0.0157
# collection1u00018s00001_hw00003.svc: NRMSE = 0.0388
# collection1u00018s00001_hw00004.svc: NRMSE = 0.0292
# collection1u00018s00001_hw00005.svc: NRMSE = 0.0020
# collection1u00018s00001_hw00006.svc: NRMSE = 0.0228
# collection1u00018s00001_hw00007.svc: NRMSE = 0.0272
# collection1u00019s00001_hw00001.svc: NRMSE = 0.0199
# collection1u00019s00001_hw00002.svc: NRMSE = 0.0207
# collection1u00019s00001_hw00003.svc: NRMSE = 0.0498
# collection1u00019s00001_hw00004.svc: NRMSE = 0.0029
# collection1u00019s00001_hw00005.svc: NRMSE = 0.0027
# collection1u00019s00001_hw00006.svc: NRMSE = 0.0266
# collection1u00019s00001_hw00007.svc: NRMSE = 0.0169
# collection1u00020s00001_hw00001.svc: NRMSE = 0.0105
# collection1u00020s00001_hw00002.svc: NRMSE = 0.0128
# collection1u00020s00001_hw00003.svc: NRMSE = 0.0313
# collection1u00020s00001_hw00004.svc: NRMSE = 0.0029
# collection1u00020s00001_hw00005.svc: NRMSE = 0.0031
# collection1u00020s00001_hw00006.svc: NRMSE = 0.0263
# collection1u00020s00001_hw00007.svc: NRMSE = 0.0166
# collection1u00021s00001_hw00001.svc: NRMSE = 0.0131
# collection1u00021s00001_hw00002.svc: NRMSE = 0.0109
# collection1u00021s00001_hw00003.svc: NRMSE = 0.0341
# collection1u00021s00001_hw00004.svc: NRMSE = 0.0024
# collection1u00021s00001_hw00005.svc: NRMSE = 0.0020
# collection1u00021s00001_hw00006.svc: NRMSE = 0.0146
# collection1u00021s00001_hw00007.svc: NRMSE = 0.0173
# collection1u00022s00001_hw00001.svc: NRMSE = 0.0062
# collection1u00022s00001_hw00002.svc: NRMSE = 0.0056
# collection1u00022s00001_hw00003.svc: NRMSE = 0.0270
# collection1u00022s00001_hw00004.svc: NRMSE = 0.0030
# collection1u00022s00001_hw00005.svc: NRMSE = 0.0031
# collection1u00022s00001_hw00006.svc: NRMSE = 0.0128
# collection1u00022s00001_hw00007.svc: NRMSE = 0.0349
# collection1u00023s00001_hw00001.svc: NRMSE = 0.0053
# collection1u00023s00001_hw00002.svc: NRMSE = 0.0099
# collection1u00023s00001_hw00003.svc: NRMSE = 0.0264
# collection1u00023s00001_hw00004.svc: NRMSE = 0.0033
# collection1u00023s00001_hw00005.svc: NRMSE = 0.0030
# collection1u00023s00001_hw00006.svc: NRMSE = 0.0268
# collection1u00023s00001_hw00007.svc: NRMSE = 0.0258
# collection1u00024s00001_hw00001.svc: NRMSE = 0.0170
# collection1u00024s00001_hw00002.svc: NRMSE = 0.0259
# collection1u00024s00001_hw00003.svc: NRMSE = 0.0268
# collection1u00024s00001_hw00004.svc: NRMSE = 0.0023
# collection1u00024s00001_hw00005.svc: NRMSE = 0.0027
# collection1u00024s00001_hw00006.svc: NRMSE = 0.0315
# collection1u00024s00001_hw00007.svc: NRMSE = 0.0365
# collection1u00025s00001_hw00001.svc: NRMSE = 0.0084
# collection1u00025s00001_hw00002.svc: NRMSE = 0.0174
# collection1u00025s00001_hw00003.svc: NRMSE = 0.0327
# collection1u00025s00001_hw00004.svc: NRMSE = 0.0027
# collection1u00025s00001_hw00005.svc: NRMSE = 0.0028
# collection1u00025s00001_hw00006.svc: NRMSE = 0.0286
# collection1u00025s00001_hw00007.svc: NRMSE = 0.0328
# collection1u00026s00001_hw00001.svc: NRMSE = 0.0135
# collection1u00026s00001_hw00002.svc: NRMSE = 0.0162
# collection1u00026s00001_hw00003.svc: NRMSE = 0.0268
# collection1u00026s00001_hw00004.svc: NRMSE = 0.0028
# collection1u00026s00001_hw00005.svc: NRMSE = 0.0027
# collection1u00026s00001_hw00006.svc: NRMSE = 0.0185
# collection1u00026s00001_hw00007.svc: NRMSE = 0.0189
# collection1u00027s00001_hw00001.svc: NRMSE = 0.0115
# collection1u00027s00001_hw00002.svc: NRMSE = 0.0131
# collection1u00027s00001_hw00003.svc: NRMSE = 0.0308
# collection1u00027s00001_hw00004.svc: NRMSE = 0.0020
# collection1u00027s00001_hw00005.svc: NRMSE = 0.0021
# collection1u00027s00001_hw00006.svc: NRMSE = 0.0073
# collection1u00027s00001_hw00007.svc: NRMSE = 0.0154
# collection1u00028s00001_hw00001.svc: NRMSE = 0.0178
# collection1u00028s00001_hw00002.svc: NRMSE = 0.0186
# collection1u00028s00001_hw00003.svc: NRMSE = 0.0378
# collection1u00028s00001_hw00004.svc: NRMSE = 0.0032
# collection1u00028s00001_hw00005.svc: NRMSE = 0.0026
# collection1u00028s00001_hw00006.svc: NRMSE = 0.0369
# collection1u00028s00001_hw00007.svc: NRMSE = 0.0164
# collection1u00029s00001_hw00001.svc: NRMSE = 0.0067
# collection1u00029s00001_hw00002.svc: NRMSE = 0.0105
# collection1u00029s00001_hw00003.svc: NRMSE = 0.0333
# collection1u00029s00001_hw00004.svc: NRMSE = 0.0025
# collection1u00029s00001_hw00005.svc: NRMSE = 0.0036
# collection1u00029s00001_hw00006.svc: NRMSE = 0.0147
# collection1u00029s00001_hw00007.svc: NRMSE = 0.0161
# collection1u00030s00001_hw00001.svc: NRMSE = 0.0133
# collection1u00030s00001_hw00002.svc: NRMSE = 0.0138
# collection1u00030s00001_hw00003.svc: NRMSE = 0.0337
# collection1u00030s00001_hw00004.svc: NRMSE = 0.0015
# collection1u00030s00001_hw00005.svc: NRMSE = 0.0011
# collection1u00030s00001_hw00006.svc: NRMSE = 0.0152
# collection1u00030s00001_hw00007.svc: NRMSE = 0.0211
# collection1u00031s00001_hw00001.svc: NRMSE = 0.0174
# collection1u00031s00001_hw00002.svc: NRMSE = 0.0228
# collection1u00031s00001_hw00003.svc: NRMSE = 0.0328
# collection1u00031s00001_hw00004.svc: NRMSE = 0.0033
# collection1u00031s00001_hw00005.svc: NRMSE = 0.0032
# collection1u00031s00001_hw00006.svc: NRMSE = 0.0203
# collection1u00031s00001_hw00007.svc: NRMSE = 0.0213
# collection1u00032s00001_hw00001.svc: NRMSE = 0.0049
# collection1u00032s00001_hw00002.svc: NRMSE = 0.0113
# collection1u00032s00001_hw00003.svc: NRMSE = 0.0241
# collection1u00032s00001_hw00004.svc: NRMSE = 0.0120
# collection1u00032s00001_hw00005.svc: NRMSE = 0.0025
# collection1u00032s00001_hw00006.svc: NRMSE = 0.0092
# collection1u00032s00001_hw00007.svc: NRMSE = 0.0534
# collection1u00033s00001_hw00001.svc: NRMSE = 0.0087
# collection1u00033s00001_hw00002.svc: NRMSE = 0.0190
# collection1u00033s00001_hw00003.svc: NRMSE = 0.0502
# collection1u00033s00001_hw00004.svc: NRMSE = 0.0168
# collection1u00033s00001_hw00005.svc: NRMSE = 0.0013
# collection1u00033s00001_hw00006.svc: NRMSE = 0.0116
# collection1u00033s00001_hw00007.svc: NRMSE = 0.1193
# collection1u00034s00001_hw00001.svc: NRMSE = 0.0240
# collection1u00034s00001_hw00002.svc: NRMSE = 0.0117
# collection1u00034s00001_hw00003.svc: NRMSE = 0.0204
# collection1u00034s00001_hw00004.svc: NRMSE = 0.0019
# collection1u00034s00001_hw00005.svc: NRMSE = 0.0025
# collection1u00034s00001_hw00006.svc: NRMSE = 0.0363
# collection1u00034s00001_hw00007.svc: NRMSE = 0.0212
# collection1u00035s00001_hw00001.svc: NRMSE = 0.0029
# collection1u00035s00001_hw00002.svc: NRMSE = 0.0043
# collection1u00035s00001_hw00003.svc: NRMSE = 0.0319
# collection1u00035s00001_hw00004.svc: NRMSE = 0.0016
# collection1u00035s00001_hw00005.svc: NRMSE = 0.0020
# collection1u00035s00001_hw00006.svc: NRMSE = 0.0080
# collection1u00035s00001_hw00007.svc: NRMSE = 0.0364
# collection1u00036s00001_hw00001.svc: NRMSE = 0.0054
# collection1u00036s00001_hw00002.svc: NRMSE = 0.0140
# collection1u00036s00001_hw00003.svc: NRMSE = 0.0381
# collection1u00036s00001_hw00004.svc: NRMSE = 0.0017
# collection1u00036s00001_hw00005.svc: NRMSE = 0.0018
# collection1u00036s00001_hw00006.svc: NRMSE = 0.0278
# collection1u00036s00001_hw00007.svc: NRMSE = 0.0303
# collection1u00037s00001_hw00001.svc: NRMSE = 0.0057
# collection1u00037s00001_hw00002.svc: NRMSE = 0.0195
# collection1u00037s00001_hw00003.svc: NRMSE = 0.0416
# collection1u00037s00001_hw00004.svc: NRMSE = 0.0032
# collection1u00037s00001_hw00005.svc: NRMSE = 0.0028
# collection1u00037s00001_hw00006.svc: NRMSE = 0.0193
# collection1u00037s00001_hw00007.svc: NRMSE = 0.0197
# collection1u00038s00001_hw00001.svc: NRMSE = 0.0129
# collection1u00038s00001_hw00002.svc: NRMSE = 0.0283
# collection1u00038s00001_hw00003.svc: NRMSE = 0.0272
# collection1u00038s00001_hw00004.svc: NRMSE = 0.0031
# collection1u00038s00001_hw00005.svc: NRMSE = 0.0031
# collection1u00038s00001_hw00006.svc: NRMSE = 0.0172
# collection1u00038s00001_hw00007.svc: NRMSE = 0.0222
# collection1u00039s00001_hw00001.svc: NRMSE = 0.0138
# collection1u00039s00001_hw00002.svc: NRMSE = 0.0101
# collection1u00039s00001_hw00003.svc: NRMSE = 0.0255
# collection1u00039s00001_hw00004.svc: NRMSE = 0.0050
# collection1u00039s00001_hw00005.svc: NRMSE = 0.0056
# collection1u00039s00001_hw00006.svc: NRMSE = 0.0424
# collection1u00039s00001_hw00007.svc: NRMSE = 0.0201
# collection1u00040s00001_hw00001.svc: NRMSE = 0.0268
# collection1u00040s00001_hw00002.svc: NRMSE = 0.0309
# collection1u00040s00001_hw00003.svc: NRMSE = 0.0387
# collection1u00040s00001_hw00004.svc: NRMSE = 0.0064
# collection1u00040s00001_hw00005.svc: NRMSE = 0.0040
# collection1u00040s00001_hw00006.svc: NRMSE = 0.0550
# collection1u00040s00001_hw00007.svc: NRMSE = 0.0116
# collection1u00041s00001_hw00001.svc: NRMSE = 0.0051
# collection1u00041s00001_hw00002.svc: NRMSE = 0.0096
# collection1u00041s00001_hw00003.svc: NRMSE = 0.0255
# collection1u00041s00001_hw00004.svc: NRMSE = 0.0011
# collection1u00041s00001_hw00005.svc: NRMSE = 0.0013
# collection1u00041s00001_hw00006.svc: NRMSE = 0.1177
# collection1u00041s00001_hw00007.svc: NRMSE = 0.0345
# collection1u00042s00001_hw00001.svc: NRMSE = 0.0098
# collection1u00042s00001_hw00002.svc: NRMSE = 0.0127
# collection1u00042s00001_hw00003.svc: NRMSE = 0.0152
# collection1u00042s00001_hw00004.svc: NRMSE = 0.0013
# collection1u00042s00001_hw00005.svc: NRMSE = 0.0012
# collection1u00042s00001_hw00006.svc: NRMSE = 0.0060
# collection1u00042s00001_hw00007.svc: NRMSE = 0.0223
# collection1u00043s00001_hw00001.svc: NRMSE = 0.0094
# collection1u00043s00001_hw00002.svc: NRMSE = 0.0049
# collection1u00043s00001_hw00003.svc: NRMSE = 0.0600
# collection1u00043s00001_hw00004.svc: NRMSE = 0.0011
# collection1u00043s00001_hw00005.svc: NRMSE = 0.0013
# collection1u00043s00001_hw00006.svc: NRMSE = 0.0127
# collection1u00043s00001_hw00007.svc: NRMSE = 0.0232
# collection1u00044s00001_hw00001.svc: NRMSE = 0.0055
# collection1u00044s00001_hw00002.svc: NRMSE = 0.0190
# collection1u00044s00001_hw00003.svc: NRMSE = 0.0381
# collection1u00044s00001_hw00004.svc: NRMSE = 0.0013
# collection1u00044s00001_hw00005.svc: NRMSE = 0.0010
# collection1u00044s00001_hw00006.svc: NRMSE = 0.0108
# collection1u00044s00001_hw00007.svc: NRMSE = 0.0187
# collection1u00045s00001_hw00001.svc: NRMSE = 0.0083
# collection1u00045s00001_hw00002.svc: NRMSE = 0.0038
# collection1u00045s00001_hw00003.svc: NRMSE = 0.0219
# collection1u00045s00001_hw00004.svc: NRMSE = 0.0009
# collection1u00045s00001_hw00005.svc: NRMSE = 0.0008
# collection1u00045s00001_hw00006.svc: NRMSE = 0.0127
# collection1u00045s00001_hw00007.svc: NRMSE = 0.1602
# u00001s00001_hw00001.svc: NRMSE = 0.0142
# u00001s00001_hw00002.svc: NRMSE = 0.0193
# u00001s00001_hw00003.svc: NRMSE = 0.0393
# u00001s00001_hw00004.svc: NRMSE = 0.0019
# u00001s00001_hw00005.svc: NRMSE = 0.0012
# u00001s00001_hw00006.svc: NRMSE = 0.0105
# u00001s00001_hw00007.svc: NRMSE = 0.0564
# u00002s00001_hw00001.svc: NRMSE = 0.0030
# u00002s00001_hw00002.svc: NRMSE = 0.0130
# u00002s00001_hw00003.svc: NRMSE = 0.0437
# u00002s00001_hw00004.svc: NRMSE = 0.0033
# u00002s00001_hw00005.svc: NRMSE = 0.0026
# u00002s00001_hw00006.svc: NRMSE = 0.0206
# u00002s00001_hw00007.svc: NRMSE = 0.0138
# u00003s00001_hw00001.svc: NRMSE = 0.0125
# u00003s00001_hw00002.svc: NRMSE = 0.0165
# u00003s00001_hw00003.svc: NRMSE = 0.0610
# u00003s00001_hw00004.svc: NRMSE = 0.0027
# u00003s00001_hw00005.svc: NRMSE = 0.0026
# u00003s00001_hw00006.svc: NRMSE = 0.0386
# u00003s00001_hw00007.svc: NRMSE = 0.0182
# u00004s00001_hw00001.svc: NRMSE = 0.0163
# u00004s00001_hw00002.svc: NRMSE = 0.0234
# u00004s00001_hw00003.svc: NRMSE = 0.0534
# u00004s00001_hw00004.svc: NRMSE = 0.0024
# u00004s00001_hw00005.svc: NRMSE = 0.0020
# u00004s00001_hw00006.svc: NRMSE = 0.0228
# u00004s00001_hw00007.svc: NRMSE = 0.0217
# u00005s00001_hw00001.svc: NRMSE = 0.0188
# u00005s00001_hw00002.svc: NRMSE = 0.0209
# u00005s00001_hw00003.svc: NRMSE = 0.0448
# u00005s00001_hw00004.svc: NRMSE = 0.0021
# u00005s00001_hw00005.svc: NRMSE = 0.0016
# u00005s00001_hw00006.svc: NRMSE = 0.0200
# u00005s00001_hw00007.svc: NRMSE = 0.0225
# u00006s00001_hw00001.svc: NRMSE = 0.0152
# u00006s00001_hw00002.svc: NRMSE = 0.0209
# u00006s00001_hw00003.svc: NRMSE = 0.0402
# u00006s00001_hw00004.svc: NRMSE = 0.0026
# u00006s00001_hw00005.svc: NRMSE = 0.0025
# u00006s00001_hw00006.svc: NRMSE = 0.0104
# u00006s00001_hw00007.svc: NRMSE = 0.0309
# u00007s00001_hw00001.svc: NRMSE = 0.0167
# u00007s00001_hw00002.svc: NRMSE = 0.0158
# u00007s00001_hw00003.svc: NRMSE = 0.0564
# u00007s00001_hw00004.svc: NRMSE = 0.0013
# u00007s00001_hw00005.svc: NRMSE = 0.0016
# u00007s00001_hw00006.svc: NRMSE = 0.0162
# u00007s00001_hw00007.svc: NRMSE = 0.0495
# u00008s00001_hw00001.svc: NRMSE = 0.0172
# u00008s00001_hw00002.svc: NRMSE = 0.0160
# u00008s00001_hw00003.svc: NRMSE = 0.0591
# u00008s00001_hw00004.svc: NRMSE = 0.0041
# u00008s00001_hw00005.svc: NRMSE = 0.0032
# u00008s00001_hw00006.svc: NRMSE = 0.0191
# u00008s00001_hw00007.svc: NRMSE = 0.0251
# u00009s00001_hw00001.svc: NRMSE = 0.0130
# u00009s00001_hw00002.svc: NRMSE = 0.0132
# u00009s00001_hw00003.svc: NRMSE = 0.0315
# u00009s00001_hw00004.svc: NRMSE = 0.0024
# u00009s00001_hw00005.svc: NRMSE = 0.0026
# u00009s00001_hw00006.svc: NRMSE = 0.0123
# u00009s00001_hw00007.svc: NRMSE = 0.0187
# u00010s00001_hw00001.svc: NRMSE = 0.0156
# u00010s00001_hw00002.svc: NRMSE = 0.0176
# u00010s00001_hw00003.svc: NRMSE = 0.0242
# u00010s00001_hw00004.svc: NRMSE = 0.0026
# u00010s00001_hw00005.svc: NRMSE = 0.0022
# u00010s00001_hw00006.svc: NRMSE = 0.0353
# u00010s00001_hw00007.svc: NRMSE = 0.0164
# u00011s00001_hw00001.svc: NRMSE = 0.0126
# u00011s00001_hw00002.svc: NRMSE = 0.0197
# u00011s00001_hw00003.svc: NRMSE = 0.0233
# u00011s00001_hw00004.svc: NRMSE = 0.0031
# u00011s00001_hw00005.svc: NRMSE = 0.0027
# u00011s00001_hw00006.svc: NRMSE = 0.0292
# u00011s00001_hw00007.svc: NRMSE = 0.0138
# u00012s00001_hw00001.svc: NRMSE = 0.0070
# u00012s00001_hw00002.svc: NRMSE = 0.0135
# u00012s00001_hw00003.svc: NRMSE = 0.0343
# u00012s00001_hw00004.svc: NRMSE = 0.0025
# u00012s00001_hw00005.svc: NRMSE = 0.0026
# u00012s00001_hw00006.svc: NRMSE = 0.0176
# u00012s00001_hw00007.svc: NRMSE = 0.0886
# u00013s00001_hw00001.svc: NRMSE = 0.0052
# u00013s00001_hw00002.svc: NRMSE = 0.0106
# u00013s00001_hw00003.svc: NRMSE = 0.0301
# u00013s00001_hw00004.svc: NRMSE = 0.0018
# u00013s00001_hw00005.svc: NRMSE = 0.0017
# u00013s00001_hw00006.svc: NRMSE = 0.0211
# u00013s00001_hw00007.svc: NRMSE = 0.0437
# u00014s00001_hw00001.svc: NRMSE = 0.0148
# u00014s00001_hw00002.svc: NRMSE = 0.0193
# u00014s00001_hw00003.svc: NRMSE = 0.0388
# u00014s00001_hw00004.svc: NRMSE = 0.0023
# u00014s00001_hw00005.svc: NRMSE = 0.0021
# u00014s00001_hw00006.svc: NRMSE = 0.0244
# u00014s00001_hw00007.svc: NRMSE = 0.0400
# u00015s00001_hw00001.svc: NRMSE = 0.0040
# u00015s00001_hw00002.svc: NRMSE = 0.0128
# u00015s00001_hw00003.svc: NRMSE = 0.0416
# u00015s00001_hw00004.svc: NRMSE = 0.0033
# u00015s00001_hw00005.svc: NRMSE = 0.0032
# u00015s00001_hw00006.svc: NRMSE = 0.0373
# u00015s00001_hw00007.svc: NRMSE = 0.0493
# u00016s00001_hw00001.svc: NRMSE = 0.0211
# u00016s00001_hw00002.svc: NRMSE = 0.0287
# u00016s00001_hw00003.svc: NRMSE = 0.0285
# u00016s00001_hw00004.svc: NRMSE = 0.0017
# u00016s00001_hw00005.svc: NRMSE = 0.0016
# u00016s00001_hw00006.svc: NRMSE = 0.0226
# u00016s00001_hw00007.svc: NRMSE = 0.0155
# u00017s00001_hw00001.svc: NRMSE = 0.0178
# u00017s00001_hw00002.svc: NRMSE = 0.0249
# u00017s00001_hw00003.svc: NRMSE = 0.0367
# u00017s00001_hw00004.svc: NRMSE = 0.0019
# u00017s00001_hw00005.svc: NRMSE = 0.0020
# u00017s00001_hw00006.svc: NRMSE = 0.0331
# u00017s00001_hw00007.svc: NRMSE = 0.0172
# u00018s00001_hw00001.svc: NRMSE = 0.0133
# u00018s00001_hw00002.svc: NRMSE = 0.0126
# u00018s00001_hw00003.svc: NRMSE = 0.0272
# u00018s00001_hw00004.svc: NRMSE = 0.0016
# u00018s00001_hw00005.svc: NRMSE = 0.0017
# u00018s00001_hw00006.svc: NRMSE = 0.0211
# u00018s00001_hw00007.svc: NRMSE = 0.0159
# u00019s00001_hw00001.svc: NRMSE = 0.0073
# u00019s00001_hw00002.svc: NRMSE = 0.0168
# u00019s00001_hw00003.svc: NRMSE = 0.0349
# u00019s00001_hw00004.svc: NRMSE = 0.0023
# u00019s00001_hw00005.svc: NRMSE = 0.0021
# u00019s00001_hw00006.svc: NRMSE = 0.0422
# u00019s00001_hw00007.svc: NRMSE = 0.0250
# u00020s00001_hw00001.svc: NRMSE = 0.0031
# u00020s00001_hw00002.svc: NRMSE = 0.0116
# u00020s00001_hw00003.svc: NRMSE = 0.0434
# u00020s00001_hw00004.svc: NRMSE = 0.0107
# u00020s00001_hw00005.svc: NRMSE = 0.0012
# u00020s00001_hw00006.svc: NRMSE = 0.0287
# u00020s00001_hw00007.svc: NRMSE = 0.0520
# u00021s00001_hw00001.svc: NRMSE = 0.0046
# u00021s00001_hw00002.svc: NRMSE = 0.0137
# u00021s00001_hw00003.svc: NRMSE = 0.0497
# u00021s00001_hw00004.svc: NRMSE = 0.0030
# u00021s00001_hw00005.svc: NRMSE = 0.0028
# u00021s00001_hw00006.svc: NRMSE = 0.0131
# u00021s00001_hw00007.svc: NRMSE = 0.0142
# u00022s00001_hw00001.svc: NRMSE = 0.0143
# u00022s00001_hw00002.svc: NRMSE = 0.0292
# u00022s00001_hw00003.svc: NRMSE = 0.0313
# u00022s00001_hw00004.svc: NRMSE = 0.0030
# u00022s00001_hw00005.svc: NRMSE = 0.0026
# u00022s00001_hw00006.svc: NRMSE = 0.0408
# u00022s00001_hw00007.svc: NRMSE = 0.0148
# u00023s00001_hw00001.svc: NRMSE = 0.0138
# u00023s00001_hw00002.svc: NRMSE = 0.0143
# u00023s00001_hw00003.svc: NRMSE = 0.0321
# u00023s00001_hw00004.svc: NRMSE = 0.0025
# u00023s00001_hw00005.svc: NRMSE = 0.0021
# u00023s00001_hw00006.svc: NRMSE = 0.0154
# u00023s00001_hw00007.svc: NRMSE = 0.0184
# u00024s00001_hw00001.svc: NRMSE = 0.0065
# u00024s00001_hw00002.svc: NRMSE = 0.0083
# u00024s00001_hw00003.svc: NRMSE = 0.0380
# u00024s00001_hw00004.svc: NRMSE = 0.0019
# u00024s00001_hw00005.svc: NRMSE = 0.0016
# u00024s00001_hw00006.svc: NRMSE = 0.0377
# u00024s00001_hw00007.svc: NRMSE = 0.0210
# u00025s00001_hw00001.svc: NRMSE = 0.0137
# u00025s00001_hw00002.svc: NRMSE = 0.0224
# u00025s00001_hw00003.svc: NRMSE = 0.0301
# u00025s00001_hw00004.svc: NRMSE = 0.0014
# u00025s00001_hw00005.svc: NRMSE = 0.0012
# u00025s00001_hw00006.svc: NRMSE = 0.0304
# u00025s00001_hw00007.svc: NRMSE = 0.0312
# u00026s00001_hw00001.svc: NRMSE = 0.0110
# u00026s00001_hw00002.svc: NRMSE = 0.0180
# u00026s00001_hw00003.svc: NRMSE = 0.0402
# u00026s00001_hw00004.svc: NRMSE = 0.0020
# u00026s00001_hw00005.svc: NRMSE = 0.0021
# u00026s00001_hw00006.svc: NRMSE = 0.0175
# u00026s00001_hw00007.svc: NRMSE = 0.0152
# u00027s00001_hw00001.svc: NRMSE = 0.0156
# u00027s00001_hw00002.svc: NRMSE = 0.0406
# u00027s00001_hw00003.svc: NRMSE = 0.0372
# u00027s00001_hw00004.svc: NRMSE = 0.0039
# u00027s00001_hw00005.svc: NRMSE = 0.0037
# u00027s00001_hw00006.svc: NRMSE = 0.0351
# u00027s00001_hw00007.svc: NRMSE = 0.0668
# u00028s00001_hw00001.svc: NRMSE = 0.0239
# u00028s00001_hw00002.svc: NRMSE = 0.0291
# u00028s00001_hw00003.svc: NRMSE = 0.0527
# u00028s00001_hw00004.svc: NRMSE = 0.0021
# u00028s00001_hw00005.svc: NRMSE = 0.0026
# u00028s00001_hw00006.svc: NRMSE = 0.0342
# u00028s00001_hw00007.svc: NRMSE = 0.0512
# u00029s00001_hw00001.svc: NRMSE = 0.0144
# u00029s00001_hw00002.svc: NRMSE = 0.0386
# u00029s00001_hw00003.svc: NRMSE = 0.0371
# u00029s00001_hw00004.svc: NRMSE = 0.0020
# u00029s00001_hw00005.svc: NRMSE = 0.0022
# u00029s00001_hw00006.svc: NRMSE = 0.0202
# u00029s00001_hw00007.svc: NRMSE = 0.0140
# u00030s00001_hw00001.svc: NRMSE = 0.0196
# u00030s00001_hw00002.svc: NRMSE = 0.0371
# u00030s00001_hw00003.svc: NRMSE = 0.0306
# u00030s00001_hw00004.svc: NRMSE = 0.0015
# u00030s00001_hw00005.svc: NRMSE = 0.0025
# u00030s00001_hw00006.svc: NRMSE = 0.0595
# u00030s00001_hw00007.svc: NRMSE = 0.0203
# u00031s00001_hw00001.svc: NRMSE = 0.0112
# u00031s00001_hw00002.svc: NRMSE = 0.0213
# u00031s00001_hw00003.svc: NRMSE = 0.0632
# u00031s00001_hw00004.svc: NRMSE = 0.0044
# u00031s00001_hw00005.svc: NRMSE = 0.0055
# u00031s00001_hw00006.svc: NRMSE = 0.0337
# u00031s00001_hw00007.svc: NRMSE = 0.0164
# u00032s00001_hw00001.svc: NRMSE = 0.0215
# u00032s00001_hw00002.svc: NRMSE = 0.0155
# u00032s00001_hw00003.svc: NRMSE = 0.0355
# u00032s00001_hw00004.svc: NRMSE = 0.0430
# u00032s00001_hw00005.svc: NRMSE = 0.0027
# u00032s00001_hw00006.svc: NRMSE = 0.0294
# u00032s00001_hw00007.svc: NRMSE = 0.0430
# u00033s00001_hw00001.svc: NRMSE = 0.0132
# u00033s00001_hw00002.svc: NRMSE = 0.0310
# u00033s00001_hw00003.svc: NRMSE = 0.0316
# u00033s00001_hw00004.svc: NRMSE = 0.0003
# u00033s00001_hw00005.svc: NRMSE = 0.0024
# u00033s00001_hw00006.svc: NRMSE = 0.0376
# u00033s00001_hw00007.svc: NRMSE = 0.0160
# u00034s00001_hw00001.svc: NRMSE = 0.0121
# u00034s00001_hw00002.svc: NRMSE = 0.0191
# u00034s00001_hw00003.svc: NRMSE = 0.0377
# u00034s00001_hw00004.svc: NRMSE = 0.0019
# u00034s00001_hw00005.svc: NRMSE = 0.0018
# u00034s00001_hw00006.svc: NRMSE = 0.0208
# u00034s00001_hw00007.svc: NRMSE = 0.0189
# u00035s00001_hw00001.svc: NRMSE = 0.0130
# u00035s00001_hw00002.svc: NRMSE = 0.0197
# u00035s00001_hw00003.svc: NRMSE = 0.0433
# u00035s00001_hw00004.svc: NRMSE = 0.0021
# u00035s00001_hw00005.svc: NRMSE = 0.0023
# u00035s00001_hw00006.svc: NRMSE = 0.0465
# u00035s00001_hw00007.svc: NRMSE = 0.0292
# u00036s00001_hw00001.svc: NRMSE = 0.0048
# u00036s00001_hw00002.svc: NRMSE = 0.0101
# u00036s00001_hw00003.svc: NRMSE = 0.0293
# u00036s00001_hw00004.svc: NRMSE = 0.0022
# u00036s00001_hw00005.svc: NRMSE = 0.0026
# u00036s00001_hw00006.svc: NRMSE = 0.0375
# u00036s00001_hw00007.svc: NRMSE = 0.0220
# u00037s00001_hw00001.svc: NRMSE = 0.0130
# u00037s00001_hw00002.svc: NRMSE = 0.0234
# u00037s00001_hw00003.svc: NRMSE = 0.0364
# u00037s00001_hw00004.svc: NRMSE = 0.0027
# u00037s00001_hw00005.svc: NRMSE = 0.0020
# u00037s00001_hw00006.svc: NRMSE = 0.0550
# u00037s00001_hw00007.svc: NRMSE = 0.0404
# u00038s00001_hw00001.svc: NRMSE = 0.0055
# u00038s00001_hw00002.svc: NRMSE = 0.0039
# u00038s00001_hw00003.svc: NRMSE = 0.0747
# u00038s00001_hw00004.svc: NRMSE = 0.0013
# u00038s00001_hw00005.svc: NRMSE = 0.0013
# u00038s00001_hw00006.svc: NRMSE = 0.0164
# u00038s00001_hw00007.svc: NRMSE = 0.0146
# u00039s00001_hw00001.svc: NRMSE = 0.0067
# u00039s00001_hw00002.svc: NRMSE = 0.0124
# u00039s00001_hw00003.svc: NRMSE = 0.0397
# u00039s00001_hw00004.svc: NRMSE = 0.0031
# u00039s00001_hw00005.svc: NRMSE = 0.0030
# u00039s00001_hw00006.svc: NRMSE = 0.0361
# u00039s00001_hw00007.svc: NRMSE = 0.0145
# u00040s00001_hw00001.svc: NRMSE = 0.0089
# u00040s00001_hw00002.svc: NRMSE = 0.0132
# u00040s00001_hw00003.svc: NRMSE = 0.0509
# u00040s00001_hw00004.svc: NRMSE = 0.0023
# u00040s00001_hw00005.svc: NRMSE = 0.0023
# u00040s00001_hw00006.svc: NRMSE = 0.0148
# u00040s00001_hw00007.svc: NRMSE = 0.0162
# u00041s00001_hw00001.svc: NRMSE = 0.0223
# u00041s00001_hw00002.svc: NRMSE = 0.0271
# u00041s00001_hw00003.svc: NRMSE = 0.0351
# u00041s00001_hw00004.svc: NRMSE = 0.0031
# u00041s00001_hw00005.svc: NRMSE = 0.0029
# u00041s00001_hw00006.svc: NRMSE = 0.0539
# u00041s00001_hw00007.svc: NRMSE = 0.0216
# u00042s00001_hw00001.svc: NRMSE = 0.0138
# u00042s00001_hw00002.svc: NRMSE = 0.0147
# u00042s00001_hw00003.svc: NRMSE = 0.0409
# u00042s00001_hw00004.svc: NRMSE = 0.0029
# u00042s00001_hw00005.svc: NRMSE = 0.0020
# u00042s00001_hw00006.svc: NRMSE = 0.0318
# u00042s00001_hw00007.svc: NRMSE = 0.0127
# u00043s00001_hw00001.svc: NRMSE = 0.0129
# u00043s00001_hw00002.svc: NRMSE = 0.0163
# u00043s00001_hw00003.svc: NRMSE = 0.0467
# u00043s00001_hw00004.svc: NRMSE = 0.0029
# u00043s00001_hw00005.svc: NRMSE = 0.0022
# u00043s00001_hw00006.svc: NRMSE = 0.0433
# u00043s00001_hw00007.svc: NRMSE = 0.0157
# u00044s00001_hw00001.svc: NRMSE = 0.0154
# u00044s00001_hw00002.svc: NRMSE = 0.0176
# u00044s00001_hw00003.svc: NRMSE = 0.0299
# u00044s00001_hw00004.svc: NRMSE = 0.0096
# u00044s00001_hw00005.svc: NRMSE = 0.0028
# u00044s00001_hw00006.svc: NRMSE = 0.0243
# u00044s00001_hw00007.svc: NRMSE = 0.0206
# u00045s00001_hw00001.svc: NRMSE = 0.0056
# u00045s00001_hw00002.svc: NRMSE = 0.0150
# u00045s00001_hw00003.svc: NRMSE = 0.0659
# u00045s00001_hw00004.svc: NRMSE = 0.0025
# u00045s00001_hw00005.svc: NRMSE = 0.0018
# u00045s00001_hw00006.svc: NRMSE = 0.0165
# u00045s00001_hw00007.svc: NRMSE = 0.0263
# u00046s00001_hw00001.svc: NRMSE = 0.0098
# u00046s00001_hw00002.svc: NRMSE = 0.0097
# u00046s00001_hw00003.svc: NRMSE = 0.0389
# u00046s00001_hw00004.svc: NRMSE = 0.0022
# u00046s00001_hw00005.svc: NRMSE = 0.0019
# u00046s00001_hw00006.svc: NRMSE = 0.0269
# u00046s00001_hw00007.svc: NRMSE = 0.0696
# u00047s00001_hw00001.svc: NRMSE = 0.0048
# u00047s00001_hw00002.svc: NRMSE = 0.0090
# u00047s00001_hw00003.svc: NRMSE = 0.0310
# u00047s00001_hw00004.svc: NRMSE = 0.0033
# u00047s00001_hw00005.svc: NRMSE = 0.0016
# u00047s00001_hw00006.svc: NRMSE = 0.0188
# u00047s00001_hw00007.svc: NRMSE = 0.0786
# u00048s00001_hw00001.svc: NRMSE = 0.0052
# u00048s00001_hw00002.svc: NRMSE = 0.0092
# u00048s00001_hw00003.svc: NRMSE = 0.0341
# u00048s00001_hw00004.svc: NRMSE = 0.0025
# u00048s00001_hw00005.svc: NRMSE = 0.0021
# u00048s00001_hw00006.svc: NRMSE = 0.0153
# u00048s00001_hw00007.svc: NRMSE = 0.0219
# u00049s00001_hw00001.svc: NRMSE = 0.0158
# u00049s00001_hw00002.svc: NRMSE = 0.0201
# u00049s00001_hw00003.svc: NRMSE = 0.0385
# u00049s00001_hw00004.svc: NRMSE = 0.0030
# u00049s00001_hw00005.svc: NRMSE = 0.0033
# u00049s00001_hw00006.svc: NRMSE = 0.0225
# u00049s00001_hw00007.svc: NRMSE = 0.0165
# u00050s00001_hw00001.svc: NRMSE = 0.0072
# u00050s00001_hw00002.svc: NRMSE = 0.0190
# u00050s00001_hw00003.svc: NRMSE = 0.0367
# u00050s00001_hw00004.svc: NRMSE = 0.0018
# u00050s00001_hw00005.svc: NRMSE = 0.0017
# u00050s00001_hw00006.svc: NRMSE = 0.0157
# u00050s00001_hw00007.svc: NRMSE = 0.0182
# u00051s00001_hw00001.svc: NRMSE = 0.0086
# u00051s00001_hw00002.svc: NRMSE = 0.0184
# u00051s00001_hw00003.svc: NRMSE = 0.0320
# u00051s00001_hw00004.svc: NRMSE = 0.0039
# u00051s00001_hw00005.svc: NRMSE = 0.0021
# u00051s00001_hw00006.svc: NRMSE = 0.0170
# u00051s00001_hw00007.svc: NRMSE = 0.0151
# u00052s00001_hw00001.svc: NRMSE = 0.0221
# u00052s00001_hw00002.svc: NRMSE = 0.0199
# u00052s00001_hw00003.svc: NRMSE = 0.0347
# u00052s00001_hw00004.svc: NRMSE = 0.0017
# u00052s00001_hw00005.svc: NRMSE = 0.0018
# u00052s00001_hw00006.svc: NRMSE = 0.0653
# u00052s00001_hw00007.svc: NRMSE = 0.0168
# u00053s00001_hw00001.svc: NRMSE = 0.0095
# u00053s00001_hw00002.svc: NRMSE = 0.0176
# u00053s00001_hw00003.svc: NRMSE = 0.0468
# u00053s00001_hw00004.svc: NRMSE = 0.0023
# u00053s00001_hw00005.svc: NRMSE = 0.0017
# u00053s00001_hw00006.svc: NRMSE = 0.0314
# u00053s00001_hw00007.svc: NRMSE = 0.0364
# u00054s00001_hw00001.svc: NRMSE = 0.0135
# u00054s00001_hw00002.svc: NRMSE = 0.0215
# u00054s00001_hw00003.svc: NRMSE = 0.0309
# u00054s00001_hw00004.svc: NRMSE = 0.0107
# u00054s00001_hw00005.svc: NRMSE = 0.0013
# u00054s00001_hw00006.svc: NRMSE = 0.0331
# u00054s00001_hw00007.svc: NRMSE = 0.0213
# u00055s00001_hw00001.svc: NRMSE = 0.0214
# u00055s00001_hw00002.svc: NRMSE = 0.0231
# u00055s00001_hw00003.svc: NRMSE = 0.0501
# u00055s00001_hw00004.svc: NRMSE = 0.0032
# u00055s00001_hw00005.svc: NRMSE = 0.0025
# u00055s00001_hw00006.svc: NRMSE = 0.0568
# u00055s00001_hw00007.svc: NRMSE = 0.0338
# u00056s00001_hw00001.svc: NRMSE = 0.0079
# u00056s00001_hw00002.svc: NRMSE = 0.0083
# u00056s00001_hw00003.svc: NRMSE = 0.0530
# u00056s00001_hw00004.svc: NRMSE = 0.0016
# u00056s00001_hw00005.svc: NRMSE = 0.0014
# u00056s00001_hw00006.svc: NRMSE = 0.0252
# u00056s00001_hw00007.svc: NRMSE = 0.0283
# u00057s00001_hw00001.svc: NRMSE = 0.0096
# u00057s00001_hw00002.svc: NRMSE = 0.0217
# u00057s00001_hw00003.svc: NRMSE = 0.0466
# u00057s00001_hw00004.svc: NRMSE = 0.0047
# u00057s00001_hw00005.svc: NRMSE = 0.0034
# u00057s00001_hw00006.svc: NRMSE = 0.0257
# u00057s00001_hw00007.svc: NRMSE = 0.0201
# u00058s00001_hw00001.svc: NRMSE = 0.0153
# u00058s00001_hw00002.svc: NRMSE = 0.0149
# u00058s00001_hw00003.svc: NRMSE = 0.0441
# u00058s00001_hw00004.svc: NRMSE = 0.0033
# u00058s00001_hw00005.svc: NRMSE = 0.0037
# u00058s00001_hw00006.svc: NRMSE = 0.0296
# u00058s00001_hw00007.svc: NRMSE = 0.0612
# u00059s00001_hw00001.svc: NRMSE = 0.0162
# u00059s00001_hw00002.svc: NRMSE = 0.0154
# u00059s00001_hw00003.svc: NRMSE = 0.0336
# u00059s00001_hw00004.svc: NRMSE = 0.0052
# u00059s00001_hw00005.svc: NRMSE = 0.0027
# u00059s00001_hw00006.svc: NRMSE = 0.0323
# u00059s00001_hw00007.svc: NRMSE = 0.0201
# u00060s00001_hw00001.svc: NRMSE = 0.0271
# u00060s00001_hw00002.svc: NRMSE = 0.0235
# u00060s00001_hw00003.svc: NRMSE = 0.0393
# u00060s00001_hw00004.svc: NRMSE = 0.0035
# u00060s00001_hw00005.svc: NRMSE = 0.0041
# u00060s00001_hw00006.svc: NRMSE = 0.0414
# u00060s00001_hw00007.svc: NRMSE = 0.0292
# u00061s00001_hw00001.svc: NRMSE = 0.0236
# u00061s00001_hw00002.svc: NRMSE = 0.0200
# u00061s00001_hw00003.svc: NRMSE = 0.0444
# u00061s00001_hw00004.svc: NRMSE = 0.0034
# u00061s00001_hw00005.svc: NRMSE = 0.0030
# u00061s00001_hw00006.svc: NRMSE = 0.0407
# u00061s00001_hw00007.svc: NRMSE = 0.0208
# u00062s00001_hw00001.svc: NRMSE = 0.0154
# u00062s00001_hw00002.svc: NRMSE = 0.0278
# u00062s00001_hw00003.svc: NRMSE = 0.0367
# u00062s00001_hw00004.svc: NRMSE = 0.0019
# u00062s00001_hw00005.svc: NRMSE = 0.0018
# u00062s00001_hw00006.svc: NRMSE = 0.0478
# u00062s00001_hw00007.svc: NRMSE = 0.0172
# u00063s00001_hw00001.svc: NRMSE = 0.0154
# u00063s00001_hw00002.svc: NRMSE = 0.0199
# u00063s00001_hw00003.svc: NRMSE = 0.0375
# u00063s00001_hw00004.svc: NRMSE = 0.0022
# u00063s00001_hw00005.svc: NRMSE = 0.0025
# u00063s00001_hw00006.svc: NRMSE = 0.0231
# u00063s00001_hw00007.svc: NRMSE = 0.0185
# u00064s00001_hw00001.svc: NRMSE = 0.0106
# u00064s00001_hw00002.svc: NRMSE = 0.0113
# u00064s00001_hw00003.svc: NRMSE = 0.0607
# u00064s00001_hw00004.svc: NRMSE = 0.0011
# u00064s00001_hw00005.svc: NRMSE = 0.0009
# u00064s00001_hw00006.svc: NRMSE = 0.0196
# u00064s00001_hw00007.svc: NRMSE = 0.0431
# u00065s00001_hw00001.svc: NRMSE = 0.0143
# u00065s00001_hw00002.svc: NRMSE = 0.0137
# u00065s00001_hw00003.svc: NRMSE = 0.0578
# u00065s00001_hw00004.svc: NRMSE = 0.0040
# u00065s00001_hw00005.svc: NRMSE = 0.0029
# u00065s00001_hw00006.svc: NRMSE = 0.0106
# u00065s00001_hw00007.svc: NRMSE = 0.0289
# u00066s00001_hw00001.svc: NRMSE = 0.0172
# u00066s00001_hw00002.svc: NRMSE = 0.0212
# u00066s00001_hw00003.svc: NRMSE = 0.0531
# u00066s00001_hw00004.svc: NRMSE = 0.0027
# u00066s00001_hw00005.svc: NRMSE = 0.0024
# u00066s00001_hw00006.svc: NRMSE = 0.0291
# u00066s00001_hw00007.svc: NRMSE = 0.0344
# u00067s00001_hw00001.svc: NRMSE = 0.0182
# u00067s00001_hw00002.svc: NRMSE = 0.0204
# u00067s00001_hw00003.svc: NRMSE = 0.0410
# u00067s00001_hw00004.svc: NRMSE = 0.0021
# u00067s00001_hw00005.svc: NRMSE = 0.0019
# u00067s00001_hw00006.svc: NRMSE = 0.0139
# u00067s00001_hw00007.svc: NRMSE = 0.0174
# u00068s00001_hw00001.svc: NRMSE = 0.0140
# u00068s00001_hw00002.svc: NRMSE = 0.0206
# u00068s00001_hw00003.svc: NRMSE = 0.0377
# u00068s00001_hw00004.svc: NRMSE = 0.0033
# u00068s00001_hw00005.svc: NRMSE = 0.0031
# u00068s00001_hw00006.svc: NRMSE = 0.0137
# u00068s00001_hw00007.svc: NRMSE = 0.0280
# u00069s00001_hw00001.svc: NRMSE = 0.0050
# u00069s00001_hw00002.svc: NRMSE = 0.0149
# u00069s00001_hw00003.svc: NRMSE = 0.0266
# u00069s00001_hw00004.svc: NRMSE = 0.0290
# u00069s00001_hw00005.svc: NRMSE = 0.0009
# u00069s00001_hw00006.svc: NRMSE = 0.0314
# u00069s00001_hw00007.svc: NRMSE = 0.0516
# u00070s00001_hw00001.svc: NRMSE = 0.0175
# u00070s00001_hw00002.svc: NRMSE = 0.0220
# u00070s00001_hw00003.svc: NRMSE = 0.0523
# u00070s00001_hw00004.svc: NRMSE = 0.0033
# u00070s00001_hw00005.svc: NRMSE = 0.0031
# u00070s00001_hw00006.svc: NRMSE = 0.0520
# u00070s00001_hw00007.svc: NRMSE = 0.0243
# u00071s00001_hw00001.svc: NRMSE = 0.0177
# u00071s00001_hw00002.svc: NRMSE = 0.0216
# u00071s00001_hw00003.svc: NRMSE = 0.0422
# u00071s00001_hw00004.svc: NRMSE = 0.0016
# u00071s00001_hw00005.svc: NRMSE = 0.0014
# u00071s00001_hw00006.svc: NRMSE = 0.0296
# u00071s00001_hw00007.svc: NRMSE = 0.0230
# u00072s00001_hw00001.svc: NRMSE = 0.0108
# u00072s00001_hw00002.svc: NRMSE = 0.0177
# u00072s00001_hw00003.svc: NRMSE = 0.0356
# u00072s00001_hw00004.svc: NRMSE = 0.0023
# u00072s00001_hw00005.svc: NRMSE = 0.0014
# u00072s00001_hw00006.svc: NRMSE = 0.0186
# u00072s00001_hw00007.svc: NRMSE = 0.0302
# u00073s00001_hw00001.svc: NRMSE = 0.0036
# u00073s00001_hw00002.svc: NRMSE = 0.0130
# u00073s00001_hw00003.svc: NRMSE = 0.0294
# u00073s00001_hw00004.svc: NRMSE = 0.0018
# u00073s00001_hw00005.svc: NRMSE = 0.0014
# u00073s00001_hw00006.svc: NRMSE = 0.0506
# u00073s00001_hw00007.svc: NRMSE = 0.0233
# u00074s00001_hw00001.svc: NRMSE = 0.0222
# u00074s00001_hw00002.svc: NRMSE = 0.0190
# u00074s00001_hw00003.svc: NRMSE = 0.0292
# u00074s00001_hw00004.svc: NRMSE = 0.0151
# u00074s00001_hw00005.svc: NRMSE = 0.0016
# u00074s00001_hw00006.svc: NRMSE = 0.0437
# u00074s00001_hw00007.svc: NRMSE = 0.0421
# u00075s00001_hw00001.svc: NRMSE = 0.0076
# u00075s00001_hw00002.svc: NRMSE = 0.0119
# u00075s00001_hw00003.svc: NRMSE = 0.0293
# u00075s00001_hw00004.svc: NRMSE = 0.0139
# u00075s00001_hw00005.svc: NRMSE = 0.0019
# u00075s00001_hw00006.svc: NRMSE = 0.0242
# u00075s00001_hw00007.svc: NRMSE = 0.0319
# u00076s00001_hw00001.svc: NRMSE = 0.0196
# u00076s00001_hw00002.svc: NRMSE = 0.0276
# u00076s00001_hw00003.svc: NRMSE = 0.0379
# u00076s00001_hw00004.svc: NRMSE = 0.0027
# u00076s00001_hw00005.svc: NRMSE = 0.0029
# u00076s00001_hw00006.svc: NRMSE = 0.0585
# u00076s00001_hw00007.svc: NRMSE = 0.0170
# u00077s00001_hw00001.svc: NRMSE = 0.0142
# u00077s00001_hw00002.svc: NRMSE = 0.0209
# u00077s00001_hw00003.svc: NRMSE = 0.0360
# u00077s00001_hw00004.svc: NRMSE = 0.0027
# u00077s00001_hw00005.svc: NRMSE = 0.0024
# u00077s00001_hw00006.svc: NRMSE = 0.0269
# u00077s00001_hw00007.svc: NRMSE = 0.0243
# u00078s00001_hw00001.svc: NRMSE = 0.0124
# u00078s00001_hw00002.svc: NRMSE = 0.0204
# u00078s00001_hw00003.svc: NRMSE = 0.0658
# u00078s00001_hw00004.svc: NRMSE = 0.0037
# u00078s00001_hw00005.svc: NRMSE = 0.0041
# u00078s00001_hw00006.svc: NRMSE = 0.0218
# u00078s00001_hw00007.svc: NRMSE = 0.0148
# u00079s00001_hw00001.svc: NRMSE = 0.0056
# u00079s00001_hw00002.svc: NRMSE = 0.0176
# u00079s00001_hw00003.svc: NRMSE = 0.0560
# u00079s00001_hw00004.svc: NRMSE = 0.0019
# u00079s00001_hw00005.svc: NRMSE = 0.0020
# u00079s00001_hw00006.svc: NRMSE = 0.0263
# u00079s00001_hw00007.svc: NRMSE = 0.0271
# u00080s00001_hw00001.svc: NRMSE = 0.0285
# u00080s00001_hw00002.svc: NRMSE = 0.0236
# u00080s00001_hw00003.svc: NRMSE = 0.0476
# u00080s00001_hw00004.svc: NRMSE = 0.0030
# u00080s00001_hw00005.svc: NRMSE = 0.0031
# u00080s00001_hw00006.svc: NRMSE = 0.0451
# u00080s00001_hw00007.svc: NRMSE = 0.0270
# u00081s00001_hw00001.svc: NRMSE = 0.0166
# u00081s00001_hw00002.svc: NRMSE = 0.0175
# u00081s00001_hw00003.svc: NRMSE = 0.0282
# u00081s00001_hw00004.svc: NRMSE = 0.0116
# u00081s00001_hw00005.svc: NRMSE = 0.0031
# u00081s00001_hw00006.svc: NRMSE = 0.0273
# u00081s00001_hw00007.svc: NRMSE = 0.0176
# u00082s00001_hw00001.svc: NRMSE = 0.0099
# u00082s00001_hw00002.svc: NRMSE = 0.0133
# u00082s00001_hw00003.svc: NRMSE = 0.0479
# u00082s00001_hw00004.svc: NRMSE = 0.0023
# u00082s00001_hw00005.svc: NRMSE = 0.0031
# u00082s00001_hw00006.svc: NRMSE = 0.0307
# u00082s00001_hw00007.svc: NRMSE = 0.0834
# u00083s00001_hw00001.svc: NRMSE = 0.0526
# u00083s00001_hw00002.svc: NRMSE = 0.0335
# u00083s00001_hw00003.svc: NRMSE = 0.0563
# u00083s00001_hw00004.svc: NRMSE = 0.0031
# u00083s00001_hw00005.svc: NRMSE = 0.0031
# u00083s00001_hw00006.svc: NRMSE = 0.0467
# u00083s00001_hw00007.svc: NRMSE = 0.0354
# u00084s00001_hw00001.svc: NRMSE = 0.0049
# u00084s00001_hw00002.svc: NRMSE = 0.0224
# u00084s00001_hw00003.svc: NRMSE = 0.0450
# u00084s00001_hw00004.svc: NRMSE = 0.0022
# u00084s00001_hw00005.svc: NRMSE = 0.0021
# u00084s00001_hw00006.svc: NRMSE = 0.0263
# u00084s00001_hw00007.svc: NRMSE = 0.0628
#
# Overall Average NRMSE: 0.0189, Standard Deviation: 0.0169

# %%
import os
from glob import glob
import numpy as np
import logging
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Configure logging
log_filename = "posthoc_discriminative_score.txt"
logging.basicConfig(
    level=logging.INFO,
    format="%(message)s",
    handlers=[
        logging.FileHandler(log_filename, mode="w", encoding="utf-8"),
        logging.StreamHandler()
    ]
)

def process_files(original_folder, augmented_folder, input_filenames):
    all_real_data = []
    all_synthetic_data = []
    input_filenames_set = {os.path.splitext(os.path.basename(filename))[0] for filename in input_filenames}
    
    for original_file in glob(os.path.join(original_folder, "*.svc")):
        base_name = os.path.splitext(os.path.basename(original_file))[0]
        
        if base_name not in input_filenames_set:
            continue
        
        original_data = read_svc_file(original_file)
        all_real_data.append(original_data.values)
        
        matching_augmented_files = get_matching_augmented_files(original_file, augmented_folder)
        
        for augmented_file in matching_augmented_files:
            augmented_data = read_svc_file(augmented_file)
            all_synthetic_data.append(augmented_data.values)
    
    return np.concatenate(all_real_data), np.concatenate(all_synthetic_data)

def create_lstm_classifier(input_shape):
    model = Sequential([
        LSTM(64, input_shape=input_shape, return_sequences=True),
        LSTM(32),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def prepare_data_for_lstm(real_data, synthetic_data):
    n_features = min(real_data.shape[1], synthetic_data.shape[1])
    real_data_trimmed = real_data[:, :n_features]
    synthetic_data_trimmed = synthetic_data[:, :n_features]
    
    X = np.vstack((real_data_trimmed, synthetic_data_trimmed))
    y = np.concatenate((np.ones(len(real_data)), np.zeros(len(synthetic_data))))
    return X, y

def post_hoc_discriminative_score(real_data, synthetic_data, n_splits=10):
    X, y = prepare_data_for_lstm(real_data, synthetic_data)
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    
    for fold, (train_index, test_index) in enumerate(kf.split(X), start=1):
        logging.info(f"\nFold {fold}/{n_splits}:")
        
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
        X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
        
        model = create_lstm_classifier((1, X_train.shape[2]))
        
        # Train model and log epoch progress
        history = model.fit(X_train, y_train, epochs=5, batch_size=512, verbose=0)
        for epoch, metrics in enumerate(history.history["accuracy"], start=1):
            logging.info(f"  Epoch {epoch}: Accuracy = {metrics:.4f}")
        
        y_pred = (model.predict(X_test) > 0.5).astype(int)
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
    
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    logging.info(f"\nMean accuracy: {mean_accuracy:.4f}, Standard Deviation: {std_accuracy:.4f}")
    return mean_accuracy, std_accuracy

# Specify your folders
original_folder = "imputed"
augmented_folder = "../../all_datasets/timegan_augmented" #Directory ng augmented data


# Process files
real_data, synthetic_data = process_files(original_folder, augmented_folder, input_filenames)

# Compute post-hoc discriminative score
mean_accuracy, std_accuracy = post_hoc_discriminative_score(real_data, synthetic_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 97
#      93 augmented_folder = "../../all_datasets/vrnngan_augmented"
#      96 # Process files
# ---> 97 real_data, synthetic_data = process_files(original_folder, augmented_folder, input_filenames)
#      99 # Compute post-hoc discriminative score
#     100 mean_accuracy, std_accuracy = post_hoc_discriminative_score(real_data, synthetic_data)
#
# Cell In[5], line 35, in process_files(original_folder, augmented_folder, input_filenames)
#      32 original_data = read_svc_file(original_file)
#      33 all_real_data.append(original_data.values)
# ---> 35 matching_augmented_files = get_matching_augmented_files(original_file, augmented_folder)
#      37 for augmented_file in matching_augmented_files:
#      38     augmented_data = read_svc_file(augmented_file)
#
# Cell In[4], line 23, in get_matching_augmented_files(original_file, augmented_folder)
#      21 base_name_without_ext = os.path.splitext(base_name)[0]
#      22 pattern = os.path.join(augmented_folder, f"synthetic_{base_name_without_ext}*.svc")
# ---> 23 matching_files = glob(pattern)
#      25 def sort_key(filename):
#      26     match = re.search(r'\((\d+)\)', filename)
#
# File c:\Program Files\Python312\Lib\glob.py:28, in glob(pathname, root_dir, dir_fd, recursive, include_hidden)
#      13 def glob(pathname, *, root_dir=None, dir_fd=None, recursive=False,
#      14         include_hidden=False):
#      15     """Return a list of paths matching a pathname pattern.
#      16
#      17     The pattern may contain simple shell-style wildcards a la
#    (...)
#      26     zero or more directories and subdirectories.
#      27     """
# ---> 28     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive,
#      29                       include_hidden=include_hidden))
#
# File c:\Program Files\Python312\Lib\glob.py:97, in _iglob(pathname, root_dir, dir_fd, recursive, dironly, include_hidden)
#      95     glob_in_dir = _glob0
#      96 for dirname in dirs:
# ---> 97     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly,
#      98                            include_hidden=include_hidden):
#      99         yield os.path.join(dirname, name)
#
# File c:\Program Files\Python312\Lib\glob.py:106, in _glob1(dirname, pattern, dir_fd, dironly, include_hidden)
#     105 def _glob1(dirname, pattern, dir_fd, dironly, include_hidden=False):
# --> 106     names = _listdir(dirname, dir_fd, dironly)
#     107     if include_hidden or not _ishidden(pattern):
#     108         names = (x for x in names if include_hidden or not _ishidden(x))
#
# File c:\Program Files\Python312\Lib\glob.py:178, in _listdir(dirname, dir_fd, dironly)
#     176 def _listdir(dirname, dir_fd, dironly):
#     177     with contextlib.closing(_iterdir(dirname, dir_fd, dironly)) as it:
# --> 178         return list(it)
#
# File c:\Program Files\Python312\Lib\glob.py:167, in _iterdir(dirname, dir_fd, dironly)
#     165             yield fsencode(entry.name)
#     166         else:
# --> 167             yield entry.name
#     168 except OSError:
#     169     pass
#
# KeyboardInterrupt:

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor
from glob import glob
import os
import time

def write_to_log(message):
    """Write a message to the log file."""
    log_file = "posthoc_predictive_score.txt"
    with open(log_file, "a") as f:
        f.write(message + "\n")

def read_svc_file(file_path):
    """Read an SVC file and return its contents as a DataFrame."""
    try:
        df = pd.read_csv(file_path, sep=' ', header=None)
        if df.empty:
            return None
        return df
    except Exception as e:
        return None

def get_matching_augmented_file(original_file, augmented_folder):
    """Get matching augmented file for a given original file."""
    base_name = os.path.splitext(os.path.basename(original_file))[0]
    augmented_file = os.path.join(augmented_folder, f"synthetic_{base_name}.svc")
    return augmented_file if os.path.exists(augmented_file) else None

def process_files(original_folder, augmented_folder):
    """Process original and augmented files and prepare them for analysis."""
    paired_data = []
    for original_file in glob(os.path.join(original_folder, "*.svc")):
        augmented_file = get_matching_augmented_file(original_file, augmented_folder)
        if augmented_file is None:
            continue
            
        original_data = read_svc_file(original_file)
        augmented_data = read_svc_file(augmented_file)
        
        if (original_data is not None and augmented_data is not None and 
            original_data.shape[1] == augmented_data.shape[1]):
            paired_data.append((original_file, augmented_file))

    if not paired_data:
        raise ValueError("No valid data pairs found for processing")
    return paired_data

def prepare_sequences(data, time_steps=4):
    """Prepare sequences for prediction, using all but last timestep as input."""
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps - 1].flatten())
        y.append(data[i + time_steps - 1])
    return np.array(X), np.array(y)

def evaluate_synthetic_data(original_file, synthetic_file):
    """Evaluate a single synthetic dataset against its original counterpart."""
    original_df = read_svc_file(original_file)
    synthetic_df = read_svc_file(synthetic_file)

    if original_df is None or synthetic_df is None:
        return None

    integer_columns = [0, 1, 4, 5]
    scaler = MinMaxScaler()
    original_scaled = scaler.fit_transform(original_df)
    synthetic_scaled = scaler.transform(synthetic_df)

    start_time = time.time()
    X_train, y_train = prepare_sequences(synthetic_scaled)
    X_test, y_test = prepare_sequences(original_scaled)

    if len(X_train) == 0 or len(X_test) == 0:
        return None

    mapes_per_dim = []
    for dim in range(y_train.shape[1]):
        model = XGBRegressor(
            n_estimators=100,
            learning_rate=0.1,
            max_depth=6,
            random_state=42
        )

        model.fit(X_train, y_train[:, dim], verbose=False)
        y_pred = model.predict(X_test)

        y_true_original = original_df.iloc[len(original_df)-len(y_test):, dim].values

        temp_data = np.zeros((len(y_pred), original_df.shape[1]))
        temp_data[:, dim] = y_pred
        y_pred_original = scaler.inverse_transform(temp_data)[:, dim]

        if dim in integer_columns:
            y_pred_original = np.round(y_pred_original)

        if dim == 3:
            y_pred_original = np.round(y_pred_original)

        y_pred_original = np.round(y_pred_original).astype(int)
        y_true_original = np.round(y_true_original).astype(int)

        errors = []
        for true, pred in zip(y_true_original, y_pred_original):
            if true == 0:
                errors.append(100 if pred != 0 else 0)
            else:
                errors.append(min(abs((true - pred) / true) * 100, 100))

        mapes_per_dim.append(np.mean(errors))

    elapsed_time = time.time() - start_time
    return np.mean(mapes_per_dim), elapsed_time

def post_hoc_predictive_score(original_folder, augmented_folder):
    """Calculate post-hoc predictive score for all pairs of original and synthetic data."""
    try:
        paired_files = process_files(original_folder, augmented_folder)
        all_results = []
        
        for original_file, synthetic_file in paired_files:
            result = evaluate_synthetic_data(original_file, synthetic_file)
            if result is not None:
                mape, elapsed_time = result
                file_name = os.path.basename(original_file)
                log_message = (f"Processing: {file_name} Completed in {elapsed_time:.1f}s "
                               f"(MAPE: {mape:.2f}%)")
                print(log_message)
                write_to_log(log_message)
                all_results.append(mape)
        
        if not all_results:
            raise ValueError("No valid results calculated")
        
        summary_message = (f"----------------------------------------\n"
                           f"Overall Results:\n"
                           f"Average MAPE: {np.mean(all_results):.2f}%, "
                           f"Standard Deviation: {np.std(all_results):.2f}%")
        print(summary_message)
        write_to_log(summary_message)
        
        return np.mean(all_results), np.std(all_results)
        
    except Exception as e:
        error_message = f"Error: {str(e)}"
        print(error_message)
        write_to_log(error_message)
        return None, None

def main():
    try:
        original_folder = "imputed"
        augmented_folder = "../../all_datasets/timegan_augmented" #Directory ng augmented data
        post_hoc_predictive_score(original_folder, augmented_folder) 
            
    except Exception as e:
        error_message = f"Error: {str(e)}"
        print(error_message)
        write_to_log(error_message)

if __name__ == "__main__":
    main()
# Out:
# Processing: collection1u00001s00001_hw00001.svc Completed in 2.6s (MAPE: 7.16%)
# Processing: collection1u00001s00001_hw00002.svc Completed in 4.1s (MAPE: 8.86%)
# ----------------------------------------
# Overall Results:
# Average MAPE: 8.01%, Standard Deviation: 0.85%
