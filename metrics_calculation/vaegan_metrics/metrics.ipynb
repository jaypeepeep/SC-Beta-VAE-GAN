# %%
# Cell 1
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import io
import os
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import random
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model
from keras.utils import custom_object_scope
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense

# %%
# Cell 2
# Updated function
# Updated function without saving data inside
def upload_and_process_files(directory, num_files_to_use=None):
    svc_files = [f for f in os.listdir(directory) if f.endswith('.svc')]
    
    # If num_files_to_use is specified, only take that many files sequentially
    if num_files_to_use:
        svc_files = svc_files[:num_files_to_use]  # Take the first num_files_to_use files

    data_frames = []  # Processed data after scaling
    original_data_frames = []  # Save the original unscaled data
    scalers = []
    input_filenames = []  # List to store input filenames

    num_files = len(svc_files)
    

    for i, filename in enumerate(svc_files):
        file_path = os.path.join(directory, filename)
        input_filenames.append(filename)  # Store the filename
        df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
        df.columns = ['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude']
        
        # Modify timestamp to start from 0
        df['timestamp'] = (df['timestamp'] - df['timestamp'].min()).round().astype(int)
        
        # Keep a copy of the original data before scaling
        original_data_frames.append(df.copy())  # Save the original unmodified data
        
        # Process the data for use in the model
        df = df.iloc[:, [0, 1, 2, 3, 4, 5, 6]] 
        data_frames.append(df)
        scaler = MinMaxScaler()
        normalized_data = scaler.fit_transform(df[['x', 'y', 'timestamp']])
        scalers.append(scaler)


    processed_data = [np.column_stack((scaler.transform(df[['x', 'y', 'timestamp']]), df['pen_status'].values)) 
                      for df, scaler in zip(data_frames, scalers)]
    avg_data_points = int(np.mean([df.shape[0] for df in data_frames]))

    return data_frames, processed_data, scalers, avg_data_points, input_filenames, original_data_frames  # Return original data

# Save data outside the function
def save_original_data(data_frames, input_filenames, output_folder='original_absolute'):
    os.makedirs(output_folder, exist_ok=True)
    for df, filename in zip(data_frames, input_filenames):
        save_path = os.path.join(output_folder, filename)
        df.to_csv(save_path, sep=' ', index=False, header=False)

directory = '../../all_datasets/emothaw'  # Directory where the .svc files are stored
num_files_to_use = 903
data_frames, processed_data, scalers, avg_data_points, input_filenames, original_data_frames = upload_and_process_files(directory, num_files_to_use)

# Save the original data after processing
save_original_data(original_data_frames, input_filenames)

# Store the name of the first file for use in Cell 4
input_filename = input_filenames[0] if input_filenames else 'processed_data'
print(f"Number of processed files: {len(processed_data)}")
print(f"Average number of data points: {avg_data_points}")
# Out:
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# ...
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_3440\615029028.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# Number of processed files: 903
# Average number of data points: 2939

# %%
from glob import glob
import os
import re
import numpy as np
import pandas as pd

def read_svc_file(file_path):
    return pd.read_csv(file_path, sep=' ', header=None, 
                       names=['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude'])

def calculate_nrmse(original, predicted):
    if original.shape != predicted.shape:
        raise ValueError("The shapes of the original and predicted datasets must match.")
    mse = np.mean((original - predicted) ** 2)
    rmse = np.sqrt(mse)
    nrmse = rmse / (np.max(original) - np.min(original))
    return nrmse

def get_matching_augmented_files(original_file, augmented_folder):
    base_name = os.path.basename(original_file)
    base_name_without_ext = os.path.splitext(base_name)[0]
    pattern = os.path.join(augmented_folder, f"synthetic_{base_name_without_ext}*.svc")
    matching_files = glob(pattern)
    
    def sort_key(filename):
        match = re.search(r'\((\d+)\)', filename)
        return int(match.group(1)) if match else -1

    return sorted(matching_files, key=sort_key)

def process_files(original_folder, augmented_folder, input_filenames):
    nrmse_results = {}

    input_filenames_set = {os.path.splitext(os.path.basename(filename))[0] for filename in input_filenames}

    for original_file in glob(os.path.join(original_folder, "*.svc")):
        base_name = os.path.splitext(os.path.basename(original_file))[0]
        
        if base_name not in input_filenames_set:
            continue

        original_data = read_svc_file(original_file)
        matching_augmented_files = get_matching_augmented_files(original_file, augmented_folder)
        
        file_nrmse = []
        for augmented_file in matching_augmented_files:
            augmented_data = read_svc_file(augmented_file)
            
            min_length = min(len(original_data), len(augmented_data))
            original_array = original_data.iloc[:min_length].values
            augmented_array = augmented_data.iloc[:min_length].values

            nrmse = calculate_nrmse(original_array, augmented_array)
            file_nrmse.append(nrmse)

        nrmse_results[os.path.basename(original_file)] = file_nrmse

    return nrmse_results

def save_results_to_log(results, output_path):
    with open(output_path, 'w') as log_file:
        for original_file, nrmse_values in results.items():
            avg_nrmse = None
            if len(nrmse_values) > 1:
                avg_nrmse = np.mean(nrmse_values)

            nrmse_values_str = ", ".join([f"{nrmse:.4f}" for nrmse in nrmse_values])
            log_line = f"{original_file}: NRMSE = {nrmse_values_str}"
            if avg_nrmse is not None:
                log_line += f", Avg NRMSE: {avg_nrmse:.4f}"

            log_file.write(log_line + '\n')
            print(log_line)

original_folder = "original_absolute"
augmented_folder = "../../all_datasets/vaegan_augmented" # Directory ng augmented data
output_log_file = "nrmse_results_log.txt"

# Process files and save results
results = process_files(original_folder, augmented_folder, input_filenames)
save_results_to_log(results, output_log_file)

# Calculate overall average NRMSE and standard deviation
all_nrmse_values = [nrmse for nrmse_list in results.values() for nrmse in nrmse_list]
overall_avg_nrmse = np.mean(all_nrmse_values) if all_nrmse_values else None
overall_std_nrmse = np.std(all_nrmse_values) if all_nrmse_values else None

# Print and save the overall average NRMSE and standard deviation
with open(output_log_file, 'a') as log_file:
    if overall_avg_nrmse is not None and overall_std_nrmse is not None:
        log_line = f"\nOverall Average NRMSE: {overall_avg_nrmse:.4f}, Standard Deviation: {overall_std_nrmse:.4f}"
    else:
        log_line = "No NRMSE values calculated."

    log_file.write(log_line + '\n')
    print(log_line)
# Out:
# collection1u00001s00001_hw00001.svc: NRMSE = 0.0126
# collection1u00001s00001_hw00002.svc: NRMSE = 0.0144
# collection1u00001s00001_hw00003.svc: NRMSE = 0.0507
# collection1u00001s00001_hw00004.svc: NRMSE = 0.0351
# collection1u00001s00001_hw00005.svc: NRMSE = 0.0269
# collection1u00001s00001_hw00006.svc: NRMSE = 0.0261
# collection1u00001s00001_hw00007.svc: NRMSE = 0.1026
# collection1u00002s00001_hw00001.svc: NRMSE = 0.0203
# collection1u00002s00001_hw00002.svc: NRMSE = 0.0201
# collection1u00002s00001_hw00003.svc: NRMSE = 0.0512
# collection1u00002s00001_hw00004.svc: NRMSE = 0.0162
# collection1u00002s00001_hw00005.svc: NRMSE = 0.0191
# collection1u00002s00001_hw00006.svc: NRMSE = 0.0241
# collection1u00002s00001_hw00007.svc: NRMSE = 0.0499
# collection1u00003s00001_hw00001.svc: NRMSE = 0.0227
# collection1u00003s00001_hw00002.svc: NRMSE = 0.0232
# collection1u00003s00001_hw00003.svc: NRMSE = 0.0550
# collection1u00003s00001_hw00004.svc: NRMSE = 0.0084
# collection1u00003s00001_hw00005.svc: NRMSE = 0.0087
# collection1u00003s00001_hw00006.svc: NRMSE = 0.0549
# collection1u00003s00001_hw00007.svc: NRMSE = 0.0783
# collection1u00004s00001_hw00001.svc: NRMSE = 0.0114
# collection1u00004s00001_hw00002.svc: NRMSE = 0.0097
# collection1u00004s00001_hw00003.svc: NRMSE = 0.0460
# collection1u00004s00001_hw00004.svc: NRMSE = 0.0155
# collection1u00004s00001_hw00005.svc: NRMSE = 0.0125
# collection1u00004s00001_hw00006.svc: NRMSE = 0.0139
# collection1u00004s00001_hw00007.svc: NRMSE = 0.0743
# collection1u00005s00001_hw00001.svc: NRMSE = 0.0227
# collection1u00005s00001_hw00002.svc: NRMSE = 0.0137
# collection1u00005s00001_hw00003.svc: NRMSE = 0.0597
# collection1u00005s00001_hw00004.svc: NRMSE = 0.0184
# collection1u00005s00001_hw00005.svc: NRMSE = 0.0162
# collection1u00005s00001_hw00006.svc: NRMSE = 0.0584
# collection1u00005s00001_hw00007.svc: NRMSE = 0.0905
# collection1u00006s00001_hw00001.svc: NRMSE = 0.0118
# collection1u00006s00001_hw00002.svc: NRMSE = 0.0096
# collection1u00006s00001_hw00003.svc: NRMSE = 0.0536
# collection1u00006s00001_hw00004.svc: NRMSE = 0.0055
# collection1u00006s00001_hw00005.svc: NRMSE = 0.0164
# collection1u00006s00001_hw00006.svc: NRMSE = 0.0218
# collection1u00006s00001_hw00007.svc: NRMSE = 0.1117
# collection1u00007s00001_hw00001.svc: NRMSE = 0.0366
# collection1u00007s00001_hw00002.svc: NRMSE = 0.0269
# collection1u00007s00001_hw00003.svc: NRMSE = 0.0450
# collection1u00007s00001_hw00004.svc: NRMSE = 0.0165
# collection1u00007s00001_hw00005.svc: NRMSE = 0.0223
# collection1u00007s00001_hw00006.svc: NRMSE = 0.0525
# collection1u00007s00001_hw00007.svc: NRMSE = 0.0548
# collection1u00008s00001_hw00001.svc: NRMSE = 0.0116
# collection1u00008s00001_hw00002.svc: NRMSE = 0.0159
# collection1u00008s00001_hw00003.svc: NRMSE = 0.0552
# collection1u00008s00001_hw00004.svc: NRMSE = 0.0077
# collection1u00008s00001_hw00005.svc: NRMSE = 0.0085
# collection1u00008s00001_hw00006.svc: NRMSE = 0.0169
# collection1u00008s00001_hw00007.svc: NRMSE = 0.0365
# collection1u00009s00001_hw00001.svc: NRMSE = 0.0085
# collection1u00009s00001_hw00002.svc: NRMSE = 0.0098
# collection1u00009s00001_hw00003.svc: NRMSE = 0.0501
# collection1u00009s00001_hw00004.svc: NRMSE = 0.0083
# collection1u00009s00001_hw00005.svc: NRMSE = 0.0072
# collection1u00009s00001_hw00006.svc: NRMSE = 0.0323
# collection1u00009s00001_hw00007.svc: NRMSE = 0.0982
# collection1u00010s00001_hw00001.svc: NRMSE = 0.0141
# collection1u00010s00001_hw00002.svc: NRMSE = 0.0209
# collection1u00010s00001_hw00003.svc: NRMSE = 0.0531
# collection1u00010s00001_hw00004.svc: NRMSE = 0.0119
# collection1u00010s00001_hw00005.svc: NRMSE = 0.0170
# collection1u00010s00001_hw00006.svc: NRMSE = 0.0369
# collection1u00010s00001_hw00007.svc: NRMSE = 0.1094
# collection1u00011s00001_hw00001.svc: NRMSE = 0.0188
# collection1u00011s00001_hw00002.svc: NRMSE = 0.0175
# collection1u00011s00001_hw00003.svc: NRMSE = 0.0523
# collection1u00011s00001_hw00004.svc: NRMSE = 0.0096
# collection1u00011s00001_hw00005.svc: NRMSE = 0.0122
# collection1u00011s00001_hw00006.svc: NRMSE = 0.0120
# collection1u00011s00001_hw00007.svc: NRMSE = 0.0382
# collection1u00012s00001_hw00001.svc: NRMSE = 0.0080
# collection1u00012s00001_hw00002.svc: NRMSE = 0.0107
# collection1u00012s00001_hw00003.svc: NRMSE = 0.0439
# collection1u00012s00001_hw00004.svc: NRMSE = 0.0050
# collection1u00012s00001_hw00005.svc: NRMSE = 0.0090
# collection1u00012s00001_hw00006.svc: NRMSE = 0.0128
# collection1u00012s00001_hw00007.svc: NRMSE = 0.0771
# collection1u00013s00001_hw00001.svc: NRMSE = 0.0062
# collection1u00013s00001_hw00002.svc: NRMSE = 0.0121
# collection1u00013s00001_hw00003.svc: NRMSE = 0.0456
# collection1u00013s00001_hw00004.svc: NRMSE = 0.0091
# collection1u00013s00001_hw00005.svc: NRMSE = 0.0103
# collection1u00013s00001_hw00006.svc: NRMSE = 0.0216
# collection1u00013s00001_hw00007.svc: NRMSE = 0.0143
# collection1u00014s00001_hw00001.svc: NRMSE = 0.0123
# collection1u00014s00001_hw00002.svc: NRMSE = 0.0127
# collection1u00014s00001_hw00003.svc: NRMSE = 0.0505
# collection1u00014s00001_hw00004.svc: NRMSE = 0.0141
# collection1u00014s00001_hw00005.svc: NRMSE = 0.0147
# collection1u00014s00001_hw00006.svc: NRMSE = 0.0130
# collection1u00014s00001_hw00007.svc: NRMSE = 0.0690
# collection1u00015s00001_hw00001.svc: NRMSE = 0.0162
# collection1u00015s00001_hw00002.svc: NRMSE = 0.0243
# collection1u00015s00001_hw00003.svc: NRMSE = 0.0216
# collection1u00015s00001_hw00004.svc: NRMSE = 0.0096
# collection1u00015s00001_hw00005.svc: NRMSE = 0.0064
# collection1u00015s00001_hw00006.svc: NRMSE = 0.0235
# collection1u00015s00001_hw00007.svc: NRMSE = 0.0310
# collection1u00016s00001_hw00001.svc: NRMSE = 0.0103
# collection1u00016s00001_hw00002.svc: NRMSE = 0.0185
# collection1u00016s00001_hw00003.svc: NRMSE = 0.0054
# collection1u00016s00001_hw00004.svc: NRMSE = 0.0217
# collection1u00016s00001_hw00005.svc: NRMSE = 0.0170
# collection1u00016s00001_hw00006.svc: NRMSE = 0.0166
# collection1u00016s00001_hw00007.svc: NRMSE = 0.0081
# collection1u00017s00001_hw00001.svc: NRMSE = 0.0159
# collection1u00017s00001_hw00002.svc: NRMSE = 0.0183
# collection1u00017s00001_hw00003.svc: NRMSE = 0.0300
# collection1u00017s00001_hw00004.svc: NRMSE = 0.0062
# collection1u00017s00001_hw00005.svc: NRMSE = 0.0099
# collection1u00017s00001_hw00006.svc: NRMSE = 0.0263
# collection1u00017s00001_hw00007.svc: NRMSE = 0.0168
# collection1u00018s00001_hw00001.svc: NRMSE = 0.0063
# collection1u00018s00001_hw00002.svc: NRMSE = 0.0233
# collection1u00018s00001_hw00003.svc: NRMSE = 0.0237
# collection1u00018s00001_hw00004.svc: NRMSE = 0.0303
# collection1u00018s00001_hw00005.svc: NRMSE = 0.0072
# collection1u00018s00001_hw00006.svc: NRMSE = 0.0336
# collection1u00018s00001_hw00007.svc: NRMSE = 0.0209
# collection1u00019s00001_hw00001.svc: NRMSE = 0.0267
# collection1u00019s00001_hw00002.svc: NRMSE = 0.0233
# collection1u00019s00001_hw00003.svc: NRMSE = 0.0654
# collection1u00019s00001_hw00004.svc: NRMSE = 0.0101
# collection1u00019s00001_hw00005.svc: NRMSE = 0.0077
# collection1u00019s00001_hw00006.svc: NRMSE = 0.0328
# collection1u00019s00001_hw00007.svc: NRMSE = 0.0138
# collection1u00020s00001_hw00001.svc: NRMSE = 0.0028
# collection1u00020s00001_hw00002.svc: NRMSE = 0.0131
# collection1u00020s00001_hw00003.svc: NRMSE = 0.0172
# collection1u00020s00001_hw00004.svc: NRMSE = 0.0084
# collection1u00020s00001_hw00005.svc: NRMSE = 0.0117
# collection1u00020s00001_hw00006.svc: NRMSE = 0.0248
# collection1u00020s00001_hw00007.svc: NRMSE = 0.0117
# collection1u00021s00001_hw00001.svc: NRMSE = 0.0139
# collection1u00021s00001_hw00002.svc: NRMSE = 0.0148
# collection1u00021s00001_hw00003.svc: NRMSE = 0.0261
# collection1u00021s00001_hw00004.svc: NRMSE = 0.0080
# collection1u00021s00001_hw00005.svc: NRMSE = 0.0072
# collection1u00021s00001_hw00006.svc: NRMSE = 0.0194
# collection1u00021s00001_hw00007.svc: NRMSE = 0.0132
# collection1u00022s00001_hw00001.svc: NRMSE = 0.0053
# collection1u00022s00001_hw00002.svc: NRMSE = 0.0167
# collection1u00022s00001_hw00003.svc: NRMSE = 0.0110
# collection1u00022s00001_hw00004.svc: NRMSE = 0.0061
# collection1u00022s00001_hw00005.svc: NRMSE = 0.0041
# collection1u00022s00001_hw00006.svc: NRMSE = 0.0101
# collection1u00022s00001_hw00007.svc: NRMSE = 0.0287
# collection1u00023s00001_hw00001.svc: NRMSE = 0.0040
# collection1u00023s00001_hw00002.svc: NRMSE = 0.0165
# collection1u00023s00001_hw00003.svc: NRMSE = 0.0103
# collection1u00023s00001_hw00004.svc: NRMSE = 0.0120
# collection1u00023s00001_hw00005.svc: NRMSE = 0.0097
# collection1u00023s00001_hw00006.svc: NRMSE = 0.0209
# collection1u00023s00001_hw00007.svc: NRMSE = 0.0167
# collection1u00024s00001_hw00001.svc: NRMSE = 0.0162
# collection1u00024s00001_hw00002.svc: NRMSE = 0.0343
# collection1u00024s00001_hw00003.svc: NRMSE = 0.0115
# collection1u00024s00001_hw00004.svc: NRMSE = 0.0073
# collection1u00024s00001_hw00005.svc: NRMSE = 0.0083
# collection1u00024s00001_hw00006.svc: NRMSE = 0.0323
# collection1u00024s00001_hw00007.svc: NRMSE = 0.0431
# collection1u00025s00001_hw00001.svc: NRMSE = 0.0046
# collection1u00025s00001_hw00002.svc: NRMSE = 0.0214
# collection1u00025s00001_hw00003.svc: NRMSE = 0.0204
# collection1u00025s00001_hw00004.svc: NRMSE = 0.0065
# collection1u00025s00001_hw00005.svc: NRMSE = 0.0098
# collection1u00025s00001_hw00006.svc: NRMSE = 0.0292
# collection1u00025s00001_hw00007.svc: NRMSE = 0.0098
# collection1u00026s00001_hw00001.svc: NRMSE = 0.0043
# collection1u00026s00001_hw00002.svc: NRMSE = 0.0091
# collection1u00026s00001_hw00003.svc: NRMSE = 0.0192
# collection1u00026s00001_hw00004.svc: NRMSE = 0.0146
# collection1u00026s00001_hw00005.svc: NRMSE = 0.0097
# collection1u00026s00001_hw00006.svc: NRMSE = 0.0181
# collection1u00026s00001_hw00007.svc: NRMSE = 0.0136
# collection1u00027s00001_hw00001.svc: NRMSE = 0.0034
# collection1u00027s00001_hw00002.svc: NRMSE = 0.0095
# collection1u00027s00001_hw00003.svc: NRMSE = 0.0231
# collection1u00027s00001_hw00004.svc: NRMSE = 0.0008
# collection1u00027s00001_hw00005.svc: NRMSE = 0.0021
# collection1u00027s00001_hw00006.svc: NRMSE = 0.0048
# collection1u00027s00001_hw00007.svc: NRMSE = 0.0129
# collection1u00028s00001_hw00001.svc: NRMSE = 0.0108
# collection1u00028s00001_hw00002.svc: NRMSE = 0.0209
# collection1u00028s00001_hw00003.svc: NRMSE = 0.0327
# collection1u00028s00001_hw00004.svc: NRMSE = 0.0113
# collection1u00028s00001_hw00005.svc: NRMSE = 0.0082
# collection1u00028s00001_hw00006.svc: NRMSE = 0.0322
# collection1u00028s00001_hw00007.svc: NRMSE = 0.0106
# collection1u00029s00001_hw00001.svc: NRMSE = 0.0055
# collection1u00029s00001_hw00002.svc: NRMSE = 0.0094
# collection1u00029s00001_hw00003.svc: NRMSE = 0.0153
# collection1u00029s00001_hw00004.svc: NRMSE = 0.0020
# collection1u00029s00001_hw00005.svc: NRMSE = 0.0006
# collection1u00029s00001_hw00006.svc: NRMSE = 0.0181
# collection1u00029s00001_hw00007.svc: NRMSE = 0.0090
# collection1u00030s00001_hw00001.svc: NRMSE = 0.0071
# collection1u00030s00001_hw00002.svc: NRMSE = 0.0132
# collection1u00030s00001_hw00003.svc: NRMSE = 0.0116
# collection1u00030s00001_hw00004.svc: NRMSE = 0.0005
# collection1u00030s00001_hw00005.svc: NRMSE = 0.0003
# collection1u00030s00001_hw00006.svc: NRMSE = 0.0072
# collection1u00030s00001_hw00007.svc: NRMSE = 0.0160
# collection1u00031s00001_hw00001.svc: NRMSE = 0.0113
# collection1u00031s00001_hw00002.svc: NRMSE = 0.0232
# collection1u00031s00001_hw00003.svc: NRMSE = 0.0252
# collection1u00031s00001_hw00004.svc: NRMSE = 0.0008
# collection1u00031s00001_hw00005.svc: NRMSE = 0.0008
# collection1u00031s00001_hw00006.svc: NRMSE = 0.0172
# collection1u00031s00001_hw00007.svc: NRMSE = 0.0128
# collection1u00032s00001_hw00001.svc: NRMSE = 0.0030
# collection1u00032s00001_hw00002.svc: NRMSE = 0.0060
# collection1u00032s00001_hw00003.svc: NRMSE = 0.0079
# collection1u00032s00001_hw00004.svc: NRMSE = 0.0116
# collection1u00032s00001_hw00005.svc: NRMSE = 0.0006
# collection1u00032s00001_hw00006.svc: NRMSE = 0.0054
# collection1u00032s00001_hw00007.svc: NRMSE = 0.0172
# collection1u00033s00001_hw00001.svc: NRMSE = 0.0033
# collection1u00033s00001_hw00002.svc: NRMSE = 0.0195
# collection1u00033s00001_hw00003.svc: NRMSE = 0.0326
# collection1u00033s00001_hw00004.svc: NRMSE = 0.0166
# collection1u00033s00001_hw00005.svc: NRMSE = 0.0004
# collection1u00033s00001_hw00006.svc: NRMSE = 0.0182
# collection1u00033s00001_hw00007.svc: NRMSE = 0.0435
# collection1u00034s00001_hw00001.svc: NRMSE = 0.0190
# collection1u00034s00001_hw00002.svc: NRMSE = 0.0076
# collection1u00034s00001_hw00003.svc: NRMSE = 0.0149
# collection1u00034s00001_hw00004.svc: NRMSE = 0.0005
# collection1u00034s00001_hw00005.svc: NRMSE = 0.0008
# collection1u00034s00001_hw00006.svc: NRMSE = 0.0304
# collection1u00034s00001_hw00007.svc: NRMSE = 0.0173
# collection1u00035s00001_hw00001.svc: NRMSE = 0.0008
# collection1u00035s00001_hw00002.svc: NRMSE = 0.0016
# collection1u00035s00001_hw00003.svc: NRMSE = 0.0097
# collection1u00035s00001_hw00004.svc: NRMSE = 0.0005
# collection1u00035s00001_hw00005.svc: NRMSE = 0.0005
# collection1u00035s00001_hw00006.svc: NRMSE = 0.0013
# collection1u00035s00001_hw00007.svc: NRMSE = 0.0298
# collection1u00036s00001_hw00001.svc: NRMSE = 0.0031
# collection1u00036s00001_hw00002.svc: NRMSE = 0.0124
# collection1u00036s00001_hw00003.svc: NRMSE = 0.0325
# collection1u00036s00001_hw00004.svc: NRMSE = 0.0006
# collection1u00036s00001_hw00005.svc: NRMSE = 0.0005
# collection1u00036s00001_hw00006.svc: NRMSE = 0.0221
# collection1u00036s00001_hw00007.svc: NRMSE = 0.0282
# collection1u00037s00001_hw00001.svc: NRMSE = 0.0038
# collection1u00037s00001_hw00002.svc: NRMSE = 0.0162
# collection1u00037s00001_hw00003.svc: NRMSE = 0.0133
# collection1u00037s00001_hw00004.svc: NRMSE = 0.0008
# collection1u00037s00001_hw00005.svc: NRMSE = 0.0007
# collection1u00037s00001_hw00006.svc: NRMSE = 0.0129
# collection1u00037s00001_hw00007.svc: NRMSE = 0.0094
# collection1u00038s00001_hw00001.svc: NRMSE = 0.0068
# collection1u00038s00001_hw00002.svc: NRMSE = 0.0284
# collection1u00038s00001_hw00003.svc: NRMSE = 0.0163
# collection1u00038s00001_hw00004.svc: NRMSE = 0.0008
# collection1u00038s00001_hw00005.svc: NRMSE = 0.0008
# collection1u00038s00001_hw00006.svc: NRMSE = 0.0101
# collection1u00038s00001_hw00007.svc: NRMSE = 0.0212
# collection1u00039s00001_hw00001.svc: NRMSE = 0.0026
# collection1u00039s00001_hw00002.svc: NRMSE = 0.0054
# collection1u00039s00001_hw00003.svc: NRMSE = 0.0096
# collection1u00039s00001_hw00004.svc: NRMSE = 0.0013
# collection1u00039s00001_hw00005.svc: NRMSE = 0.0012
# collection1u00039s00001_hw00006.svc: NRMSE = 0.0098
# collection1u00039s00001_hw00007.svc: NRMSE = 0.0171
# collection1u00040s00001_hw00001.svc: NRMSE = 0.0242
# collection1u00040s00001_hw00002.svc: NRMSE = 0.0261
# collection1u00040s00001_hw00003.svc: NRMSE = 0.0278
# collection1u00040s00001_hw00004.svc: NRMSE = 0.0012
# collection1u00040s00001_hw00005.svc: NRMSE = 0.0010
# collection1u00040s00001_hw00006.svc: NRMSE = 0.0429
# collection1u00040s00001_hw00007.svc: NRMSE = 0.0042
# collection1u00041s00001_hw00001.svc: NRMSE = 0.0040
# collection1u00041s00001_hw00002.svc: NRMSE = 0.0052
# collection1u00041s00001_hw00003.svc: NRMSE = 0.0050
# collection1u00041s00001_hw00004.svc: NRMSE = 0.0003
# collection1u00041s00001_hw00005.svc: NRMSE = 0.0004
# collection1u00041s00001_hw00006.svc: NRMSE = 0.1177
# collection1u00041s00001_hw00007.svc: NRMSE = 0.0164
# collection1u00042s00001_hw00001.svc: NRMSE = 0.0034
# collection1u00042s00001_hw00002.svc: NRMSE = 0.0094
# collection1u00042s00001_hw00003.svc: NRMSE = 0.0055
# collection1u00042s00001_hw00004.svc: NRMSE = 0.0003
# collection1u00042s00001_hw00005.svc: NRMSE = 0.0003
# collection1u00042s00001_hw00006.svc: NRMSE = 0.0011
# collection1u00042s00001_hw00007.svc: NRMSE = 0.0195
# collection1u00043s00001_hw00001.svc: NRMSE = 0.0032
# collection1u00043s00001_hw00002.svc: NRMSE = 0.0040
# collection1u00043s00001_hw00003.svc: NRMSE = 0.0659
# collection1u00043s00001_hw00004.svc: NRMSE = 0.0003
# collection1u00043s00001_hw00005.svc: NRMSE = 0.0004
# collection1u00043s00001_hw00006.svc: NRMSE = 0.0029
# collection1u00043s00001_hw00007.svc: NRMSE = 0.0846
# collection1u00044s00001_hw00001.svc: NRMSE = 0.0233
# collection1u00044s00001_hw00002.svc: NRMSE = 0.0321
# collection1u00044s00001_hw00003.svc: NRMSE = 0.0711
# collection1u00044s00001_hw00004.svc: NRMSE = 0.0121
# collection1u00044s00001_hw00005.svc: NRMSE = 0.0078
# collection1u00044s00001_hw00006.svc: NRMSE = 0.0406
# collection1u00044s00001_hw00007.svc: NRMSE = 0.0784
# collection1u00045s00001_hw00001.svc: NRMSE = 0.0286
# collection1u00045s00001_hw00002.svc: NRMSE = 0.0169
# collection1u00045s00001_hw00003.svc: NRMSE = 0.0622
# collection1u00045s00001_hw00004.svc: NRMSE = 0.0074
# collection1u00045s00001_hw00005.svc: NRMSE = 0.0065
# collection1u00045s00001_hw00006.svc: NRMSE = 0.0227
# collection1u00045s00001_hw00007.svc: NRMSE = 0.1660
# u00001s00001_hw00001.svc: NRMSE = 0.0240
# u00001s00001_hw00002.svc: NRMSE = 0.0305
# u00001s00001_hw00003.svc: NRMSE = 0.0906
# u00001s00001_hw00004.svc: NRMSE = 0.0157
# u00001s00001_hw00005.svc: NRMSE = 0.0101
# u00001s00001_hw00006.svc: NRMSE = 0.0209
# u00001s00001_hw00007.svc: NRMSE = 0.1262
# u00002s00001_hw00001.svc: NRMSE = 0.0171
# u00002s00001_hw00002.svc: NRMSE = 0.0282
# u00002s00001_hw00003.svc: NRMSE = 0.0836
# u00002s00001_hw00004.svc: NRMSE = 0.0304
# u00002s00001_hw00005.svc: NRMSE = 0.0237
# u00002s00001_hw00006.svc: NRMSE = 0.0335
# u00002s00001_hw00007.svc: NRMSE = 0.0916
# u00003s00001_hw00001.svc: NRMSE = 0.0233
# u00003s00001_hw00002.svc: NRMSE = 0.0233
# u00003s00001_hw00003.svc: NRMSE = 0.1076
# u00003s00001_hw00004.svc: NRMSE = 0.0229
# u00003s00001_hw00005.svc: NRMSE = 0.0223
# u00003s00001_hw00006.svc: NRMSE = 0.0466
# u00003s00001_hw00007.svc: NRMSE = 0.0884
# u00004s00001_hw00001.svc: NRMSE = 0.0231
# u00004s00001_hw00002.svc: NRMSE = 0.0359
# u00004s00001_hw00003.svc: NRMSE = 0.1025
# u00004s00001_hw00004.svc: NRMSE = 0.0213
# u00004s00001_hw00005.svc: NRMSE = 0.0179
# u00004s00001_hw00006.svc: NRMSE = 0.0325
# u00004s00001_hw00007.svc: NRMSE = 0.0956
# u00005s00001_hw00001.svc: NRMSE = 0.0246
# u00005s00001_hw00002.svc: NRMSE = 0.0272
# u00005s00001_hw00003.svc: NRMSE = 0.0910
# u00005s00001_hw00004.svc: NRMSE = 0.0177
# u00005s00001_hw00005.svc: NRMSE = 0.0140
# u00005s00001_hw00006.svc: NRMSE = 0.0626
# u00005s00001_hw00007.svc: NRMSE = 0.0892
# u00006s00001_hw00001.svc: NRMSE = 0.0240
# u00006s00001_hw00002.svc: NRMSE = 0.0372
# u00006s00001_hw00003.svc: NRMSE = 0.0715
# u00006s00001_hw00004.svc: NRMSE = 0.0200
# u00006s00001_hw00005.svc: NRMSE = 0.0201
# u00006s00001_hw00006.svc: NRMSE = 0.0521
# u00006s00001_hw00007.svc: NRMSE = 0.0937
# u00007s00001_hw00001.svc: NRMSE = 0.0305
# u00007s00001_hw00002.svc: NRMSE = 0.0222
# u00007s00001_hw00003.svc: NRMSE = 0.0908
# u00007s00001_hw00004.svc: NRMSE = 0.0121
# u00007s00001_hw00005.svc: NRMSE = 0.0147
# u00007s00001_hw00006.svc: NRMSE = 0.0276
# u00007s00001_hw00007.svc: NRMSE = 0.1096
# u00008s00001_hw00001.svc: NRMSE = 0.0310
# u00008s00001_hw00002.svc: NRMSE = 0.0497
# u00008s00001_hw00003.svc: NRMSE = 0.0840
# u00008s00001_hw00004.svc: NRMSE = 0.0313
# u00008s00001_hw00005.svc: NRMSE = 0.0278
# u00008s00001_hw00006.svc: NRMSE = 0.0469
# u00008s00001_hw00007.svc: NRMSE = 0.0874
# u00009s00001_hw00001.svc: NRMSE = 0.0332
# u00009s00001_hw00002.svc: NRMSE = 0.0289
# u00009s00001_hw00003.svc: NRMSE = 0.0727
# u00009s00001_hw00004.svc: NRMSE = 0.0216
# u00009s00001_hw00005.svc: NRMSE = 0.0197
# u00009s00001_hw00006.svc: NRMSE = 0.0281
# u00009s00001_hw00007.svc: NRMSE = 0.0648
# u00010s00001_hw00001.svc: NRMSE = 0.0263
# u00010s00001_hw00002.svc: NRMSE = 0.0312
# u00010s00001_hw00003.svc: NRMSE = 0.0619
# u00010s00001_hw00004.svc: NRMSE = 0.0206
# u00010s00001_hw00005.svc: NRMSE = 0.0192
# u00010s00001_hw00006.svc: NRMSE = 0.0449
# u00010s00001_hw00007.svc: NRMSE = 0.0981
# u00011s00001_hw00001.svc: NRMSE = 0.0317
# u00011s00001_hw00002.svc: NRMSE = 0.0377
# u00011s00001_hw00003.svc: NRMSE = 0.0782
# u00011s00001_hw00004.svc: NRMSE = 0.0249
# u00011s00001_hw00005.svc: NRMSE = 0.0251
# u00011s00001_hw00006.svc: NRMSE = 0.0428
# u00011s00001_hw00007.svc: NRMSE = 0.0833
# u00012s00001_hw00001.svc: NRMSE = 0.0301
# u00012s00001_hw00002.svc: NRMSE = 0.0204
# u00012s00001_hw00003.svc: NRMSE = 0.0828
# u00012s00001_hw00004.svc: NRMSE = 0.0223
# u00012s00001_hw00005.svc: NRMSE = 0.0227
# u00012s00001_hw00006.svc: NRMSE = 0.0372
# u00012s00001_hw00007.svc: NRMSE = 0.1237
# u00013s00001_hw00001.svc: NRMSE = 0.0209
# u00013s00001_hw00002.svc: NRMSE = 0.0148
# u00013s00001_hw00003.svc: NRMSE = 0.0532
# u00013s00001_hw00004.svc: NRMSE = 0.0108
# u00013s00001_hw00005.svc: NRMSE = 0.0116
# u00013s00001_hw00006.svc: NRMSE = 0.0233
# u00013s00001_hw00007.svc: NRMSE = 0.0685
# u00014s00001_hw00001.svc: NRMSE = 0.0205
# u00014s00001_hw00002.svc: NRMSE = 0.0266
# u00014s00001_hw00003.svc: NRMSE = 0.0668
# u00014s00001_hw00004.svc: NRMSE = 0.0151
# u00014s00001_hw00005.svc: NRMSE = 0.0106
# u00014s00001_hw00006.svc: NRMSE = 0.0368
# u00014s00001_hw00007.svc: NRMSE = 0.1035
# u00015s00001_hw00001.svc: NRMSE = 0.0186
# u00015s00001_hw00002.svc: NRMSE = 0.0200
# u00015s00001_hw00003.svc: NRMSE = 0.0674
# u00015s00001_hw00004.svc: NRMSE = 0.0157
# u00015s00001_hw00005.svc: NRMSE = 0.0209
# u00015s00001_hw00006.svc: NRMSE = 0.0725
# u00015s00001_hw00007.svc: NRMSE = 0.0785
# u00016s00001_hw00001.svc: NRMSE = 0.0243
# u00016s00001_hw00002.svc: NRMSE = 0.0357
# u00016s00001_hw00003.svc: NRMSE = 0.0624
# u00016s00001_hw00004.svc: NRMSE = 0.0105
# u00016s00001_hw00005.svc: NRMSE = 0.0104
# u00016s00001_hw00006.svc: NRMSE = 0.0320
# u00016s00001_hw00007.svc: NRMSE = 0.1169
# u00017s00001_hw00001.svc: NRMSE = 0.0296
# u00017s00001_hw00002.svc: NRMSE = 0.0336
# u00017s00001_hw00003.svc: NRMSE = 0.0768
# u00017s00001_hw00004.svc: NRMSE = 0.0094
# u00017s00001_hw00005.svc: NRMSE = 0.0088
# u00017s00001_hw00006.svc: NRMSE = 0.0448
# u00017s00001_hw00007.svc: NRMSE = 0.0866
# u00018s00001_hw00001.svc: NRMSE = 0.0223
# u00018s00001_hw00002.svc: NRMSE = 0.0195
# u00018s00001_hw00003.svc: NRMSE = 0.0658
# u00018s00001_hw00004.svc: NRMSE = 0.0106
# u00018s00001_hw00005.svc: NRMSE = 0.0119
# u00018s00001_hw00006.svc: NRMSE = 0.0303
# u00018s00001_hw00007.svc: NRMSE = 0.0897
# u00019s00001_hw00001.svc: NRMSE = 0.0212
# u00019s00001_hw00002.svc: NRMSE = 0.0273
# u00019s00001_hw00003.svc: NRMSE = 0.0690
# u00019s00001_hw00004.svc: NRMSE = 0.0086
# u00019s00001_hw00005.svc: NRMSE = 0.0108
# u00019s00001_hw00006.svc: NRMSE = 0.0489
# u00019s00001_hw00007.svc: NRMSE = 0.1028
# u00020s00001_hw00001.svc: NRMSE = 0.0218
# u00020s00001_hw00002.svc: NRMSE = 0.0197
# u00020s00001_hw00003.svc: NRMSE = 0.0780
# u00020s00001_hw00004.svc: NRMSE = 0.0163
# u00020s00001_hw00005.svc: NRMSE = 0.0078
# u00020s00001_hw00006.svc: NRMSE = 0.0393
# u00020s00001_hw00007.svc: NRMSE = 0.0858
# u00021s00001_hw00001.svc: NRMSE = 0.0270
# u00021s00001_hw00002.svc: NRMSE = 0.0181
# u00021s00001_hw00003.svc: NRMSE = 0.0724
# u00021s00001_hw00004.svc: NRMSE = 0.0164
# u00021s00001_hw00005.svc: NRMSE = 0.0200
# u00021s00001_hw00006.svc: NRMSE = 0.0224
# u00021s00001_hw00007.svc: NRMSE = 0.1043
# u00022s00001_hw00001.svc: NRMSE = 0.0270
# u00022s00001_hw00002.svc: NRMSE = 0.0490
# u00022s00001_hw00003.svc: NRMSE = 0.0646
# u00022s00001_hw00004.svc: NRMSE = 0.0178
# u00022s00001_hw00005.svc: NRMSE = 0.0172
# u00022s00001_hw00006.svc: NRMSE = 0.0618
# u00022s00001_hw00007.svc: NRMSE = 0.0921
# u00023s00001_hw00001.svc: NRMSE = 0.0194
# u00023s00001_hw00002.svc: NRMSE = 0.0168
# u00023s00001_hw00003.svc: NRMSE = 0.0568
# u00023s00001_hw00004.svc: NRMSE = 0.0139
# u00023s00001_hw00005.svc: NRMSE = 0.0134
# u00023s00001_hw00006.svc: NRMSE = 0.0289
# u00023s00001_hw00007.svc: NRMSE = 0.0988
# u00024s00001_hw00001.svc: NRMSE = 0.0228
# u00024s00001_hw00002.svc: NRMSE = 0.0191
# u00024s00001_hw00003.svc: NRMSE = 0.0594
# u00024s00001_hw00004.svc: NRMSE = 0.0095
# u00024s00001_hw00005.svc: NRMSE = 0.0094
# u00024s00001_hw00006.svc: NRMSE = 0.0449
# u00024s00001_hw00007.svc: NRMSE = 0.1453
# u00025s00001_hw00001.svc: NRMSE = 0.0178
# u00025s00001_hw00002.svc: NRMSE = 0.0351
# u00025s00001_hw00003.svc: NRMSE = 0.0605
# u00025s00001_hw00004.svc: NRMSE = 0.0080
# u00025s00001_hw00005.svc: NRMSE = 0.0088
# u00025s00001_hw00006.svc: NRMSE = 0.0376
# u00025s00001_hw00007.svc: NRMSE = 0.0751
# u00026s00001_hw00001.svc: NRMSE = 0.0127
# u00026s00001_hw00002.svc: NRMSE = 0.0174
# u00026s00001_hw00003.svc: NRMSE = 0.0690
# u00026s00001_hw00004.svc: NRMSE = 0.0108
# u00026s00001_hw00005.svc: NRMSE = 0.0124
# u00026s00001_hw00006.svc: NRMSE = 0.0250
# u00026s00001_hw00007.svc: NRMSE = 0.1144
# u00027s00001_hw00001.svc: NRMSE = 0.0239
# u00027s00001_hw00002.svc: NRMSE = 0.0522
# u00027s00001_hw00003.svc: NRMSE = 0.0709
# u00027s00001_hw00004.svc: NRMSE = 0.0259
# u00027s00001_hw00005.svc: NRMSE = 0.0242
# u00027s00001_hw00006.svc: NRMSE = 0.0500
# u00027s00001_hw00007.svc: NRMSE = 0.0717
# u00028s00001_hw00001.svc: NRMSE = 0.0367
# u00028s00001_hw00002.svc: NRMSE = 0.0375
# u00028s00001_hw00003.svc: NRMSE = 0.0479
# u00028s00001_hw00004.svc: NRMSE = 0.0174
# u00028s00001_hw00005.svc: NRMSE = 0.0172
# u00028s00001_hw00006.svc: NRMSE = 0.0756
# u00028s00001_hw00007.svc: NRMSE = 0.0625
# u00029s00001_hw00001.svc: NRMSE = 0.0126
# u00029s00001_hw00002.svc: NRMSE = 0.0448
# u00029s00001_hw00003.svc: NRMSE = 0.0364
# u00029s00001_hw00004.svc: NRMSE = 0.0150
# u00029s00001_hw00005.svc: NRMSE = 0.0177
# u00029s00001_hw00006.svc: NRMSE = 0.0409
# u00029s00001_hw00007.svc: NRMSE = 0.0065
# u00030s00001_hw00001.svc: NRMSE = 0.0269
# u00030s00001_hw00002.svc: NRMSE = 0.0481
# u00030s00001_hw00003.svc: NRMSE = 0.0279
# u00030s00001_hw00004.svc: NRMSE = 0.0117
# u00030s00001_hw00005.svc: NRMSE = 0.0180
# u00030s00001_hw00006.svc: NRMSE = 0.0634
# u00030s00001_hw00007.svc: NRMSE = 0.0225
# u00031s00001_hw00001.svc: NRMSE = 0.0157
# u00031s00001_hw00002.svc: NRMSE = 0.0348
# u00031s00001_hw00003.svc: NRMSE = 0.0516
# u00031s00001_hw00004.svc: NRMSE = 0.0321
# u00031s00001_hw00005.svc: NRMSE = 0.0342
# u00031s00001_hw00006.svc: NRMSE = 0.0389
# u00031s00001_hw00007.svc: NRMSE = 0.0174
# u00032s00001_hw00001.svc: NRMSE = 0.0390
# u00032s00001_hw00002.svc: NRMSE = 0.0214
# u00032s00001_hw00003.svc: NRMSE = 0.0434
# u00032s00001_hw00004.svc: NRMSE = 0.0295
# u00032s00001_hw00005.svc: NRMSE = 0.0205
# u00032s00001_hw00006.svc: NRMSE = 0.0420
# u00032s00001_hw00007.svc: NRMSE = 0.0437
# u00033s00001_hw00001.svc: NRMSE = 0.0161
# u00033s00001_hw00002.svc: NRMSE = 0.0467
# u00033s00001_hw00003.svc: NRMSE = 0.0298
# u00033s00001_hw00004.svc: NRMSE = 0.0013
# u00033s00001_hw00005.svc: NRMSE = 0.0165
# u00033s00001_hw00006.svc: NRMSE = 0.0661
# u00033s00001_hw00007.svc: NRMSE = 0.0088
# u00034s00001_hw00001.svc: NRMSE = 0.0121
# u00034s00001_hw00002.svc: NRMSE = 0.0238
# u00034s00001_hw00003.svc: NRMSE = 0.0318
# u00034s00001_hw00004.svc: NRMSE = 0.0141
# u00034s00001_hw00005.svc: NRMSE = 0.0129
# u00034s00001_hw00006.svc: NRMSE = 0.0239
# u00034s00001_hw00007.svc: NRMSE = 0.0175
# u00035s00001_hw00001.svc: NRMSE = 0.0120
# u00035s00001_hw00002.svc: NRMSE = 0.0231
# u00035s00001_hw00003.svc: NRMSE = 0.0366
# u00035s00001_hw00004.svc: NRMSE = 0.0160
# u00035s00001_hw00005.svc: NRMSE = 0.0174
# u00035s00001_hw00006.svc: NRMSE = 0.0535
# u00035s00001_hw00007.svc: NRMSE = 0.0306
# u00036s00001_hw00001.svc: NRMSE = 0.0115
# u00036s00001_hw00002.svc: NRMSE = 0.0184
# u00036s00001_hw00003.svc: NRMSE = 0.0164
# u00036s00001_hw00004.svc: NRMSE = 0.0164
# u00036s00001_hw00005.svc: NRMSE = 0.0192
# u00036s00001_hw00006.svc: NRMSE = 0.0475
# u00036s00001_hw00007.svc: NRMSE = 0.0238
# u00037s00001_hw00001.svc: NRMSE = 0.0091
# u00037s00001_hw00002.svc: NRMSE = 0.0272
# u00037s00001_hw00003.svc: NRMSE = 0.0529
# u00037s00001_hw00004.svc: NRMSE = 0.0185
# u00037s00001_hw00005.svc: NRMSE = 0.0158
# u00037s00001_hw00006.svc: NRMSE = 0.0656
# u00037s00001_hw00007.svc: NRMSE = 0.0442
# u00038s00001_hw00001.svc: NRMSE = 0.0113
# u00038s00001_hw00002.svc: NRMSE = 0.0107
# u00038s00001_hw00003.svc: NRMSE = 0.0826
# u00038s00001_hw00004.svc: NRMSE = 0.0107
# u00038s00001_hw00005.svc: NRMSE = 0.0097
# u00038s00001_hw00006.svc: NRMSE = 0.0235
# u00038s00001_hw00007.svc: NRMSE = 0.0117
# u00039s00001_hw00001.svc: NRMSE = 0.0081
# u00039s00001_hw00002.svc: NRMSE = 0.0225
# u00039s00001_hw00003.svc: NRMSE = 0.0349
# u00039s00001_hw00004.svc: NRMSE = 0.0249
# u00039s00001_hw00005.svc: NRMSE = 0.0212
# u00039s00001_hw00006.svc: NRMSE = 0.0402
# u00039s00001_hw00007.svc: NRMSE = 0.0108
# u00040s00001_hw00001.svc: NRMSE = 0.0093
# u00040s00001_hw00002.svc: NRMSE = 0.0148
# u00040s00001_hw00003.svc: NRMSE = 0.0464
# u00040s00001_hw00004.svc: NRMSE = 0.0175
# u00040s00001_hw00005.svc: NRMSE = 0.0175
# u00040s00001_hw00006.svc: NRMSE = 0.0193
# u00040s00001_hw00007.svc: NRMSE = 0.0052
# u00041s00001_hw00001.svc: NRMSE = 0.0299
# u00041s00001_hw00002.svc: NRMSE = 0.0329
# u00041s00001_hw00003.svc: NRMSE = 0.0227
# u00041s00001_hw00004.svc: NRMSE = 0.0237
# u00041s00001_hw00005.svc: NRMSE = 0.0211
# u00041s00001_hw00006.svc: NRMSE = 0.0573
# u00041s00001_hw00007.svc: NRMSE = 0.0762
# u00042s00001_hw00001.svc: NRMSE = 0.0267
# u00042s00001_hw00002.svc: NRMSE = 0.0287
# u00042s00001_hw00003.svc: NRMSE = 0.0618
# u00042s00001_hw00004.svc: NRMSE = 0.0194
# u00042s00001_hw00005.svc: NRMSE = 0.0177
# u00042s00001_hw00006.svc: NRMSE = 0.0394
# u00042s00001_hw00007.svc: NRMSE = 0.0698
# u00043s00001_hw00001.svc: NRMSE = 0.0196
# u00043s00001_hw00002.svc: NRMSE = 0.0271
# u00043s00001_hw00003.svc: NRMSE = 0.0529
# u00043s00001_hw00004.svc: NRMSE = 0.0152
# u00043s00001_hw00005.svc: NRMSE = 0.0235
# u00043s00001_hw00006.svc: NRMSE = 0.0450
# u00043s00001_hw00007.svc: NRMSE = 0.0888
# u00044s00001_hw00001.svc: NRMSE = 0.0306
# u00044s00001_hw00002.svc: NRMSE = 0.0259
# u00044s00001_hw00003.svc: NRMSE = 0.0478
# u00044s00001_hw00004.svc: NRMSE = 0.0268
# u00044s00001_hw00005.svc: NRMSE = 0.0316
# u00044s00001_hw00006.svc: NRMSE = 0.0288
# u00044s00001_hw00007.svc: NRMSE = 0.0585
# u00045s00001_hw00001.svc: NRMSE = 0.0189
# u00045s00001_hw00002.svc: NRMSE = 0.0214
# u00045s00001_hw00003.svc: NRMSE = 0.0834
# u00045s00001_hw00004.svc: NRMSE = 0.0184
# u00045s00001_hw00005.svc: NRMSE = 0.0182
# u00045s00001_hw00006.svc: NRMSE = 0.0217
# u00045s00001_hw00007.svc: NRMSE = 0.0999
# u00046s00001_hw00001.svc: NRMSE = 0.0177
# u00046s00001_hw00002.svc: NRMSE = 0.0250
# u00046s00001_hw00003.svc: NRMSE = 0.0545
# u00046s00001_hw00004.svc: NRMSE = 0.0182
# u00046s00001_hw00005.svc: NRMSE = 0.0167
# u00046s00001_hw00006.svc: NRMSE = 0.0307
# u00046s00001_hw00007.svc: NRMSE = 0.0934
# u00047s00001_hw00001.svc: NRMSE = 0.0064
# u00047s00001_hw00002.svc: NRMSE = 0.0351
# u00047s00001_hw00003.svc: NRMSE = 0.0358
# u00047s00001_hw00004.svc: NRMSE = 0.0058
# u00047s00001_hw00005.svc: NRMSE = 0.0166
# u00047s00001_hw00006.svc: NRMSE = 0.0359
# u00047s00001_hw00007.svc: NRMSE = 0.1107
# u00048s00001_hw00001.svc: NRMSE = 0.0172
# u00048s00001_hw00002.svc: NRMSE = 0.0223
# u00048s00001_hw00003.svc: NRMSE = 0.0541
# u00048s00001_hw00004.svc: NRMSE = 0.0198
# u00048s00001_hw00005.svc: NRMSE = 0.0190
# u00048s00001_hw00006.svc: NRMSE = 0.0166
# u00048s00001_hw00007.svc: NRMSE = 0.0940
# u00049s00001_hw00001.svc: NRMSE = 0.0271
# u00049s00001_hw00002.svc: NRMSE = 0.0261
# u00049s00001_hw00003.svc: NRMSE = 0.0538
# u00049s00001_hw00004.svc: NRMSE = 0.0263
# u00049s00001_hw00005.svc: NRMSE = 0.0271
# u00049s00001_hw00006.svc: NRMSE = 0.0449
# u00049s00001_hw00007.svc: NRMSE = 0.0857
# u00050s00001_hw00001.svc: NRMSE = 0.0129
# u00050s00001_hw00002.svc: NRMSE = 0.0144
# u00050s00001_hw00003.svc: NRMSE = 0.0548
# u00050s00001_hw00004.svc: NRMSE = 0.0149
# u00050s00001_hw00005.svc: NRMSE = 0.0153
# u00050s00001_hw00006.svc: NRMSE = 0.0188
# u00050s00001_hw00007.svc: NRMSE = 0.0982
# u00051s00001_hw00001.svc: NRMSE = 0.0270
# u00051s00001_hw00002.svc: NRMSE = 0.0264
# u00051s00001_hw00003.svc: NRMSE = 0.0694
# u00051s00001_hw00004.svc: NRMSE = 0.0139
# u00051s00001_hw00005.svc: NRMSE = 0.0158
# u00051s00001_hw00006.svc: NRMSE = 0.0148
# u00051s00001_hw00007.svc: NRMSE = 0.0736
# u00052s00001_hw00001.svc: NRMSE = 0.0325
# u00052s00001_hw00002.svc: NRMSE = 0.0338
# u00052s00001_hw00003.svc: NRMSE = 0.0536
# u00052s00001_hw00004.svc: NRMSE = 0.0148
# u00052s00001_hw00005.svc: NRMSE = 0.0180
# u00052s00001_hw00006.svc: NRMSE = 0.0669
# u00052s00001_hw00007.svc: NRMSE = 0.0745
# u00053s00001_hw00001.svc: NRMSE = 0.0207
# u00053s00001_hw00002.svc: NRMSE = 0.0184
# u00053s00001_hw00003.svc: NRMSE = 0.0538
# u00053s00001_hw00004.svc: NRMSE = 0.0128
# u00053s00001_hw00005.svc: NRMSE = 0.0165
# u00053s00001_hw00006.svc: NRMSE = 0.0404
# u00053s00001_hw00007.svc: NRMSE = 0.1044
# u00054s00001_hw00001.svc: NRMSE = 0.0262
# u00054s00001_hw00002.svc: NRMSE = 0.0725
# u00054s00001_hw00003.svc: NRMSE = 0.0562
# u00054s00001_hw00004.svc: NRMSE = 0.0194
# u00054s00001_hw00005.svc: NRMSE = 0.0110
# u00054s00001_hw00006.svc: NRMSE = 0.0495
# u00054s00001_hw00007.svc: NRMSE = 0.1210
# u00055s00001_hw00001.svc: NRMSE = 0.0235
# u00055s00001_hw00002.svc: NRMSE = 0.0401
# u00055s00001_hw00003.svc: NRMSE = 0.0624
# u00055s00001_hw00004.svc: NRMSE = 0.0170
# u00055s00001_hw00005.svc: NRMSE = 0.0242
# u00055s00001_hw00006.svc: NRMSE = 0.0699
# u00055s00001_hw00007.svc: NRMSE = 0.0844
# u00056s00001_hw00001.svc: NRMSE = 0.0020
# u00056s00001_hw00002.svc: NRMSE = 0.0033
# u00056s00001_hw00003.svc: NRMSE = 0.0201
# u00056s00001_hw00004.svc: NRMSE = 0.0005
# u00056s00001_hw00005.svc: NRMSE = 0.0016
# u00056s00001_hw00006.svc: NRMSE = 0.0321
# u00056s00001_hw00007.svc: NRMSE = 0.0211
# u00057s00001_hw00001.svc: NRMSE = 0.0026
# u00057s00001_hw00002.svc: NRMSE = 0.0200
# u00057s00001_hw00003.svc: NRMSE = 0.0397
# u00057s00001_hw00004.svc: NRMSE = 0.0007
# u00057s00001_hw00005.svc: NRMSE = 0.0007
# u00057s00001_hw00006.svc: NRMSE = 0.0215
# u00057s00001_hw00007.svc: NRMSE = 0.0165
# u00058s00001_hw00001.svc: NRMSE = 0.0159
# u00058s00001_hw00002.svc: NRMSE = 0.0132
# u00058s00001_hw00003.svc: NRMSE = 0.0373
# u00058s00001_hw00004.svc: NRMSE = 0.0007
# u00058s00001_hw00005.svc: NRMSE = 0.0009
# u00058s00001_hw00006.svc: NRMSE = 0.0396
# u00058s00001_hw00007.svc: NRMSE = 0.0646
# u00059s00001_hw00001.svc: NRMSE = 0.0156
# u00059s00001_hw00002.svc: NRMSE = 0.0141
# u00059s00001_hw00003.svc: NRMSE = 0.0097
# u00059s00001_hw00004.svc: NRMSE = 0.0010
# u00059s00001_hw00005.svc: NRMSE = 0.0006
# u00059s00001_hw00006.svc: NRMSE = 0.0305
# u00059s00001_hw00007.svc: NRMSE = 0.0165
# u00060s00001_hw00001.svc: NRMSE = 0.0415
# u00060s00001_hw00002.svc: NRMSE = 0.0359
# u00060s00001_hw00003.svc: NRMSE = 0.0238
# u00060s00001_hw00004.svc: NRMSE = 0.0006
# u00060s00001_hw00005.svc: NRMSE = 0.0006
# u00060s00001_hw00006.svc: NRMSE = 0.0411
# u00060s00001_hw00007.svc: NRMSE = 0.0329
# u00061s00001_hw00001.svc: NRMSE = 0.0296
# u00061s00001_hw00002.svc: NRMSE = 0.0187
# u00061s00001_hw00003.svc: NRMSE = 0.0224
# u00061s00001_hw00004.svc: NRMSE = 0.0006
# u00061s00001_hw00005.svc: NRMSE = 0.0006
# u00061s00001_hw00006.svc: NRMSE = 0.0396
# u00061s00001_hw00007.svc: NRMSE = 0.0173
# u00062s00001_hw00001.svc: NRMSE = 0.0132
# u00062s00001_hw00002.svc: NRMSE = 0.0207
# u00062s00001_hw00003.svc: NRMSE = 0.0265
# u00062s00001_hw00004.svc: NRMSE = 0.0036
# u00062s00001_hw00005.svc: NRMSE = 0.0005
# u00062s00001_hw00006.svc: NRMSE = 0.0826
# u00062s00001_hw00007.svc: NRMSE = 0.0113
# u00063s00001_hw00001.svc: NRMSE = 0.0093
# u00063s00001_hw00002.svc: NRMSE = 0.0191
# u00063s00001_hw00003.svc: NRMSE = 0.0181
# u00063s00001_hw00004.svc: NRMSE = 0.0005
# u00063s00001_hw00005.svc: NRMSE = 0.0006
# u00063s00001_hw00006.svc: NRMSE = 0.0237
# u00063s00001_hw00007.svc: NRMSE = 0.0137
# u00064s00001_hw00001.svc: NRMSE = 0.0035
# u00064s00001_hw00002.svc: NRMSE = 0.0036
# u00064s00001_hw00003.svc: NRMSE = 0.0374
# u00064s00001_hw00004.svc: NRMSE = 0.0003
# u00064s00001_hw00005.svc: NRMSE = 0.0005
# u00064s00001_hw00006.svc: NRMSE = 0.0186
# u00064s00001_hw00007.svc: NRMSE = 0.0528
# u00065s00001_hw00001.svc: NRMSE = 0.0374
# u00065s00001_hw00002.svc: NRMSE = 0.0323
# u00065s00001_hw00003.svc: NRMSE = 0.0343
# u00065s00001_hw00004.svc: NRMSE = 0.0032
# u00065s00001_hw00005.svc: NRMSE = 0.0005
# u00065s00001_hw00006.svc: NRMSE = 0.0353
# u00065s00001_hw00007.svc: NRMSE = 0.0193
# u00066s00001_hw00001.svc: NRMSE = 0.0313
# u00066s00001_hw00002.svc: NRMSE = 0.0334
# u00066s00001_hw00003.svc: NRMSE = 0.0245
# u00066s00001_hw00004.svc: NRMSE = 0.0006
# u00066s00001_hw00005.svc: NRMSE = 0.0006
# u00066s00001_hw00006.svc: NRMSE = 0.0475
# u00066s00001_hw00007.svc: NRMSE = 0.0204
# u00067s00001_hw00001.svc: NRMSE = 0.0177
# u00067s00001_hw00002.svc: NRMSE = 0.0269
# u00067s00001_hw00003.svc: NRMSE = 0.0155
# u00067s00001_hw00004.svc: NRMSE = 0.0005
# u00067s00001_hw00005.svc: NRMSE = 0.0004
# u00067s00001_hw00006.svc: NRMSE = 0.0185
# u00067s00001_hw00007.svc: NRMSE = 0.0147
# u00068s00001_hw00001.svc: NRMSE = 0.0059
# u00068s00001_hw00002.svc: NRMSE = 0.0275
# u00068s00001_hw00003.svc: NRMSE = 0.0102
# u00068s00001_hw00004.svc: NRMSE = 0.0009
# u00068s00001_hw00005.svc: NRMSE = 0.0006
# u00068s00001_hw00006.svc: NRMSE = 0.0085
# u00068s00001_hw00007.svc: NRMSE = 0.0218
# u00069s00001_hw00001.svc: NRMSE = 0.0027
# u00069s00001_hw00002.svc: NRMSE = 0.0055
# u00069s00001_hw00003.svc: NRMSE = 0.0125
# u00069s00001_hw00004.svc: NRMSE = 0.0598
# u00069s00001_hw00005.svc: NRMSE = 0.0002
# u00069s00001_hw00006.svc: NRMSE = 0.0333
# u00069s00001_hw00007.svc: NRMSE = 0.0097
# u00070s00001_hw00001.svc: NRMSE = 0.0129
# u00070s00001_hw00002.svc: NRMSE = 0.0244
# u00070s00001_hw00003.svc: NRMSE = 0.0262
# u00070s00001_hw00004.svc: NRMSE = 0.0136
# u00070s00001_hw00005.svc: NRMSE = 0.0140
# u00070s00001_hw00006.svc: NRMSE = 0.0645
# u00070s00001_hw00007.svc: NRMSE = 0.0217
# u00071s00001_hw00001.svc: NRMSE = 0.0210
# u00071s00001_hw00002.svc: NRMSE = 0.0465
# u00071s00001_hw00003.svc: NRMSE = 0.0366
# u00071s00001_hw00004.svc: NRMSE = 0.0061
# u00071s00001_hw00005.svc: NRMSE = 0.0063
# u00071s00001_hw00006.svc: NRMSE = 0.0475
# u00071s00001_hw00007.svc: NRMSE = 0.0216
# u00072s00001_hw00001.svc: NRMSE = 0.0138
# u00072s00001_hw00002.svc: NRMSE = 0.0305
# u00072s00001_hw00003.svc: NRMSE = 0.0308
# u00072s00001_hw00004.svc: NRMSE = 0.0129
# u00072s00001_hw00005.svc: NRMSE = 0.0070
# u00072s00001_hw00006.svc: NRMSE = 0.0254
# u00072s00001_hw00007.svc: NRMSE = 0.0286
# u00073s00001_hw00001.svc: NRMSE = 0.0028
# u00073s00001_hw00002.svc: NRMSE = 0.0243
# u00073s00001_hw00003.svc: NRMSE = 0.0059
# u00073s00001_hw00004.svc: NRMSE = 0.0102
# u00073s00001_hw00005.svc: NRMSE = 0.0049
# u00073s00001_hw00006.svc: NRMSE = 0.0629
# u00073s00001_hw00007.svc: NRMSE = 0.0223
# u00074s00001_hw00001.svc: NRMSE = 0.0242
# u00074s00001_hw00002.svc: NRMSE = 0.0313
# u00074s00001_hw00003.svc: NRMSE = 0.0132
# u00074s00001_hw00004.svc: NRMSE = 0.0184
# u00074s00001_hw00005.svc: NRMSE = 0.0074
# u00074s00001_hw00006.svc: NRMSE = 0.0452
# u00074s00001_hw00007.svc: NRMSE = 0.0258
# u00075s00001_hw00001.svc: NRMSE = 0.0052
# u00075s00001_hw00002.svc: NRMSE = 0.0200
# u00075s00001_hw00003.svc: NRMSE = 0.0209
# u00075s00001_hw00004.svc: NRMSE = 0.0198
# u00075s00001_hw00005.svc: NRMSE = 0.0065
# u00075s00001_hw00006.svc: NRMSE = 0.0244
# u00075s00001_hw00007.svc: NRMSE = 0.0129
# u00076s00001_hw00001.svc: NRMSE = 0.0170
# u00076s00001_hw00002.svc: NRMSE = 0.0312
# u00076s00001_hw00003.svc: NRMSE = 0.0314
# u00076s00001_hw00004.svc: NRMSE = 0.0101
# u00076s00001_hw00005.svc: NRMSE = 0.0154
# u00076s00001_hw00006.svc: NRMSE = 0.0792
# u00076s00001_hw00007.svc: NRMSE = 0.0096
# u00077s00001_hw00001.svc: NRMSE = 0.0110
# u00077s00001_hw00002.svc: NRMSE = 0.0312
# u00077s00001_hw00003.svc: NRMSE = 0.0138
# u00077s00001_hw00004.svc: NRMSE = 0.0103
# u00077s00001_hw00005.svc: NRMSE = 0.0079
# u00077s00001_hw00006.svc: NRMSE = 0.0314
# u00077s00001_hw00007.svc: NRMSE = 0.0272
# u00078s00001_hw00001.svc: NRMSE = 0.0040
# u00078s00001_hw00002.svc: NRMSE = 0.0110
# u00078s00001_hw00003.svc: NRMSE = 0.0429
# u00078s00001_hw00004.svc: NRMSE = 0.0190
# u00078s00001_hw00005.svc: NRMSE = 0.0170
# u00078s00001_hw00006.svc: NRMSE = 0.0188
# u00078s00001_hw00007.svc: NRMSE = 0.0134
# u00079s00001_hw00001.svc: NRMSE = 0.0036
# u00079s00001_hw00002.svc: NRMSE = 0.0159
# u00079s00001_hw00003.svc: NRMSE = 0.0520
# u00079s00001_hw00004.svc: NRMSE = 0.0035
# u00079s00001_hw00005.svc: NRMSE = 0.0060
# u00079s00001_hw00006.svc: NRMSE = 0.0695
# u00079s00001_hw00007.svc: NRMSE = 0.0188
# u00080s00001_hw00001.svc: NRMSE = 0.0465
# u00080s00001_hw00002.svc: NRMSE = 0.0237
# u00080s00001_hw00003.svc: NRMSE = 0.0439
# u00080s00001_hw00004.svc: NRMSE = 0.0058
# u00080s00001_hw00005.svc: NRMSE = 0.0074
# u00080s00001_hw00006.svc: NRMSE = 0.0751
# u00080s00001_hw00007.svc: NRMSE = 0.0254
# u00081s00001_hw00001.svc: NRMSE = 0.0206
# u00081s00001_hw00002.svc: NRMSE = 0.0251
# u00081s00001_hw00003.svc: NRMSE = 0.0337
# u00081s00001_hw00004.svc: NRMSE = 0.0167
# u00081s00001_hw00005.svc: NRMSE = 0.0105
# u00081s00001_hw00006.svc: NRMSE = 0.0311
# u00081s00001_hw00007.svc: NRMSE = 0.0134
# u00082s00001_hw00001.svc: NRMSE = 0.0049
# u00082s00001_hw00002.svc: NRMSE = 0.0074
# u00082s00001_hw00003.svc: NRMSE = 0.0464
# u00082s00001_hw00004.svc: NRMSE = 0.0094
# u00082s00001_hw00005.svc: NRMSE = 0.0124
# u00082s00001_hw00006.svc: NRMSE = 0.0311
# u00082s00001_hw00007.svc: NRMSE = 0.1013
# u00083s00001_hw00001.svc: NRMSE = 0.0632
# u00083s00001_hw00002.svc: NRMSE = 0.0455
# u00083s00001_hw00003.svc: NRMSE = 0.0555
# u00083s00001_hw00004.svc: NRMSE = 0.0071
# u00083s00001_hw00005.svc: NRMSE = 0.0115
# u00083s00001_hw00006.svc: NRMSE = 0.0628
# u00083s00001_hw00007.svc: NRMSE = 0.0464
# u00084s00001_hw00001.svc: NRMSE = 0.0037
# u00084s00001_hw00002.svc: NRMSE = 0.0155
# u00084s00001_hw00003.svc: NRMSE = 0.0459
# u00084s00001_hw00004.svc: NRMSE = 0.0053
# u00084s00001_hw00005.svc: NRMSE = 0.0079
# u00084s00001_hw00006.svc: NRMSE = 0.0344
# u00084s00001_hw00007.svc: NRMSE = 0.0206
#
# Overall Average NRMSE: 0.0279, Standard Deviation: 0.0252

# %%
import os
from glob import glob
import numpy as np
import logging
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Configure logging
log_filename = "posthoc_discriminative_score.txt"
logging.basicConfig(
    level=logging.INFO,
    format="%(message)s",
    handlers=[
        logging.FileHandler(log_filename, mode="w", encoding="utf-8"),
        logging.StreamHandler()
    ]
)

def process_files(original_folder, augmented_folder, input_filenames):
    all_real_data = []
    all_synthetic_data = []
    input_filenames_set = {os.path.splitext(os.path.basename(filename))[0] for filename in input_filenames}
    
    for original_file in glob(os.path.join(original_folder, "*.svc")):
        base_name = os.path.splitext(os.path.basename(original_file))[0]
        
        if base_name not in input_filenames_set:
            continue
        
        original_data = read_svc_file(original_file)
        all_real_data.append(original_data.values)
        
        matching_augmented_files = get_matching_augmented_files(original_file, augmented_folder)
        
        for augmented_file in matching_augmented_files:
            augmented_data = read_svc_file(augmented_file)
            all_synthetic_data.append(augmented_data.values)
    
    return np.concatenate(all_real_data), np.concatenate(all_synthetic_data)

def create_lstm_classifier(input_shape):
    model = Sequential([
        LSTM(64, input_shape=input_shape, return_sequences=True),
        LSTM(32),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def prepare_data_for_lstm(real_data, synthetic_data):
    n_features = min(real_data.shape[1], synthetic_data.shape[1])
    real_data_trimmed = real_data[:, :n_features]
    synthetic_data_trimmed = synthetic_data[:, :n_features]
    
    X = np.vstack((real_data_trimmed, synthetic_data_trimmed))
    y = np.concatenate((np.ones(len(real_data)), np.zeros(len(synthetic_data))))
    return X, y

def post_hoc_discriminative_score(real_data, synthetic_data, n_splits=10):
    X, y = prepare_data_for_lstm(real_data, synthetic_data)
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    
    for fold, (train_index, test_index) in enumerate(kf.split(X), start=1):
        logging.info(f"\nFold {fold}/{n_splits}:")
        
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
        X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
        
        model = create_lstm_classifier((1, X_train.shape[2]))
        
        # Train model and log epoch progress
        history = model.fit(X_train, y_train, epochs=5, batch_size=512, verbose=0)
        for epoch, metrics in enumerate(history.history["accuracy"], start=1):
            logging.info(f"  Epoch {epoch}: Accuracy = {metrics:.4f}")
        
        y_pred = (model.predict(X_test) > 0.5).astype(int)
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
    
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    logging.info(f"\nMean accuracy: {mean_accuracy:.4f}, Standard Deviation: {std_accuracy:.4f}")
    return mean_accuracy, std_accuracy

# Specify your folders
original_folder = "original_absolute"
augmented_folder = "../../all_datasets/vaegan_augmented" #Directory ng augmented data


# Process files
real_data, synthetic_data = process_files(original_folder, augmented_folder, input_filenames)

# Compute post-hoc discriminative score
mean_accuracy, std_accuracy = post_hoc_discriminative_score(real_data, synthetic_data)
# Out:
# Fold 1/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5205
#   Epoch 2: Accuracy = 0.5198
#   Epoch 3: Accuracy = 0.5209
#   Epoch 4: Accuracy = 0.5225
#   Epoch 5: Accuracy = 0.5086
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 16s 962us/step
# Fold 2/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5235
#   Epoch 2: Accuracy = 0.5239
#   Epoch 3: Accuracy = 0.5240
#   Epoch 4: Accuracy = 0.5226
#   Epoch 5: Accuracy = 0.5230
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 17s 1ms/step
# Fold 3/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5228
#   Epoch 2: Accuracy = 0.5232
#   Epoch 3: Accuracy = 0.5235
#   Epoch 4: Accuracy = 0.5237
#   Epoch 5: Accuracy = 0.5248
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 18s 1ms/step
# Fold 4/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5239
#   Epoch 2: Accuracy = 0.5235
#   Epoch 3: Accuracy = 0.5237
#   Epoch 4: Accuracy = 0.5241
#   Epoch 5: Accuracy = 0.5254
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 59s 3ms/step
# Fold 5/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5218
#   Epoch 2: Accuracy = 0.5228
#   Epoch 3: Accuracy = 0.5213
#   Epoch 4: Accuracy = 0.5232
#   Epoch 5: Accuracy = 0.5235
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 18s 1ms/step
# Fold 6/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5244
#   Epoch 2: Accuracy = 0.5239
#   Epoch 3: Accuracy = 0.5226
#   Epoch 4: Accuracy = 0.5235
#   Epoch 5: Accuracy = 0.5212
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 18s 1ms/step
# Fold 7/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5236
#   Epoch 2: Accuracy = 0.5241
#   Epoch 3: Accuracy = 0.5234
#   Epoch 4: Accuracy = 0.5242
#   Epoch 5: Accuracy = 0.5226
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 19s 1ms/step
# Fold 8/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5238
#   Epoch 2: Accuracy = 0.5243
#   Epoch 3: Accuracy = 0.5245
#   Epoch 4: Accuracy = 0.5242
#   Epoch 5: Accuracy = 0.5244
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 876us/step
# Fold 9/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5241
#   Epoch 2: Accuracy = 0.5249
#   Epoch 3: Accuracy = 0.5255
#   Epoch 4: Accuracy = 0.5232
#   Epoch 5: Accuracy = 0.5252
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 874us/step
# Fold 10/10:
# c:\Users\Grimes\OneDrive\Desktop\Thesis-Project\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5239
#   Epoch 2: Accuracy = 0.5232
#   Epoch 3: Accuracy = 0.5230
#   Epoch 4: Accuracy = 0.5225
#   Epoch 5: Accuracy = 0.5213
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 900us/step
# Mean accuracy: 0.5232, Standard Deviation: 0.0024

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor
from glob import glob
import os
import time

def write_to_log(message):
    """Write a message to the log file."""
    log_file = "posthoc_predictive_score.txt"
    with open(log_file, "a") as f:
        f.write(message + "\n")

def read_svc_file(file_path):
    """Read an SVC file and return its contents as a DataFrame."""
    try:
        df = pd.read_csv(file_path, sep=' ', header=None)
        if df.empty:
            return None
        return df
    except Exception as e:
        return None

def get_matching_augmented_file(original_file, augmented_folder):
    """Get matching augmented file for a given original file."""
    base_name = os.path.splitext(os.path.basename(original_file))[0]
    augmented_file = os.path.join(augmented_folder, f"synthetic_{base_name}.svc")
    return augmented_file if os.path.exists(augmented_file) else None

def process_files(original_folder, augmented_folder):
    """Process original and augmented files and prepare them for analysis."""
    paired_data = []
    for original_file in glob(os.path.join(original_folder, "*.svc")):
        augmented_file = get_matching_augmented_file(original_file, augmented_folder)
        if augmented_file is None:
            continue
            
        original_data = read_svc_file(original_file)
        augmented_data = read_svc_file(augmented_file)
        
        if (original_data is not None and augmented_data is not None and 
            original_data.shape[1] == augmented_data.shape[1]):
            paired_data.append((original_file, augmented_file))

    if not paired_data:
        raise ValueError("No valid data pairs found for processing")
    return paired_data

def prepare_sequences(data, time_steps=4):
    """Prepare sequences for prediction, using all but last timestep as input."""
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps - 1].flatten())
        y.append(data[i + time_steps - 1])
    return np.array(X), np.array(y)

def evaluate_synthetic_data(original_file, synthetic_file):
    """Evaluate a single synthetic dataset against its original counterpart."""
    original_df = read_svc_file(original_file)
    synthetic_df = read_svc_file(synthetic_file)

    if original_df is None or synthetic_df is None:
        return None

    integer_columns = [0, 1, 4, 5]
    scaler = MinMaxScaler()
    original_scaled = scaler.fit_transform(original_df)
    synthetic_scaled = scaler.transform(synthetic_df)

    start_time = time.time()
    X_train, y_train = prepare_sequences(synthetic_scaled)
    X_test, y_test = prepare_sequences(original_scaled)

    if len(X_train) == 0 or len(X_test) == 0:
        return None

    mapes_per_dim = []
    for dim in range(y_train.shape[1]):
        model = XGBRegressor(
            n_estimators=100,
            learning_rate=0.1,
            max_depth=6,
            random_state=42
        )

        model.fit(X_train, y_train[:, dim], verbose=False)
        y_pred = model.predict(X_test)

        y_true_original = original_df.iloc[len(original_df)-len(y_test):, dim].values

        temp_data = np.zeros((len(y_pred), original_df.shape[1]))
        temp_data[:, dim] = y_pred
        y_pred_original = scaler.inverse_transform(temp_data)[:, dim]

        if dim in integer_columns:
            y_pred_original = np.round(y_pred_original)

        if dim == 3:
            y_pred_original = np.round(y_pred_original)

        y_pred_original = np.round(y_pred_original).astype(int)
        y_true_original = np.round(y_true_original).astype(int)

        errors = []
        for true, pred in zip(y_true_original, y_pred_original):
            if true == 0:
                errors.append(100 if pred != 0 else 0)
            else:
                errors.append(min(abs((true - pred) / true) * 100, 100))

        mapes_per_dim.append(np.mean(errors))

    elapsed_time = time.time() - start_time
    return np.mean(mapes_per_dim), elapsed_time

def post_hoc_predictive_score(original_folder, augmented_folder):
    """Calculate post-hoc predictive score for all pairs of original and synthetic data."""
    try:
        paired_files = process_files(original_folder, augmented_folder)
        all_results = []
        
        for original_file, synthetic_file in paired_files:
            result = evaluate_synthetic_data(original_file, synthetic_file)
            if result is not None:
                mape, elapsed_time = result
                file_name = os.path.basename(original_file)
                log_message = (f"Processing: {file_name} Completed in {elapsed_time:.1f}s "
                               f"(MAPE: {mape:.2f}%)")
                print(log_message)
                write_to_log(log_message)
                all_results.append(mape)
        
        if not all_results:
            raise ValueError("No valid results calculated")
        
        summary_message = (f"----------------------------------------\n"
                           f"Overall Results:\n"
                           f"Average MAPE: {np.mean(all_results):.2f}%, "
                           f"Standard Deviation: {np.std(all_results):.2f}%")
        print(summary_message)
        write_to_log(summary_message)
        
        return np.mean(all_results), np.std(all_results)
        
    except Exception as e:
        error_message = f"Error: {str(e)}"
        print(error_message)
        write_to_log(error_message)
        return None, None

def main():
    try:
        original_folder = "original_absolute"
        augmented_folder = "../../all_datasets/vaegan_augmented" #Directory ng augmented data
        post_hoc_predictive_score(original_folder, augmented_folder)
            
    except Exception as e:
        error_message = f"Error: {str(e)}"
        print(error_message)
        write_to_log(error_message)

if __name__ == "__main__":
    main()
# Out:
# Processing: collection1u00001s00001_hw00001.svc Completed in 1.1s (MAPE: 4.25%)
# Processing: collection1u00001s00001_hw00002.svc Completed in 1.6s (MAPE: 6.79%)
# Processing: collection1u00001s00001_hw00003.svc Completed in 1.4s (MAPE: 8.95%)
# Processing: collection1u00001s00001_hw00004.svc Completed in 1.0s (MAPE: 6.16%)
# Processing: collection1u00001s00001_hw00005.svc Completed in 2.2s (MAPE: 5.90%)
# Processing: collection1u00001s00001_hw00006.svc Completed in 2.4s (MAPE: 7.40%)
# Processing: collection1u00001s00001_hw00007.svc Completed in 1.4s (MAPE: 10.31%)
# Processing: collection1u00002s00001_hw00001.svc Completed in 1.4s (MAPE: 4.42%)
# Processing: collection1u00002s00001_hw00002.svc Completed in 1.7s (MAPE: 5.84%)
# Processing: collection1u00002s00001_hw00003.svc Completed in 2.2s (MAPE: 9.39%)
# Processing: collection1u00002s00001_hw00004.svc Completed in 1.3s (MAPE: 1.17%)
# Processing: collection1u00002s00001_hw00005.svc Completed in 1.4s (MAPE: 1.51%)
# Processing: collection1u00002s00001_hw00006.svc Completed in 2.6s (MAPE: 6.90%)
# Processing: collection1u00002s00001_hw00007.svc Completed in 2.3s (MAPE: 10.08%)
# Processing: collection1u00003s00001_hw00001.svc Completed in 1.6s (MAPE: 5.71%)
# Processing: collection1u00003s00001_hw00002.svc Completed in 2.1s (MAPE: 5.55%)
# Processing: collection1u00003s00001_hw00003.svc Completed in 1.9s (MAPE: 11.40%)
# Processing: collection1u00003s00001_hw00004.svc Completed in 1.3s (MAPE: 0.59%)
# Processing: collection1u00003s00001_hw00005.svc Completed in 1.0s (MAPE: 0.72%)
# Processing: collection1u00003s00001_hw00006.svc Completed in 1.8s (MAPE: 9.54%)
# Processing: collection1u00003s00001_hw00007.svc Completed in 1.7s (MAPE: 9.90%)
# Processing: collection1u00004s00001_hw00001.svc Completed in 1.3s (MAPE: 3.40%)
# Processing: collection1u00004s00001_hw00002.svc Completed in 1.6s (MAPE: 3.59%)
# Processing: collection1u00004s00001_hw00003.svc Completed in 1.7s (MAPE: 8.48%)
# Processing: collection1u00004s00001_hw00004.svc Completed in 1.2s (MAPE: 3.96%)
# Processing: collection1u00004s00001_hw00005.svc Completed in 1.8s (MAPE: 0.70%)
# Processing: collection1u00004s00001_hw00006.svc Completed in 1.5s (MAPE: 4.45%)
# Processing: collection1u00004s00001_hw00007.svc Completed in 1.8s (MAPE: 8.66%)
# Processing: collection1u00005s00001_hw00001.svc Completed in 2.2s (MAPE: 6.02%)
# Processing: collection1u00005s00001_hw00002.svc Completed in 1.5s (MAPE: 6.20%)
# Processing: collection1u00005s00001_hw00003.svc Completed in 1.3s (MAPE: 10.94%)
# Processing: collection1u00005s00001_hw00004.svc Completed in 0.9s (MAPE: 2.50%)
# Processing: collection1u00005s00001_hw00005.svc Completed in 1.0s (MAPE: 1.00%)
# Processing: collection1u00005s00001_hw00006.svc Completed in 1.3s (MAPE: 7.34%)
# Processing: collection1u00005s00001_hw00007.svc Completed in 1.7s (MAPE: 9.45%)
# Processing: collection1u00006s00001_hw00001.svc Completed in 1.2s (MAPE: 1.25%)
# Processing: collection1u00006s00001_hw00002.svc Completed in 1.8s (MAPE: 5.25%)
# Processing: collection1u00006s00001_hw00003.svc Completed in 1.5s (MAPE: 10.62%)
# Processing: collection1u00006s00001_hw00004.svc Completed in 1.0s (MAPE: 0.65%)
# Processing: collection1u00006s00001_hw00005.svc Completed in 1.1s (MAPE: 4.04%)
# Processing: collection1u00006s00001_hw00006.svc Completed in 2.0s (MAPE: 7.86%)
# Processing: collection1u00006s00001_hw00007.svc Completed in 1.6s (MAPE: 11.07%)
# Processing: collection1u00007s00001_hw00001.svc Completed in 1.7s (MAPE: 5.40%)
# Processing: collection1u00007s00001_hw00002.svc Completed in 1.7s (MAPE: 5.91%)
# Processing: collection1u00007s00001_hw00003.svc Completed in 1.7s (MAPE: 10.80%)
# Processing: collection1u00007s00001_hw00004.svc Completed in 1.2s (MAPE: 1.19%)
# Processing: collection1u00007s00001_hw00005.svc Completed in 1.7s (MAPE: 1.12%)
# Processing: collection1u00007s00001_hw00006.svc Completed in 1.7s (MAPE: 9.46%)
# Processing: collection1u00007s00001_hw00007.svc Completed in 1.5s (MAPE: 8.88%)
# Processing: collection1u00008s00001_hw00001.svc Completed in 1.7s (MAPE: 3.22%)
# Processing: collection1u00008s00001_hw00002.svc Completed in 1.5s (MAPE: 5.51%)
# Processing: collection1u00008s00001_hw00003.svc Completed in 1.7s (MAPE: 10.00%)
# Processing: collection1u00008s00001_hw00004.svc Completed in 0.9s (MAPE: 6.24%)
# Processing: collection1u00008s00001_hw00005.svc Completed in 1.5s (MAPE: 0.99%)
# Processing: collection1u00008s00001_hw00006.svc Completed in 1.3s (MAPE: 5.74%)
# Processing: collection1u00008s00001_hw00007.svc Completed in 1.5s (MAPE: 8.39%)
# Processing: collection1u00009s00001_hw00001.svc Completed in 0.8s (MAPE: 2.07%)
# Processing: collection1u00009s00001_hw00002.svc Completed in 1.6s (MAPE: 5.46%)
# Processing: collection1u00009s00001_hw00003.svc Completed in 1.6s (MAPE: 10.51%)
# Processing: collection1u00009s00001_hw00004.svc Completed in 1.3s (MAPE: 0.71%)
# Processing: collection1u00009s00001_hw00005.svc Completed in 1.3s (MAPE: 1.01%)
# Processing: collection1u00009s00001_hw00006.svc Completed in 2.2s (MAPE: 7.05%)
# Processing: collection1u00009s00001_hw00007.svc Completed in 1.7s (MAPE: 14.04%)
# Processing: collection1u00010s00001_hw00001.svc Completed in 1.1s (MAPE: 3.80%)
# Processing: collection1u00010s00001_hw00002.svc Completed in 1.9s (MAPE: 6.11%)
# Processing: collection1u00010s00001_hw00003.svc Completed in 1.7s (MAPE: 11.17%)
# Processing: collection1u00010s00001_hw00004.svc Completed in 1.9s (MAPE: 1.05%)
# Processing: collection1u00010s00001_hw00005.svc Completed in 1.2s (MAPE: 1.48%)
# Processing: collection1u00010s00001_hw00006.svc Completed in 1.4s (MAPE: 5.48%)
# Processing: collection1u00010s00001_hw00007.svc Completed in 1.7s (MAPE: 10.04%)
# Processing: collection1u00011s00001_hw00001.svc Completed in 1.7s (MAPE: 4.90%)
# Processing: collection1u00011s00001_hw00002.svc Completed in 1.8s (MAPE: 6.78%)
# Processing: collection1u00011s00001_hw00003.svc Completed in 2.0s (MAPE: 9.61%)
# Processing: collection1u00011s00001_hw00004.svc Completed in 1.4s (MAPE: 4.65%)
# Processing: collection1u00011s00001_hw00005.svc Completed in 1.3s (MAPE: 0.74%)
# Processing: collection1u00011s00001_hw00006.svc Completed in 1.7s (MAPE: 7.29%)
# Processing: collection1u00011s00001_hw00007.svc Completed in 2.4s (MAPE: 8.73%)
# Processing: collection1u00012s00001_hw00001.svc Completed in 1.2s (MAPE: 2.65%)
# Processing: collection1u00012s00001_hw00002.svc Completed in 1.7s (MAPE: 3.93%)
# Processing: collection1u00012s00001_hw00003.svc Completed in 2.6s (MAPE: 8.52%)
# Processing: collection1u00012s00001_hw00004.svc Completed in 1.5s (MAPE: 0.55%)
# Processing: collection1u00012s00001_hw00005.svc Completed in 2.0s (MAPE: 0.83%)
# Processing: collection1u00012s00001_hw00006.svc Completed in 1.7s (MAPE: 6.82%)
# Processing: collection1u00012s00001_hw00007.svc Completed in 2.1s (MAPE: 7.38%)
# Processing: collection1u00013s00001_hw00001.svc Completed in 1.7s (MAPE: 2.08%)
# Processing: collection1u00013s00001_hw00002.svc Completed in 2.5s (MAPE: 3.97%)
# Processing: collection1u00013s00001_hw00003.svc Completed in 2.3s (MAPE: 7.47%)
# Processing: collection1u00013s00001_hw00004.svc Completed in 1.2s (MAPE: 0.43%)
# Processing: collection1u00013s00001_hw00005.svc Completed in 1.4s (MAPE: 0.61%)
# Processing: collection1u00013s00001_hw00006.svc Completed in 3.7s (MAPE: 4.50%)
# Processing: collection1u00013s00001_hw00007.svc Completed in 3.0s (MAPE: 4.52%)
# Processing: collection1u00014s00001_hw00001.svc Completed in 3.3s (MAPE: 2.56%)
# Processing: collection1u00014s00001_hw00002.svc Completed in 2.2s (MAPE: 6.04%)
# Processing: collection1u00014s00001_hw00003.svc Completed in 1.9s (MAPE: 11.13%)
# Processing: collection1u00014s00001_hw00004.svc Completed in 1.7s (MAPE: 0.90%)
# Processing: collection1u00014s00001_hw00005.svc Completed in 2.0s (MAPE: 0.91%)
# Processing: collection1u00014s00001_hw00006.svc Completed in 2.2s (MAPE: 4.44%)
# Processing: collection1u00014s00001_hw00007.svc Completed in 2.7s (MAPE: 8.63%)
# Processing: collection1u00015s00001_hw00001.svc Completed in 1.8s (MAPE: 2.91%)
# Processing: collection1u00015s00001_hw00002.svc Completed in 2.1s (MAPE: 5.38%)
# Processing: collection1u00015s00001_hw00003.svc Completed in 4.2s (MAPE: 8.46%)
# Processing: collection1u00015s00001_hw00004.svc Completed in 3.8s (MAPE: 4.39%)
# Processing: collection1u00015s00001_hw00005.svc Completed in 3.0s (MAPE: 0.69%)
# Processing: collection1u00015s00001_hw00006.svc Completed in 5.7s (MAPE: 6.38%)
# Processing: collection1u00015s00001_hw00007.svc Completed in 5.6s (MAPE: 8.12%)
# Processing: collection1u00016s00001_hw00001.svc Completed in 4.3s (MAPE: 1.50%)
# Processing: collection1u00016s00001_hw00002.svc Completed in 4.4s (MAPE: 2.94%)
# Processing: collection1u00016s00001_hw00003.svc Completed in 3.8s (MAPE: 6.85%)
# Processing: collection1u00016s00001_hw00004.svc Completed in 3.4s (MAPE: 2.94%)
# Processing: collection1u00016s00001_hw00005.svc Completed in 2.6s (MAPE: 1.61%)
# Processing: collection1u00016s00001_hw00006.svc Completed in 1.9s (MAPE: 4.76%)
# Processing: collection1u00016s00001_hw00007.svc Completed in 1.5s (MAPE: 5.81%)
# Processing: collection1u00017s00001_hw00001.svc Completed in 2.4s (MAPE: 2.08%)
# Processing: collection1u00017s00001_hw00002.svc Completed in 2.4s (MAPE: 4.86%)
# Processing: collection1u00017s00001_hw00003.svc Completed in 1.6s (MAPE: 10.54%)
# Processing: collection1u00017s00001_hw00004.svc Completed in 1.0s (MAPE: 3.87%)
# Processing: collection1u00017s00001_hw00005.svc Completed in 1.0s (MAPE: 1.30%)
# Processing: collection1u00017s00001_hw00006.svc Completed in 1.6s (MAPE: 4.38%)
# Processing: collection1u00017s00001_hw00007.svc Completed in 1.6s (MAPE: 8.60%)
# Processing: collection1u00018s00001_hw00001.svc Completed in 0.9s (MAPE: 2.87%)
# Processing: collection1u00018s00001_hw00002.svc Completed in 1.6s (MAPE: 5.28%)
# Processing: collection1u00018s00001_hw00003.svc Completed in 1.5s (MAPE: 8.48%)
# Processing: collection1u00018s00001_hw00004.svc Completed in 1.2s (MAPE: 3.95%)
# Processing: collection1u00018s00001_hw00005.svc Completed in 1.1s (MAPE: 1.73%)
# Processing: collection1u00018s00001_hw00006.svc Completed in 1.7s (MAPE: 7.05%)
# Processing: collection1u00018s00001_hw00007.svc Completed in 1.6s (MAPE: 8.36%)
# Processing: collection1u00019s00001_hw00001.svc Completed in 1.5s (MAPE: 4.11%)
# Processing: collection1u00019s00001_hw00002.svc Completed in 2.0s (MAPE: 2.99%)
# Processing: collection1u00019s00001_hw00003.svc Completed in 1.7s (MAPE: 11.56%)
# Processing: collection1u00019s00001_hw00004.svc Completed in 1.1s (MAPE: 1.23%)
# Processing: collection1u00019s00001_hw00005.svc Completed in 1.2s (MAPE: 0.99%)
# Processing: collection1u00019s00001_hw00006.svc Completed in 2.2s (MAPE: 3.50%)
# Processing: collection1u00019s00001_hw00007.svc Completed in 1.6s (MAPE: 7.47%)
# Processing: collection1u00020s00001_hw00001.svc Completed in 1.2s (MAPE: 3.05%)
# Processing: collection1u00020s00001_hw00002.svc Completed in 1.6s (MAPE: 6.76%)
# Processing: collection1u00020s00001_hw00003.svc Completed in 1.6s (MAPE: 9.72%)
# Processing: collection1u00020s00001_hw00004.svc Completed in 1.2s (MAPE: 2.33%)
# Processing: collection1u00020s00001_hw00005.svc Completed in 1.2s (MAPE: 1.12%)
# Processing: collection1u00020s00001_hw00006.svc Completed in 1.5s (MAPE: 8.42%)
# Processing: collection1u00020s00001_hw00007.svc Completed in 1.6s (MAPE: 7.28%)
# Processing: collection1u00021s00001_hw00001.svc Completed in 1.4s (MAPE: 3.48%)
# Processing: collection1u00021s00001_hw00002.svc Completed in 1.6s (MAPE: 4.11%)
# Processing: collection1u00021s00001_hw00003.svc Completed in 1.5s (MAPE: 8.49%)
# Processing: collection1u00021s00001_hw00004.svc Completed in 1.1s (MAPE: 3.49%)
# Processing: collection1u00021s00001_hw00005.svc Completed in 1.1s (MAPE: 0.73%)
# Processing: collection1u00021s00001_hw00006.svc Completed in 2.0s (MAPE: 4.62%)
# Processing: collection1u00021s00001_hw00007.svc Completed in 1.5s (MAPE: 7.42%)
# Processing: collection1u00022s00001_hw00001.svc Completed in 1.0s (MAPE: 3.17%)
# Processing: collection1u00022s00001_hw00002.svc Completed in 1.5s (MAPE: 4.81%)
# Processing: collection1u00022s00001_hw00003.svc Completed in 1.7s (MAPE: 7.95%)
# Processing: collection1u00022s00001_hw00004.svc Completed in 1.2s (MAPE: 6.31%)
# Processing: collection1u00022s00001_hw00005.svc Completed in 1.1s (MAPE: 1.54%)
# Processing: collection1u00022s00001_hw00006.svc Completed in 1.6s (MAPE: 4.07%)
# Processing: collection1u00022s00001_hw00007.svc Completed in 1.7s (MAPE: 7.09%)
# Processing: collection1u00023s00001_hw00001.svc Completed in 1.3s (MAPE: 2.60%)
# Processing: collection1u00023s00001_hw00002.svc Completed in 1.6s (MAPE: 5.39%)
# Processing: collection1u00023s00001_hw00003.svc Completed in 1.6s (MAPE: 8.49%)
# Processing: collection1u00023s00001_hw00004.svc Completed in 1.2s (MAPE: 5.00%)
# Processing: collection1u00023s00001_hw00005.svc Completed in 1.1s (MAPE: 0.97%)
# Processing: collection1u00023s00001_hw00006.svc Completed in 1.7s (MAPE: 7.87%)
# Processing: collection1u00023s00001_hw00007.svc Completed in 1.5s (MAPE: 6.83%)
# Processing: collection1u00024s00001_hw00001.svc Completed in 1.4s (MAPE: 2.67%)
# Processing: collection1u00024s00001_hw00002.svc Completed in 1.7s (MAPE: 8.45%)
# Processing: collection1u00024s00001_hw00003.svc Completed in 1.5s (MAPE: 10.43%)
# Processing: collection1u00024s00001_hw00004.svc Completed in 1.1s (MAPE: 1.38%)
# Processing: collection1u00024s00001_hw00005.svc Completed in 1.2s (MAPE: 0.99%)
# Processing: collection1u00024s00001_hw00006.svc Completed in 1.5s (MAPE: 7.88%)
# Processing: collection1u00024s00001_hw00007.svc Completed in 1.6s (MAPE: 10.47%)
# Processing: collection1u00025s00001_hw00001.svc Completed in 1.4s (MAPE: 3.17%)
# Processing: collection1u00025s00001_hw00002.svc Completed in 1.8s (MAPE: 4.64%)
# Processing: collection1u00025s00001_hw00003.svc Completed in 1.8s (MAPE: 8.73%)
# Processing: collection1u00025s00001_hw00004.svc Completed in 1.0s (MAPE: 4.00%)
# Processing: collection1u00025s00001_hw00005.svc Completed in 1.1s (MAPE: 1.07%)
# Processing: collection1u00025s00001_hw00006.svc Completed in 1.5s (MAPE: 6.38%)
# Processing: collection1u00025s00001_hw00007.svc Completed in 1.7s (MAPE: 6.10%)
# Processing: collection1u00026s00001_hw00001.svc Completed in 1.2s (MAPE: 2.05%)
# Processing: collection1u00026s00001_hw00002.svc Completed in 1.5s (MAPE: 5.10%)
# Processing: collection1u00026s00001_hw00003.svc Completed in 1.6s (MAPE: 9.10%)
# Processing: collection1u00026s00001_hw00004.svc Completed in 1.1s (MAPE: 2.67%)
# Processing: collection1u00026s00001_hw00005.svc Completed in 1.1s (MAPE: 1.06%)
# Processing: collection1u00026s00001_hw00006.svc Completed in 1.4s (MAPE: 6.48%)
# Processing: collection1u00026s00001_hw00007.svc Completed in 1.5s (MAPE: 7.55%)
# Processing: collection1u00027s00001_hw00001.svc Completed in 1.5s (MAPE: 2.11%)
# Processing: collection1u00027s00001_hw00002.svc Completed in 1.6s (MAPE: 3.78%)
# Processing: collection1u00027s00001_hw00003.svc Completed in 1.8s (MAPE: 8.49%)
# Processing: collection1u00027s00001_hw00004.svc Completed in 0.8s (MAPE: 1.02%)
# Processing: collection1u00027s00001_hw00005.svc Completed in 0.9s (MAPE: 0.85%)
# Processing: collection1u00027s00001_hw00006.svc Completed in 1.5s (MAPE: 4.05%)
# Processing: collection1u00027s00001_hw00007.svc Completed in 1.5s (MAPE: 6.03%)
# Processing: collection1u00028s00001_hw00001.svc Completed in 1.5s (MAPE: 5.90%)
# Processing: collection1u00028s00001_hw00002.svc Completed in 1.8s (MAPE: 6.74%)
# Processing: collection1u00028s00001_hw00003.svc Completed in 1.9s (MAPE: 10.41%)
# Processing: collection1u00028s00001_hw00004.svc Completed in 1.0s (MAPE: 3.00%)
# Processing: collection1u00028s00001_hw00005.svc Completed in 1.2s (MAPE: 2.12%)
# Processing: collection1u00028s00001_hw00006.svc Completed in 1.5s (MAPE: 9.23%)
# Processing: collection1u00028s00001_hw00007.svc Completed in 1.9s (MAPE: 6.90%)
# Processing: collection1u00029s00001_hw00001.svc Completed in 1.4s (MAPE: 0.97%)
# Processing: collection1u00029s00001_hw00002.svc Completed in 2.0s (MAPE: 1.52%)
# Processing: collection1u00029s00001_hw00003.svc Completed in 2.2s (MAPE: 9.54%)
# Processing: collection1u00029s00001_hw00004.svc Completed in 1.3s (MAPE: 0.93%)
# Processing: collection1u00029s00001_hw00005.svc Completed in 1.0s (MAPE: 2.36%)
# Processing: collection1u00029s00001_hw00006.svc Completed in 1.6s (MAPE: 6.12%)
# Processing: collection1u00029s00001_hw00007.svc Completed in 2.1s (MAPE: 6.69%)
# Processing: collection1u00030s00001_hw00001.svc Completed in 1.9s (MAPE: 2.83%)
# Processing: collection1u00030s00001_hw00002.svc Completed in 2.7s (MAPE: 3.21%)
# Processing: collection1u00030s00001_hw00003.svc Completed in 1.4s (MAPE: 9.82%)
# Processing: collection1u00030s00001_hw00004.svc Completed in 1.0s (MAPE: 2.49%)
# Processing: collection1u00030s00001_hw00005.svc Completed in 1.2s (MAPE: 0.54%)
# Processing: collection1u00030s00001_hw00006.svc Completed in 2.2s (MAPE: 7.28%)
# Processing: collection1u00030s00001_hw00007.svc Completed in 2.2s (MAPE: 7.48%)
# Processing: collection1u00031s00001_hw00001.svc Completed in 1.5s (MAPE: 2.66%)
# Processing: collection1u00031s00001_hw00002.svc Completed in 2.2s (MAPE: 5.32%)
# Processing: collection1u00031s00001_hw00003.svc Completed in 2.2s (MAPE: 9.28%)
# Processing: collection1u00031s00001_hw00004.svc Completed in 0.8s (MAPE: 1.32%)
# Processing: collection1u00031s00001_hw00005.svc Completed in 1.2s (MAPE: 0.58%)
# Processing: collection1u00031s00001_hw00006.svc Completed in 2.1s (MAPE: 6.27%)
# Processing: collection1u00031s00001_hw00007.svc Completed in 2.0s (MAPE: 9.31%)
# Processing: collection1u00032s00001_hw00001.svc Completed in 1.3s (MAPE: 1.08%)
# Processing: collection1u00032s00001_hw00002.svc Completed in 1.8s (MAPE: 2.21%)
# Processing: collection1u00032s00001_hw00003.svc Completed in 1.6s (MAPE: 7.53%)
# Processing: collection1u00032s00001_hw00004.svc Completed in 0.9s (MAPE: 3.14%)
# Processing: collection1u00032s00001_hw00005.svc Completed in 0.9s (MAPE: 0.53%)
# Processing: collection1u00032s00001_hw00006.svc Completed in 1.7s (MAPE: 4.58%)
# Processing: collection1u00032s00001_hw00007.svc Completed in 1.9s (MAPE: 7.71%)
# Processing: collection1u00033s00001_hw00001.svc Completed in 1.4s (MAPE: 3.06%)
# Processing: collection1u00033s00001_hw00002.svc Completed in 1.9s (MAPE: 4.64%)
# Processing: collection1u00033s00001_hw00003.svc Completed in 1.7s (MAPE: 9.35%)
# Processing: collection1u00033s00001_hw00004.svc Completed in 0.9s (MAPE: 3.28%)
# Processing: collection1u00033s00001_hw00005.svc Completed in 0.8s (MAPE: 0.54%)
# Processing: collection1u00033s00001_hw00006.svc Completed in 1.9s (MAPE: 7.40%)
# Processing: collection1u00033s00001_hw00007.svc Completed in 1.5s (MAPE: 8.14%)
# Processing: collection1u00034s00001_hw00001.svc Completed in 1.5s (MAPE: 6.30%)
# Processing: collection1u00034s00001_hw00002.svc Completed in 1.4s (MAPE: 2.83%)
# Processing: collection1u00034s00001_hw00003.svc Completed in 1.9s (MAPE: 7.08%)
# Processing: collection1u00034s00001_hw00004.svc Completed in 0.9s (MAPE: 3.18%)
# Processing: collection1u00034s00001_hw00005.svc Completed in 1.0s (MAPE: 0.95%)
# Processing: collection1u00034s00001_hw00006.svc Completed in 1.6s (MAPE: 8.08%)
# Processing: collection1u00034s00001_hw00007.svc Completed in 1.7s (MAPE: 7.95%)
# Processing: collection1u00035s00001_hw00001.svc Completed in 1.1s (MAPE: 0.48%)
# Processing: collection1u00035s00001_hw00002.svc Completed in 1.5s (MAPE: 3.47%)
# Processing: collection1u00035s00001_hw00003.svc Completed in 1.6s (MAPE: 8.70%)
# Processing: collection1u00035s00001_hw00004.svc Completed in 0.8s (MAPE: 1.07%)
# Processing: collection1u00035s00001_hw00005.svc Completed in 1.0s (MAPE: 0.74%)
# Processing: collection1u00035s00001_hw00006.svc Completed in 1.3s (MAPE: 3.56%)
# Processing: collection1u00035s00001_hw00007.svc Completed in 1.6s (MAPE: 5.55%)
# Processing: collection1u00036s00001_hw00001.svc Completed in 1.3s (MAPE: 1.37%)
# Processing: collection1u00036s00001_hw00002.svc Completed in 1.7s (MAPE: 3.27%)
# Processing: collection1u00036s00001_hw00003.svc Completed in 1.8s (MAPE: 9.41%)
# Processing: collection1u00036s00001_hw00004.svc Completed in 0.7s (MAPE: 4.21%)
# Processing: collection1u00036s00001_hw00005.svc Completed in 0.8s (MAPE: 0.77%)
# Processing: collection1u00036s00001_hw00006.svc Completed in 1.5s (MAPE: 6.52%)
# Processing: collection1u00036s00001_hw00007.svc Completed in 1.7s (MAPE: 8.46%)
# Processing: collection1u00037s00001_hw00001.svc Completed in 1.1s (MAPE: 2.35%)
# Processing: collection1u00037s00001_hw00002.svc Completed in 1.5s (MAPE: 5.95%)
# Processing: collection1u00037s00001_hw00003.svc Completed in 1.4s (MAPE: 8.91%)
# Processing: collection1u00037s00001_hw00004.svc Completed in 0.9s (MAPE: 0.58%)
# Processing: collection1u00037s00001_hw00005.svc Completed in 0.9s (MAPE: 0.66%)
# Processing: collection1u00037s00001_hw00006.svc Completed in 1.4s (MAPE: 5.05%)
# Processing: collection1u00037s00001_hw00007.svc Completed in 1.6s (MAPE: 6.97%)
# Processing: collection1u00038s00001_hw00001.svc Completed in 1.2s (MAPE: 3.12%)
# Processing: collection1u00038s00001_hw00002.svc Completed in 1.4s (MAPE: 5.42%)
# Processing: collection1u00038s00001_hw00003.svc Completed in 1.6s (MAPE: 8.70%)
# Processing: collection1u00038s00001_hw00004.svc Completed in 0.9s (MAPE: 0.84%)
# Processing: collection1u00038s00001_hw00005.svc Completed in 0.9s (MAPE: 0.51%)
# Processing: collection1u00038s00001_hw00006.svc Completed in 1.3s (MAPE: 6.42%)
# Processing: collection1u00038s00001_hw00007.svc Completed in 1.6s (MAPE: 7.71%)
# Processing: collection1u00039s00001_hw00001.svc Completed in 1.2s (MAPE: 3.04%)
# Processing: collection1u00039s00001_hw00002.svc Completed in 1.5s (MAPE: 5.15%)
# Processing: collection1u00039s00001_hw00003.svc Completed in 1.5s (MAPE: 9.99%)
# Processing: collection1u00039s00001_hw00004.svc Completed in 1.0s (MAPE: 1.15%)
# Processing: collection1u00039s00001_hw00005.svc Completed in 1.0s (MAPE: 1.50%)
# Processing: collection1u00039s00001_hw00006.svc Completed in 1.5s (MAPE: 7.76%)
# Processing: collection1u00039s00001_hw00007.svc Completed in 1.5s (MAPE: 8.28%)
# Processing: collection1u00040s00001_hw00001.svc Completed in 1.3s (MAPE: 11.09%)
# Processing: collection1u00040s00001_hw00002.svc Completed in 1.4s (MAPE: 9.54%)
# Processing: collection1u00040s00001_hw00003.svc Completed in 1.5s (MAPE: 9.81%)
# Processing: collection1u00040s00001_hw00004.svc Completed in 0.9s (MAPE: 2.10%)
# Processing: collection1u00040s00001_hw00005.svc Completed in 0.8s (MAPE: 0.62%)
# Processing: collection1u00040s00001_hw00006.svc Completed in 1.7s (MAPE: 10.08%)
# Processing: collection1u00040s00001_hw00007.svc Completed in 1.5s (MAPE: 6.56%)
# Processing: collection1u00041s00001_hw00001.svc Completed in 1.2s (MAPE: 1.92%)
# Processing: collection1u00041s00001_hw00002.svc Completed in 1.5s (MAPE: 3.85%)
# Processing: collection1u00041s00001_hw00003.svc Completed in 1.5s (MAPE: 8.28%)
# Processing: collection1u00041s00001_hw00004.svc Completed in 0.8s (MAPE: 0.78%)
# Processing: collection1u00041s00001_hw00005.svc Completed in 0.7s (MAPE: 0.83%)
# Processing: collection1u00041s00001_hw00006.svc Completed in 1.4s (MAPE: 15.59%)
# Processing: collection1u00041s00001_hw00007.svc Completed in 1.6s (MAPE: 7.13%)
# Processing: collection1u00042s00001_hw00001.svc Completed in 1.1s (MAPE: 2.02%)
# Processing: collection1u00042s00001_hw00002.svc Completed in 1.7s (MAPE: 2.73%)
# Processing: collection1u00042s00001_hw00003.svc Completed in 1.6s (MAPE: 7.26%)
# Processing: collection1u00042s00001_hw00004.svc Completed in 0.8s (MAPE: 0.70%)
# Processing: collection1u00042s00001_hw00005.svc Completed in 0.7s (MAPE: 0.62%)
# Processing: collection1u00042s00001_hw00006.svc Completed in 1.4s (MAPE: 3.61%)
# Processing: collection1u00042s00001_hw00007.svc Completed in 1.7s (MAPE: 5.64%)
# Processing: collection1u00043s00001_hw00001.svc Completed in 1.3s (MAPE: 2.22%)
# Processing: collection1u00043s00001_hw00002.svc Completed in 1.5s (MAPE: 3.36%)
# Processing: collection1u00043s00001_hw00003.svc Completed in 1.7s (MAPE: 10.01%)
# Processing: collection1u00043s00001_hw00004.svc Completed in 1.0s (MAPE: 1.05%)
# Processing: collection1u00043s00001_hw00005.svc Completed in 0.6s (MAPE: 1.18%)
# Processing: collection1u00043s00001_hw00006.svc Completed in 1.4s (MAPE: 4.73%)
# Processing: collection1u00043s00001_hw00007.svc Completed in 1.7s (MAPE: 8.14%)
# Processing: collection1u00044s00001_hw00001.svc Completed in 1.4s (MAPE: 5.16%)
# Processing: collection1u00044s00001_hw00002.svc Completed in 1.8s (MAPE: 4.05%)
# Processing: collection1u00044s00001_hw00003.svc Completed in 1.6s (MAPE: 9.51%)
# Processing: collection1u00044s00001_hw00004.svc Completed in 0.7s (MAPE: 4.35%)
# Processing: collection1u00044s00001_hw00005.svc Completed in 1.1s (MAPE: 3.77%)
# Processing: collection1u00044s00001_hw00006.svc Completed in 1.6s (MAPE: 7.36%)
# Processing: collection1u00044s00001_hw00007.svc Completed in 1.6s (MAPE: 9.28%)
# Processing: collection1u00045s00001_hw00001.svc Completed in 1.3s (MAPE: 6.75%)
# Processing: collection1u00045s00001_hw00002.svc Completed in 1.4s (MAPE: 4.51%)
# Processing: collection1u00045s00001_hw00003.svc Completed in 1.7s (MAPE: 9.13%)
# Processing: collection1u00045s00001_hw00004.svc Completed in 0.9s (MAPE: 4.60%)
# Processing: collection1u00045s00001_hw00005.svc Completed in 1.0s (MAPE: 3.87%)
# Processing: collection1u00045s00001_hw00006.svc Completed in 1.6s (MAPE: 5.98%)
# Processing: collection1u00045s00001_hw00007.svc Completed in 1.6s (MAPE: 15.33%)
# Processing: u00001s00001_hw00001.svc Completed in 1.4s (MAPE: 3.09%)
# Processing: u00001s00001_hw00002.svc Completed in 1.8s (MAPE: 5.31%)
# Processing: u00001s00001_hw00003.svc Completed in 1.8s (MAPE: 12.67%)
# Processing: u00001s00001_hw00004.svc Completed in 1.6s (MAPE: 2.91%)
# Processing: u00001s00001_hw00005.svc Completed in 1.4s (MAPE: 3.62%)
# Processing: u00001s00001_hw00006.svc Completed in 1.7s (MAPE: 8.63%)
# Processing: u00001s00001_hw00007.svc Completed in 1.6s (MAPE: 11.43%)
# Processing: u00002s00001_hw00001.svc Completed in 1.2s (MAPE: 3.00%)
# Processing: u00002s00001_hw00002.svc Completed in 1.8s (MAPE: 7.05%)
# Processing: u00002s00001_hw00003.svc Completed in 1.7s (MAPE: 10.22%)
# Processing: u00002s00001_hw00004.svc Completed in 1.9s (MAPE: 7.68%)
# Processing: u00002s00001_hw00005.svc Completed in 1.9s (MAPE: 2.60%)
# Processing: u00002s00001_hw00006.svc Completed in 3.2s (MAPE: 8.11%)
# Processing: u00002s00001_hw00007.svc Completed in 2.6s (MAPE: 10.09%)
# Processing: u00003s00001_hw00001.svc Completed in 2.2s (MAPE: 7.30%)
# Processing: u00003s00001_hw00002.svc Completed in 1.8s (MAPE: 9.28%)
# Processing: u00003s00001_hw00003.svc Completed in 1.9s (MAPE: 16.45%)
# Processing: u00003s00001_hw00004.svc Completed in 1.5s (MAPE: 3.60%)
# Processing: u00003s00001_hw00005.svc Completed in 1.6s (MAPE: 2.59%)
# Processing: u00003s00001_hw00006.svc Completed in 1.7s (MAPE: 10.33%)
# Processing: u00003s00001_hw00007.svc Completed in 2.1s (MAPE: 12.49%)
# Processing: u00004s00001_hw00001.svc Completed in 1.5s (MAPE: 4.01%)
# Processing: u00004s00001_hw00002.svc Completed in 1.8s (MAPE: 6.35%)
# Processing: u00004s00001_hw00003.svc Completed in 1.7s (MAPE: 14.83%)
# Processing: u00004s00001_hw00004.svc Completed in 1.4s (MAPE: 9.84%)
# Processing: u00004s00001_hw00005.svc Completed in 1.6s (MAPE: 2.62%)
# Processing: u00004s00001_hw00006.svc Completed in 2.1s (MAPE: 4.71%)
# Processing: u00004s00001_hw00007.svc Completed in 1.8s (MAPE: 11.30%)
# Processing: u00005s00001_hw00001.svc Completed in 1.3s (MAPE: 6.97%)
# Processing: u00005s00001_hw00002.svc Completed in 1.6s (MAPE: 4.65%)
# Processing: u00005s00001_hw00003.svc Completed in 1.8s (MAPE: 12.23%)
# Processing: u00005s00001_hw00004.svc Completed in 1.3s (MAPE: 2.29%)
# Processing: u00005s00001_hw00005.svc Completed in 1.3s (MAPE: 2.95%)
# Processing: u00005s00001_hw00006.svc Completed in 2.2s (MAPE: 6.33%)
# Processing: u00005s00001_hw00007.svc Completed in 1.5s (MAPE: 12.42%)
# Processing: u00006s00001_hw00001.svc Completed in 1.8s (MAPE: 4.57%)
# Processing: u00006s00001_hw00002.svc Completed in 1.9s (MAPE: 4.56%)
# Processing: u00006s00001_hw00003.svc Completed in 2.1s (MAPE: 9.45%)
# Processing: u00006s00001_hw00004.svc Completed in 1.4s (MAPE: 9.38%)
# Processing: u00006s00001_hw00005.svc Completed in 1.5s (MAPE: 2.21%)
# Processing: u00006s00001_hw00006.svc Completed in 2.3s (MAPE: 9.32%)
# Processing: u00006s00001_hw00007.svc Completed in 1.8s (MAPE: 12.36%)
# Processing: u00007s00001_hw00001.svc Completed in 2.0s (MAPE: 4.78%)
# Processing: u00007s00001_hw00002.svc Completed in 2.0s (MAPE: 4.36%)
# Processing: u00007s00001_hw00003.svc Completed in 1.8s (MAPE: 11.52%)
# Processing: u00007s00001_hw00004.svc Completed in 1.5s (MAPE: 2.13%)
# Processing: u00007s00001_hw00005.svc Completed in 1.6s (MAPE: 3.37%)
# Processing: u00007s00001_hw00006.svc Completed in 1.8s (MAPE: 4.55%)
# Processing: u00007s00001_hw00007.svc Completed in 1.6s (MAPE: 9.13%)
# Processing: u00008s00001_hw00001.svc Completed in 1.9s (MAPE: 3.94%)
# Processing: u00008s00001_hw00002.svc Completed in 2.4s (MAPE: 5.22%)
# Processing: u00008s00001_hw00003.svc Completed in 1.8s (MAPE: 11.11%)
# Processing: u00008s00001_hw00004.svc Completed in 1.3s (MAPE: 2.14%)
# Processing: u00008s00001_hw00005.svc Completed in 1.3s (MAPE: 3.02%)
# Processing: u00008s00001_hw00006.svc Completed in 2.1s (MAPE: 6.98%)
# Processing: u00008s00001_hw00007.svc Completed in 1.6s (MAPE: 12.54%)
# Processing: u00009s00001_hw00001.svc Completed in 1.7s (MAPE: 6.06%)
# Processing: u00009s00001_hw00002.svc Completed in 1.9s (MAPE: 4.27%)
# Processing: u00009s00001_hw00003.svc Completed in 2.0s (MAPE: 10.41%)
# Processing: u00009s00001_hw00004.svc Completed in 1.3s (MAPE: 4.53%)
# Processing: u00009s00001_hw00005.svc Completed in 1.3s (MAPE: 2.74%)
# Processing: u00009s00001_hw00006.svc Completed in 2.0s (MAPE: 5.29%)
# Processing: u00009s00001_hw00007.svc Completed in 1.9s (MAPE: 11.91%)
# Processing: u00010s00001_hw00001.svc Completed in 1.8s (MAPE: 5.85%)
# Processing: u00010s00001_hw00002.svc Completed in 2.1s (MAPE: 7.01%)
# Processing: u00010s00001_hw00003.svc Completed in 1.8s (MAPE: 10.10%)
# Processing: u00010s00001_hw00004.svc Completed in 1.4s (MAPE: 4.25%)
# Processing: u00010s00001_hw00005.svc Completed in 1.3s (MAPE: 4.00%)
# Processing: u00010s00001_hw00006.svc Completed in 1.6s (MAPE: 8.80%)
# Processing: u00010s00001_hw00007.svc Completed in 1.6s (MAPE: 11.42%)
# Processing: u00011s00001_hw00001.svc Completed in 1.5s (MAPE: 5.96%)
# Processing: u00011s00001_hw00002.svc Completed in 1.8s (MAPE: 7.01%)
# Processing: u00011s00001_hw00003.svc Completed in 1.6s (MAPE: 10.15%)
# Processing: u00011s00001_hw00004.svc Completed in 1.2s (MAPE: 3.24%)
# Processing: u00011s00001_hw00005.svc Completed in 1.3s (MAPE: 3.78%)
# Processing: u00011s00001_hw00006.svc Completed in 1.6s (MAPE: 8.01%)
# Processing: u00011s00001_hw00007.svc Completed in 1.7s (MAPE: 10.68%)
# Processing: u00012s00001_hw00001.svc Completed in 1.3s (MAPE: 6.77%)
# Processing: u00012s00001_hw00002.svc Completed in 1.7s (MAPE: 5.08%)
# Processing: u00012s00001_hw00003.svc Completed in 1.7s (MAPE: 10.42%)
# Processing: u00012s00001_hw00004.svc Completed in 1.3s (MAPE: 3.53%)
# Processing: u00012s00001_hw00005.svc Completed in 1.5s (MAPE: 2.83%)
# Processing: u00012s00001_hw00006.svc Completed in 1.6s (MAPE: 6.93%)
# Processing: u00012s00001_hw00007.svc Completed in 1.6s (MAPE: 11.48%)
# Processing: u00013s00001_hw00001.svc Completed in 1.2s (MAPE: 4.00%)
# Processing: u00013s00001_hw00002.svc Completed in 1.8s (MAPE: 4.49%)
# Processing: u00013s00001_hw00003.svc Completed in 1.6s (MAPE: 9.85%)
# Processing: u00013s00001_hw00004.svc Completed in 1.6s (MAPE: 1.66%)
# Processing: u00013s00001_hw00005.svc Completed in 1.3s (MAPE: 1.42%)
# Processing: u00013s00001_hw00006.svc Completed in 1.6s (MAPE: 4.87%)
# Processing: u00013s00001_hw00007.svc Completed in 1.5s (MAPE: 7.22%)
# Processing: u00014s00001_hw00001.svc Completed in 1.4s (MAPE: 3.60%)
# Processing: u00014s00001_hw00002.svc Completed in 1.7s (MAPE: 7.42%)
# Processing: u00014s00001_hw00003.svc Completed in 1.7s (MAPE: 10.98%)
# Processing: u00014s00001_hw00004.svc Completed in 1.3s (MAPE: 1.37%)
# Processing: u00014s00001_hw00005.svc Completed in 1.3s (MAPE: 1.29%)
# Processing: u00014s00001_hw00006.svc Completed in 1.5s (MAPE: 9.73%)
# Processing: u00014s00001_hw00007.svc Completed in 1.7s (MAPE: 11.91%)
# Processing: u00015s00001_hw00001.svc Completed in 1.6s (MAPE: 1.47%)
# Processing: u00015s00001_hw00002.svc Completed in 1.7s (MAPE: 4.34%)
# Processing: u00015s00001_hw00003.svc Completed in 1.7s (MAPE: 10.28%)
# Processing: u00015s00001_hw00004.svc Completed in 1.5s (MAPE: 1.20%)
# Processing: u00015s00001_hw00005.svc Completed in 1.8s (MAPE: 1.52%)
# Processing: u00015s00001_hw00006.svc Completed in 2.0s (MAPE: 9.20%)
# Processing: u00015s00001_hw00007.svc Completed in 2.0s (MAPE: 7.64%)
# Processing: u00016s00001_hw00001.svc Completed in 1.5s (MAPE: 9.47%)
# Processing: u00016s00001_hw00002.svc Completed in 1.8s (MAPE: 7.34%)
# Processing: u00016s00001_hw00003.svc Completed in 1.8s (MAPE: 11.21%)
# Processing: u00016s00001_hw00004.svc Completed in 1.4s (MAPE: 0.98%)
# Processing: u00016s00001_hw00005.svc Completed in 1.3s (MAPE: 0.79%)
# Processing: u00016s00001_hw00006.svc Completed in 1.5s (MAPE: 8.74%)
# Processing: u00016s00001_hw00007.svc Completed in 1.5s (MAPE: 9.12%)
# Processing: u00017s00001_hw00001.svc Completed in 1.8s (MAPE: 4.90%)
# Processing: u00017s00001_hw00002.svc Completed in 2.3s (MAPE: 6.68%)
# Processing: u00017s00001_hw00003.svc Completed in 2.0s (MAPE: 12.08%)
# Processing: u00017s00001_hw00004.svc Completed in 1.6s (MAPE: 2.11%)
# Processing: u00017s00001_hw00005.svc Completed in 1.8s (MAPE: 0.71%)
# Processing: u00017s00001_hw00006.svc Completed in 2.2s (MAPE: 8.62%)
# Processing: u00017s00001_hw00007.svc Completed in 1.6s (MAPE: 9.89%)
# Processing: u00018s00001_hw00001.svc Completed in 1.6s (MAPE: 4.97%)
# Processing: u00018s00001_hw00002.svc Completed in 1.6s (MAPE: 6.80%)
# Processing: u00018s00001_hw00003.svc Completed in 1.6s (MAPE: 9.83%)
# Processing: u00018s00001_hw00004.svc Completed in 1.4s (MAPE: 1.17%)
# Processing: u00018s00001_hw00005.svc Completed in 1.3s (MAPE: 1.29%)
# Processing: u00018s00001_hw00006.svc Completed in 1.6s (MAPE: 7.29%)
# Processing: u00018s00001_hw00007.svc Completed in 1.6s (MAPE: 8.76%)
# Processing: u00019s00001_hw00001.svc Completed in 1.2s (MAPE: 3.80%)
# Processing: u00019s00001_hw00002.svc Completed in 1.7s (MAPE: 7.52%)
# Processing: u00019s00001_hw00003.svc Completed in 1.7s (MAPE: 10.14%)
# Processing: u00019s00001_hw00004.svc Completed in 1.3s (MAPE: 0.75%)
# Processing: u00019s00001_hw00005.svc Completed in 1.6s (MAPE: 0.77%)
# Processing: u00019s00001_hw00006.svc Completed in 1.6s (MAPE: 8.60%)
# Processing: u00019s00001_hw00007.svc Completed in 1.6s (MAPE: 10.62%)
# Processing: u00020s00001_hw00001.svc Completed in 1.2s (MAPE: 1.84%)
# Processing: u00020s00001_hw00002.svc Completed in 1.8s (MAPE: 3.21%)
# Processing: u00020s00001_hw00003.svc Completed in 2.0s (MAPE: 10.23%)
# Processing: u00020s00001_hw00004.svc Completed in 1.4s (MAPE: 2.47%)
# Processing: u00020s00001_hw00005.svc Completed in 1.3s (MAPE: 1.26%)
# Processing: u00020s00001_hw00006.svc Completed in 1.5s (MAPE: 7.94%)
# Processing: u00020s00001_hw00007.svc Completed in 1.6s (MAPE: 7.48%)
# Processing: u00021s00001_hw00001.svc Completed in 1.6s (MAPE: 4.39%)
# Processing: u00021s00001_hw00002.svc Completed in 1.7s (MAPE: 5.61%)
# Processing: u00021s00001_hw00003.svc Completed in 1.7s (MAPE: 11.87%)
# Processing: u00021s00001_hw00004.svc Completed in 1.4s (MAPE: 2.65%)
# Processing: u00021s00001_hw00005.svc Completed in 1.5s (MAPE: 1.22%)
# Processing: u00021s00001_hw00006.svc Completed in 1.9s (MAPE: 6.88%)
# Processing: u00021s00001_hw00007.svc Completed in 1.7s (MAPE: 10.52%)
# Processing: u00022s00001_hw00001.svc Completed in 1.5s (MAPE: 7.47%)
# Processing: u00022s00001_hw00002.svc Completed in 1.7s (MAPE: 7.95%)
# Processing: u00022s00001_hw00003.svc Completed in 1.7s (MAPE: 9.61%)
# Processing: u00022s00001_hw00004.svc Completed in 1.3s (MAPE: 1.00%)
# Processing: u00022s00001_hw00005.svc Completed in 1.4s (MAPE: 2.20%)
# Processing: u00022s00001_hw00006.svc Completed in 1.7s (MAPE: 7.99%)
# Processing: u00022s00001_hw00007.svc Completed in 1.5s (MAPE: 8.52%)
# Processing: u00023s00001_hw00001.svc Completed in 1.2s (MAPE: 9.00%)
# Processing: u00023s00001_hw00002.svc Completed in 1.4s (MAPE: 8.75%)
# Processing: u00023s00001_hw00003.svc Completed in 1.7s (MAPE: 10.15%)
# Processing: u00023s00001_hw00004.svc Completed in 1.3s (MAPE: 2.31%)
# Processing: u00023s00001_hw00005.svc Completed in 1.4s (MAPE: 1.37%)
# Processing: u00023s00001_hw00006.svc Completed in 1.4s (MAPE: 9.75%)
# Processing: u00023s00001_hw00007.svc Completed in 1.4s (MAPE: 9.33%)
# Processing: u00024s00001_hw00001.svc Completed in 1.3s (MAPE: 5.77%)
# Processing: u00024s00001_hw00002.svc Completed in 1.8s (MAPE: 5.98%)
# Processing: u00024s00001_hw00003.svc Completed in 1.6s (MAPE: 11.96%)
# Processing: u00024s00001_hw00004.svc Completed in 1.3s (MAPE: 4.50%)
# Processing: u00024s00001_hw00005.svc Completed in 1.4s (MAPE: 1.38%)
# Processing: u00024s00001_hw00006.svc Completed in 1.7s (MAPE: 6.79%)
# Processing: u00024s00001_hw00007.svc Completed in 1.5s (MAPE: 11.44%)
# Processing: u00025s00001_hw00001.svc Completed in 1.5s (MAPE: 6.43%)
# Processing: u00025s00001_hw00002.svc Completed in 1.8s (MAPE: 6.83%)
# Processing: u00025s00001_hw00003.svc Completed in 1.8s (MAPE: 10.06%)
# Processing: u00025s00001_hw00004.svc Completed in 1.4s (MAPE: 5.71%)
# Processing: u00025s00001_hw00005.svc Completed in 1.5s (MAPE: 0.61%)
# Processing: u00025s00001_hw00006.svc Completed in 1.9s (MAPE: 7.33%)
# Processing: u00025s00001_hw00007.svc Completed in 1.7s (MAPE: 9.33%)
# Processing: u00026s00001_hw00001.svc Completed in 1.3s (MAPE: 3.19%)
# Processing: u00026s00001_hw00002.svc Completed in 1.7s (MAPE: 5.72%)
# Processing: u00026s00001_hw00003.svc Completed in 1.6s (MAPE: 10.29%)
# Processing: u00026s00001_hw00004.svc Completed in 1.3s (MAPE: 0.56%)
# Processing: u00026s00001_hw00005.svc Completed in 1.4s (MAPE: 0.76%)
# Processing: u00026s00001_hw00006.svc Completed in 1.6s (MAPE: 6.73%)
# Processing: u00026s00001_hw00007.svc Completed in 1.7s (MAPE: 10.37%)
# Processing: u00027s00001_hw00001.svc Completed in 1.5s (MAPE: 4.17%)
# Processing: u00027s00001_hw00002.svc Completed in 1.9s (MAPE: 6.26%)
# Processing: u00027s00001_hw00003.svc Completed in 1.9s (MAPE: 8.90%)
# Processing: u00027s00001_hw00004.svc Completed in 1.4s (MAPE: 2.74%)
# Processing: u00027s00001_hw00005.svc Completed in 1.3s (MAPE: 2.34%)
# Processing: u00027s00001_hw00006.svc Completed in 2.0s (MAPE: 6.27%)
# Processing: u00027s00001_hw00007.svc Completed in 1.7s (MAPE: 11.13%)
# Processing: u00028s00001_hw00001.svc Completed in 1.7s (MAPE: 5.96%)
# Processing: u00028s00001_hw00002.svc Completed in 1.9s (MAPE: 4.29%)
# Processing: u00028s00001_hw00003.svc Completed in 1.9s (MAPE: 10.28%)
# Processing: u00028s00001_hw00004.svc Completed in 1.3s (MAPE: 5.69%)
# Processing: u00028s00001_hw00005.svc Completed in 1.2s (MAPE: 3.08%)
# Processing: u00028s00001_hw00006.svc Completed in 2.0s (MAPE: 7.17%)
# Processing: u00028s00001_hw00007.svc Completed in 1.7s (MAPE: 10.57%)
# Processing: u00029s00001_hw00001.svc Completed in 1.5s (MAPE: 2.40%)
# Processing: u00029s00001_hw00002.svc Completed in 2.1s (MAPE: 6.15%)
# Processing: u00029s00001_hw00003.svc Completed in 1.9s (MAPE: 8.29%)
# Processing: u00029s00001_hw00004.svc Completed in 1.3s (MAPE: 0.89%)
# Processing: u00029s00001_hw00005.svc Completed in 1.4s (MAPE: 0.86%)
# Processing: u00029s00001_hw00006.svc Completed in 1.9s (MAPE: 4.88%)
# Processing: u00029s00001_hw00007.svc Completed in 1.6s (MAPE: 4.93%)
# Processing: u00030s00001_hw00001.svc Completed in 1.7s (MAPE: 8.46%)
# Processing: u00030s00001_hw00002.svc Completed in 2.0s (MAPE: 8.33%)
# Processing: u00030s00001_hw00003.svc Completed in 1.9s (MAPE: 10.47%)
# Processing: u00030s00001_hw00004.svc Completed in 1.3s (MAPE: 1.04%)
# Processing: u00030s00001_hw00005.svc Completed in 1.3s (MAPE: 1.96%)
# Processing: u00030s00001_hw00006.svc Completed in 1.8s (MAPE: 10.09%)
# Processing: u00030s00001_hw00007.svc Completed in 1.7s (MAPE: 9.32%)
# Processing: u00031s00001_hw00001.svc Completed in 1.4s (MAPE: 3.69%)
# Processing: u00031s00001_hw00002.svc Completed in 1.8s (MAPE: 7.52%)
# Processing: u00031s00001_hw00003.svc Completed in 1.8s (MAPE: 11.46%)
# Processing: u00031s00001_hw00004.svc Completed in 1.3s (MAPE: 3.47%)
# Processing: u00031s00001_hw00005.svc Completed in 1.2s (MAPE: 2.90%)
# Processing: u00031s00001_hw00006.svc Completed in 1.8s (MAPE: 8.79%)
# Processing: u00031s00001_hw00007.svc Completed in 1.6s (MAPE: 8.22%)
# Processing: u00032s00001_hw00001.svc Completed in 1.6s (MAPE: 7.98%)
# Processing: u00032s00001_hw00002.svc Completed in 1.6s (MAPE: 8.28%)
# Processing: u00032s00001_hw00003.svc Completed in 1.8s (MAPE: 10.28%)
# Processing: u00032s00001_hw00004.svc Completed in 1.4s (MAPE: 7.85%)
# Processing: u00032s00001_hw00005.svc Completed in 1.4s (MAPE: 0.88%)
# Processing: u00032s00001_hw00006.svc Completed in 7.6s (MAPE: 10.38%)
# Processing: u00032s00001_hw00007.svc Completed in 2.4s (MAPE: 10.20%)
# Processing: u00033s00001_hw00001.svc Completed in 1.9s (MAPE: 3.43%)
# Processing: u00033s00001_hw00002.svc Completed in 2.2s (MAPE: 6.32%)
# Processing: u00033s00001_hw00003.svc Completed in 1.8s (MAPE: 9.12%)
# Processing: u00033s00001_hw00004.svc Completed in 0.1s (MAPE: 11.49%)
# Processing: u00033s00001_hw00005.svc Completed in 1.3s (MAPE: 0.84%)
# Processing: u00033s00001_hw00006.svc Completed in 1.7s (MAPE: 7.48%)
# Processing: u00033s00001_hw00007.svc Completed in 1.6s (MAPE: 5.94%)
# Processing: u00034s00001_hw00001.svc Completed in 1.5s (MAPE: 2.34%)
# Processing: u00034s00001_hw00002.svc Completed in 1.9s (MAPE: 4.06%)
# Processing: u00034s00001_hw00003.svc Completed in 1.6s (MAPE: 9.90%)
# Processing: u00034s00001_hw00004.svc Completed in 1.3s (MAPE: 0.59%)
# Processing: u00034s00001_hw00005.svc Completed in 1.2s (MAPE: 0.87%)
# Processing: u00034s00001_hw00006.svc Completed in 1.8s (MAPE: 5.98%)
# Processing: u00034s00001_hw00007.svc Completed in 1.6s (MAPE: 7.92%)
# Processing: u00035s00001_hw00001.svc Completed in 1.3s (MAPE: 4.73%)
# Processing: u00035s00001_hw00002.svc Completed in 1.5s (MAPE: 7.85%)
# Processing: u00035s00001_hw00003.svc Completed in 1.6s (MAPE: 10.42%)
# Processing: u00035s00001_hw00004.svc Completed in 1.3s (MAPE: 3.95%)
# Processing: u00035s00001_hw00005.svc Completed in 1.3s (MAPE: 1.70%)
# Processing: u00035s00001_hw00006.svc Completed in 1.7s (MAPE: 7.39%)
# Processing: u00035s00001_hw00007.svc Completed in 1.4s (MAPE: 9.32%)
# Processing: u00036s00001_hw00001.svc Completed in 1.2s (MAPE: 2.63%)
# Processing: u00036s00001_hw00002.svc Completed in 1.8s (MAPE: 2.56%)
# Processing: u00036s00001_hw00003.svc Completed in 1.7s (MAPE: 9.20%)
# Processing: u00036s00001_hw00004.svc Completed in 1.4s (MAPE: 4.03%)
# Processing: u00036s00001_hw00005.svc Completed in 1.3s (MAPE: 0.94%)
# Processing: u00036s00001_hw00006.svc Completed in 1.8s (MAPE: 6.57%)
# Processing: u00036s00001_hw00007.svc Completed in 1.5s (MAPE: 6.55%)
# Processing: u00037s00001_hw00001.svc Completed in 1.3s (MAPE: 4.50%)
# Processing: u00037s00001_hw00002.svc Completed in 1.7s (MAPE: 7.59%)
# Processing: u00037s00001_hw00003.svc Completed in 1.7s (MAPE: 10.83%)
# Processing: u00037s00001_hw00004.svc Completed in 1.3s (MAPE: 4.06%)
# Processing: u00037s00001_hw00005.svc Completed in 1.4s (MAPE: 1.36%)
# Processing: u00037s00001_hw00006.svc Completed in 1.7s (MAPE: 11.00%)
# Processing: u00037s00001_hw00007.svc Completed in 1.5s (MAPE: 10.81%)
# Processing: u00038s00001_hw00001.svc Completed in 1.3s (MAPE: 3.56%)
# Processing: u00038s00001_hw00002.svc Completed in 1.6s (MAPE: 3.15%)
# Processing: u00038s00001_hw00003.svc Completed in 1.7s (MAPE: 12.34%)
# Processing: u00038s00001_hw00004.svc Completed in 1.3s (MAPE: 1.27%)
# Processing: u00038s00001_hw00005.svc Completed in 1.4s (MAPE: 0.98%)
# Processing: u00038s00001_hw00006.svc Completed in 1.6s (MAPE: 5.27%)
# Processing: u00038s00001_hw00007.svc Completed in 1.5s (MAPE: 6.42%)
# Processing: u00039s00001_hw00001.svc Completed in 1.3s (MAPE: 2.79%)
# Processing: u00039s00001_hw00002.svc Completed in 1.6s (MAPE: 5.55%)
# Processing: u00039s00001_hw00003.svc Completed in 1.9s (MAPE: 9.40%)
# Processing: u00039s00001_hw00004.svc Completed in 1.3s (MAPE: 5.63%)
# Processing: u00039s00001_hw00005.svc Completed in 1.3s (MAPE: 1.51%)
# Processing: u00039s00001_hw00006.svc Completed in 1.7s (MAPE: 8.72%)
# Processing: u00039s00001_hw00007.svc Completed in 1.5s (MAPE: 5.62%)
# Processing: u00040s00001_hw00001.svc Completed in 1.5s (MAPE: 3.09%)
# Processing: u00040s00001_hw00002.svc Completed in 1.7s (MAPE: 4.93%)
# Processing: u00040s00001_hw00003.svc Completed in 1.8s (MAPE: 9.41%)
# Processing: u00040s00001_hw00004.svc Completed in 1.3s (MAPE: 2.82%)
# Processing: u00040s00001_hw00005.svc Completed in 1.3s (MAPE: 0.86%)
# Processing: u00040s00001_hw00006.svc Completed in 1.6s (MAPE: 6.31%)
# Processing: u00040s00001_hw00007.svc Completed in 1.5s (MAPE: 6.94%)
# Processing: u00041s00001_hw00001.svc Completed in 1.5s (MAPE: 7.96%)
# Processing: u00041s00001_hw00002.svc Completed in 1.6s (MAPE: 7.04%)
# Processing: u00041s00001_hw00003.svc Completed in 1.5s (MAPE: 9.18%)
# Processing: u00041s00001_hw00004.svc Completed in 1.3s (MAPE: 2.78%)
# Processing: u00041s00001_hw00005.svc Completed in 1.4s (MAPE: 0.97%)
# Processing: u00041s00001_hw00006.svc Completed in 1.5s (MAPE: 9.07%)
# Processing: u00041s00001_hw00007.svc Completed in 1.4s (MAPE: 7.10%)
# Processing: u00042s00001_hw00001.svc Completed in 1.4s (MAPE: 5.36%)
# Processing: u00042s00001_hw00002.svc Completed in 1.8s (MAPE: 3.67%)
# Processing: u00042s00001_hw00003.svc Completed in 1.7s (MAPE: 10.59%)
# Processing: u00042s00001_hw00004.svc Completed in 1.4s (MAPE: 1.48%)
# Processing: u00042s00001_hw00005.svc Completed in 1.2s (MAPE: 1.90%)
# Processing: u00042s00001_hw00006.svc Completed in 1.6s (MAPE: 7.11%)
# Processing: u00042s00001_hw00007.svc Completed in 1.6s (MAPE: 5.32%)
# Processing: u00043s00001_hw00001.svc Completed in 1.4s (MAPE: 5.53%)
# Processing: u00043s00001_hw00002.svc Completed in 2.0s (MAPE: 9.04%)
# Processing: u00043s00001_hw00003.svc Completed in 1.8s (MAPE: 10.52%)
# Processing: u00043s00001_hw00004.svc Completed in 1.3s (MAPE: 1.17%)
# Processing: u00043s00001_hw00005.svc Completed in 1.3s (MAPE: 1.71%)
# Processing: u00043s00001_hw00006.svc Completed in 1.8s (MAPE: 7.17%)
# Processing: u00043s00001_hw00007.svc Completed in 1.6s (MAPE: 8.91%)
# Processing: u00044s00001_hw00001.svc Completed in 1.5s (MAPE: 5.29%)
# Processing: u00044s00001_hw00002.svc Completed in 1.7s (MAPE: 6.23%)
# Processing: u00044s00001_hw00003.svc Completed in 2.0s (MAPE: 9.87%)
# Processing: u00044s00001_hw00004.svc Completed in 1.2s (MAPE: 2.98%)
# Processing: u00044s00001_hw00005.svc Completed in 1.3s (MAPE: 1.60%)
# Processing: u00044s00001_hw00006.svc Completed in 1.6s (MAPE: 6.85%)
# Processing: u00044s00001_hw00007.svc Completed in 1.6s (MAPE: 6.98%)
# Processing: u00045s00001_hw00001.svc Completed in 1.2s (MAPE: 3.88%)
# Processing: u00045s00001_hw00002.svc Completed in 1.8s (MAPE: 5.95%)
# Processing: u00045s00001_hw00003.svc Completed in 1.7s (MAPE: 11.60%)
# Processing: u00045s00001_hw00004.svc Completed in 1.4s (MAPE: 2.19%)
# Processing: u00045s00001_hw00005.svc Completed in 1.3s (MAPE: 0.86%)
# Processing: u00045s00001_hw00006.svc Completed in 1.7s (MAPE: 6.26%)
# Processing: u00045s00001_hw00007.svc Completed in 1.6s (MAPE: 8.82%)
# Processing: u00046s00001_hw00001.svc Completed in 1.3s (MAPE: 3.77%)
# Processing: u00046s00001_hw00002.svc Completed in 1.6s (MAPE: 7.13%)
# Processing: u00046s00001_hw00003.svc Completed in 1.5s (MAPE: 9.82%)
# Processing: u00046s00001_hw00004.svc Completed in 1.3s (MAPE: 3.66%)
# Processing: u00046s00001_hw00005.svc Completed in 1.4s (MAPE: 1.90%)
# Processing: u00046s00001_hw00006.svc Completed in 1.7s (MAPE: 5.80%)
# Processing: u00046s00001_hw00007.svc Completed in 1.9s (MAPE: 12.91%)
# Processing: u00047s00001_hw00001.svc Completed in 1.0s (MAPE: 4.46%)
# Processing: u00047s00001_hw00002.svc Completed in 1.5s (MAPE: 4.97%)
# Processing: u00047s00001_hw00003.svc Completed in 1.8s (MAPE: 7.90%)
# Processing: u00047s00001_hw00004.svc Completed in 1.3s (MAPE: 2.59%)
# Processing: u00047s00001_hw00005.svc Completed in 1.4s (MAPE: 2.20%)
# Processing: u00047s00001_hw00006.svc Completed in 1.6s (MAPE: 7.98%)
# Processing: u00047s00001_hw00007.svc Completed in 1.6s (MAPE: 9.36%)
# ...
# Processing: u00052s00001_hw00002.svc Completed in 1.9s (MAPE: 5.26%)
# Processing: u00052s00001_hw00003.svc Completed in 1.7s (MAPE: 9.54%)
# Processing: u00052s00001_hw00004.svc Completed in 1.2s (MAPE: 1.45%)
# Processing: u00052s00001_hw00005.svc Completed in 1.4s (MAPE: 1.77%)
# Processing: u00052s00001_hw00006.svc Completed in 1.7s (MAPE: 10.54%)
# Processing: u00052s00001_hw00007.svc Completed in 1.6s (MAPE: 5.90%)
# Processing: u00053s00001_hw00001.svc Completed in 1.3s (MAPE: 2.92%)
# Processing: u00053s00001_hw00002.svc Completed in 1.8s (MAPE: 5.26%)
# Processing: u00053s00001_hw00003.svc Completed in 1.7s (MAPE: 10.43%)
# Processing: u00053s00001_hw00004.svc Completed in 1.3s (MAPE: 1.44%)
# Processing: u00053s00001_hw00005.svc Completed in 1.4s (MAPE: 1.79%)
# Processing: u00053s00001_hw00006.svc Completed in 1.6s (MAPE: 6.61%)
# Processing: u00053s00001_hw00007.svc Completed in 1.8s (MAPE: 10.82%)
# Processing: u00054s00001_hw00001.svc Completed in 2.2s (MAPE: 2.30%)
# Processing: u00054s00001_hw00002.svc Completed in 2.1s (MAPE: 6.52%)
# Processing: u00054s00001_hw00003.svc Completed in 1.6s (MAPE: 9.69%)
# Processing: u00054s00001_hw00004.svc Completed in 1.4s (MAPE: 4.99%)
# Processing: u00054s00001_hw00005.svc Completed in 1.3s (MAPE: 1.75%)
# Processing: u00054s00001_hw00006.svc Completed in 1.8s (MAPE: 4.63%)
# Processing: u00054s00001_hw00007.svc Completed in 1.7s (MAPE: 8.06%)
# Processing: u00055s00001_hw00001.svc Completed in 1.4s (MAPE: 5.29%)
# Processing: u00055s00001_hw00002.svc Completed in 1.7s (MAPE: 7.62%)
# Processing: u00055s00001_hw00003.svc Completed in 1.7s (MAPE: 11.03%)
# Processing: u00055s00001_hw00004.svc Completed in 1.4s (MAPE: 4.66%)
# Processing: u00055s00001_hw00005.svc Completed in 1.2s (MAPE: 1.30%)
# Processing: u00055s00001_hw00006.svc Completed in 1.6s (MAPE: 7.44%)
# Processing: u00055s00001_hw00007.svc Completed in 1.5s (MAPE: 10.85%)
# Processing: u00056s00001_hw00001.svc Completed in 1.0s (MAPE: 1.23%)
# Processing: u00056s00001_hw00002.svc Completed in 1.7s (MAPE: 2.49%)
# Processing: u00056s00001_hw00003.svc Completed in 1.7s (MAPE: 9.08%)
# Processing: u00056s00001_hw00004.svc Completed in 1.2s (MAPE: 0.60%)
# Processing: u00056s00001_hw00005.svc Completed in 1.1s (MAPE: 0.42%)
# Processing: u00056s00001_hw00006.svc Completed in 1.5s (MAPE: 6.46%)
# Processing: u00056s00001_hw00007.svc Completed in 1.8s (MAPE: 7.37%)
# Processing: u00057s00001_hw00001.svc Completed in 1.6s (MAPE: 3.90%)
# Processing: u00057s00001_hw00002.svc Completed in 1.7s (MAPE: 5.21%)
# Processing: u00057s00001_hw00003.svc Completed in 1.7s (MAPE: 10.71%)
# Processing: u00057s00001_hw00004.svc Completed in 1.3s (MAPE: 2.82%)
# Processing: u00057s00001_hw00005.svc Completed in 1.4s (MAPE: 0.96%)
# Processing: u00057s00001_hw00006.svc Completed in 1.5s (MAPE: 5.97%)
# Processing: u00057s00001_hw00007.svc Completed in 1.6s (MAPE: 7.67%)
# Processing: u00058s00001_hw00001.svc Completed in 1.4s (MAPE: 4.60%)
# Processing: u00058s00001_hw00002.svc Completed in 1.5s (MAPE: 5.22%)
# Processing: u00058s00001_hw00003.svc Completed in 3.1s (MAPE: 11.79%)
# Processing: u00058s00001_hw00004.svc Completed in 1.6s (MAPE: 0.50%)
# Processing: u00058s00001_hw00005.svc Completed in 1.2s (MAPE: 0.34%)
# Processing: u00058s00001_hw00006.svc Completed in 1.7s (MAPE: 9.62%)
# Processing: u00058s00001_hw00007.svc Completed in 2.2s (MAPE: 10.56%)
# Processing: u00059s00001_hw00001.svc Completed in 1.6s (MAPE: 8.44%)
# Processing: u00059s00001_hw00002.svc Completed in 2.0s (MAPE: 7.51%)
# Processing: u00059s00001_hw00003.svc Completed in 1.6s (MAPE: 8.82%)
# Processing: u00059s00001_hw00004.svc Completed in 1.1s (MAPE: 3.72%)
# Processing: u00059s00001_hw00005.svc Completed in 1.1s (MAPE: 0.39%)
# Processing: u00059s00001_hw00006.svc Completed in 1.6s (MAPE: 9.36%)
# Processing: u00059s00001_hw00007.svc Completed in 1.6s (MAPE: 7.18%)
# Processing: u00060s00001_hw00001.svc Completed in 1.5s (MAPE: 8.62%)
# Processing: u00060s00001_hw00002.svc Completed in 1.9s (MAPE: 8.49%)
# Processing: u00060s00001_hw00003.svc Completed in 1.6s (MAPE: 10.04%)
# Processing: u00060s00001_hw00004.svc Completed in 1.2s (MAPE: 0.76%)
# Processing: u00060s00001_hw00005.svc Completed in 1.3s (MAPE: 0.79%)
# Processing: u00060s00001_hw00006.svc Completed in 1.7s (MAPE: 7.21%)
# Processing: u00060s00001_hw00007.svc Completed in 1.7s (MAPE: 9.02%)
# Processing: u00061s00001_hw00001.svc Completed in 1.5s (MAPE: 4.67%)
# Processing: u00061s00001_hw00002.svc Completed in 1.7s (MAPE: 5.26%)
# Processing: u00061s00001_hw00003.svc Completed in 1.5s (MAPE: 10.06%)
# Processing: u00061s00001_hw00004.svc Completed in 1.0s (MAPE: 1.28%)
# Processing: u00061s00001_hw00005.svc Completed in 1.1s (MAPE: 0.36%)
# Processing: u00061s00001_hw00006.svc Completed in 2.0s (MAPE: 7.53%)
# Processing: u00061s00001_hw00007.svc Completed in 1.6s (MAPE: 8.63%)
# Processing: u00062s00001_hw00001.svc Completed in 1.3s (MAPE: 4.32%)
# Processing: u00062s00001_hw00002.svc Completed in 1.5s (MAPE: 5.88%)
# Processing: u00062s00001_hw00003.svc Completed in 1.5s (MAPE: 9.68%)
# Processing: u00062s00001_hw00004.svc Completed in 1.1s (MAPE: 2.87%)
# Processing: u00062s00001_hw00005.svc Completed in 1.3s (MAPE: 0.50%)
# Processing: u00062s00001_hw00006.svc Completed in 1.6s (MAPE: 9.88%)
# Processing: u00062s00001_hw00007.svc Completed in 1.6s (MAPE: 8.97%)
# Processing: u00063s00001_hw00001.svc Completed in 1.6s (MAPE: 3.74%)
# Processing: u00063s00001_hw00002.svc Completed in 1.6s (MAPE: 6.55%)
# Processing: u00063s00001_hw00003.svc Completed in 1.6s (MAPE: 10.49%)
# Processing: u00063s00001_hw00004.svc Completed in 1.1s (MAPE: 0.44%)
# Processing: u00063s00001_hw00005.svc Completed in 1.3s (MAPE: 0.40%)
# Processing: u00063s00001_hw00006.svc Completed in 1.9s (MAPE: 7.47%)
# Processing: u00063s00001_hw00007.svc Completed in 1.7s (MAPE: 8.02%)
# Processing: u00064s00001_hw00001.svc Completed in 1.3s (MAPE: 2.00%)
# Processing: u00064s00001_hw00002.svc Completed in 1.6s (MAPE: 4.22%)
# Processing: u00064s00001_hw00003.svc Completed in 1.6s (MAPE: 9.65%)
# Processing: u00064s00001_hw00004.svc Completed in 1.1s (MAPE: 0.75%)
# Processing: u00064s00001_hw00005.svc Completed in 1.2s (MAPE: 0.56%)
# Processing: u00064s00001_hw00006.svc Completed in 1.8s (MAPE: 5.96%)
# Processing: u00064s00001_hw00007.svc Completed in 1.7s (MAPE: 10.15%)
# Processing: u00065s00001_hw00001.svc Completed in 2.0s (MAPE: 3.91%)
# Processing: u00065s00001_hw00002.svc Completed in 2.3s (MAPE: 3.79%)
# Processing: u00065s00001_hw00003.svc Completed in 1.7s (MAPE: 9.09%)
# Processing: u00065s00001_hw00004.svc Completed in 1.2s (MAPE: 2.38%)
# Processing: u00065s00001_hw00005.svc Completed in 1.2s (MAPE: 1.33%)
# Processing: u00065s00001_hw00006.svc Completed in 1.7s (MAPE: 5.32%)
# Processing: u00065s00001_hw00007.svc Completed in 1.7s (MAPE: 6.79%)
# Processing: u00066s00001_hw00001.svc Completed in 1.7s (MAPE: 4.74%)
# Processing: u00066s00001_hw00002.svc Completed in 1.8s (MAPE: 5.83%)
# Processing: u00066s00001_hw00003.svc Completed in 1.7s (MAPE: 9.44%)
# Processing: u00066s00001_hw00004.svc Completed in 1.0s (MAPE: 0.58%)
# Processing: u00066s00001_hw00005.svc Completed in 1.3s (MAPE: 0.62%)
# Processing: u00066s00001_hw00006.svc Completed in 1.8s (MAPE: 7.45%)
# Processing: u00066s00001_hw00007.svc Completed in 1.9s (MAPE: 7.24%)
# Processing: u00067s00001_hw00001.svc Completed in 1.3s (MAPE: 6.80%)
# Processing: u00067s00001_hw00002.svc Completed in 1.9s (MAPE: 4.49%)
# Processing: u00067s00001_hw00003.svc Completed in 1.7s (MAPE: 9.22%)
# Processing: u00067s00001_hw00004.svc Completed in 1.0s (MAPE: 1.45%)
# Processing: u00067s00001_hw00005.svc Completed in 1.0s (MAPE: 0.70%)
# Processing: u00067s00001_hw00006.svc Completed in 1.8s (MAPE: 5.62%)
# Processing: u00067s00001_hw00007.svc Completed in 1.6s (MAPE: 6.03%)
# Processing: u00068s00001_hw00001.svc Completed in 1.5s (MAPE: 3.69%)
# Processing: u00068s00001_hw00002.svc Completed in 1.6s (MAPE: 7.29%)
# Processing: u00068s00001_hw00003.svc Completed in 1.6s (MAPE: 9.22%)
# Processing: u00068s00001_hw00004.svc Completed in 0.9s (MAPE: 2.16%)
# Processing: u00068s00001_hw00005.svc Completed in 1.0s (MAPE: 0.52%)
# Processing: u00068s00001_hw00006.svc Completed in 1.4s (MAPE: 4.57%)
# Processing: u00068s00001_hw00007.svc Completed in 1.6s (MAPE: 9.10%)
# Processing: u00069s00001_hw00001.svc Completed in 1.3s (MAPE: 3.07%)
# Processing: u00069s00001_hw00002.svc Completed in 1.7s (MAPE: 3.31%)
# Processing: u00069s00001_hw00003.svc Completed in 1.8s (MAPE: 6.33%)
# Processing: u00069s00001_hw00004.svc Completed in 1.2s (MAPE: 10.33%)
# Processing: u00069s00001_hw00005.svc Completed in 0.9s (MAPE: 0.98%)
# Processing: u00069s00001_hw00006.svc Completed in 1.7s (MAPE: 7.45%)
# Processing: u00069s00001_hw00007.svc Completed in 2.0s (MAPE: 6.78%)
# Processing: u00070s00001_hw00001.svc Completed in 1.5s (MAPE: 5.77%)
# Processing: u00070s00001_hw00002.svc Completed in 1.6s (MAPE: 5.25%)
# Processing: u00070s00001_hw00003.svc Completed in 1.6s (MAPE: 9.93%)
# Processing: u00070s00001_hw00004.svc Completed in 1.3s (MAPE: 3.71%)
# Processing: u00070s00001_hw00005.svc Completed in 1.1s (MAPE: 2.51%)
# Processing: u00070s00001_hw00006.svc Completed in 1.8s (MAPE: 8.57%)
# Processing: u00070s00001_hw00007.svc Completed in 1.6s (MAPE: 9.68%)
# Processing: u00071s00001_hw00001.svc Completed in 1.6s (MAPE: 3.03%)
# Processing: u00071s00001_hw00002.svc Completed in 2.1s (MAPE: 6.89%)
# Processing: u00071s00001_hw00003.svc Completed in 1.9s (MAPE: 10.21%)
# Processing: u00071s00001_hw00004.svc Completed in 1.2s (MAPE: 2.90%)
# Processing: u00071s00001_hw00005.svc Completed in 1.1s (MAPE: 1.34%)
# Processing: u00071s00001_hw00006.svc Completed in 1.8s (MAPE: 10.04%)
# Processing: u00071s00001_hw00007.svc Completed in 1.6s (MAPE: 7.65%)
# Processing: u00072s00001_hw00001.svc Completed in 1.4s (MAPE: 5.27%)
# Processing: u00072s00001_hw00002.svc Completed in 1.8s (MAPE: 3.75%)
# Processing: u00072s00001_hw00003.svc Completed in 1.9s (MAPE: 8.04%)
# Processing: u00072s00001_hw00004.svc Completed in 1.4s (MAPE: 2.14%)
# Processing: u00072s00001_hw00005.svc Completed in 1.2s (MAPE: 1.33%)
# Processing: u00072s00001_hw00006.svc Completed in 1.8s (MAPE: 5.34%)
# Processing: u00072s00001_hw00007.svc Completed in 1.6s (MAPE: 8.33%)
# Processing: u00073s00001_hw00001.svc Completed in 1.1s (MAPE: 2.11%)
# Processing: u00073s00001_hw00002.svc Completed in 1.7s (MAPE: 4.40%)
# Processing: u00073s00001_hw00003.svc Completed in 1.5s (MAPE: 8.74%)
# Processing: u00073s00001_hw00004.svc Completed in 1.2s (MAPE: 1.88%)
# Processing: u00073s00001_hw00005.svc Completed in 1.6s (MAPE: 0.74%)
# Processing: u00073s00001_hw00006.svc Completed in 1.6s (MAPE: 11.11%)
# Processing: u00073s00001_hw00007.svc Completed in 1.6s (MAPE: 7.76%)
# Processing: u00074s00001_hw00001.svc Completed in 1.3s (MAPE: 8.35%)
# Processing: u00074s00001_hw00002.svc Completed in 1.6s (MAPE: 8.62%)
# Processing: u00074s00001_hw00003.svc Completed in 1.5s (MAPE: 9.84%)
# Processing: u00074s00001_hw00004.svc Completed in 1.2s (MAPE: 5.82%)
# Processing: u00074s00001_hw00005.svc Completed in 1.1s (MAPE: 1.02%)
# Processing: u00074s00001_hw00006.svc Completed in 1.8s (MAPE: 8.65%)
# Processing: u00074s00001_hw00007.svc Completed in 1.5s (MAPE: 8.45%)
# Processing: u00075s00001_hw00001.svc Completed in 1.7s (MAPE: 2.12%)
# Processing: u00075s00001_hw00002.svc Completed in 1.9s (MAPE: 5.52%)
# Processing: u00075s00001_hw00003.svc Completed in 1.8s (MAPE: 8.92%)
# Processing: u00075s00001_hw00004.svc Completed in 1.3s (MAPE: 4.66%)
# Processing: u00075s00001_hw00005.svc Completed in 1.2s (MAPE: 1.36%)
# Processing: u00075s00001_hw00006.svc Completed in 1.6s (MAPE: 6.58%)
# Processing: u00075s00001_hw00007.svc Completed in 1.7s (MAPE: 6.68%)
# Processing: u00076s00001_hw00001.svc Completed in 1.5s (MAPE: 5.99%)
# Processing: u00076s00001_hw00002.svc Completed in 1.7s (MAPE: 7.09%)
# Processing: u00076s00001_hw00003.svc Completed in 1.5s (MAPE: 11.23%)
# Processing: u00076s00001_hw00004.svc Completed in 1.1s (MAPE: 1.02%)
# Processing: u00076s00001_hw00005.svc Completed in 1.3s (MAPE: 1.73%)
# Processing: u00076s00001_hw00006.svc Completed in 1.7s (MAPE: 11.11%)
# Processing: u00076s00001_hw00007.svc Completed in 1.5s (MAPE: 8.16%)
# Processing: u00077s00001_hw00001.svc Completed in 1.3s (MAPE: 5.72%)
# Processing: u00077s00001_hw00002.svc Completed in 1.7s (MAPE: 8.33%)
# Processing: u00077s00001_hw00003.svc Completed in 1.5s (MAPE: 9.10%)
# Processing: u00077s00001_hw00004.svc Completed in 1.1s (MAPE: 3.27%)
# Processing: u00077s00001_hw00005.svc Completed in 1.2s (MAPE: 1.16%)
# Processing: u00077s00001_hw00006.svc Completed in 1.6s (MAPE: 6.70%)
# Processing: u00077s00001_hw00007.svc Completed in 1.6s (MAPE: 7.24%)
# Processing: u00078s00001_hw00001.svc Completed in 1.1s (MAPE: 2.64%)
# Processing: u00078s00001_hw00002.svc Completed in 1.7s (MAPE: 5.59%)
# Processing: u00078s00001_hw00003.svc Completed in 1.6s (MAPE: 8.93%)
# Processing: u00078s00001_hw00004.svc Completed in 1.3s (MAPE: 2.78%)
# Processing: u00078s00001_hw00005.svc Completed in 1.2s (MAPE: 1.87%)
# Processing: u00078s00001_hw00006.svc Completed in 1.7s (MAPE: 4.86%)
# Processing: u00078s00001_hw00007.svc Completed in 1.5s (MAPE: 6.55%)
# Processing: u00079s00001_hw00001.svc Completed in 1.3s (MAPE: 1.86%)
# Processing: u00079s00001_hw00002.svc Completed in 1.7s (MAPE: 4.24%)
# Processing: u00079s00001_hw00003.svc Completed in 1.7s (MAPE: 10.39%)
# Processing: u00079s00001_hw00004.svc Completed in 1.3s (MAPE: 3.09%)
# Processing: u00079s00001_hw00005.svc Completed in 1.3s (MAPE: 1.04%)
# Processing: u00079s00001_hw00006.svc Completed in 1.5s (MAPE: 6.74%)
# Processing: u00079s00001_hw00007.svc Completed in 1.8s (MAPE: 8.40%)
# Processing: u00080s00001_hw00001.svc Completed in 1.4s (MAPE: 12.26%)
# Processing: u00080s00001_hw00002.svc Completed in 1.7s (MAPE: 7.32%)
# Processing: u00080s00001_hw00003.svc Completed in 1.7s (MAPE: 11.07%)
# Processing: u00080s00001_hw00004.svc Completed in 1.3s (MAPE: 1.68%)
# Processing: u00080s00001_hw00005.svc Completed in 1.2s (MAPE: 1.45%)
# Processing: u00080s00001_hw00006.svc Completed in 1.9s (MAPE: 12.10%)
# Processing: u00080s00001_hw00007.svc Completed in 1.6s (MAPE: 8.59%)
# Processing: u00081s00001_hw00001.svc Completed in 2.5s (MAPE: 2.46%)
# Processing: u00081s00001_hw00002.svc Completed in 2.6s (MAPE: 4.19%)
# Processing: u00081s00001_hw00003.svc Completed in 2.1s (MAPE: 9.25%)
# Processing: u00081s00001_hw00004.svc Completed in 1.4s (MAPE: 4.61%)
# Processing: u00081s00001_hw00005.svc Completed in 1.5s (MAPE: 2.39%)
# Processing: u00081s00001_hw00006.svc Completed in 1.9s (MAPE: 4.79%)
# Processing: u00081s00001_hw00007.svc Completed in 1.6s (MAPE: 8.12%)
# Processing: u00082s00001_hw00001.svc Completed in 1.6s (MAPE: 2.30%)
# Processing: u00082s00001_hw00002.svc Completed in 1.8s (MAPE: 3.04%)
# Processing: u00082s00001_hw00003.svc Completed in 1.8s (MAPE: 9.41%)
# Processing: u00082s00001_hw00004.svc Completed in 1.4s (MAPE: 2.64%)
# Processing: u00082s00001_hw00005.svc Completed in 1.2s (MAPE: 2.35%)
# Processing: u00082s00001_hw00006.svc Completed in 1.8s (MAPE: 5.77%)
# Processing: u00082s00001_hw00007.svc Completed in 1.9s (MAPE: 11.79%)
# Processing: u00083s00001_hw00001.svc Completed in 1.6s (MAPE: 8.17%)
# Processing: u00083s00001_hw00002.svc Completed in 2.0s (MAPE: 5.37%)
# Processing: u00083s00001_hw00003.svc Completed in 1.8s (MAPE: 9.76%)
# Processing: u00083s00001_hw00004.svc Completed in 1.3s (MAPE: 3.29%)
# Processing: u00083s00001_hw00005.svc Completed in 1.1s (MAPE: 2.59%)
# Processing: u00083s00001_hw00006.svc Completed in 2.3s (MAPE: 8.80%)
# Processing: u00083s00001_hw00007.svc Completed in 1.6s (MAPE: 5.48%)
# Processing: u00084s00001_hw00001.svc Completed in 1.2s (MAPE: 1.45%)
# Processing: u00084s00001_hw00002.svc Completed in 1.7s (MAPE: 4.56%)
# Processing: u00084s00001_hw00003.svc Completed in 1.9s (MAPE: 9.45%)
# Processing: u00084s00001_hw00004.svc Completed in 1.4s (MAPE: 2.12%)
# Processing: u00084s00001_hw00005.svc Completed in 1.4s (MAPE: 1.12%)
# Processing: u00084s00001_hw00006.svc Completed in 1.6s (MAPE: 5.92%)
# Processing: u00084s00001_hw00007.svc Completed in 1.6s (MAPE: 7.96%)
# ----------------------------------------
# Overall Results:
# Average MAPE: 5.66%, Standard Deviation: 3.35%
