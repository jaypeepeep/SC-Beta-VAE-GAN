# %%
# Cell 1
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import io
import os
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import random
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model
from keras.utils import custom_object_scope
from tensorflow.keras.layers import Bidirectional, SimpleRNN, Dense

# %%
# Cell 2
# Updated function
# Updated function without saving data inside
def upload_and_process_files(directory, num_files_to_use=None):
    svc_files = [f for f in os.listdir(directory) if f.endswith('.svc')]
    
    # If num_files_to_use is specified, only take that many files sequentially
    if num_files_to_use:
        svc_files = svc_files[:num_files_to_use]  # Take the first num_files_to_use files

    data_frames = []  # Processed data after scaling
    original_data_frames = []  # Save the original unscaled data
    scalers = []
    input_filenames = []  # List to store input filenames

    num_files = len(svc_files)
    

    for i, filename in enumerate(svc_files):
        file_path = os.path.join(directory, filename)
        input_filenames.append(filename)  # Store the filename
        df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
        df.columns = ['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude']
        
        # Modify timestamp to start from 0
        df['timestamp'] = (df['timestamp'] - df['timestamp'].min()).round().astype(int)
        
        # Keep a copy of the original data before scaling
        original_data_frames.append(df.copy())  # Save the original unmodified data
        
        # Process the data for use in the model
        df = df.iloc[:, [0, 1, 2, 3, 4, 5, 6]] 
        data_frames.append(df)
        scaler = MinMaxScaler()
        normalized_data = scaler.fit_transform(df[['x', 'y', 'timestamp']])
        scalers.append(scaler)


    processed_data = [np.column_stack((scaler.transform(df[['x', 'y', 'timestamp']]), df['pen_status'].values)) 
                      for df, scaler in zip(data_frames, scalers)]
    avg_data_points = int(np.mean([df.shape[0] for df in data_frames]))

    return data_frames, processed_data, scalers, avg_data_points, input_filenames, original_data_frames  # Return original data

# Save data outside the function
def save_original_data(data_frames, input_filenames, output_folder='original_absolute'):
    os.makedirs(output_folder, exist_ok=True)
    for df, filename in zip(data_frames, input_filenames):
        save_path = os.path.join(output_folder, filename)
        df.to_csv(save_path, sep=' ', index=False, header=False)

directory = '../../final vaegan copy/emothaw'  # Directory where the .svc files are stored
num_files_to_use = 903
data_frames, processed_data, scalers, avg_data_points, input_filenames, original_data_frames = upload_and_process_files(directory, num_files_to_use)

# Save the original data after processing
save_original_data(original_data_frames, input_filenames)

# Store the name of the first file for use in Cell 4
input_filename = input_filenames[0] if input_filenames else 'processed_data'
print(f"Number of processed files: {len(processed_data)}")
print(f"Average number of data points: {avg_data_points}")
# Out:
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# ...
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# C:\Users\Grimes\AppData\Local\Temp\ipykernel_6536\1738231875.py:22: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, skiprows=1, header=None, delim_whitespace=True)
# Number of processed files: 903
# Average number of data points: 2939

# %%
from glob import glob
import os
import re
import numpy as np
import pandas as pd

def read_svc_file(file_path):
    return pd.read_csv(file_path, sep=' ', header=None, 
                       names=['x', 'y', 'timestamp', 'pen_status', 'pressure', 'azimuth', 'altitude'])

def calculate_nrmse(original, predicted):
    if original.shape != predicted.shape:
        raise ValueError("The shapes of the original and predicted datasets must match.")
    mse = np.mean((original - predicted) ** 2)
    rmse = np.sqrt(mse)
    nrmse = rmse / (np.max(original) - np.min(original))
    return nrmse

def get_matching_augmented_files(original_file, augmented_folder):
    base_name = os.path.basename(original_file)
    base_name_without_ext = os.path.splitext(base_name)[0]
    pattern = os.path.join(augmented_folder, f"synthetic_{base_name_without_ext}*.svc")
    matching_files = glob(pattern)
    
    def sort_key(filename):
        match = re.search(r'\((\d+)\)', filename)
        return int(match.group(1)) if match else -1

    return sorted(matching_files, key=sort_key)

def process_files(original_folder, augmented_folder, input_filenames):
    nrmse_results = {}

    input_filenames_set = {os.path.splitext(os.path.basename(filename))[0] for filename in input_filenames}

    for original_file in glob(os.path.join(original_folder, "*.svc")):
        base_name = os.path.splitext(os.path.basename(original_file))[0]
        
        if base_name not in input_filenames_set:
            continue

        original_data = read_svc_file(original_file)
        matching_augmented_files = get_matching_augmented_files(original_file, augmented_folder)
        
        file_nrmse = []
        for augmented_file in matching_augmented_files:
            augmented_data = read_svc_file(augmented_file)
            
            min_length = min(len(original_data), len(augmented_data))
            original_array = original_data.iloc[:min_length].values
            augmented_array = augmented_data.iloc[:min_length].values

            nrmse = calculate_nrmse(original_array, augmented_array)
            file_nrmse.append(nrmse)

        nrmse_results[os.path.basename(original_file)] = file_nrmse

    return nrmse_results

def save_results_to_log(results, output_path):
    with open(output_path, 'w') as log_file:
        for original_file, nrmse_values in results.items():
            avg_nrmse = None
            if len(nrmse_values) > 1:
                avg_nrmse = np.mean(nrmse_values)

            nrmse_values_str = ", ".join([f"{nrmse:.4f}" for nrmse in nrmse_values])
            log_line = f"{original_file}: NRMSE = {nrmse_values_str}"
            if avg_nrmse is not None:
                log_line += f", Avg NRMSE: {avg_nrmse:.4f}"

            log_file.write(log_line + '\n')
            print(log_line)

original_folder = "original_absolute"
augmented_folder = "../../final vaegan copy/augmented_data" # Directory ng augmented data
output_log_file = "nrmse_results_log.txt"

# Process files and save results
results = process_files(original_folder, augmented_folder, input_filenames)
save_results_to_log(results, output_log_file)

# Calculate overall average NRMSE and standard deviation
all_nrmse_values = [nrmse for nrmse_list in results.values() for nrmse in nrmse_list]
overall_avg_nrmse = np.mean(all_nrmse_values) if all_nrmse_values else None
overall_std_nrmse = np.std(all_nrmse_values) if all_nrmse_values else None

# Print and save the overall average NRMSE and standard deviation
with open(output_log_file, 'a') as log_file:
    if overall_avg_nrmse is not None and overall_std_nrmse is not None:
        log_line = f"\nOverall Average NRMSE: {overall_avg_nrmse:.4f}, Standard Deviation: {overall_std_nrmse:.4f}"
    else:
        log_line = "No NRMSE values calculated."

    log_file.write(log_line + '\n')
    print(log_line)
# Out:
# collection1u00001s00001_hw00001.svc: NRMSE = 0.0257
# collection1u00001s00001_hw00002.svc: NRMSE = 0.0258
# collection1u00001s00001_hw00003.svc: NRMSE = 0.0693
# collection1u00001s00001_hw00004.svc: NRMSE = 0.0350
# collection1u00001s00001_hw00005.svc: NRMSE = 0.0175
# collection1u00001s00001_hw00006.svc: NRMSE = 0.0621
# collection1u00001s00001_hw00007.svc: NRMSE = 0.0781
# collection1u00002s00001_hw00001.svc: NRMSE = 0.0194
# collection1u00002s00001_hw00002.svc: NRMSE = 0.0273
# collection1u00002s00001_hw00003.svc: NRMSE = 0.0874
# collection1u00002s00001_hw00004.svc: NRMSE = 0.0138
# collection1u00002s00001_hw00005.svc: NRMSE = 0.0142
# collection1u00002s00001_hw00006.svc: NRMSE = 0.0354
# collection1u00002s00001_hw00007.svc: NRMSE = 0.0870
# collection1u00003s00001_hw00001.svc: NRMSE = 0.0239
# collection1u00003s00001_hw00002.svc: NRMSE = 0.0288
# collection1u00003s00001_hw00003.svc: NRMSE = 0.0841
# collection1u00003s00001_hw00004.svc: NRMSE = 0.0080
# collection1u00003s00001_hw00005.svc: NRMSE = 0.0078
# collection1u00003s00001_hw00006.svc: NRMSE = 0.0594
# collection1u00003s00001_hw00007.svc: NRMSE = 0.0801
# collection1u00004s00001_hw00001.svc: NRMSE = 0.0152
# collection1u00004s00001_hw00002.svc: NRMSE = 0.0214
# collection1u00004s00001_hw00003.svc: NRMSE = 0.0623
# collection1u00004s00001_hw00004.svc: NRMSE = 0.0203
# collection1u00004s00001_hw00005.svc: NRMSE = 0.0149
# collection1u00004s00001_hw00006.svc: NRMSE = 0.0396
# collection1u00004s00001_hw00007.svc: NRMSE = 0.0880
# collection1u00005s00001_hw00001.svc: NRMSE = 0.0248
# collection1u00005s00001_hw00002.svc: NRMSE = 0.0262
# collection1u00005s00001_hw00003.svc: NRMSE = 0.0792
# collection1u00005s00001_hw00004.svc: NRMSE = 0.0126
# collection1u00005s00001_hw00005.svc: NRMSE = 0.0119
# collection1u00005s00001_hw00006.svc: NRMSE = 0.0796
# collection1u00005s00001_hw00007.svc: NRMSE = 0.1084
# collection1u00006s00001_hw00001.svc: NRMSE = 0.0143
# collection1u00006s00001_hw00002.svc: NRMSE = 0.0296
# collection1u00006s00001_hw00003.svc: NRMSE = 0.0838
# collection1u00006s00001_hw00004.svc: NRMSE = 0.0084
# collection1u00006s00001_hw00005.svc: NRMSE = 0.0157
# collection1u00006s00001_hw00006.svc: NRMSE = 0.0383
# collection1u00006s00001_hw00007.svc: NRMSE = 0.1011
# collection1u00007s00001_hw00001.svc: NRMSE = 0.0365
# collection1u00007s00001_hw00002.svc: NRMSE = 0.0339
# collection1u00007s00001_hw00003.svc: NRMSE = 0.0804
# collection1u00007s00001_hw00004.svc: NRMSE = 0.0219
# collection1u00007s00001_hw00005.svc: NRMSE = 0.0178
# collection1u00007s00001_hw00006.svc: NRMSE = 0.0570
# collection1u00007s00001_hw00007.svc: NRMSE = 0.0889
# collection1u00008s00001_hw00001.svc: NRMSE = 0.0203
# collection1u00008s00001_hw00002.svc: NRMSE = 0.0312
# collection1u00008s00001_hw00003.svc: NRMSE = 0.0799
# collection1u00008s00001_hw00004.svc: NRMSE = 0.0058
# collection1u00008s00001_hw00005.svc: NRMSE = 0.0075
# collection1u00008s00001_hw00006.svc: NRMSE = 0.0250
# collection1u00008s00001_hw00007.svc: NRMSE = 0.0985
# collection1u00009s00001_hw00001.svc: NRMSE = 0.0116
# collection1u00009s00001_hw00002.svc: NRMSE = 0.0201
# collection1u00009s00001_hw00003.svc: NRMSE = 0.0790
# collection1u00009s00001_hw00004.svc: NRMSE = 0.0093
# collection1u00009s00001_hw00005.svc: NRMSE = 0.0055
# collection1u00009s00001_hw00006.svc: NRMSE = 0.0514
# collection1u00009s00001_hw00007.svc: NRMSE = 0.0807
# collection1u00010s00001_hw00001.svc: NRMSE = 0.0275
# collection1u00010s00001_hw00002.svc: NRMSE = 0.0289
# collection1u00010s00001_hw00003.svc: NRMSE = 0.0784
# collection1u00010s00001_hw00004.svc: NRMSE = 0.0165
# collection1u00010s00001_hw00005.svc: NRMSE = 0.0151
# collection1u00010s00001_hw00006.svc: NRMSE = 0.0530
# collection1u00010s00001_hw00007.svc: NRMSE = 0.0944
# collection1u00011s00001_hw00001.svc: NRMSE = 0.0208
# collection1u00011s00001_hw00002.svc: NRMSE = 0.0273
# collection1u00011s00001_hw00003.svc: NRMSE = 0.0765
# collection1u00011s00001_hw00004.svc: NRMSE = 0.0116
# collection1u00011s00001_hw00005.svc: NRMSE = 0.0117
# collection1u00011s00001_hw00006.svc: NRMSE = 0.0449
# collection1u00011s00001_hw00007.svc: NRMSE = 0.0930
# collection1u00012s00001_hw00001.svc: NRMSE = 0.0223
# collection1u00012s00001_hw00002.svc: NRMSE = 0.0196
# collection1u00012s00001_hw00003.svc: NRMSE = 0.0718
# collection1u00012s00001_hw00004.svc: NRMSE = 0.0073
# collection1u00012s00001_hw00005.svc: NRMSE = 0.0088
# collection1u00012s00001_hw00006.svc: NRMSE = 0.0424
# collection1u00012s00001_hw00007.svc: NRMSE = 0.0784
# collection1u00013s00001_hw00001.svc: NRMSE = 0.0152
# collection1u00013s00001_hw00002.svc: NRMSE = 0.0202
# collection1u00013s00001_hw00003.svc: NRMSE = 0.0637
# collection1u00013s00001_hw00004.svc: NRMSE = 0.0092
# collection1u00013s00001_hw00005.svc: NRMSE = 0.0092
# collection1u00013s00001_hw00006.svc: NRMSE = 0.0292
# collection1u00013s00001_hw00007.svc: NRMSE = 0.0989
# collection1u00014s00001_hw00001.svc: NRMSE = 0.0200
# collection1u00014s00001_hw00002.svc: NRMSE = 0.0199
# collection1u00014s00001_hw00003.svc: NRMSE = 0.0740
# collection1u00014s00001_hw00004.svc: NRMSE = 0.0124
# collection1u00014s00001_hw00005.svc: NRMSE = 0.0138
# collection1u00014s00001_hw00006.svc: NRMSE = 0.0267
# collection1u00014s00001_hw00007.svc: NRMSE = 0.1049
# collection1u00015s00001_hw00001.svc: NRMSE = 0.0207
# collection1u00015s00001_hw00002.svc: NRMSE = 0.0289
# collection1u00015s00001_hw00003.svc: NRMSE = 0.0694
# collection1u00015s00001_hw00004.svc: NRMSE = 0.0124
# collection1u00015s00001_hw00005.svc: NRMSE = 0.0114
# collection1u00015s00001_hw00006.svc: NRMSE = 0.0652
# collection1u00015s00001_hw00007.svc: NRMSE = 0.0983
# collection1u00016s00001_hw00001.svc: NRMSE = 0.0139
# collection1u00016s00001_hw00002.svc: NRMSE = 0.0204
# collection1u00016s00001_hw00003.svc: NRMSE = 0.0536
# collection1u00016s00001_hw00004.svc: NRMSE = 0.0158
# collection1u00016s00001_hw00005.svc: NRMSE = 0.0166
# collection1u00016s00001_hw00006.svc: NRMSE = 0.0331
# collection1u00016s00001_hw00007.svc: NRMSE = 0.0905
# collection1u00017s00001_hw00001.svc: NRMSE = 0.0239
# collection1u00017s00001_hw00002.svc: NRMSE = 0.0214
# collection1u00017s00001_hw00003.svc: NRMSE = 0.0802
# collection1u00017s00001_hw00004.svc: NRMSE = 0.0118
# collection1u00017s00001_hw00005.svc: NRMSE = 0.0120
# collection1u00017s00001_hw00006.svc: NRMSE = 0.0280
# collection1u00017s00001_hw00007.svc: NRMSE = 0.0688
# collection1u00018s00001_hw00001.svc: NRMSE = 0.0189
# collection1u00018s00001_hw00002.svc: NRMSE = 0.0307
# collection1u00018s00001_hw00003.svc: NRMSE = 0.0731
# collection1u00018s00001_hw00004.svc: NRMSE = 0.0314
# collection1u00018s00001_hw00005.svc: NRMSE = 0.0094
# collection1u00018s00001_hw00006.svc: NRMSE = 0.0435
# collection1u00018s00001_hw00007.svc: NRMSE = 0.0871
# collection1u00019s00001_hw00001.svc: NRMSE = 0.0365
# collection1u00019s00001_hw00002.svc: NRMSE = 0.0276
# collection1u00019s00001_hw00003.svc: NRMSE = 0.0906
# collection1u00019s00001_hw00004.svc: NRMSE = 0.0137
# collection1u00019s00001_hw00005.svc: NRMSE = 0.0121
# collection1u00019s00001_hw00006.svc: NRMSE = 0.0336
# collection1u00019s00001_hw00007.svc: NRMSE = 0.0765
# collection1u00020s00001_hw00001.svc: NRMSE = 0.0184
# collection1u00020s00001_hw00002.svc: NRMSE = 0.0230
# collection1u00020s00001_hw00003.svc: NRMSE = 0.0734
# collection1u00020s00001_hw00004.svc: NRMSE = 0.0124
# collection1u00020s00001_hw00005.svc: NRMSE = 0.0168
# collection1u00020s00001_hw00006.svc: NRMSE = 0.0437
# collection1u00020s00001_hw00007.svc: NRMSE = 0.0947
# collection1u00021s00001_hw00001.svc: NRMSE = 0.0219
# collection1u00021s00001_hw00002.svc: NRMSE = 0.0215
# collection1u00021s00001_hw00003.svc: NRMSE = 0.0795
# collection1u00021s00001_hw00004.svc: NRMSE = 0.0110
# collection1u00021s00001_hw00005.svc: NRMSE = 0.0102
# collection1u00021s00001_hw00006.svc: NRMSE = 0.0251
# collection1u00021s00001_hw00007.svc: NRMSE = 0.0760
# collection1u00022s00001_hw00001.svc: NRMSE = 0.0180
# collection1u00022s00001_hw00002.svc: NRMSE = 0.0243
# collection1u00022s00001_hw00003.svc: NRMSE = 0.0754
# collection1u00022s00001_hw00004.svc: NRMSE = 0.0162
# collection1u00022s00001_hw00005.svc: NRMSE = 0.0156
# collection1u00022s00001_hw00006.svc: NRMSE = 0.0359
# collection1u00022s00001_hw00007.svc: NRMSE = 0.1218
# collection1u00023s00001_hw00001.svc: NRMSE = 0.0142
# collection1u00023s00001_hw00002.svc: NRMSE = 0.0219
# collection1u00023s00001_hw00003.svc: NRMSE = 0.0728
# collection1u00023s00001_hw00004.svc: NRMSE = 0.0156
# collection1u00023s00001_hw00005.svc: NRMSE = 0.0131
# collection1u00023s00001_hw00006.svc: NRMSE = 0.0465
# collection1u00023s00001_hw00007.svc: NRMSE = 0.0946
# collection1u00024s00001_hw00001.svc: NRMSE = 0.0283
# collection1u00024s00001_hw00002.svc: NRMSE = 0.0374
# collection1u00024s00001_hw00003.svc: NRMSE = 0.0756
# collection1u00024s00001_hw00004.svc: NRMSE = 0.0149
# collection1u00024s00001_hw00005.svc: NRMSE = 0.0178
# collection1u00024s00001_hw00006.svc: NRMSE = 0.0392
# collection1u00024s00001_hw00007.svc: NRMSE = 0.0776
# collection1u00025s00001_hw00001.svc: NRMSE = 0.0204
# collection1u00025s00001_hw00002.svc: NRMSE = 0.0279
# collection1u00025s00001_hw00003.svc: NRMSE = 0.0710
# collection1u00025s00001_hw00004.svc: NRMSE = 0.0103
# collection1u00025s00001_hw00005.svc: NRMSE = 0.0176
# collection1u00025s00001_hw00006.svc: NRMSE = 0.0474
# collection1u00025s00001_hw00007.svc: NRMSE = 0.0986
# collection1u00026s00001_hw00001.svc: NRMSE = 0.0181
# collection1u00026s00001_hw00002.svc: NRMSE = 0.0216
# collection1u00026s00001_hw00003.svc: NRMSE = 0.0655
# collection1u00026s00001_hw00004.svc: NRMSE = 0.0115
# collection1u00026s00001_hw00005.svc: NRMSE = 0.0138
# collection1u00026s00001_hw00006.svc: NRMSE = 0.0429
# collection1u00026s00001_hw00007.svc: NRMSE = 0.0784
# collection1u00027s00001_hw00001.svc: NRMSE = 0.0170
# collection1u00027s00001_hw00002.svc: NRMSE = 0.0205
# collection1u00027s00001_hw00003.svc: NRMSE = 0.0699
# collection1u00027s00001_hw00004.svc: NRMSE = 0.0073
# collection1u00027s00001_hw00005.svc: NRMSE = 0.0126
# collection1u00027s00001_hw00006.svc: NRMSE = 0.0259
# collection1u00027s00001_hw00007.svc: NRMSE = 0.0845
# collection1u00028s00001_hw00001.svc: NRMSE = 0.0182
# collection1u00028s00001_hw00002.svc: NRMSE = 0.0245
# collection1u00028s00001_hw00003.svc: NRMSE = 0.0584
# collection1u00028s00001_hw00004.svc: NRMSE = 0.0169
# collection1u00028s00001_hw00005.svc: NRMSE = 0.0143
# collection1u00028s00001_hw00006.svc: NRMSE = 0.0504
# collection1u00028s00001_hw00007.svc: NRMSE = 0.0962
# collection1u00029s00001_hw00001.svc: NRMSE = 0.0198
# collection1u00029s00001_hw00002.svc: NRMSE = 0.0247
# collection1u00029s00001_hw00003.svc: NRMSE = 0.0781
# collection1u00029s00001_hw00004.svc: NRMSE = 0.0125
# collection1u00029s00001_hw00005.svc: NRMSE = 0.0112
# collection1u00029s00001_hw00006.svc: NRMSE = 0.0378
# collection1u00029s00001_hw00007.svc: NRMSE = 0.0915
# collection1u00030s00001_hw00001.svc: NRMSE = 0.0244
# collection1u00030s00001_hw00002.svc: NRMSE = 0.0269
# collection1u00030s00001_hw00003.svc: NRMSE = 0.0768
# collection1u00030s00001_hw00004.svc: NRMSE = 0.0067
# collection1u00030s00001_hw00005.svc: NRMSE = 0.0064
# collection1u00030s00001_hw00006.svc: NRMSE = 0.0561
# collection1u00030s00001_hw00007.svc: NRMSE = 0.0771
# collection1u00031s00001_hw00001.svc: NRMSE = 0.0247
# collection1u00031s00001_hw00002.svc: NRMSE = 0.0339
# collection1u00031s00001_hw00003.svc: NRMSE = 0.0675
# collection1u00031s00001_hw00004.svc: NRMSE = 0.0182
# collection1u00031s00001_hw00005.svc: NRMSE = 0.0139
# collection1u00031s00001_hw00006.svc: NRMSE = 0.0475
# collection1u00031s00001_hw00007.svc: NRMSE = 0.1018
# collection1u00032s00001_hw00001.svc: NRMSE = 0.0224
# collection1u00032s00001_hw00002.svc: NRMSE = 0.0286
# collection1u00032s00001_hw00003.svc: NRMSE = 0.0713
# collection1u00032s00001_hw00004.svc: NRMSE = 0.0189
# collection1u00032s00001_hw00005.svc: NRMSE = 0.0099
# collection1u00032s00001_hw00006.svc: NRMSE = 0.0389
# collection1u00032s00001_hw00007.svc: NRMSE = 0.1063
# collection1u00033s00001_hw00001.svc: NRMSE = 0.0177
# collection1u00033s00001_hw00002.svc: NRMSE = 0.0325
# collection1u00033s00001_hw00003.svc: NRMSE = 0.0806
# collection1u00033s00001_hw00004.svc: NRMSE = 0.0207
# collection1u00033s00001_hw00005.svc: NRMSE = 0.0072
# collection1u00033s00001_hw00006.svc: NRMSE = 0.0240
# collection1u00033s00001_hw00007.svc: NRMSE = 0.1268
# collection1u00034s00001_hw00001.svc: NRMSE = 0.0288
# collection1u00034s00001_hw00002.svc: NRMSE = 0.0276
# collection1u00034s00001_hw00003.svc: NRMSE = 0.0495
# collection1u00034s00001_hw00004.svc: NRMSE = 0.0109
# collection1u00034s00001_hw00005.svc: NRMSE = 0.0145
# collection1u00034s00001_hw00006.svc: NRMSE = 0.0444
# collection1u00034s00001_hw00007.svc: NRMSE = 0.0842
# collection1u00035s00001_hw00001.svc: NRMSE = 0.0168
# collection1u00035s00001_hw00002.svc: NRMSE = 0.0166
# collection1u00035s00001_hw00003.svc: NRMSE = 0.0763
# collection1u00035s00001_hw00004.svc: NRMSE = 0.0092
# collection1u00035s00001_hw00005.svc: NRMSE = 0.0088
# collection1u00035s00001_hw00006.svc: NRMSE = 0.0305
# collection1u00035s00001_hw00007.svc: NRMSE = 0.1034
# collection1u00036s00001_hw00001.svc: NRMSE = 0.0192
# collection1u00036s00001_hw00002.svc: NRMSE = 0.0300
# collection1u00036s00001_hw00003.svc: NRMSE = 0.0611
# collection1u00036s00001_hw00004.svc: NRMSE = 0.0094
# collection1u00036s00001_hw00005.svc: NRMSE = 0.0092
# collection1u00036s00001_hw00006.svc: NRMSE = 0.0553
# collection1u00036s00001_hw00007.svc: NRMSE = 0.0882
# collection1u00037s00001_hw00001.svc: NRMSE = 0.0202
# collection1u00037s00001_hw00002.svc: NRMSE = 0.0284
# collection1u00037s00001_hw00003.svc: NRMSE = 0.0738
# collection1u00037s00001_hw00004.svc: NRMSE = 0.0168
# collection1u00037s00001_hw00005.svc: NRMSE = 0.0148
# collection1u00037s00001_hw00006.svc: NRMSE = 0.0507
# collection1u00037s00001_hw00007.svc: NRMSE = 0.0627
# collection1u00038s00001_hw00001.svc: NRMSE = 0.0264
# collection1u00038s00001_hw00002.svc: NRMSE = 0.0413
# collection1u00038s00001_hw00003.svc: NRMSE = 0.0792
# collection1u00038s00001_hw00004.svc: NRMSE = 0.0164
# collection1u00038s00001_hw00005.svc: NRMSE = 0.0150
# collection1u00038s00001_hw00006.svc: NRMSE = 0.0481
# collection1u00038s00001_hw00007.svc: NRMSE = 0.0660
# collection1u00039s00001_hw00001.svc: NRMSE = 0.0470
# collection1u00039s00001_hw00002.svc: NRMSE = 0.0318
# collection1u00039s00001_hw00003.svc: NRMSE = 0.0749
# collection1u00039s00001_hw00004.svc: NRMSE = 0.0216
# collection1u00039s00001_hw00005.svc: NRMSE = 0.0160
# collection1u00039s00001_hw00006.svc: NRMSE = 0.0865
# collection1u00039s00001_hw00007.svc: NRMSE = 0.0850
# collection1u00040s00001_hw00001.svc: NRMSE = 0.0379
# collection1u00040s00001_hw00002.svc: NRMSE = 0.0402
# collection1u00040s00001_hw00003.svc: NRMSE = 0.0773
# collection1u00040s00001_hw00004.svc: NRMSE = 0.0233
# collection1u00040s00001_hw00005.svc: NRMSE = 0.0238
# collection1u00040s00001_hw00006.svc: NRMSE = 0.0868
# collection1u00040s00001_hw00007.svc: NRMSE = 0.0743
# collection1u00041s00001_hw00001.svc: NRMSE = 0.0151
# collection1u00041s00001_hw00002.svc: NRMSE = 0.0224
# collection1u00041s00001_hw00003.svc: NRMSE = 0.0646
# collection1u00041s00001_hw00004.svc: NRMSE = 0.0046
# collection1u00041s00001_hw00005.svc: NRMSE = 0.0074
# collection1u00041s00001_hw00006.svc: NRMSE = 0.1223
# collection1u00041s00001_hw00007.svc: NRMSE = 0.0857
# collection1u00042s00001_hw00001.svc: NRMSE = 0.0093
# collection1u00042s00001_hw00002.svc: NRMSE = 0.0196
# collection1u00042s00001_hw00003.svc: NRMSE = 0.0515
# collection1u00042s00001_hw00004.svc: NRMSE = 0.0053
# collection1u00042s00001_hw00005.svc: NRMSE = 0.0080
# collection1u00042s00001_hw00006.svc: NRMSE = 0.0261
# collection1u00042s00001_hw00007.svc: NRMSE = 0.0603
# collection1u00043s00001_hw00001.svc: NRMSE = 0.0123
# collection1u00043s00001_hw00002.svc: NRMSE = 0.0199
# collection1u00043s00001_hw00003.svc: NRMSE = 0.0774
# collection1u00043s00001_hw00004.svc: NRMSE = 0.0054
# collection1u00043s00001_hw00005.svc: NRMSE = 0.0064
# collection1u00043s00001_hw00006.svc: NRMSE = 0.0373
# collection1u00043s00001_hw00007.svc: NRMSE = 0.0838
# collection1u00044s00001_hw00001.svc: NRMSE = 0.0154
# collection1u00044s00001_hw00002.svc: NRMSE = 0.0256
# collection1u00044s00001_hw00003.svc: NRMSE = 0.0524
# collection1u00044s00001_hw00004.svc: NRMSE = 0.0074
# collection1u00044s00001_hw00005.svc: NRMSE = 0.0057
# collection1u00044s00001_hw00006.svc: NRMSE = 0.0296
# collection1u00044s00001_hw00007.svc: NRMSE = 0.0896
# collection1u00045s00001_hw00001.svc: NRMSE = 0.0082
# collection1u00045s00001_hw00002.svc: NRMSE = 0.0154
# collection1u00045s00001_hw00003.svc: NRMSE = 0.0539
# collection1u00045s00001_hw00004.svc: NRMSE = 0.0047
# collection1u00045s00001_hw00005.svc: NRMSE = 0.0047
# collection1u00045s00001_hw00006.svc: NRMSE = 0.0247
# collection1u00045s00001_hw00007.svc: NRMSE = 0.1689
# u00001s00001_hw00001.svc: NRMSE = 0.0220
# u00001s00001_hw00002.svc: NRMSE = 0.0286
# u00001s00001_hw00003.svc: NRMSE = 0.0741
# u00001s00001_hw00004.svc: NRMSE = 0.0106
# u00001s00001_hw00005.svc: NRMSE = 0.0068
# u00001s00001_hw00006.svc: NRMSE = 0.0246
# u00001s00001_hw00007.svc: NRMSE = 0.1111
# u00002s00001_hw00001.svc: NRMSE = 0.0085
# u00002s00001_hw00002.svc: NRMSE = 0.0174
# u00002s00001_hw00003.svc: NRMSE = 0.0731
# u00002s00001_hw00004.svc: NRMSE = 0.0166
# u00002s00001_hw00005.svc: NRMSE = 0.0159
# u00002s00001_hw00006.svc: NRMSE = 0.0318
# u00002s00001_hw00007.svc: NRMSE = 0.0883
# u00003s00001_hw00001.svc: NRMSE = 0.0195
# u00003s00001_hw00002.svc: NRMSE = 0.0279
# u00003s00001_hw00003.svc: NRMSE = 0.0992
# u00003s00001_hw00004.svc: NRMSE = 0.0166
# u00003s00001_hw00005.svc: NRMSE = 0.0165
# u00003s00001_hw00006.svc: NRMSE = 0.0518
# u00003s00001_hw00007.svc: NRMSE = 0.0835
# u00004s00001_hw00001.svc: NRMSE = 0.0210
# u00004s00001_hw00002.svc: NRMSE = 0.0362
# u00004s00001_hw00003.svc: NRMSE = 0.0967
# u00004s00001_hw00004.svc: NRMSE = 0.0140
# u00004s00001_hw00005.svc: NRMSE = 0.0120
# u00004s00001_hw00006.svc: NRMSE = 0.0325
# u00004s00001_hw00007.svc: NRMSE = 0.0801
# u00005s00001_hw00001.svc: NRMSE = 0.0219
# u00005s00001_hw00002.svc: NRMSE = 0.0271
# u00005s00001_hw00003.svc: NRMSE = 0.0740
# u00005s00001_hw00004.svc: NRMSE = 0.0099
# u00005s00001_hw00005.svc: NRMSE = 0.0096
# u00005s00001_hw00006.svc: NRMSE = 0.0631
# u00005s00001_hw00007.svc: NRMSE = 0.0709
# u00006s00001_hw00001.svc: NRMSE = 0.0203
# u00006s00001_hw00002.svc: NRMSE = 0.0382
# u00006s00001_hw00003.svc: NRMSE = 0.0659
# u00006s00001_hw00004.svc: NRMSE = 0.0122
# u00006s00001_hw00005.svc: NRMSE = 0.0146
# u00006s00001_hw00006.svc: NRMSE = 0.0524
# u00006s00001_hw00007.svc: NRMSE = 0.0871
# u00007s00001_hw00001.svc: NRMSE = 0.0260
# u00007s00001_hw00002.svc: NRMSE = 0.0250
# u00007s00001_hw00003.svc: NRMSE = 0.0841
# u00007s00001_hw00004.svc: NRMSE = 0.0078
# u00007s00001_hw00005.svc: NRMSE = 0.0095
# u00007s00001_hw00006.svc: NRMSE = 0.0273
# u00007s00001_hw00007.svc: NRMSE = 0.1045
# u00008s00001_hw00001.svc: NRMSE = 0.0239
# u00008s00001_hw00002.svc: NRMSE = 0.0510
# u00008s00001_hw00003.svc: NRMSE = 0.0748
# u00008s00001_hw00004.svc: NRMSE = 0.0191
# u00008s00001_hw00005.svc: NRMSE = 0.0162
# u00008s00001_hw00006.svc: NRMSE = 0.0472
# u00008s00001_hw00007.svc: NRMSE = 0.0885
# u00009s00001_hw00001.svc: NRMSE = 0.0234
# u00009s00001_hw00002.svc: NRMSE = 0.0236
# u00009s00001_hw00003.svc: NRMSE = 0.0674
# u00009s00001_hw00004.svc: NRMSE = 0.0152
# u00009s00001_hw00005.svc: NRMSE = 0.0121
# u00009s00001_hw00006.svc: NRMSE = 0.0284
# u00009s00001_hw00007.svc: NRMSE = 0.0541
# u00010s00001_hw00001.svc: NRMSE = 0.0259
# u00010s00001_hw00002.svc: NRMSE = 0.0324
# u00010s00001_hw00003.svc: NRMSE = 0.0561
# u00010s00001_hw00004.svc: NRMSE = 0.0140
# u00010s00001_hw00005.svc: NRMSE = 0.0120
# u00010s00001_hw00006.svc: NRMSE = 0.0459
# u00010s00001_hw00007.svc: NRMSE = 0.0765
# u00011s00001_hw00001.svc: NRMSE = 0.0262
# u00011s00001_hw00002.svc: NRMSE = 0.0329
# u00011s00001_hw00003.svc: NRMSE = 0.0711
# u00011s00001_hw00004.svc: NRMSE = 0.0121
# u00011s00001_hw00005.svc: NRMSE = 0.0162
# u00011s00001_hw00006.svc: NRMSE = 0.0447
# u00011s00001_hw00007.svc: NRMSE = 0.0794
# u00012s00001_hw00001.svc: NRMSE = 0.0183
# u00012s00001_hw00002.svc: NRMSE = 0.0201
# u00012s00001_hw00003.svc: NRMSE = 0.0778
# u00012s00001_hw00004.svc: NRMSE = 0.0109
# u00012s00001_hw00005.svc: NRMSE = 0.0148
# u00012s00001_hw00006.svc: NRMSE = 0.0361
# u00012s00001_hw00007.svc: NRMSE = 0.1199
# u00013s00001_hw00001.svc: NRMSE = 0.0142
# u00013s00001_hw00002.svc: NRMSE = 0.0202
# u00013s00001_hw00003.svc: NRMSE = 0.0625
# u00013s00001_hw00004.svc: NRMSE = 0.0102
# u00013s00001_hw00005.svc: NRMSE = 0.0099
# u00013s00001_hw00006.svc: NRMSE = 0.0420
# u00013s00001_hw00007.svc: NRMSE = 0.0974
# u00014s00001_hw00001.svc: NRMSE = 0.0191
# u00014s00001_hw00002.svc: NRMSE = 0.0303
# u00014s00001_hw00003.svc: NRMSE = 0.0692
# u00014s00001_hw00004.svc: NRMSE = 0.0114
# u00014s00001_hw00005.svc: NRMSE = 0.0118
# u00014s00001_hw00006.svc: NRMSE = 0.0491
# u00014s00001_hw00007.svc: NRMSE = 0.0818
# u00015s00001_hw00001.svc: NRMSE = 0.0158
# u00015s00001_hw00002.svc: NRMSE = 0.0229
# u00015s00001_hw00003.svc: NRMSE = 0.0817
# u00015s00001_hw00004.svc: NRMSE = 0.0156
# u00015s00001_hw00005.svc: NRMSE = 0.0178
# u00015s00001_hw00006.svc: NRMSE = 0.0819
# u00015s00001_hw00007.svc: NRMSE = 0.0928
# u00016s00001_hw00001.svc: NRMSE = 0.0235
# u00016s00001_hw00002.svc: NRMSE = 0.0370
# u00016s00001_hw00003.svc: NRMSE = 0.0727
# u00016s00001_hw00004.svc: NRMSE = 0.0073
# u00016s00001_hw00005.svc: NRMSE = 0.0085
# u00016s00001_hw00006.svc: NRMSE = 0.0383
# u00016s00001_hw00007.svc: NRMSE = 0.0873
# u00017s00001_hw00001.svc: NRMSE = 0.0331
# u00017s00001_hw00002.svc: NRMSE = 0.0342
# u00017s00001_hw00003.svc: NRMSE = 0.0814
# u00017s00001_hw00004.svc: NRMSE = 0.0116
# u00017s00001_hw00005.svc: NRMSE = 0.0114
# u00017s00001_hw00006.svc: NRMSE = 0.0480
# u00017s00001_hw00007.svc: NRMSE = 0.0913
# u00018s00001_hw00001.svc: NRMSE = 0.0222
# u00018s00001_hw00002.svc: NRMSE = 0.0218
# u00018s00001_hw00003.svc: NRMSE = 0.0732
# u00018s00001_hw00004.svc: NRMSE = 0.0068
# u00018s00001_hw00005.svc: NRMSE = 0.0077
# u00018s00001_hw00006.svc: NRMSE = 0.0349
# u00018s00001_hw00007.svc: NRMSE = 0.0815
# u00019s00001_hw00001.svc: NRMSE = 0.0157
# u00019s00001_hw00002.svc: NRMSE = 0.0277
# u00019s00001_hw00003.svc: NRMSE = 0.0723
# u00019s00001_hw00004.svc: NRMSE = 0.0112
# u00019s00001_hw00005.svc: NRMSE = 0.0086
# u00019s00001_hw00006.svc: NRMSE = 0.0525
# u00019s00001_hw00007.svc: NRMSE = 0.0938
# u00020s00001_hw00001.svc: NRMSE = 0.0081
# u00020s00001_hw00002.svc: NRMSE = 0.0233
# u00020s00001_hw00003.svc: NRMSE = 0.0766
# u00020s00001_hw00004.svc: NRMSE = 0.0136
# u00020s00001_hw00005.svc: NRMSE = 0.0060
# u00020s00001_hw00006.svc: NRMSE = 0.0562
# u00020s00001_hw00007.svc: NRMSE = 0.0781
# u00021s00001_hw00001.svc: NRMSE = 0.0171
# u00021s00001_hw00002.svc: NRMSE = 0.0189
# u00021s00001_hw00003.svc: NRMSE = 0.0850
# u00021s00001_hw00004.svc: NRMSE = 0.0169
# u00021s00001_hw00005.svc: NRMSE = 0.0103
# u00021s00001_hw00006.svc: NRMSE = 0.0314
# u00021s00001_hw00007.svc: NRMSE = 0.0833
# u00022s00001_hw00001.svc: NRMSE = 0.0272
# u00022s00001_hw00002.svc: NRMSE = 0.0501
# u00022s00001_hw00003.svc: NRMSE = 0.0748
# u00022s00001_hw00004.svc: NRMSE = 0.0097
# u00022s00001_hw00005.svc: NRMSE = 0.0143
# u00022s00001_hw00006.svc: NRMSE = 0.0662
# u00022s00001_hw00007.svc: NRMSE = 0.0810
# u00023s00001_hw00001.svc: NRMSE = 0.0174
# u00023s00001_hw00002.svc: NRMSE = 0.0174
# u00023s00001_hw00003.svc: NRMSE = 0.0609
# u00023s00001_hw00004.svc: NRMSE = 0.0106
# u00023s00001_hw00005.svc: NRMSE = 0.0099
# u00023s00001_hw00006.svc: NRMSE = 0.0325
# u00023s00001_hw00007.svc: NRMSE = 0.0936
# u00024s00001_hw00001.svc: NRMSE = 0.0208
# u00024s00001_hw00002.svc: NRMSE = 0.0215
# u00024s00001_hw00003.svc: NRMSE = 0.0774
# u00024s00001_hw00004.svc: NRMSE = 0.0095
# u00024s00001_hw00005.svc: NRMSE = 0.0080
# u00024s00001_hw00006.svc: NRMSE = 0.0556
# u00024s00001_hw00007.svc: NRMSE = 0.0895
# u00025s00001_hw00001.svc: NRMSE = 0.0189
# u00025s00001_hw00002.svc: NRMSE = 0.0367
# u00025s00001_hw00003.svc: NRMSE = 0.0743
# u00025s00001_hw00004.svc: NRMSE = 0.0065
# u00025s00001_hw00005.svc: NRMSE = 0.0061
# u00025s00001_hw00006.svc: NRMSE = 0.0393
# u00025s00001_hw00007.svc: NRMSE = 0.0944
# u00026s00001_hw00001.svc: NRMSE = 0.0128
# u00026s00001_hw00002.svc: NRMSE = 0.0200
# u00026s00001_hw00003.svc: NRMSE = 0.0784
# u00026s00001_hw00004.svc: NRMSE = 0.0115
# u00026s00001_hw00005.svc: NRMSE = 0.0111
# u00026s00001_hw00006.svc: NRMSE = 0.0253
# u00026s00001_hw00007.svc: NRMSE = 0.0945
# u00027s00001_hw00001.svc: NRMSE = 0.0183
# u00027s00001_hw00002.svc: NRMSE = 0.0515
# u00027s00001_hw00003.svc: NRMSE = 0.0748
# u00027s00001_hw00004.svc: NRMSE = 0.0162
# u00027s00001_hw00005.svc: NRMSE = 0.0183
# u00027s00001_hw00006.svc: NRMSE = 0.0577
# u00027s00001_hw00007.svc: NRMSE = 0.1049
# u00028s00001_hw00001.svc: NRMSE = 0.0403
# u00028s00001_hw00002.svc: NRMSE = 0.0409
# u00028s00001_hw00003.svc: NRMSE = 0.0795
# u00028s00001_hw00004.svc: NRMSE = 0.0109
# u00028s00001_hw00005.svc: NRMSE = 0.0116
# u00028s00001_hw00006.svc: NRMSE = 0.0772
# u00028s00001_hw00007.svc: NRMSE = 0.1039
# u00029s00001_hw00001.svc: NRMSE = 0.0224
# u00029s00001_hw00002.svc: NRMSE = 0.0501
# u00029s00001_hw00003.svc: NRMSE = 0.0739
# u00029s00001_hw00004.svc: NRMSE = 0.0105
# u00029s00001_hw00005.svc: NRMSE = 0.0122
# u00029s00001_hw00006.svc: NRMSE = 0.0427
# u00029s00001_hw00007.svc: NRMSE = 0.0927
# u00030s00001_hw00001.svc: NRMSE = 0.0303
# u00030s00001_hw00002.svc: NRMSE = 0.0481
# u00030s00001_hw00003.svc: NRMSE = 0.0803
# u00030s00001_hw00004.svc: NRMSE = 0.0073
# u00030s00001_hw00005.svc: NRMSE = 0.0134
# u00030s00001_hw00006.svc: NRMSE = 0.0691
# u00030s00001_hw00007.svc: NRMSE = 0.0915
# u00031s00001_hw00001.svc: NRMSE = 0.0239
# u00031s00001_hw00002.svc: NRMSE = 0.0388
# u00031s00001_hw00003.svc: NRMSE = 0.0851
# u00031s00001_hw00004.svc: NRMSE = 0.0240
# u00031s00001_hw00005.svc: NRMSE = 0.0227
# u00031s00001_hw00006.svc: NRMSE = 0.0477
# u00031s00001_hw00007.svc: NRMSE = 0.0756
# u00032s00001_hw00001.svc: NRMSE = 0.0425
# u00032s00001_hw00002.svc: NRMSE = 0.0254
# u00032s00001_hw00003.svc: NRMSE = 0.0816
# u00032s00001_hw00004.svc: NRMSE = 0.0221
# u00032s00001_hw00005.svc: NRMSE = 0.0156
# u00032s00001_hw00006.svc: NRMSE = 0.0539
# u00032s00001_hw00007.svc: NRMSE = 0.0925
# u00033s00001_hw00001.svc: NRMSE = 0.0206
# u00033s00001_hw00002.svc: NRMSE = 0.0479
# u00033s00001_hw00003.svc: NRMSE = 0.0681
# u00033s00001_hw00004.svc: NRMSE = 0.0007
# u00033s00001_hw00005.svc: NRMSE = 0.0095
# u00033s00001_hw00006.svc: NRMSE = 0.0679
# u00033s00001_hw00007.svc: NRMSE = 0.0864
# u00034s00001_hw00001.svc: NRMSE = 0.0218
# u00034s00001_hw00002.svc: NRMSE = 0.0295
# u00034s00001_hw00003.svc: NRMSE = 0.0678
# u00034s00001_hw00004.svc: NRMSE = 0.0101
# u00034s00001_hw00005.svc: NRMSE = 0.0087
# u00034s00001_hw00006.svc: NRMSE = 0.0338
# u00034s00001_hw00007.svc: NRMSE = 0.0654
# u00035s00001_hw00001.svc: NRMSE = 0.0193
# u00035s00001_hw00002.svc: NRMSE = 0.0259
# u00035s00001_hw00003.svc: NRMSE = 0.0835
# u00035s00001_hw00004.svc: NRMSE = 0.0073
# u00035s00001_hw00005.svc: NRMSE = 0.0102
# u00035s00001_hw00006.svc: NRMSE = 0.0661
# u00035s00001_hw00007.svc: NRMSE = 0.0957
# u00036s00001_hw00001.svc: NRMSE = 0.0145
# u00036s00001_hw00002.svc: NRMSE = 0.0201
# u00036s00001_hw00003.svc: NRMSE = 0.0689
# u00036s00001_hw00004.svc: NRMSE = 0.0106
# u00036s00001_hw00005.svc: NRMSE = 0.0117
# u00036s00001_hw00006.svc: NRMSE = 0.0523
# u00036s00001_hw00007.svc: NRMSE = 0.0747
# u00037s00001_hw00001.svc: NRMSE = 0.0158
# u00037s00001_hw00002.svc: NRMSE = 0.0307
# u00037s00001_hw00003.svc: NRMSE = 0.0828
# u00037s00001_hw00004.svc: NRMSE = 0.0106
# u00037s00001_hw00005.svc: NRMSE = 0.0102
# u00037s00001_hw00006.svc: NRMSE = 0.0686
# u00037s00001_hw00007.svc: NRMSE = 0.0763
# u00038s00001_hw00001.svc: NRMSE = 0.0169
# u00038s00001_hw00002.svc: NRMSE = 0.0178
# u00038s00001_hw00003.svc: NRMSE = 0.1047
# u00038s00001_hw00004.svc: NRMSE = 0.0090
# u00038s00001_hw00005.svc: NRMSE = 0.0071
# u00038s00001_hw00006.svc: NRMSE = 0.0330
# u00038s00001_hw00007.svc: NRMSE = 0.0748
# u00039s00001_hw00001.svc: NRMSE = 0.0129
# u00039s00001_hw00002.svc: NRMSE = 0.0255
# u00039s00001_hw00003.svc: NRMSE = 0.0725
# u00039s00001_hw00004.svc: NRMSE = 0.0137
# u00039s00001_hw00005.svc: NRMSE = 0.0181
# u00039s00001_hw00006.svc: NRMSE = 0.0502
# u00039s00001_hw00007.svc: NRMSE = 0.0640
# u00040s00001_hw00001.svc: NRMSE = 0.0216
# u00040s00001_hw00002.svc: NRMSE = 0.0243
# u00040s00001_hw00003.svc: NRMSE = 0.0870
# u00040s00001_hw00004.svc: NRMSE = 0.0106
# u00040s00001_hw00005.svc: NRMSE = 0.0128
# u00040s00001_hw00006.svc: NRMSE = 0.0282
# u00040s00001_hw00007.svc: NRMSE = 0.0830
# u00041s00001_hw00001.svc: NRMSE = 0.0325
# u00041s00001_hw00002.svc: NRMSE = 0.0369
# u00041s00001_hw00003.svc: NRMSE = 0.0702
# u00041s00001_hw00004.svc: NRMSE = 0.0164
# u00041s00001_hw00005.svc: NRMSE = 0.0148
# u00041s00001_hw00006.svc: NRMSE = 0.0711
# u00041s00001_hw00007.svc: NRMSE = 0.0817
# u00042s00001_hw00001.svc: NRMSE = 0.0155
# u00042s00001_hw00002.svc: NRMSE = 0.0284
# u00042s00001_hw00003.svc: NRMSE = 0.0800
# u00042s00001_hw00004.svc: NRMSE = 0.0106
# u00042s00001_hw00005.svc: NRMSE = 0.0112
# u00042s00001_hw00006.svc: NRMSE = 0.0504
# u00042s00001_hw00007.svc: NRMSE = 0.0833
# u00043s00001_hw00001.svc: NRMSE = 0.0190
# u00043s00001_hw00002.svc: NRMSE = 0.0254
# u00043s00001_hw00003.svc: NRMSE = 0.0775
# u00043s00001_hw00004.svc: NRMSE = 0.0130
# u00043s00001_hw00005.svc: NRMSE = 0.0103
# u00043s00001_hw00006.svc: NRMSE = 0.0484
# u00043s00001_hw00007.svc: NRMSE = 0.0733
# u00044s00001_hw00001.svc: NRMSE = 0.0282
# u00044s00001_hw00002.svc: NRMSE = 0.0256
# u00044s00001_hw00003.svc: NRMSE = 0.0708
# u00044s00001_hw00004.svc: NRMSE = 0.0162
# u00044s00001_hw00005.svc: NRMSE = 0.0110
# u00044s00001_hw00006.svc: NRMSE = 0.0403
# u00044s00001_hw00007.svc: NRMSE = 0.0808
# u00045s00001_hw00001.svc: NRMSE = 0.0152
# u00045s00001_hw00002.svc: NRMSE = 0.0229
# u00045s00001_hw00003.svc: NRMSE = 0.0911
# u00045s00001_hw00004.svc: NRMSE = 0.0095
# u00045s00001_hw00005.svc: NRMSE = 0.0119
# u00045s00001_hw00006.svc: NRMSE = 0.0351
# u00045s00001_hw00007.svc: NRMSE = 0.1016
# u00046s00001_hw00001.svc: NRMSE = 0.0172
# u00046s00001_hw00002.svc: NRMSE = 0.0216
# u00046s00001_hw00003.svc: NRMSE = 0.0778
# u00046s00001_hw00004.svc: NRMSE = 0.0099
# u00046s00001_hw00005.svc: NRMSE = 0.0097
# u00046s00001_hw00006.svc: NRMSE = 0.0382
# u00046s00001_hw00007.svc: NRMSE = 0.0896
# u00047s00001_hw00001.svc: NRMSE = 0.0106
# u00047s00001_hw00002.svc: NRMSE = 0.0359
# u00047s00001_hw00003.svc: NRMSE = 0.0642
# u00047s00001_hw00004.svc: NRMSE = 0.0101
# u00047s00001_hw00005.svc: NRMSE = 0.0086
# u00047s00001_hw00006.svc: NRMSE = 0.0458
# u00047s00001_hw00007.svc: NRMSE = 0.1018
# u00048s00001_hw00001.svc: NRMSE = 0.0164
# u00048s00001_hw00002.svc: NRMSE = 0.0225
# u00048s00001_hw00003.svc: NRMSE = 0.0757
# u00048s00001_hw00004.svc: NRMSE = 0.0135
# u00048s00001_hw00005.svc: NRMSE = 0.0082
# u00048s00001_hw00006.svc: NRMSE = 0.0310
# u00048s00001_hw00007.svc: NRMSE = 0.0945
# u00049s00001_hw00001.svc: NRMSE = 0.0222
# u00049s00001_hw00002.svc: NRMSE = 0.0292
# u00049s00001_hw00003.svc: NRMSE = 0.0680
# u00049s00001_hw00004.svc: NRMSE = 0.0115
# u00049s00001_hw00005.svc: NRMSE = 0.0188
# u00049s00001_hw00006.svc: NRMSE = 0.0479
# u00049s00001_hw00007.svc: NRMSE = 0.0789
# u00050s00001_hw00001.svc: NRMSE = 0.0212
# u00050s00001_hw00002.svc: NRMSE = 0.0230
# u00050s00001_hw00003.svc: NRMSE = 0.0696
# u00050s00001_hw00004.svc: NRMSE = 0.0105
# u00050s00001_hw00005.svc: NRMSE = 0.0085
# u00050s00001_hw00006.svc: NRMSE = 0.0451
# u00050s00001_hw00007.svc: NRMSE = 0.0934
# u00051s00001_hw00001.svc: NRMSE = 0.0178
# u00051s00001_hw00002.svc: NRMSE = 0.0305
# u00051s00001_hw00003.svc: NRMSE = 0.0705
# u00051s00001_hw00004.svc: NRMSE = 0.0120
# u00051s00001_hw00005.svc: NRMSE = 0.0110
# u00051s00001_hw00006.svc: NRMSE = 0.0311
# u00051s00001_hw00007.svc: NRMSE = 0.0953
# u00052s00001_hw00001.svc: NRMSE = 0.0347
# u00052s00001_hw00002.svc: NRMSE = 0.0313
# u00052s00001_hw00003.svc: NRMSE = 0.0693
# u00052s00001_hw00004.svc: NRMSE = 0.0078
# u00052s00001_hw00005.svc: NRMSE = 0.0094
# u00052s00001_hw00006.svc: NRMSE = 0.0675
# u00052s00001_hw00007.svc: NRMSE = 0.0978
# u00053s00001_hw00001.svc: NRMSE = 0.0170
# u00053s00001_hw00002.svc: NRMSE = 0.0238
# u00053s00001_hw00003.svc: NRMSE = 0.0793
# u00053s00001_hw00004.svc: NRMSE = 0.0125
# u00053s00001_hw00005.svc: NRMSE = 0.0094
# u00053s00001_hw00006.svc: NRMSE = 0.0580
# u00053s00001_hw00007.svc: NRMSE = 0.0782
# u00054s00001_hw00001.svc: NRMSE = 0.0188
# u00054s00001_hw00002.svc: NRMSE = 0.0720
# u00054s00001_hw00003.svc: NRMSE = 0.0743
# u00054s00001_hw00004.svc: NRMSE = 0.0038
# u00054s00001_hw00005.svc: NRMSE = 0.0073
# u00054s00001_hw00006.svc: NRMSE = 0.0505
# u00054s00001_hw00007.svc: NRMSE = 0.0929
# u00055s00001_hw00001.svc: NRMSE = 0.0291
# u00055s00001_hw00002.svc: NRMSE = 0.0444
# u00055s00001_hw00003.svc: NRMSE = 0.0880
# u00055s00001_hw00004.svc: NRMSE = 0.0145
# u00055s00001_hw00005.svc: NRMSE = 0.0129
# u00055s00001_hw00006.svc: NRMSE = 0.0683
# u00055s00001_hw00007.svc: NRMSE = 0.0762
# u00056s00001_hw00001.svc: NRMSE = 0.0167
# u00056s00001_hw00002.svc: NRMSE = 0.0161
# u00056s00001_hw00003.svc: NRMSE = 0.0778
# u00056s00001_hw00004.svc: NRMSE = 0.0075
# u00056s00001_hw00005.svc: NRMSE = 0.0063
# u00056s00001_hw00006.svc: NRMSE = 0.0415
# u00056s00001_hw00007.svc: NRMSE = 0.0668
# u00057s00001_hw00001.svc: NRMSE = 0.0233
# u00057s00001_hw00002.svc: NRMSE = 0.0314
# u00057s00001_hw00003.svc: NRMSE = 0.0850
# u00057s00001_hw00004.svc: NRMSE = 0.0183
# u00057s00001_hw00005.svc: NRMSE = 0.0179
# u00057s00001_hw00006.svc: NRMSE = 0.0488
# u00057s00001_hw00007.svc: NRMSE = 0.0896
# u00058s00001_hw00001.svc: NRMSE = 0.0212
# u00058s00001_hw00002.svc: NRMSE = 0.0275
# u00058s00001_hw00003.svc: NRMSE = 0.0924
# u00058s00001_hw00004.svc: NRMSE = 0.0171
# u00058s00001_hw00005.svc: NRMSE = 0.0146
# u00058s00001_hw00006.svc: NRMSE = 0.0549
# u00058s00001_hw00007.svc: NRMSE = 0.0832
# u00059s00001_hw00001.svc: NRMSE = 0.0294
# u00059s00001_hw00002.svc: NRMSE = 0.0280
# u00059s00001_hw00003.svc: NRMSE = 0.0709
# u00059s00001_hw00004.svc: NRMSE = 0.0131
# u00059s00001_hw00005.svc: NRMSE = 0.0136
# u00059s00001_hw00006.svc: NRMSE = 0.0574
# u00059s00001_hw00007.svc: NRMSE = 0.0921
# u00060s00001_hw00001.svc: NRMSE = 0.0451
# u00060s00001_hw00002.svc: NRMSE = 0.0428
# u00060s00001_hw00003.svc: NRMSE = 0.0757
# u00060s00001_hw00004.svc: NRMSE = 0.0162
# u00060s00001_hw00005.svc: NRMSE = 0.0195
# u00060s00001_hw00006.svc: NRMSE = 0.0534
# u00060s00001_hw00007.svc: NRMSE = 0.0826
# u00061s00001_hw00001.svc: NRMSE = 0.0351
# u00061s00001_hw00002.svc: NRMSE = 0.0324
# u00061s00001_hw00003.svc: NRMSE = 0.0735
# u00061s00001_hw00004.svc: NRMSE = 0.0192
# u00061s00001_hw00005.svc: NRMSE = 0.0127
# u00061s00001_hw00006.svc: NRMSE = 0.0561
# u00061s00001_hw00007.svc: NRMSE = 0.0823
# u00062s00001_hw00001.svc: NRMSE = 0.0267
# u00062s00001_hw00002.svc: NRMSE = 0.0321
# u00062s00001_hw00003.svc: NRMSE = 0.0798
# u00062s00001_hw00004.svc: NRMSE = 0.0083
# u00062s00001_hw00005.svc: NRMSE = 0.0096
# u00062s00001_hw00006.svc: NRMSE = 0.0866
# u00062s00001_hw00007.svc: NRMSE = 0.0931
# u00063s00001_hw00001.svc: NRMSE = 0.0200
# u00063s00001_hw00002.svc: NRMSE = 0.0313
# u00063s00001_hw00003.svc: NRMSE = 0.0749
# u00063s00001_hw00004.svc: NRMSE = 0.0076
# u00063s00001_hw00005.svc: NRMSE = 0.0115
# u00063s00001_hw00006.svc: NRMSE = 0.0387
# u00063s00001_hw00007.svc: NRMSE = 0.0919
# u00064s00001_hw00001.svc: NRMSE = 0.0190
# u00064s00001_hw00002.svc: NRMSE = 0.0204
# u00064s00001_hw00003.svc: NRMSE = 0.0858
# u00064s00001_hw00004.svc: NRMSE = 0.0048
# u00064s00001_hw00005.svc: NRMSE = 0.0054
# u00064s00001_hw00006.svc: NRMSE = 0.0420
# u00064s00001_hw00007.svc: NRMSE = 0.1022
# u00065s00001_hw00001.svc: NRMSE = 0.0392
# u00065s00001_hw00002.svc: NRMSE = 0.0342
# u00065s00001_hw00003.svc: NRMSE = 0.0766
# u00065s00001_hw00004.svc: NRMSE = 0.0099
# u00065s00001_hw00005.svc: NRMSE = 0.0098
# u00065s00001_hw00006.svc: NRMSE = 0.0366
# u00065s00001_hw00007.svc: NRMSE = 0.0907
# u00066s00001_hw00001.svc: NRMSE = 0.0358
# u00066s00001_hw00002.svc: NRMSE = 0.0385
# u00066s00001_hw00003.svc: NRMSE = 0.0784
# u00066s00001_hw00004.svc: NRMSE = 0.0145
# u00066s00001_hw00005.svc: NRMSE = 0.0142
# u00066s00001_hw00006.svc: NRMSE = 0.0517
# u00066s00001_hw00007.svc: NRMSE = 0.0532
# u00067s00001_hw00001.svc: NRMSE = 0.0262
# u00067s00001_hw00002.svc: NRMSE = 0.0333
# u00067s00001_hw00003.svc: NRMSE = 0.0719
# u00067s00001_hw00004.svc: NRMSE = 0.0108
# u00067s00001_hw00005.svc: NRMSE = 0.0118
# u00067s00001_hw00006.svc: NRMSE = 0.0321
# u00067s00001_hw00007.svc: NRMSE = 0.0665
# u00068s00001_hw00001.svc: NRMSE = 0.0243
# u00068s00001_hw00002.svc: NRMSE = 0.0347
# u00068s00001_hw00003.svc: NRMSE = 0.0781
# u00068s00001_hw00004.svc: NRMSE = 0.0144
# u00068s00001_hw00005.svc: NRMSE = 0.0157
# u00068s00001_hw00006.svc: NRMSE = 0.0318
# u00068s00001_hw00007.svc: NRMSE = 0.0693
# u00069s00001_hw00001.svc: NRMSE = 0.0172
# u00069s00001_hw00002.svc: NRMSE = 0.0267
# u00069s00001_hw00003.svc: NRMSE = 0.0604
# u00069s00001_hw00004.svc: NRMSE = 0.0616
# u00069s00001_hw00005.svc: NRMSE = 0.0056
# u00069s00001_hw00006.svc: NRMSE = 0.0432
# u00069s00001_hw00007.svc: NRMSE = 0.1099
# u00070s00001_hw00001.svc: NRMSE = 0.0203
# u00070s00001_hw00002.svc: NRMSE = 0.0346
# u00070s00001_hw00003.svc: NRMSE = 0.0748
# u00070s00001_hw00004.svc: NRMSE = 0.0153
# u00070s00001_hw00005.svc: NRMSE = 0.0129
# u00070s00001_hw00006.svc: NRMSE = 0.0686
# u00070s00001_hw00007.svc: NRMSE = 0.1019
# u00071s00001_hw00001.svc: NRMSE = 0.0251
# u00071s00001_hw00002.svc: NRMSE = 0.0473
# u00071s00001_hw00003.svc: NRMSE = 0.0792
# u00071s00001_hw00004.svc: NRMSE = 0.0069
# u00071s00001_hw00005.svc: NRMSE = 0.0093
# u00071s00001_hw00006.svc: NRMSE = 0.0651
# u00071s00001_hw00007.svc: NRMSE = 0.0925
# u00072s00001_hw00001.svc: NRMSE = 0.0209
# u00072s00001_hw00002.svc: NRMSE = 0.0308
# u00072s00001_hw00003.svc: NRMSE = 0.0703
# u00072s00001_hw00004.svc: NRMSE = 0.0121
# u00072s00001_hw00005.svc: NRMSE = 0.0065
# u00072s00001_hw00006.svc: NRMSE = 0.0344
# u00072s00001_hw00007.svc: NRMSE = 0.0822
# u00073s00001_hw00001.svc: NRMSE = 0.0158
# u00073s00001_hw00002.svc: NRMSE = 0.0229
# u00073s00001_hw00003.svc: NRMSE = 0.0708
# u00073s00001_hw00004.svc: NRMSE = 0.0090
# u00073s00001_hw00005.svc: NRMSE = 0.0072
# u00073s00001_hw00006.svc: NRMSE = 0.0673
# u00073s00001_hw00007.svc: NRMSE = 0.0890
# u00074s00001_hw00001.svc: NRMSE = 0.0305
# u00074s00001_hw00002.svc: NRMSE = 0.0366
# u00074s00001_hw00003.svc: NRMSE = 0.0715
# u00074s00001_hw00004.svc: NRMSE = 0.0189
# u00074s00001_hw00005.svc: NRMSE = 0.0095
# u00074s00001_hw00006.svc: NRMSE = 0.0657
# u00074s00001_hw00007.svc: NRMSE = 0.0835
# u00075s00001_hw00001.svc: NRMSE = 0.0183
# u00075s00001_hw00002.svc: NRMSE = 0.0226
# u00075s00001_hw00003.svc: NRMSE = 0.0638
# u00075s00001_hw00004.svc: NRMSE = 0.0167
# u00075s00001_hw00005.svc: NRMSE = 0.0098
# u00075s00001_hw00006.svc: NRMSE = 0.0337
# u00075s00001_hw00007.svc: NRMSE = 0.1220
# u00076s00001_hw00001.svc: NRMSE = 0.0258
# u00076s00001_hw00002.svc: NRMSE = 0.0391
# u00076s00001_hw00003.svc: NRMSE = 0.0725
# u00076s00001_hw00004.svc: NRMSE = 0.0128
# u00076s00001_hw00005.svc: NRMSE = 0.0146
# u00076s00001_hw00006.svc: NRMSE = 0.0897
# u00076s00001_hw00007.svc: NRMSE = 0.0866
# u00077s00001_hw00001.svc: NRMSE = 0.0205
# u00077s00001_hw00002.svc: NRMSE = 0.0344
# u00077s00001_hw00003.svc: NRMSE = 0.0668
# u00077s00001_hw00004.svc: NRMSE = 0.0116
# u00077s00001_hw00005.svc: NRMSE = 0.0112
# u00077s00001_hw00006.svc: NRMSE = 0.0401
# u00077s00001_hw00007.svc: NRMSE = 0.0833
# u00078s00001_hw00001.svc: NRMSE = 0.0191
# u00078s00001_hw00002.svc: NRMSE = 0.0222
# u00078s00001_hw00003.svc: NRMSE = 0.0794
# u00078s00001_hw00004.svc: NRMSE = 0.0126
# u00078s00001_hw00005.svc: NRMSE = 0.0209
# u00078s00001_hw00006.svc: NRMSE = 0.0483
# u00078s00001_hw00007.svc: NRMSE = 0.0828
# u00079s00001_hw00001.svc: NRMSE = 0.0205
# u00079s00001_hw00002.svc: NRMSE = 0.0242
# u00079s00001_hw00003.svc: NRMSE = 0.0881
# u00079s00001_hw00004.svc: NRMSE = 0.0082
# u00079s00001_hw00005.svc: NRMSE = 0.0095
# u00079s00001_hw00006.svc: NRMSE = 0.0761
# u00079s00001_hw00007.svc: NRMSE = 0.0813
# u00080s00001_hw00001.svc: NRMSE = 0.0568
# u00080s00001_hw00002.svc: NRMSE = 0.0327
# u00080s00001_hw00003.svc: NRMSE = 0.0751
# u00080s00001_hw00004.svc: NRMSE = 0.0132
# u00080s00001_hw00005.svc: NRMSE = 0.0184
# u00080s00001_hw00006.svc: NRMSE = 0.0773
# u00080s00001_hw00007.svc: NRMSE = 0.0877
# u00081s00001_hw00001.svc: NRMSE = 0.0221
# u00081s00001_hw00002.svc: NRMSE = 0.0270
# u00081s00001_hw00003.svc: NRMSE = 0.0710
# u00081s00001_hw00004.svc: NRMSE = 0.0134
# u00081s00001_hw00005.svc: NRMSE = 0.0157
# u00081s00001_hw00006.svc: NRMSE = 0.0326
# u00081s00001_hw00007.svc: NRMSE = 0.0905
# u00082s00001_hw00001.svc: NRMSE = 0.0166
# u00082s00001_hw00002.svc: NRMSE = 0.0213
# u00082s00001_hw00003.svc: NRMSE = 0.0782
# u00082s00001_hw00004.svc: NRMSE = 0.0100
# u00082s00001_hw00005.svc: NRMSE = 0.0119
# u00082s00001_hw00006.svc: NRMSE = 0.0403
# u00082s00001_hw00007.svc: NRMSE = 0.1206
# u00083s00001_hw00001.svc: NRMSE = 0.0675
# u00083s00001_hw00002.svc: NRMSE = 0.0516
# u00083s00001_hw00003.svc: NRMSE = 0.0741
# u00083s00001_hw00004.svc: NRMSE = 0.0136
# u00083s00001_hw00005.svc: NRMSE = 0.0149
# u00083s00001_hw00006.svc: NRMSE = 0.0632
# u00083s00001_hw00007.svc: NRMSE = 0.0952
# u00084s00001_hw00001.svc: NRMSE = 0.0169
# u00084s00001_hw00002.svc: NRMSE = 0.0284
# u00084s00001_hw00003.svc: NRMSE = 0.0770
# u00084s00001_hw00004.svc: NRMSE = 0.0082
# u00084s00001_hw00005.svc: NRMSE = 0.0118
# u00084s00001_hw00006.svc: NRMSE = 0.0498
# u00084s00001_hw00007.svc: NRMSE = 0.0924
#
# Overall Average NRMSE: 0.0411, Standard Deviation: 0.0302

# %%
import os
from glob import glob
import numpy as np
import logging
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Configure logging
log_filename = "posthoc_discriminative_score.txt"
logging.basicConfig(
    level=logging.INFO,
    format="%(message)s",
    handlers=[
        logging.FileHandler(log_filename, mode="w", encoding="utf-8"),
        logging.StreamHandler()
    ]
)

def process_files(original_folder, augmented_folder, input_filenames):
    all_real_data = []
    all_synthetic_data = []
    input_filenames_set = {os.path.splitext(os.path.basename(filename))[0] for filename in input_filenames}
    
    for original_file in glob(os.path.join(original_folder, "*.svc")):
        base_name = os.path.splitext(os.path.basename(original_file))[0]
        
        if base_name not in input_filenames_set:
            continue
        
        original_data = read_svc_file(original_file)
        all_real_data.append(original_data.values)
        
        matching_augmented_files = get_matching_augmented_files(original_file, augmented_folder)
        
        for augmented_file in matching_augmented_files:
            augmented_data = read_svc_file(augmented_file)
            all_synthetic_data.append(augmented_data.values)
    
    return np.concatenate(all_real_data), np.concatenate(all_synthetic_data)

def create_lstm_classifier(input_shape):
    model = Sequential([
        LSTM(64, input_shape=input_shape, return_sequences=True),
        LSTM(32),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def prepare_data_for_lstm(real_data, synthetic_data):
    n_features = min(real_data.shape[1], synthetic_data.shape[1])
    real_data_trimmed = real_data[:, :n_features]
    synthetic_data_trimmed = synthetic_data[:, :n_features]
    
    X = np.vstack((real_data_trimmed, synthetic_data_trimmed))
    y = np.concatenate((np.ones(len(real_data)), np.zeros(len(synthetic_data))))
    return X, y

def post_hoc_discriminative_score(real_data, synthetic_data, n_splits=10):
    X, y = prepare_data_for_lstm(real_data, synthetic_data)
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    
    for fold, (train_index, test_index) in enumerate(kf.split(X), start=1):
        logging.info(f"\nFold {fold}/{n_splits}:")
        
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
        X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
        
        model = create_lstm_classifier((1, X_train.shape[2]))
        
        # Train model and log epoch progress
        history = model.fit(X_train, y_train, epochs=5, batch_size=512, verbose=0)
        for epoch, metrics in enumerate(history.history["accuracy"], start=1):
            logging.info(f"  Epoch {epoch}: Accuracy = {metrics:.4f}")
        
        y_pred = (model.predict(X_test) > 0.5).astype(int)
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
    
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    logging.info(f"\nMean accuracy: {mean_accuracy:.4f}, Standard Deviation: {std_accuracy:.4f}")
    return mean_accuracy, std_accuracy

# Specify your folders
original_folder = "original_absolute"
augmented_folder = "../../final vaegan copy/augmented_data" #Directory ng augmented data


# Process files
real_data, synthetic_data = process_files(original_folder, augmented_folder, input_filenames)

# Compute post-hoc discriminative score
mean_accuracy, std_accuracy = post_hoc_discriminative_score(real_data, synthetic_data)
# Out:
# Fold 1/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5331
#   Epoch 2: Accuracy = 0.5336
#   Epoch 3: Accuracy = 0.5348
#   Epoch 4: Accuracy = 0.5335
#   Epoch 5: Accuracy = 0.5382
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step
# Fold 2/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5329
#   Epoch 2: Accuracy = 0.5332
#   Epoch 3: Accuracy = 0.5380
#   Epoch 4: Accuracy = 0.5367
#   Epoch 5: Accuracy = 0.5399
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 883us/step
# Fold 3/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5337
#   Epoch 2: Accuracy = 0.5374
#   Epoch 3: Accuracy = 0.5424
#   Epoch 4: Accuracy = 0.5444
#   Epoch 5: Accuracy = 0.5383
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 868us/step
# Fold 4/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5360
#   Epoch 2: Accuracy = 0.5396
#   Epoch 3: Accuracy = 0.5430
#   Epoch 4: Accuracy = 0.5426
#   Epoch 5: Accuracy = 0.5400
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 16s 950us/step
# Fold 5/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5346
#   Epoch 2: Accuracy = 0.5366
#   Epoch 3: Accuracy = 0.5440
#   Epoch 4: Accuracy = 0.5405
#   Epoch 5: Accuracy = 0.5457
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 911us/step
# Fold 6/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5307
#   Epoch 2: Accuracy = 0.5323
#   Epoch 3: Accuracy = 0.5329
#   Epoch 4: Accuracy = 0.5366
#   Epoch 5: Accuracy = 0.5383
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 880us/step
# Fold 7/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5341
#   Epoch 2: Accuracy = 0.5373
#   Epoch 3: Accuracy = 0.5340
#   Epoch 4: Accuracy = 0.5364
#   Epoch 5: Accuracy = 0.5404
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 902us/step
# Fold 8/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5357
#   Epoch 2: Accuracy = 0.5375
#   Epoch 3: Accuracy = 0.5421
#   Epoch 4: Accuracy = 0.5430
#   Epoch 5: Accuracy = 0.5414
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 14s 836us/step
# Fold 9/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5342
#   Epoch 2: Accuracy = 0.5361
#   Epoch 3: Accuracy = 0.5350
#   Epoch 4: Accuracy = 0.5362
#   Epoch 5: Accuracy = 0.5340
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 862us/step
# Fold 10/10:
# c:\Users\Grimes\OneDrive\Desktop\tryyy\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   Epoch 1: Accuracy = 0.5352
#   Epoch 2: Accuracy = 0.5384
#   Epoch 3: Accuracy = 0.5370
#   Epoch 4: Accuracy = 0.5427
#   Epoch 5: Accuracy = 0.5462
# 16590/16590 ━━━━━━━━━━━━━━━━━━━━ 15s 884us/step
# Mean accuracy: 0.5401, Standard Deviation: 0.0076

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor
from glob import glob
import os
import time

def write_to_log(message):
    """Write a message to the log file."""
    log_file = "posthoc_predictive_score.txt"
    with open(log_file, "a") as f:
        f.write(message + "\n")

def read_svc_file(file_path):
    """Read an SVC file and return its contents as a DataFrame."""
    try:
        df = pd.read_csv(file_path, sep=' ', header=None)
        if df.empty:
            return None
        return df
    except Exception as e:
        return None

def get_matching_augmented_file(original_file, augmented_folder):
    """Get matching augmented file for a given original file."""
    base_name = os.path.splitext(os.path.basename(original_file))[0]
    augmented_file = os.path.join(augmented_folder, f"synthetic_{base_name}.svc")
    return augmented_file if os.path.exists(augmented_file) else None

def process_files(original_folder, augmented_folder):
    """Process original and augmented files and prepare them for analysis."""
    paired_data = []
    for original_file in glob(os.path.join(original_folder, "*.svc")):
        augmented_file = get_matching_augmented_file(original_file, augmented_folder)
        if augmented_file is None:
            continue
            
        original_data = read_svc_file(original_file)
        augmented_data = read_svc_file(augmented_file)
        
        if (original_data is not None and augmented_data is not None and 
            original_data.shape[1] == augmented_data.shape[1]):
            paired_data.append((original_file, augmented_file))

    if not paired_data:
        raise ValueError("No valid data pairs found for processing")
    return paired_data

def prepare_sequences(data, time_steps=4):
    """Prepare sequences for prediction, using all but last timestep as input."""
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps - 1].flatten())
        y.append(data[i + time_steps - 1])
    return np.array(X), np.array(y)

def evaluate_synthetic_data(original_file, synthetic_file):
    """Evaluate a single synthetic dataset against its original counterpart."""
    original_df = read_svc_file(original_file)
    synthetic_df = read_svc_file(synthetic_file)

    if original_df is None or synthetic_df is None:
        return None

    integer_columns = [0, 1, 4, 5]
    scaler = MinMaxScaler()
    original_scaled = scaler.fit_transform(original_df)
    synthetic_scaled = scaler.transform(synthetic_df)

    start_time = time.time()
    X_train, y_train = prepare_sequences(synthetic_scaled)
    X_test, y_test = prepare_sequences(original_scaled)

    if len(X_train) == 0 or len(X_test) == 0:
        return None

    mapes_per_dim = []
    for dim in range(y_train.shape[1]):
        model = XGBRegressor(
            n_estimators=100,
            learning_rate=0.1,
            max_depth=6,
            random_state=42
        )

        model.fit(X_train, y_train[:, dim], verbose=False)
        y_pred = model.predict(X_test)

        y_true_original = original_df.iloc[len(original_df)-len(y_test):, dim].values

        temp_data = np.zeros((len(y_pred), original_df.shape[1]))
        temp_data[:, dim] = y_pred
        y_pred_original = scaler.inverse_transform(temp_data)[:, dim]

        if dim in integer_columns:
            y_pred_original = np.round(y_pred_original)

        if dim == 3:
            y_pred_original = np.round(y_pred_original)

        y_pred_original = np.round(y_pred_original).astype(int)
        y_true_original = np.round(y_true_original).astype(int)

        errors = []
        for true, pred in zip(y_true_original, y_pred_original):
            if true == 0:
                errors.append(100 if pred != 0 else 0)
            else:
                errors.append(min(abs((true - pred) / true) * 100, 100))

        mapes_per_dim.append(np.mean(errors))

    elapsed_time = time.time() - start_time
    return np.mean(mapes_per_dim), elapsed_time

def post_hoc_predictive_score(original_folder, augmented_folder):
    """Calculate post-hoc predictive score for all pairs of original and synthetic data."""
    try:
        paired_files = process_files(original_folder, augmented_folder)
        all_results = []
        
        for original_file, synthetic_file in paired_files:
            result = evaluate_synthetic_data(original_file, synthetic_file)
            if result is not None:
                mape, elapsed_time = result
                file_name = os.path.basename(original_file)
                log_message = (f"Processing: {file_name} Completed in {elapsed_time:.1f}s "
                               f"(MAPE: {mape:.2f}%)")
                print(log_message)
                write_to_log(log_message)
                all_results.append(mape)
        
        if not all_results:
            raise ValueError("No valid results calculated")
        
        summary_message = (f"----------------------------------------\n"
                           f"Overall Results:\n"
                           f"Average MAPE: {np.mean(all_results):.2f}%, "
                           f"Standard Deviation: {np.std(all_results):.2f}%")
        print(summary_message)
        write_to_log(summary_message)
        
        return np.mean(all_results), np.std(all_results)
        
    except Exception as e:
        error_message = f"Error: {str(e)}"
        print(error_message)
        write_to_log(error_message)
        return None, None

def main():
    try:
        original_folder = "original_absolute"
        augmented_folder = "../../final vaegan copy/augmented_data" #Directory ng augmented data
        post_hoc_predictive_score(original_folder, augmented_folder)
            
    except Exception as e:
        error_message = f"Error: {str(e)}"
        print(error_message)
        write_to_log(error_message)

if __name__ == "__main__":
    main()
# Out:
# Processing: collection1u00001s00001_hw00001.svc Completed in 1.7s (MAPE: 6.91%)
# Processing: collection1u00001s00001_hw00002.svc Completed in 1.7s (MAPE: 6.50%)
# Processing: collection1u00001s00001_hw00003.svc Completed in 1.3s (MAPE: 9.67%)
# Processing: collection1u00001s00001_hw00004.svc Completed in 1.5s (MAPE: 6.72%)
# Processing: collection1u00001s00001_hw00005.svc Completed in 0.9s (MAPE: 0.91%)
# Processing: collection1u00001s00001_hw00006.svc Completed in 1.3s (MAPE: 7.87%)
# Processing: collection1u00001s00001_hw00007.svc Completed in 1.1s (MAPE: 7.47%)
# Processing: collection1u00002s00001_hw00001.svc Completed in 1.0s (MAPE: 4.64%)
# Processing: collection1u00002s00001_hw00002.svc Completed in 1.4s (MAPE: 6.42%)
# Processing: collection1u00002s00001_hw00003.svc Completed in 1.4s (MAPE: 10.72%)
# Processing: collection1u00002s00001_hw00004.svc Completed in 0.9s (MAPE: 2.47%)
# Processing: collection1u00002s00001_hw00005.svc Completed in 0.9s (MAPE: 2.03%)
# Processing: collection1u00002s00001_hw00006.svc Completed in 1.4s (MAPE: 8.44%)
# Processing: collection1u00002s00001_hw00007.svc Completed in 1.4s (MAPE: 9.36%)
# Processing: collection1u00003s00001_hw00001.svc Completed in 1.1s (MAPE: 7.06%)
# Processing: collection1u00003s00001_hw00002.svc Completed in 1.3s (MAPE: 7.04%)
# Processing: collection1u00003s00001_hw00003.svc Completed in 1.3s (MAPE: 10.66%)
# Processing: collection1u00003s00001_hw00004.svc Completed in 0.8s (MAPE: 1.61%)
# Processing: collection1u00003s00001_hw00005.svc Completed in 0.8s (MAPE: 1.41%)
# Processing: collection1u00003s00001_hw00006.svc Completed in 1.4s (MAPE: 10.14%)
# Processing: collection1u00003s00001_hw00007.svc Completed in 1.2s (MAPE: 9.68%)
# Processing: collection1u00004s00001_hw00001.svc Completed in 1.0s (MAPE: 2.36%)
# Processing: collection1u00004s00001_hw00002.svc Completed in 1.1s (MAPE: 5.78%)
# Processing: collection1u00004s00001_hw00003.svc Completed in 1.3s (MAPE: 9.65%)
# Processing: collection1u00004s00001_hw00004.svc Completed in 1.0s (MAPE: 5.60%)
# Processing: collection1u00004s00001_hw00005.svc Completed in 0.9s (MAPE: 0.62%)
# Processing: collection1u00004s00001_hw00006.svc Completed in 1.3s (MAPE: 5.32%)
# Processing: collection1u00004s00001_hw00007.svc Completed in 1.5s (MAPE: 9.07%)
# Processing: collection1u00005s00001_hw00001.svc Completed in 1.2s (MAPE: 6.65%)
# Processing: collection1u00005s00001_hw00002.svc Completed in 1.5s (MAPE: 8.40%)
# Processing: collection1u00005s00001_hw00003.svc Completed in 1.4s (MAPE: 10.62%)
# Processing: collection1u00005s00001_hw00004.svc Completed in 1.0s (MAPE: 2.45%)
# Processing: collection1u00005s00001_hw00005.svc Completed in 1.0s (MAPE: 1.95%)
# Processing: collection1u00005s00001_hw00006.svc Completed in 1.5s (MAPE: 9.02%)
# Processing: collection1u00005s00001_hw00007.svc Completed in 1.6s (MAPE: 8.27%)
# Processing: collection1u00006s00001_hw00001.svc Completed in 1.1s (MAPE: 2.94%)
# Processing: collection1u00006s00001_hw00002.svc Completed in 1.6s (MAPE: 7.20%)
# Processing: collection1u00006s00001_hw00003.svc Completed in 1.6s (MAPE: 9.97%)
# Processing: collection1u00006s00001_hw00004.svc Completed in 1.1s (MAPE: 2.01%)
# Processing: collection1u00006s00001_hw00005.svc Completed in 1.1s (MAPE: 4.81%)
# Processing: collection1u00006s00001_hw00006.svc Completed in 1.7s (MAPE: 9.17%)
# Processing: collection1u00006s00001_hw00007.svc Completed in 1.7s (MAPE: 8.39%)
# Processing: collection1u00007s00001_hw00001.svc Completed in 1.5s (MAPE: 6.69%)
# Processing: collection1u00007s00001_hw00002.svc Completed in 1.7s (MAPE: 7.47%)
# Processing: collection1u00007s00001_hw00003.svc Completed in 1.6s (MAPE: 11.96%)
# Processing: collection1u00007s00001_hw00004.svc Completed in 1.2s (MAPE: 1.54%)
# Processing: collection1u00007s00001_hw00005.svc Completed in 1.2s (MAPE: 2.67%)
# Processing: collection1u00007s00001_hw00006.svc Completed in 1.7s (MAPE: 10.37%)
# Processing: collection1u00007s00001_hw00007.svc Completed in 1.3s (MAPE: 9.65%)
# Processing: collection1u00008s00001_hw00001.svc Completed in 1.2s (MAPE: 5.33%)
# Processing: collection1u00008s00001_hw00002.svc Completed in 1.7s (MAPE: 6.03%)
# Processing: collection1u00008s00001_hw00003.svc Completed in 1.4s (MAPE: 11.55%)
# Processing: collection1u00008s00001_hw00004.svc Completed in 0.9s (MAPE: 7.10%)
# Processing: collection1u00008s00001_hw00005.svc Completed in 1.1s (MAPE: 0.77%)
# Processing: collection1u00008s00001_hw00006.svc Completed in 1.5s (MAPE: 6.06%)
# Processing: collection1u00008s00001_hw00007.svc Completed in 1.7s (MAPE: 8.47%)
# Processing: collection1u00009s00001_hw00001.svc Completed in 1.0s (MAPE: 3.74%)
# Processing: collection1u00009s00001_hw00002.svc Completed in 1.5s (MAPE: 6.48%)
# Processing: collection1u00009s00001_hw00003.svc Completed in 1.6s (MAPE: 11.45%)
# Processing: collection1u00009s00001_hw00004.svc Completed in 1.2s (MAPE: 2.30%)
# Processing: collection1u00009s00001_hw00005.svc Completed in 1.3s (MAPE: 1.84%)
# Processing: collection1u00009s00001_hw00006.svc Completed in 1.5s (MAPE: 8.22%)
# Processing: collection1u00009s00001_hw00007.svc Completed in 1.7s (MAPE: 11.42%)
# Processing: collection1u00010s00001_hw00001.svc Completed in 1.3s (MAPE: 3.96%)
# Processing: collection1u00010s00001_hw00002.svc Completed in 1.6s (MAPE: 4.78%)
# Processing: collection1u00010s00001_hw00003.svc Completed in 1.6s (MAPE: 11.79%)
# Processing: collection1u00010s00001_hw00004.svc Completed in 1.2s (MAPE: 1.70%)
# Processing: collection1u00010s00001_hw00005.svc Completed in 1.1s (MAPE: 1.11%)
# Processing: collection1u00010s00001_hw00006.svc Completed in 1.6s (MAPE: 8.82%)
# Processing: collection1u00010s00001_hw00007.svc Completed in 1.4s (MAPE: 8.29%)
# Processing: collection1u00011s00001_hw00001.svc Completed in 1.4s (MAPE: 4.07%)
# Processing: collection1u00011s00001_hw00002.svc Completed in 1.5s (MAPE: 6.61%)
# Processing: collection1u00011s00001_hw00003.svc Completed in 1.6s (MAPE: 9.98%)
# Processing: collection1u00011s00001_hw00004.svc Completed in 1.2s (MAPE: 6.13%)
# Processing: collection1u00011s00001_hw00005.svc Completed in 1.1s (MAPE: 1.34%)
# Processing: collection1u00011s00001_hw00006.svc Completed in 1.4s (MAPE: 8.65%)
# Processing: collection1u00011s00001_hw00007.svc Completed in 1.5s (MAPE: 8.80%)
# Processing: collection1u00012s00001_hw00001.svc Completed in 1.0s (MAPE: 6.18%)
# Processing: collection1u00012s00001_hw00002.svc Completed in 1.3s (MAPE: 5.36%)
# Processing: collection1u00012s00001_hw00003.svc Completed in 1.5s (MAPE: 8.32%)
# Processing: collection1u00012s00001_hw00004.svc Completed in 1.0s (MAPE: 0.93%)
# Processing: collection1u00012s00001_hw00005.svc Completed in 1.0s (MAPE: 0.95%)
# Processing: collection1u00012s00001_hw00006.svc Completed in 1.3s (MAPE: 9.01%)
# Processing: collection1u00012s00001_hw00007.svc Completed in 1.5s (MAPE: 6.14%)
# Processing: collection1u00013s00001_hw00001.svc Completed in 1.2s (MAPE: 2.72%)
# Processing: collection1u00013s00001_hw00002.svc Completed in 1.7s (MAPE: 4.55%)
# Processing: collection1u00013s00001_hw00003.svc Completed in 1.6s (MAPE: 8.22%)
# Processing: collection1u00013s00001_hw00004.svc Completed in 2.7s (MAPE: 2.41%)
# Processing: collection1u00013s00001_hw00005.svc Completed in 2.5s (MAPE: 1.30%)
# Processing: collection1u00013s00001_hw00006.svc Completed in 4.6s (MAPE: 3.58%)
# Processing: collection1u00013s00001_hw00007.svc Completed in 2.8s (MAPE: 5.90%)
# Processing: collection1u00014s00001_hw00001.svc Completed in 2.1s (MAPE: 3.41%)
# Processing: collection1u00014s00001_hw00002.svc Completed in 1.9s (MAPE: 7.83%)
# Processing: collection1u00014s00001_hw00003.svc Completed in 2.1s (MAPE: 12.35%)
# Processing: collection1u00014s00001_hw00004.svc Completed in 1.4s (MAPE: 1.70%)
# Processing: collection1u00014s00001_hw00005.svc Completed in 1.4s (MAPE: 0.69%)
# Processing: collection1u00014s00001_hw00006.svc Completed in 1.9s (MAPE: 5.77%)
# Processing: collection1u00014s00001_hw00007.svc Completed in 1.7s (MAPE: 8.25%)
# Processing: collection1u00015s00001_hw00001.svc Completed in 1.9s (MAPE: 3.14%)
# Processing: collection1u00015s00001_hw00002.svc Completed in 2.0s (MAPE: 5.96%)
# Processing: collection1u00015s00001_hw00003.svc Completed in 1.9s (MAPE: 9.95%)
# Processing: collection1u00015s00001_hw00004.svc Completed in 1.1s (MAPE: 6.17%)
# Processing: collection1u00015s00001_hw00005.svc Completed in 2.3s (MAPE: 1.61%)
# Processing: collection1u00015s00001_hw00006.svc Completed in 2.1s (MAPE: 9.72%)
# Processing: collection1u00015s00001_hw00007.svc Completed in 2.6s (MAPE: 8.50%)
# Processing: collection1u00016s00001_hw00001.svc Completed in 3.1s (MAPE: 2.37%)
# Processing: collection1u00016s00001_hw00002.svc Completed in 3.0s (MAPE: 3.27%)
# Processing: collection1u00016s00001_hw00003.svc Completed in 2.4s (MAPE: 8.48%)
# Processing: collection1u00016s00001_hw00004.svc Completed in 1.4s (MAPE: 2.36%)
# Processing: collection1u00016s00001_hw00005.svc Completed in 1.4s (MAPE: 1.09%)
# Processing: collection1u00016s00001_hw00006.svc Completed in 2.3s (MAPE: 7.76%)
# Processing: collection1u00016s00001_hw00007.svc Completed in 2.1s (MAPE: 6.93%)
# Processing: collection1u00017s00001_hw00001.svc Completed in 2.3s (MAPE: 2.82%)
# Processing: collection1u00017s00001_hw00002.svc Completed in 3.2s (MAPE: 4.78%)
# Processing: collection1u00017s00001_hw00003.svc Completed in 2.5s (MAPE: 11.78%)
# Processing: collection1u00017s00001_hw00004.svc Completed in 1.5s (MAPE: 4.06%)
# Processing: collection1u00017s00001_hw00005.svc Completed in 1.5s (MAPE: 0.59%)
# Processing: collection1u00017s00001_hw00006.svc Completed in 2.6s (MAPE: 6.35%)
# Processing: collection1u00017s00001_hw00007.svc Completed in 2.9s (MAPE: 11.05%)
# Processing: collection1u00018s00001_hw00001.svc Completed in 1.5s (MAPE: 3.16%)
# Processing: collection1u00018s00001_hw00002.svc Completed in 2.7s (MAPE: 5.80%)
# Processing: collection1u00018s00001_hw00003.svc Completed in 2.2s (MAPE: 10.70%)
# Processing: collection1u00018s00001_hw00004.svc Completed in 1.5s (MAPE: 3.96%)
# Processing: collection1u00018s00001_hw00005.svc Completed in 1.7s (MAPE: 1.32%)
# Processing: collection1u00018s00001_hw00006.svc Completed in 2.6s (MAPE: 9.12%)
# Processing: collection1u00018s00001_hw00007.svc Completed in 2.4s (MAPE: 9.37%)
# Processing: collection1u00019s00001_hw00001.svc Completed in 1.9s (MAPE: 5.52%)
# Processing: collection1u00019s00001_hw00002.svc Completed in 2.1s (MAPE: 3.50%)
# Processing: collection1u00019s00001_hw00003.svc Completed in 2.2s (MAPE: 14.83%)
# Processing: collection1u00019s00001_hw00004.svc Completed in 1.5s (MAPE: 2.00%)
# Processing: collection1u00019s00001_hw00005.svc Completed in 1.3s (MAPE: 0.90%)
# Processing: collection1u00019s00001_hw00006.svc Completed in 2.6s (MAPE: 4.34%)
# Processing: collection1u00019s00001_hw00007.svc Completed in 2.1s (MAPE: 8.32%)
# Processing: collection1u00020s00001_hw00001.svc Completed in 1.8s (MAPE: 3.36%)
# Processing: collection1u00020s00001_hw00002.svc Completed in 2.0s (MAPE: 7.43%)
# Processing: collection1u00020s00001_hw00003.svc Completed in 2.0s (MAPE: 9.93%)
# Processing: collection1u00020s00001_hw00004.svc Completed in 1.4s (MAPE: 3.12%)
# Processing: collection1u00020s00001_hw00005.svc Completed in 2.1s (MAPE: 1.85%)
# Processing: collection1u00020s00001_hw00006.svc Completed in 1.8s (MAPE: 8.24%)
# Processing: collection1u00020s00001_hw00007.svc Completed in 1.9s (MAPE: 8.35%)
# Processing: collection1u00021s00001_hw00001.svc Completed in 1.8s (MAPE: 3.44%)
# Processing: collection1u00021s00001_hw00002.svc Completed in 2.3s (MAPE: 3.96%)
# Processing: collection1u00021s00001_hw00003.svc Completed in 2.0s (MAPE: 10.01%)
# Processing: collection1u00021s00001_hw00004.svc Completed in 1.4s (MAPE: 3.80%)
# Processing: collection1u00021s00001_hw00005.svc Completed in 1.4s (MAPE: 1.97%)
# Processing: collection1u00021s00001_hw00006.svc Completed in 2.5s (MAPE: 5.61%)
# Processing: collection1u00021s00001_hw00007.svc Completed in 2.0s (MAPE: 8.18%)
# Processing: collection1u00022s00001_hw00001.svc Completed in 1.5s (MAPE: 4.62%)
# Processing: collection1u00022s00001_hw00002.svc Completed in 2.0s (MAPE: 6.57%)
# Processing: collection1u00022s00001_hw00003.svc Completed in 2.2s (MAPE: 9.36%)
# Processing: collection1u00022s00001_hw00004.svc Completed in 1.9s (MAPE: 6.26%)
# Processing: collection1u00022s00001_hw00005.svc Completed in 1.8s (MAPE: 1.66%)
# Processing: collection1u00022s00001_hw00006.svc Completed in 1.9s (MAPE: 6.64%)
# Processing: collection1u00022s00001_hw00007.svc Completed in 2.1s (MAPE: 7.92%)
# Processing: collection1u00023s00001_hw00001.svc Completed in 4.0s (MAPE: 3.93%)
# Processing: collection1u00023s00001_hw00002.svc Completed in 2.6s (MAPE: 7.99%)
# Processing: collection1u00023s00001_hw00003.svc Completed in 2.1s (MAPE: 9.58%)
# Processing: collection1u00023s00001_hw00004.svc Completed in 1.6s (MAPE: 5.00%)
# Processing: collection1u00023s00001_hw00005.svc Completed in 1.6s (MAPE: 1.59%)
# Processing: collection1u00023s00001_hw00006.svc Completed in 2.0s (MAPE: 9.04%)
# Processing: collection1u00023s00001_hw00007.svc Completed in 2.1s (MAPE: 8.31%)
# Processing: collection1u00024s00001_hw00001.svc Completed in 1.8s (MAPE: 3.42%)
# Processing: collection1u00024s00001_hw00002.svc Completed in 2.1s (MAPE: 8.10%)
# Processing: collection1u00024s00001_hw00003.svc Completed in 2.0s (MAPE: 12.56%)
# Processing: collection1u00024s00001_hw00004.svc Completed in 1.4s (MAPE: 2.28%)
# Processing: collection1u00024s00001_hw00005.svc Completed in 1.3s (MAPE: 1.90%)
# Processing: collection1u00024s00001_hw00006.svc Completed in 2.1s (MAPE: 9.34%)
# Processing: collection1u00024s00001_hw00007.svc Completed in 2.0s (MAPE: 9.69%)
# Processing: collection1u00025s00001_hw00001.svc Completed in 2.5s (MAPE: 3.20%)
# Processing: collection1u00025s00001_hw00002.svc Completed in 4.8s (MAPE: 6.95%)
# Processing: collection1u00025s00001_hw00003.svc Completed in 3.3s (MAPE: 9.70%)
# Processing: collection1u00025s00001_hw00004.svc Completed in 1.5s (MAPE: 4.03%)
# Processing: collection1u00025s00001_hw00005.svc Completed in 2.1s (MAPE: 1.89%)
# Processing: collection1u00025s00001_hw00006.svc Completed in 1.9s (MAPE: 7.16%)
# Processing: collection1u00025s00001_hw00007.svc Completed in 2.2s (MAPE: 7.73%)
# Processing: collection1u00026s00001_hw00001.svc Completed in 1.9s (MAPE: 2.80%)
# Processing: collection1u00026s00001_hw00002.svc Completed in 2.5s (MAPE: 7.09%)
# Processing: collection1u00026s00001_hw00003.svc Completed in 1.9s (MAPE: 10.38%)
# Processing: collection1u00026s00001_hw00004.svc Completed in 1.2s (MAPE: 0.94%)
# Processing: collection1u00026s00001_hw00005.svc Completed in 1.4s (MAPE: 1.65%)
# Processing: collection1u00026s00001_hw00006.svc Completed in 1.7s (MAPE: 8.14%)
# Processing: collection1u00026s00001_hw00007.svc Completed in 1.9s (MAPE: 7.97%)
# Processing: collection1u00027s00001_hw00001.svc Completed in 2.2s (MAPE: 3.23%)
# Processing: collection1u00027s00001_hw00002.svc Completed in 2.0s (MAPE: 4.27%)
# Processing: collection1u00027s00001_hw00003.svc Completed in 2.1s (MAPE: 9.72%)
# Processing: collection1u00027s00001_hw00004.svc Completed in 1.2s (MAPE: 1.63%)
# Processing: collection1u00027s00001_hw00005.svc Completed in 1.2s (MAPE: 1.83%)
# Processing: collection1u00027s00001_hw00006.svc Completed in 2.2s (MAPE: 5.58%)
# Processing: collection1u00027s00001_hw00007.svc Completed in 1.9s (MAPE: 7.87%)
# Processing: collection1u00028s00001_hw00001.svc Completed in 2.0s (MAPE: 6.54%)
# Processing: collection1u00028s00001_hw00002.svc Completed in 2.2s (MAPE: 7.40%)
# Processing: collection1u00028s00001_hw00003.svc Completed in 2.7s (MAPE: 10.94%)
# Processing: collection1u00028s00001_hw00004.svc Completed in 1.4s (MAPE: 4.23%)
# Processing: collection1u00028s00001_hw00005.svc Completed in 4.4s (MAPE: 2.50%)
# Processing: collection1u00028s00001_hw00006.svc Completed in 2.6s (MAPE: 12.10%)
# Processing: collection1u00028s00001_hw00007.svc Completed in 3.6s (MAPE: 8.68%)
# Processing: collection1u00029s00001_hw00001.svc Completed in 1.6s (MAPE: 3.62%)
# Processing: collection1u00029s00001_hw00002.svc Completed in 2.5s (MAPE: 4.21%)
# Processing: collection1u00029s00001_hw00003.svc Completed in 2.6s (MAPE: 12.67%)
# Processing: collection1u00029s00001_hw00004.svc Completed in 1.7s (MAPE: 3.31%)
# Processing: collection1u00029s00001_hw00005.svc Completed in 1.8s (MAPE: 4.38%)
# Processing: collection1u00029s00001_hw00006.svc Completed in 3.3s (MAPE: 7.02%)
# Processing: collection1u00029s00001_hw00007.svc Completed in 2.8s (MAPE: 7.95%)
# Processing: collection1u00030s00001_hw00001.svc Completed in 2.7s (MAPE: 2.71%)
# Processing: collection1u00030s00001_hw00002.svc Completed in 3.2s (MAPE: 4.86%)
# Processing: collection1u00030s00001_hw00003.svc Completed in 2.3s (MAPE: 13.19%)
# Processing: collection1u00030s00001_hw00004.svc Completed in 1.3s (MAPE: 2.26%)
# Processing: collection1u00030s00001_hw00005.svc Completed in 1.5s (MAPE: 1.01%)
# Processing: collection1u00030s00001_hw00006.svc Completed in 2.2s (MAPE: 7.13%)
# Processing: collection1u00030s00001_hw00007.svc Completed in 2.9s (MAPE: 8.50%)
# Processing: collection1u00031s00001_hw00001.svc Completed in 2.3s (MAPE: 2.52%)
# Processing: collection1u00031s00001_hw00002.svc Completed in 3.3s (MAPE: 5.13%)
# Processing: collection1u00031s00001_hw00003.svc Completed in 3.0s (MAPE: 9.72%)
# Processing: collection1u00031s00001_hw00004.svc Completed in 0.9s (MAPE: 2.51%)
# Processing: collection1u00031s00001_hw00005.svc Completed in 1.1s (MAPE: 1.34%)
# Processing: collection1u00031s00001_hw00006.svc Completed in 1.9s (MAPE: 8.15%)
# Processing: collection1u00031s00001_hw00007.svc Completed in 1.8s (MAPE: 9.52%)
# Processing: collection1u00032s00001_hw00001.svc Completed in 1.1s (MAPE: 1.34%)
# Processing: collection1u00032s00001_hw00002.svc Completed in 2.0s (MAPE: 3.91%)
# Processing: collection1u00032s00001_hw00003.svc Completed in 2.4s (MAPE: 10.29%)
# Processing: collection1u00032s00001_hw00004.svc Completed in 1.2s (MAPE: 4.96%)
# Processing: collection1u00032s00001_hw00005.svc Completed in 1.3s (MAPE: 1.21%)
# Processing: collection1u00032s00001_hw00006.svc Completed in 1.8s (MAPE: 8.91%)
# Processing: collection1u00032s00001_hw00007.svc Completed in 2.3s (MAPE: 9.83%)
# Processing: collection1u00033s00001_hw00001.svc Completed in 9.2s (MAPE: 3.70%)
# Processing: collection1u00033s00001_hw00002.svc Completed in 2.8s (MAPE: 5.96%)
# Processing: collection1u00033s00001_hw00003.svc Completed in 3.0s (MAPE: 11.07%)
# Processing: collection1u00033s00001_hw00004.svc Completed in 1.6s (MAPE: 6.08%)
# Processing: collection1u00033s00001_hw00005.svc Completed in 1.6s (MAPE: 1.87%)
# Processing: collection1u00033s00001_hw00006.svc Completed in 3.2s (MAPE: 8.21%)
# Processing: collection1u00033s00001_hw00007.svc Completed in 2.4s (MAPE: 10.51%)
# Processing: collection1u00034s00001_hw00001.svc Completed in 3.4s (MAPE: 4.86%)
# Processing: collection1u00034s00001_hw00002.svc Completed in 2.6s (MAPE: 5.01%)
# Processing: collection1u00034s00001_hw00003.svc Completed in 3.2s (MAPE: 9.96%)
# Processing: collection1u00034s00001_hw00004.svc Completed in 1.6s (MAPE: 5.69%)
# Processing: collection1u00034s00001_hw00005.svc Completed in 1.8s (MAPE: 1.01%)
# Processing: collection1u00034s00001_hw00006.svc Completed in 2.4s (MAPE: 11.59%)
# Processing: collection1u00034s00001_hw00007.svc Completed in 2.7s (MAPE: 8.65%)
# Processing: collection1u00035s00001_hw00001.svc Completed in 1.8s (MAPE: 1.22%)
# Processing: collection1u00035s00001_hw00002.svc Completed in 2.2s (MAPE: 4.78%)
# Processing: collection1u00035s00001_hw00003.svc Completed in 2.4s (MAPE: 10.47%)
# Processing: collection1u00035s00001_hw00004.svc Completed in 1.3s (MAPE: 1.86%)
# Processing: collection1u00035s00001_hw00005.svc Completed in 1.7s (MAPE: 1.24%)
# Processing: collection1u00035s00001_hw00006.svc Completed in 2.8s (MAPE: 5.75%)
# Processing: collection1u00035s00001_hw00007.svc Completed in 3.5s (MAPE: 7.98%)
# Processing: collection1u00036s00001_hw00001.svc Completed in 3.2s (MAPE: 2.74%)
# Processing: collection1u00036s00001_hw00002.svc Completed in 3.5s (MAPE: 5.14%)
# Processing: collection1u00036s00001_hw00003.svc Completed in 3.8s (MAPE: 10.32%)
# Processing: collection1u00036s00001_hw00004.svc Completed in 1.6s (MAPE: 4.57%)
# Processing: collection1u00036s00001_hw00005.svc Completed in 1.8s (MAPE: 1.91%)
# Processing: collection1u00036s00001_hw00006.svc Completed in 3.1s (MAPE: 8.08%)
# Processing: collection1u00036s00001_hw00007.svc Completed in 4.3s (MAPE: 9.33%)
# Processing: collection1u00037s00001_hw00001.svc Completed in 2.2s (MAPE: 3.58%)
# Processing: collection1u00037s00001_hw00002.svc Completed in 2.6s (MAPE: 6.84%)
# Processing: collection1u00037s00001_hw00003.svc Completed in 2.6s (MAPE: 9.66%)
# Processing: collection1u00037s00001_hw00004.svc Completed in 1.9s (MAPE: 1.27%)
# Processing: collection1u00037s00001_hw00005.svc Completed in 1.8s (MAPE: 2.60%)
# Processing: collection1u00037s00001_hw00006.svc Completed in 2.9s (MAPE: 6.00%)
# Processing: collection1u00037s00001_hw00007.svc Completed in 2.7s (MAPE: 7.26%)
# Processing: collection1u00038s00001_hw00001.svc Completed in 2.4s (MAPE: 3.34%)
# Processing: collection1u00038s00001_hw00002.svc Completed in 2.6s (MAPE: 7.66%)
# Processing: collection1u00038s00001_hw00003.svc Completed in 2.9s (MAPE: 12.08%)
# Processing: collection1u00038s00001_hw00004.svc Completed in 1.8s (MAPE: 1.59%)
# Processing: collection1u00038s00001_hw00005.svc Completed in 1.8s (MAPE: 1.66%)
# Processing: collection1u00038s00001_hw00006.svc Completed in 2.4s (MAPE: 8.67%)
# Processing: collection1u00038s00001_hw00007.svc Completed in 2.5s (MAPE: 7.55%)
# Processing: collection1u00039s00001_hw00001.svc Completed in 2.5s (MAPE: 4.58%)
# Processing: collection1u00039s00001_hw00002.svc Completed in 2.7s (MAPE: 7.04%)
# Processing: collection1u00039s00001_hw00003.svc Completed in 3.0s (MAPE: 13.48%)
# Processing: collection1u00039s00001_hw00004.svc Completed in 2.0s (MAPE: 2.05%)
# Processing: collection1u00039s00001_hw00005.svc Completed in 2.3s (MAPE: 0.83%)
# Processing: collection1u00039s00001_hw00006.svc Completed in 2.7s (MAPE: 10.12%)
# Processing: collection1u00039s00001_hw00007.svc Completed in 2.8s (MAPE: 9.87%)
# Processing: collection1u00040s00001_hw00001.svc Completed in 2.4s (MAPE: 10.24%)
# Processing: collection1u00040s00001_hw00002.svc Completed in 2.4s (MAPE: 11.52%)
# Processing: collection1u00040s00001_hw00003.svc Completed in 2.8s (MAPE: 13.02%)
# Processing: collection1u00040s00001_hw00004.svc Completed in 1.8s (MAPE: 2.45%)
# Processing: collection1u00040s00001_hw00005.svc Completed in 2.2s (MAPE: 1.19%)
# Processing: collection1u00040s00001_hw00006.svc Completed in 2.5s (MAPE: 12.88%)
# Processing: collection1u00040s00001_hw00007.svc Completed in 2.7s (MAPE: 7.57%)
# Processing: collection1u00041s00001_hw00001.svc Completed in 2.2s (MAPE: 3.04%)
# Processing: collection1u00041s00001_hw00002.svc Completed in 2.5s (MAPE: 5.40%)
# Processing: collection1u00041s00001_hw00003.svc Completed in 2.8s (MAPE: 9.88%)
# Processing: collection1u00041s00001_hw00004.svc Completed in 1.8s (MAPE: 1.73%)
# Processing: collection1u00041s00001_hw00005.svc Completed in 1.6s (MAPE: 1.11%)
# Processing: collection1u00041s00001_hw00006.svc Completed in 2.6s (MAPE: 11.69%)
# Processing: collection1u00041s00001_hw00007.svc Completed in 2.8s (MAPE: 8.87%)
# Processing: collection1u00042s00001_hw00001.svc Completed in 2.1s (MAPE: 3.08%)
# Processing: collection1u00042s00001_hw00002.svc Completed in 2.8s (MAPE: 4.36%)
# Processing: collection1u00042s00001_hw00003.svc Completed in 3.1s (MAPE: 8.17%)
# Processing: collection1u00042s00001_hw00004.svc Completed in 1.8s (MAPE: 1.55%)
# Processing: collection1u00042s00001_hw00005.svc Completed in 1.6s (MAPE: 1.92%)
# Processing: collection1u00042s00001_hw00006.svc Completed in 2.5s (MAPE: 5.64%)
# Processing: collection1u00042s00001_hw00007.svc Completed in 3.3s (MAPE: 6.89%)
# Processing: collection1u00043s00001_hw00001.svc Completed in 2.4s (MAPE: 2.22%)
# Processing: collection1u00043s00001_hw00002.svc Completed in 2.5s (MAPE: 5.12%)
# Processing: collection1u00043s00001_hw00003.svc Completed in 2.9s (MAPE: 10.75%)
# Processing: collection1u00043s00001_hw00004.svc Completed in 1.6s (MAPE: 2.36%)
# Processing: collection1u00043s00001_hw00005.svc Completed in 0.9s (MAPE: 1.69%)
# Processing: collection1u00043s00001_hw00006.svc Completed in 2.2s (MAPE: 5.37%)
# Processing: collection1u00043s00001_hw00007.svc Completed in 2.3s (MAPE: 6.81%)
# Processing: collection1u00044s00001_hw00001.svc Completed in 2.5s (MAPE: 2.63%)
# Processing: collection1u00044s00001_hw00002.svc Completed in 2.7s (MAPE: 5.51%)
# Processing: collection1u00044s00001_hw00003.svc Completed in 2.5s (MAPE: 5.85%)
# Processing: collection1u00044s00001_hw00004.svc Completed in 1.3s (MAPE: 2.21%)
# Processing: collection1u00044s00001_hw00005.svc Completed in 1.6s (MAPE: 1.33%)
# Processing: collection1u00044s00001_hw00006.svc Completed in 2.3s (MAPE: 7.20%)
# Processing: collection1u00044s00001_hw00007.svc Completed in 2.5s (MAPE: 6.08%)
# Processing: collection1u00045s00001_hw00001.svc Completed in 2.0s (MAPE: 2.22%)
# Processing: collection1u00045s00001_hw00002.svc Completed in 2.3s (MAPE: 4.32%)
# Processing: collection1u00045s00001_hw00003.svc Completed in 2.8s (MAPE: 8.80%)
# Processing: collection1u00045s00001_hw00004.svc Completed in 1.7s (MAPE: 1.38%)
# Processing: collection1u00045s00001_hw00005.svc Completed in 1.7s (MAPE: 0.88%)
# Processing: collection1u00045s00001_hw00006.svc Completed in 2.5s (MAPE: 5.17%)
# Processing: collection1u00045s00001_hw00007.svc Completed in 2.9s (MAPE: 14.69%)
# Processing: u00001s00001_hw00001.svc Completed in 2.9s (MAPE: 3.33%)
# Processing: u00001s00001_hw00002.svc Completed in 3.5s (MAPE: 4.29%)
# Processing: u00001s00001_hw00003.svc Completed in 3.7s (MAPE: 11.25%)
# Processing: u00001s00001_hw00004.svc Completed in 13.5s (MAPE: 2.70%)
# Processing: u00001s00001_hw00005.svc Completed in 4.4s (MAPE: 1.74%)
# Processing: u00001s00001_hw00006.svc Completed in 6.1s (MAPE: 8.66%)
# Processing: u00001s00001_hw00007.svc Completed in 3.5s (MAPE: 9.54%)
# Processing: u00002s00001_hw00001.svc Completed in 2.5s (MAPE: 1.45%)
# Processing: u00002s00001_hw00002.svc Completed in 3.4s (MAPE: 4.69%)
# Processing: u00002s00001_hw00003.svc Completed in 3.7s (MAPE: 10.06%)
# Processing: u00002s00001_hw00004.svc Completed in 2.9s (MAPE: 5.50%)
# Processing: u00002s00001_hw00005.svc Completed in 2.8s (MAPE: 1.18%)
# Processing: u00002s00001_hw00006.svc Completed in 3.1s (MAPE: 7.39%)
# Processing: u00002s00001_hw00007.svc Completed in 2.7s (MAPE: 6.61%)
# Processing: u00003s00001_hw00001.svc Completed in 2.4s (MAPE: 4.98%)
# Processing: u00003s00001_hw00002.svc Completed in 2.8s (MAPE: 10.73%)
# Processing: u00003s00001_hw00003.svc Completed in 2.9s (MAPE: 13.84%)
# Processing: u00003s00001_hw00004.svc Completed in 2.2s (MAPE: 2.33%)
# Processing: u00003s00001_hw00005.svc Completed in 2.8s (MAPE: 1.44%)
# Processing: u00003s00001_hw00006.svc Completed in 3.5s (MAPE: 12.75%)
# Processing: u00003s00001_hw00007.svc Completed in 2.9s (MAPE: 9.05%)
# Processing: u00004s00001_hw00001.svc Completed in 2.9s (MAPE: 3.57%)
# Processing: u00004s00001_hw00002.svc Completed in 3.1s (MAPE: 5.32%)
# Processing: u00004s00001_hw00003.svc Completed in 2.9s (MAPE: 12.55%)
# Processing: u00004s00001_hw00004.svc Completed in 2.3s (MAPE: 6.71%)
# Processing: u00004s00001_hw00005.svc Completed in 3.6s (MAPE: 1.16%)
# Processing: u00004s00001_hw00006.svc Completed in 3.7s (MAPE: 4.67%)
# Processing: u00004s00001_hw00007.svc Completed in 3.1s (MAPE: 8.51%)
# Processing: u00005s00001_hw00001.svc Completed in 2.2s (MAPE: 4.26%)
# Processing: u00005s00001_hw00002.svc Completed in 2.9s (MAPE: 4.37%)
# Processing: u00005s00001_hw00003.svc Completed in 2.8s (MAPE: 11.81%)
# Processing: u00005s00001_hw00004.svc Completed in 2.2s (MAPE: 1.33%)
# Processing: u00005s00001_hw00005.svc Completed in 2.1s (MAPE: 0.95%)
# Processing: u00005s00001_hw00006.svc Completed in 3.7s (MAPE: 6.78%)
# Processing: u00005s00001_hw00007.svc Completed in 2.6s (MAPE: 8.88%)
# Processing: u00006s00001_hw00001.svc Completed in 2.5s (MAPE: 3.72%)
# Processing: u00006s00001_hw00002.svc Completed in 3.2s (MAPE: 4.21%)
# Processing: u00006s00001_hw00003.svc Completed in 3.1s (MAPE: 9.75%)
# Processing: u00006s00001_hw00004.svc Completed in 2.6s (MAPE: 6.75%)
# Processing: u00006s00001_hw00005.svc Completed in 2.9s (MAPE: 1.38%)
# Processing: u00006s00001_hw00006.svc Completed in 4.7s (MAPE: 9.07%)
# Processing: u00006s00001_hw00007.svc Completed in 3.3s (MAPE: 9.57%)
# Processing: u00007s00001_hw00001.svc Completed in 2.9s (MAPE: 4.00%)
# Processing: u00007s00001_hw00002.svc Completed in 3.2s (MAPE: 4.90%)
# Processing: u00007s00001_hw00003.svc Completed in 2.9s (MAPE: 12.04%)
# Processing: u00007s00001_hw00004.svc Completed in 2.4s (MAPE: 1.39%)
# Processing: u00007s00001_hw00005.svc Completed in 2.4s (MAPE: 0.79%)
# Processing: u00007s00001_hw00006.svc Completed in 3.2s (MAPE: 4.60%)
# Processing: u00007s00001_hw00007.svc Completed in 2.8s (MAPE: 6.56%)
# Processing: u00008s00001_hw00001.svc Completed in 3.2s (MAPE: 1.76%)
# Processing: u00008s00001_hw00002.svc Completed in 4.2s (MAPE: 6.68%)
# Processing: u00008s00001_hw00003.svc Completed in 2.9s (MAPE: 10.77%)
# Processing: u00008s00001_hw00004.svc Completed in 2.0s (MAPE: 1.68%)
# Processing: u00008s00001_hw00005.svc Completed in 1.9s (MAPE: 1.74%)
# Processing: u00008s00001_hw00006.svc Completed in 3.3s (MAPE: 6.46%)
# Processing: u00008s00001_hw00007.svc Completed in 2.6s (MAPE: 7.98%)
# Processing: u00009s00001_hw00001.svc Completed in 2.4s (MAPE: 2.43%)
# Processing: u00009s00001_hw00002.svc Completed in 2.9s (MAPE: 4.45%)
# Processing: u00009s00001_hw00003.svc Completed in 3.0s (MAPE: 12.01%)
# Processing: u00009s00001_hw00004.svc Completed in 2.2s (MAPE: 1.50%)
# Processing: u00009s00001_hw00005.svc Completed in 2.3s (MAPE: 1.32%)
# Processing: u00009s00001_hw00006.svc Completed in 3.1s (MAPE: 5.93%)
# Processing: u00009s00001_hw00007.svc Completed in 3.2s (MAPE: 8.81%)
# Processing: u00010s00001_hw00001.svc Completed in 3.0s (MAPE: 5.58%)
# Processing: u00010s00001_hw00002.svc Completed in 3.4s (MAPE: 5.59%)
# Processing: u00010s00001_hw00003.svc Completed in 3.2s (MAPE: 8.80%)
# Processing: u00010s00001_hw00004.svc Completed in 2.9s (MAPE: 3.35%)
# Processing: u00010s00001_hw00005.svc Completed in 2.2s (MAPE: 1.40%)
# Processing: u00010s00001_hw00006.svc Completed in 2.7s (MAPE: 7.21%)
# Processing: u00010s00001_hw00007.svc Completed in 2.9s (MAPE: 7.93%)
# Processing: u00011s00001_hw00001.svc Completed in 2.6s (MAPE: 3.77%)
# Processing: u00011s00001_hw00002.svc Completed in 2.9s (MAPE: 5.77%)
# Processing: u00011s00001_hw00003.svc Completed in 2.9s (MAPE: 10.74%)
# Processing: u00011s00001_hw00004.svc Completed in 2.2s (MAPE: 1.40%)
# Processing: u00011s00001_hw00005.svc Completed in 2.3s (MAPE: 1.95%)
# Processing: u00011s00001_hw00006.svc Completed in 2.8s (MAPE: 6.65%)
# Processing: u00011s00001_hw00007.svc Completed in 2.7s (MAPE: 7.06%)
# Processing: u00012s00001_hw00001.svc Completed in 2.2s (MAPE: 2.59%)
# Processing: u00012s00001_hw00002.svc Completed in 2.9s (MAPE: 6.19%)
# Processing: u00012s00001_hw00003.svc Completed in 2.8s (MAPE: 11.78%)
# Processing: u00012s00001_hw00004.svc Completed in 2.6s (MAPE: 0.92%)
# Processing: u00012s00001_hw00005.svc Completed in 3.8s (MAPE: 1.71%)
# Processing: u00012s00001_hw00006.svc Completed in 7.3s (MAPE: 7.40%)
# Processing: u00012s00001_hw00007.svc Completed in 6.3s (MAPE: 11.56%)
# Processing: u00013s00001_hw00001.svc Completed in 2.4s (MAPE: 4.68%)
# Processing: u00013s00001_hw00002.svc Completed in 2.6s (MAPE: 4.83%)
# Processing: u00013s00001_hw00003.svc Completed in 2.6s (MAPE: 9.05%)
# Processing: u00013s00001_hw00004.svc Completed in 1.8s (MAPE: 0.98%)
# Processing: u00013s00001_hw00005.svc Completed in 1.7s (MAPE: 0.96%)
# Processing: u00013s00001_hw00006.svc Completed in 2.2s (MAPE: 6.35%)
# Processing: u00013s00001_hw00007.svc Completed in 2.2s (MAPE: 6.35%)
# Processing: u00014s00001_hw00001.svc Completed in 2.1s (MAPE: 4.39%)
# Processing: u00014s00001_hw00002.svc Completed in 2.3s (MAPE: 6.67%)
# Processing: u00014s00001_hw00003.svc Completed in 2.4s (MAPE: 10.14%)
# Processing: u00014s00001_hw00004.svc Completed in 1.8s (MAPE: 1.25%)
# Processing: u00014s00001_hw00005.svc Completed in 1.5s (MAPE: 0.98%)
# Processing: u00014s00001_hw00006.svc Completed in 1.6s (MAPE: 10.06%)
# Processing: u00014s00001_hw00007.svc Completed in 2.0s (MAPE: 9.55%)
# Processing: u00015s00001_hw00001.svc Completed in 1.5s (MAPE: 1.81%)
# Processing: u00015s00001_hw00002.svc Completed in 2.2s (MAPE: 4.55%)
# Processing: u00015s00001_hw00003.svc Completed in 1.7s (MAPE: 9.09%)
# Processing: u00015s00001_hw00004.svc Completed in 1.3s (MAPE: 1.09%)
# Processing: u00015s00001_hw00005.svc Completed in 1.4s (MAPE: 0.93%)
# Processing: u00015s00001_hw00006.svc Completed in 1.6s (MAPE: 12.25%)
# Processing: u00015s00001_hw00007.svc Completed in 1.7s (MAPE: 7.02%)
# Processing: u00016s00001_hw00001.svc Completed in 1.4s (MAPE: 7.49%)
# Processing: u00016s00001_hw00002.svc Completed in 1.7s (MAPE: 9.48%)
# Processing: u00016s00001_hw00003.svc Completed in 1.7s (MAPE: 10.48%)
# Processing: u00016s00001_hw00004.svc Completed in 1.2s (MAPE: 0.49%)
# Processing: u00016s00001_hw00005.svc Completed in 1.3s (MAPE: 0.54%)
# Processing: u00016s00001_hw00006.svc Completed in 1.5s (MAPE: 8.80%)
# Processing: u00016s00001_hw00007.svc Completed in 1.6s (MAPE: 6.33%)
# Processing: u00017s00001_hw00001.svc Completed in 1.6s (MAPE: 4.37%)
# Processing: u00017s00001_hw00002.svc Completed in 1.8s (MAPE: 7.10%)
# Processing: u00017s00001_hw00003.svc Completed in 1.6s (MAPE: 12.51%)
# Processing: u00017s00001_hw00004.svc Completed in 1.2s (MAPE: 2.40%)
# Processing: u00017s00001_hw00005.svc Completed in 1.2s (MAPE: 0.75%)
# Processing: u00017s00001_hw00006.svc Completed in 1.5s (MAPE: 9.89%)
# Processing: u00017s00001_hw00007.svc Completed in 1.6s (MAPE: 7.99%)
# Processing: u00018s00001_hw00001.svc Completed in 1.5s (MAPE: 4.12%)
# Processing: u00018s00001_hw00002.svc Completed in 1.6s (MAPE: 7.33%)
# Processing: u00018s00001_hw00003.svc Completed in 1.8s (MAPE: 9.74%)
# Processing: u00018s00001_hw00004.svc Completed in 1.2s (MAPE: 1.25%)
# Processing: u00018s00001_hw00005.svc Completed in 1.2s (MAPE: 0.63%)
# Processing: u00018s00001_hw00006.svc Completed in 1.4s (MAPE: 8.81%)
# Processing: u00018s00001_hw00007.svc Completed in 1.6s (MAPE: 7.86%)
# Processing: u00019s00001_hw00001.svc Completed in 1.2s (MAPE: 3.43%)
# Processing: u00019s00001_hw00002.svc Completed in 1.6s (MAPE: 7.43%)
# Processing: u00019s00001_hw00003.svc Completed in 1.6s (MAPE: 10.46%)
# Processing: u00019s00001_hw00004.svc Completed in 1.3s (MAPE: 1.17%)
# Processing: u00019s00001_hw00005.svc Completed in 1.2s (MAPE: 2.52%)
# Processing: u00019s00001_hw00006.svc Completed in 1.7s (MAPE: 8.69%)
# Processing: u00019s00001_hw00007.svc Completed in 1.5s (MAPE: 8.34%)
# Processing: u00020s00001_hw00001.svc Completed in 1.2s (MAPE: 1.88%)
# Processing: u00020s00001_hw00002.svc Completed in 1.8s (MAPE: 4.17%)
# Processing: u00020s00001_hw00003.svc Completed in 1.8s (MAPE: 9.47%)
# Processing: u00020s00001_hw00004.svc Completed in 1.3s (MAPE: 2.80%)
# Processing: u00020s00001_hw00005.svc Completed in 1.2s (MAPE: 1.45%)
# Processing: u00020s00001_hw00006.svc Completed in 1.4s (MAPE: 10.17%)
# Processing: u00020s00001_hw00007.svc Completed in 1.5s (MAPE: 6.67%)
# Processing: u00021s00001_hw00001.svc Completed in 1.4s (MAPE: 3.48%)
# Processing: u00021s00001_hw00002.svc Completed in 1.6s (MAPE: 5.75%)
# Processing: u00021s00001_hw00003.svc Completed in 1.7s (MAPE: 12.55%)
# Processing: u00021s00001_hw00004.svc Completed in 1.3s (MAPE: 3.18%)
# Processing: u00021s00001_hw00005.svc Completed in 1.3s (MAPE: 0.80%)
# Processing: u00021s00001_hw00006.svc Completed in 1.6s (MAPE: 9.14%)
# Processing: u00021s00001_hw00007.svc Completed in 1.6s (MAPE: 9.17%)
# Processing: u00022s00001_hw00001.svc Completed in 1.4s (MAPE: 3.11%)
# Processing: u00022s00001_hw00002.svc Completed in 1.6s (MAPE: 6.53%)
# Processing: u00022s00001_hw00003.svc Completed in 1.7s (MAPE: 9.47%)
# Processing: u00022s00001_hw00004.svc Completed in 1.2s (MAPE: 0.72%)
# Processing: u00022s00001_hw00005.svc Completed in 1.2s (MAPE: 2.13%)
# Processing: u00022s00001_hw00006.svc Completed in 1.7s (MAPE: 8.58%)
# Processing: u00022s00001_hw00007.svc Completed in 1.5s (MAPE: 7.18%)
# Processing: u00023s00001_hw00001.svc Completed in 1.4s (MAPE: 7.81%)
# Processing: u00023s00001_hw00002.svc Completed in 1.6s (MAPE: 8.15%)
# Processing: u00023s00001_hw00003.svc Completed in 2.1s (MAPE: 8.44%)
# Processing: u00023s00001_hw00004.svc Completed in 1.5s (MAPE: 1.98%)
# Processing: u00023s00001_hw00005.svc Completed in 1.3s (MAPE: 1.35%)
# Processing: u00023s00001_hw00006.svc Completed in 1.3s (MAPE: 9.01%)
# Processing: u00023s00001_hw00007.svc Completed in 1.2s (MAPE: 6.00%)
# Processing: u00024s00001_hw00001.svc Completed in 1.2s (MAPE: 4.44%)
# Processing: u00024s00001_hw00002.svc Completed in 1.4s (MAPE: 6.81%)
# Processing: u00024s00001_hw00003.svc Completed in 1.4s (MAPE: 10.58%)
# Processing: u00024s00001_hw00004.svc Completed in 1.1s (MAPE: 3.85%)
# Processing: u00024s00001_hw00005.svc Completed in 1.1s (MAPE: 1.42%)
# Processing: u00024s00001_hw00006.svc Completed in 1.5s (MAPE: 8.65%)
# Processing: u00024s00001_hw00007.svc Completed in 1.3s (MAPE: 7.24%)
# Processing: u00025s00001_hw00001.svc Completed in 1.3s (MAPE: 4.83%)
# Processing: u00025s00001_hw00002.svc Completed in 1.5s (MAPE: 5.71%)
# Processing: u00025s00001_hw00003.svc Completed in 1.5s (MAPE: 9.82%)
# Processing: u00025s00001_hw00004.svc Completed in 1.2s (MAPE: 5.64%)
# Processing: u00025s00001_hw00005.svc Completed in 1.1s (MAPE: 0.90%)
# Processing: u00025s00001_hw00006.svc Completed in 1.6s (MAPE: 7.29%)
# Processing: u00025s00001_hw00007.svc Completed in 1.4s (MAPE: 9.37%)
# Processing: u00026s00001_hw00001.svc Completed in 1.2s (MAPE: 2.98%)
# Processing: u00026s00001_hw00002.svc Completed in 1.4s (MAPE: 6.16%)
# Processing: u00026s00001_hw00003.svc Completed in 1.4s (MAPE: 10.18%)
# Processing: u00026s00001_hw00004.svc Completed in 1.0s (MAPE: 0.94%)
# Processing: u00026s00001_hw00005.svc Completed in 1.2s (MAPE: 1.40%)
# Processing: u00026s00001_hw00006.svc Completed in 1.4s (MAPE: 6.37%)
# Processing: u00026s00001_hw00007.svc Completed in 1.4s (MAPE: 6.74%)
# Processing: u00027s00001_hw00001.svc Completed in 1.3s (MAPE: 3.08%)
# Processing: u00027s00001_hw00002.svc Completed in 1.6s (MAPE: 6.00%)
# Processing: u00027s00001_hw00003.svc Completed in 1.6s (MAPE: 9.27%)
# Processing: u00027s00001_hw00004.svc Completed in 1.1s (MAPE: 0.95%)
# Processing: u00027s00001_hw00005.svc Completed in 1.1s (MAPE: 1.15%)
# Processing: u00027s00001_hw00006.svc Completed in 1.7s (MAPE: 7.55%)
# Processing: u00027s00001_hw00007.svc Completed in 1.5s (MAPE: 9.64%)
# Processing: u00028s00001_hw00001.svc Completed in 1.4s (MAPE: 6.66%)
# Processing: u00028s00001_hw00002.svc Completed in 1.6s (MAPE: 5.69%)
# Processing: u00028s00001_hw00003.svc Completed in 1.6s (MAPE: 10.26%)
# Processing: u00028s00001_hw00004.svc Completed in 1.0s (MAPE: 4.33%)
# Processing: u00028s00001_hw00005.svc Completed in 1.0s (MAPE: 1.54%)
# Processing: u00028s00001_hw00006.svc Completed in 1.5s (MAPE: 7.82%)
# Processing: u00028s00001_hw00007.svc Completed in 1.4s (MAPE: 9.24%)
# Processing: u00029s00001_hw00001.svc Completed in 1.4s (MAPE: 3.77%)
# Processing: u00029s00001_hw00002.svc Completed in 1.7s (MAPE: 6.60%)
# Processing: u00029s00001_hw00003.svc Completed in 1.4s (MAPE: 9.23%)
# Processing: u00029s00001_hw00004.svc Completed in 1.0s (MAPE: 1.69%)
# Processing: u00029s00001_hw00005.svc Completed in 1.1s (MAPE: 0.77%)
# Processing: u00029s00001_hw00006.svc Completed in 1.5s (MAPE: 5.64%)
# Processing: u00029s00001_hw00007.svc Completed in 1.5s (MAPE: 5.74%)
# Processing: u00030s00001_hw00001.svc Completed in 1.3s (MAPE: 7.57%)
# Processing: u00030s00001_hw00002.svc Completed in 1.5s (MAPE: 10.43%)
# Processing: u00030s00001_hw00003.svc Completed in 1.7s (MAPE: 11.83%)
# Processing: u00030s00001_hw00004.svc Completed in 1.2s (MAPE: 0.81%)
# Processing: u00030s00001_hw00005.svc Completed in 1.1s (MAPE: 1.17%)
# Processing: u00030s00001_hw00006.svc Completed in 1.4s (MAPE: 12.56%)
# Processing: u00030s00001_hw00007.svc Completed in 1.6s (MAPE: 10.32%)
# Processing: u00031s00001_hw00001.svc Completed in 3.8s (MAPE: 4.22%)
# Processing: u00031s00001_hw00002.svc Completed in 1.5s (MAPE: 7.28%)
# Processing: u00031s00001_hw00003.svc Completed in 1.5s (MAPE: 14.34%)
# Processing: u00031s00001_hw00004.svc Completed in 1.1s (MAPE: 2.99%)
# Processing: u00031s00001_hw00005.svc Completed in 1.0s (MAPE: 1.06%)
# Processing: u00031s00001_hw00006.svc Completed in 1.6s (MAPE: 9.84%)
# Processing: u00031s00001_hw00007.svc Completed in 1.5s (MAPE: 9.03%)
# Processing: u00032s00001_hw00001.svc Completed in 1.3s (MAPE: 11.97%)
# Processing: u00032s00001_hw00002.svc Completed in 1.4s (MAPE: 7.90%)
# Processing: u00032s00001_hw00003.svc Completed in 1.5s (MAPE: 11.60%)
# Processing: u00032s00001_hw00004.svc Completed in 1.1s (MAPE: 5.89%)
# Processing: u00032s00001_hw00005.svc Completed in 1.1s (MAPE: 1.15%)
# Processing: u00032s00001_hw00006.svc Completed in 1.4s (MAPE: 9.54%)
# Processing: u00032s00001_hw00007.svc Completed in 1.6s (MAPE: 10.60%)
# Processing: u00033s00001_hw00001.svc Completed in 1.2s (MAPE: 4.31%)
# Processing: u00033s00001_hw00002.svc Completed in 1.7s (MAPE: 7.21%)
# Processing: u00033s00001_hw00003.svc Completed in 1.5s (MAPE: 10.57%)
# Processing: u00033s00001_hw00004.svc Completed in 0.1s (MAPE: 3.59%)
# Processing: u00033s00001_hw00005.svc Completed in 1.1s (MAPE: 1.42%)
# Processing: u00033s00001_hw00006.svc Completed in 1.6s (MAPE: 11.27%)
# Processing: u00033s00001_hw00007.svc Completed in 1.4s (MAPE: 7.04%)
# Processing: u00034s00001_hw00001.svc Completed in 1.3s (MAPE: 3.77%)
# Processing: u00034s00001_hw00002.svc Completed in 1.5s (MAPE: 4.64%)
# Processing: u00034s00001_hw00003.svc Completed in 1.4s (MAPE: 11.14%)
# Processing: u00034s00001_hw00004.svc Completed in 1.1s (MAPE: 0.81%)
# Processing: u00034s00001_hw00005.svc Completed in 1.0s (MAPE: 0.66%)
# Processing: u00034s00001_hw00006.svc Completed in 1.5s (MAPE: 8.45%)
# Processing: u00034s00001_hw00007.svc Completed in 1.4s (MAPE: 8.58%)
# Processing: u00035s00001_hw00001.svc Completed in 1.2s (MAPE: 5.73%)
# Processing: u00035s00001_hw00002.svc Completed in 1.3s (MAPE: 6.50%)
# Processing: u00035s00001_hw00003.svc Completed in 1.4s (MAPE: 10.32%)
# Processing: u00035s00001_hw00004.svc Completed in 1.1s (MAPE: 3.46%)
# Processing: u00035s00001_hw00005.svc Completed in 1.2s (MAPE: 1.24%)
# Processing: u00035s00001_hw00006.svc Completed in 1.3s (MAPE: 8.90%)
# Processing: u00035s00001_hw00007.svc Completed in 1.3s (MAPE: 9.24%)
# Processing: u00036s00001_hw00001.svc Completed in 1.0s (MAPE: 3.56%)
# Processing: u00036s00001_hw00002.svc Completed in 1.5s (MAPE: 4.27%)
# Processing: u00036s00001_hw00003.svc Completed in 1.4s (MAPE: 10.37%)
# Processing: u00036s00001_hw00004.svc Completed in 1.1s (MAPE: 4.44%)
# Processing: u00036s00001_hw00005.svc Completed in 1.1s (MAPE: 1.43%)
# Processing: u00036s00001_hw00006.svc Completed in 1.4s (MAPE: 7.11%)
# Processing: u00036s00001_hw00007.svc Completed in 1.4s (MAPE: 8.14%)
# Processing: u00037s00001_hw00001.svc Completed in 1.1s (MAPE: 3.97%)
# Processing: u00037s00001_hw00002.svc Completed in 1.3s (MAPE: 10.24%)
# Processing: u00037s00001_hw00003.svc Completed in 1.5s (MAPE: 11.93%)
# Processing: u00037s00001_hw00004.svc Completed in 1.0s (MAPE: 4.24%)
# Processing: u00037s00001_hw00005.svc Completed in 1.2s (MAPE: 1.43%)
# Processing: u00037s00001_hw00006.svc Completed in 1.4s (MAPE: 13.51%)
# Processing: u00037s00001_hw00007.svc Completed in 1.3s (MAPE: 12.94%)
# Processing: u00038s00001_hw00001.svc Completed in 1.1s (MAPE: 4.47%)
# Processing: u00038s00001_hw00002.svc Completed in 1.4s (MAPE: 5.21%)
# Processing: u00038s00001_hw00003.svc Completed in 1.4s (MAPE: 13.91%)
# Processing: u00038s00001_hw00004.svc Completed in 1.1s (MAPE: 2.22%)
# Processing: u00038s00001_hw00005.svc Completed in 3.1s (MAPE: 1.96%)
# Processing: u00038s00001_hw00006.svc Completed in 1.9s (MAPE: 6.30%)
# Processing: u00038s00001_hw00007.svc Completed in 1.5s (MAPE: 8.42%)
# Processing: u00039s00001_hw00001.svc Completed in 1.1s (MAPE: 2.59%)
# Processing: u00039s00001_hw00002.svc Completed in 1.3s (MAPE: 7.30%)
# Processing: u00039s00001_hw00003.svc Completed in 1.5s (MAPE: 9.82%)
# Processing: u00039s00001_hw00004.svc Completed in 1.0s (MAPE: 5.00%)
# Processing: u00039s00001_hw00005.svc Completed in 1.1s (MAPE: 1.16%)
# Processing: u00039s00001_hw00006.svc Completed in 1.5s (MAPE: 11.74%)
# Processing: u00039s00001_hw00007.svc Completed in 1.5s (MAPE: 6.62%)
# Processing: u00040s00001_hw00001.svc Completed in 1.2s (MAPE: 3.87%)
# Processing: u00040s00001_hw00002.svc Completed in 1.5s (MAPE: 4.91%)
# Processing: u00040s00001_hw00003.svc Completed in 1.7s (MAPE: 11.04%)
# Processing: u00040s00001_hw00004.svc Completed in 1.0s (MAPE: 4.16%)
# Processing: u00040s00001_hw00005.svc Completed in 1.1s (MAPE: 2.24%)
# Processing: u00040s00001_hw00006.svc Completed in 1.3s (MAPE: 7.19%)
# Processing: u00040s00001_hw00007.svc Completed in 1.4s (MAPE: 8.64%)
# Processing: u00041s00001_hw00001.svc Completed in 1.3s (MAPE: 10.58%)
# Processing: u00041s00001_hw00002.svc Completed in 1.4s (MAPE: 9.18%)
# Processing: u00041s00001_hw00003.svc Completed in 1.5s (MAPE: 10.23%)
# Processing: u00041s00001_hw00004.svc Completed in 1.0s (MAPE: 2.25%)
# Processing: u00041s00001_hw00005.svc Completed in 1.0s (MAPE: 1.98%)
# Processing: u00041s00001_hw00006.svc Completed in 1.3s (MAPE: 12.08%)
# Processing: u00041s00001_hw00007.svc Completed in 1.3s (MAPE: 7.66%)
# Processing: u00042s00001_hw00001.svc Completed in 1.2s (MAPE: 3.01%)
# Processing: u00042s00001_hw00002.svc Completed in 1.4s (MAPE: 4.67%)
# Processing: u00042s00001_hw00003.svc Completed in 1.4s (MAPE: 12.07%)
# Processing: u00042s00001_hw00004.svc Completed in 1.0s (MAPE: 1.20%)
# Processing: u00042s00001_hw00005.svc Completed in 1.1s (MAPE: 0.89%)
# Processing: u00042s00001_hw00006.svc Completed in 1.4s (MAPE: 8.15%)
# Processing: u00042s00001_hw00007.svc Completed in 1.2s (MAPE: 6.43%)
# Processing: u00043s00001_hw00001.svc Completed in 1.2s (MAPE: 7.07%)
# Processing: u00043s00001_hw00002.svc Completed in 1.6s (MAPE: 7.76%)
# Processing: u00043s00001_hw00003.svc Completed in 1.4s (MAPE: 11.13%)
# Processing: u00043s00001_hw00004.svc Completed in 1.1s (MAPE: 1.07%)
# Processing: u00043s00001_hw00005.svc Completed in 1.0s (MAPE: 1.27%)
# Processing: u00043s00001_hw00006.svc Completed in 1.5s (MAPE: 9.35%)
# Processing: u00043s00001_hw00007.svc Completed in 1.4s (MAPE: 7.87%)
# Processing: u00044s00001_hw00001.svc Completed in 1.3s (MAPE: 6.62%)
# Processing: u00044s00001_hw00002.svc Completed in 1.4s (MAPE: 5.84%)
# Processing: u00044s00001_hw00003.svc Completed in 1.5s (MAPE: 10.86%)
# Processing: u00044s00001_hw00004.svc Completed in 1.0s (MAPE: 2.81%)
# Processing: u00044s00001_hw00005.svc Completed in 1.0s (MAPE: 1.57%)
# Processing: u00044s00001_hw00006.svc Completed in 1.5s (MAPE: 7.56%)
# Processing: u00044s00001_hw00007.svc Completed in 1.4s (MAPE: 8.76%)
# Processing: u00045s00001_hw00001.svc Completed in 1.0s (MAPE: 2.93%)
# Processing: u00045s00001_hw00002.svc Completed in 1.4s (MAPE: 6.40%)
# Processing: u00045s00001_hw00003.svc Completed in 1.6s (MAPE: 13.68%)
# Processing: u00045s00001_hw00004.svc Completed in 1.1s (MAPE: 2.39%)
# Processing: u00045s00001_hw00005.svc Completed in 1.1s (MAPE: 1.99%)
# Processing: u00045s00001_hw00006.svc Completed in 1.6s (MAPE: 5.99%)
# Processing: u00045s00001_hw00007.svc Completed in 1.8s (MAPE: 10.66%)
# Processing: u00046s00001_hw00001.svc Completed in 1.2s (MAPE: 3.20%)
# Processing: u00046s00001_hw00002.svc Completed in 1.4s (MAPE: 6.73%)
# Processing: u00046s00001_hw00003.svc Completed in 1.4s (MAPE: 12.19%)
# Processing: u00046s00001_hw00004.svc Completed in 1.1s (MAPE: 2.39%)
# Processing: u00046s00001_hw00005.svc Completed in 1.1s (MAPE: 1.12%)
# Processing: u00046s00001_hw00006.svc Completed in 1.5s (MAPE: 6.89%)
# Processing: u00046s00001_hw00007.svc Completed in 1.6s (MAPE: 11.94%)
# Processing: u00047s00001_hw00001.svc Completed in 0.8s (MAPE: 3.82%)
# Processing: u00047s00001_hw00002.svc Completed in 1.2s (MAPE: 5.40%)
# Processing: u00047s00001_hw00003.svc Completed in 1.5s (MAPE: 9.37%)
# Processing: u00047s00001_hw00004.svc Completed in 1.1s (MAPE: 3.45%)
# Processing: u00047s00001_hw00005.svc Completed in 1.1s (MAPE: 0.69%)
# Processing: u00047s00001_hw00006.svc Completed in 1.4s (MAPE: 9.31%)
# Processing: u00047s00001_hw00007.svc Completed in 1.4s (MAPE: 8.64%)
# ...
# Processing: u00052s00001_hw00003.svc Completed in 1.4s (MAPE: 11.31%)
# Processing: u00052s00001_hw00004.svc Completed in 1.1s (MAPE: 1.62%)
# Processing: u00052s00001_hw00005.svc Completed in 1.0s (MAPE: 1.07%)
# Processing: u00052s00001_hw00006.svc Completed in 1.4s (MAPE: 9.13%)
# Processing: u00052s00001_hw00007.svc Completed in 1.4s (MAPE: 6.12%)
# Processing: u00053s00001_hw00001.svc Completed in 1.2s (MAPE: 3.51%)
# Processing: u00053s00001_hw00002.svc Completed in 1.5s (MAPE: 4.68%)
# Processing: u00053s00001_hw00003.svc Completed in 1.5s (MAPE: 11.57%)
# Processing: u00053s00001_hw00004.svc Completed in 1.1s (MAPE: 2.08%)
# Processing: u00053s00001_hw00005.svc Completed in 1.3s (MAPE: 2.28%)
# Processing: u00053s00001_hw00006.svc Completed in 1.4s (MAPE: 7.52%)
# Processing: u00053s00001_hw00007.svc Completed in 1.4s (MAPE: 10.78%)
# Processing: u00054s00001_hw00001.svc Completed in 1.9s (MAPE: 2.10%)
# Processing: u00054s00001_hw00002.svc Completed in 1.9s (MAPE: 3.70%)
# Processing: u00054s00001_hw00003.svc Completed in 1.4s (MAPE: 10.20%)
# Processing: u00054s00001_hw00004.svc Completed in 1.1s (MAPE: 4.45%)
# Processing: u00054s00001_hw00005.svc Completed in 1.0s (MAPE: 2.04%)
# Processing: u00054s00001_hw00006.svc Completed in 1.5s (MAPE: 8.03%)
# Processing: u00054s00001_hw00007.svc Completed in 1.3s (MAPE: 7.29%)
# Processing: u00055s00001_hw00001.svc Completed in 1.2s (MAPE: 5.78%)
# Processing: u00055s00001_hw00002.svc Completed in 1.7s (MAPE: 6.31%)
# Processing: u00055s00001_hw00003.svc Completed in 1.5s (MAPE: 12.11%)
# Processing: u00055s00001_hw00004.svc Completed in 1.1s (MAPE: 5.21%)
# Processing: u00055s00001_hw00005.svc Completed in 1.1s (MAPE: 2.90%)
# Processing: u00055s00001_hw00006.svc Completed in 1.4s (MAPE: 9.78%)
# Processing: u00055s00001_hw00007.svc Completed in 1.3s (MAPE: 12.30%)
# Processing: u00056s00001_hw00001.svc Completed in 1.0s (MAPE: 2.51%)
# Processing: u00056s00001_hw00002.svc Completed in 1.7s (MAPE: 5.10%)
# Processing: u00056s00001_hw00003.svc Completed in 1.5s (MAPE: 9.96%)
# Processing: u00056s00001_hw00004.svc Completed in 1.2s (MAPE: 1.41%)
# Processing: u00056s00001_hw00005.svc Completed in 1.2s (MAPE: 0.58%)
# Processing: u00056s00001_hw00006.svc Completed in 1.4s (MAPE: 7.09%)
# Processing: u00056s00001_hw00007.svc Completed in 1.4s (MAPE: 8.72%)
# Processing: u00057s00001_hw00001.svc Completed in 1.2s (MAPE: 3.74%)
# Processing: u00057s00001_hw00002.svc Completed in 1.5s (MAPE: 7.86%)
# Processing: u00057s00001_hw00003.svc Completed in 1.5s (MAPE: 11.35%)
# Processing: u00057s00001_hw00004.svc Completed in 1.2s (MAPE: 3.60%)
# Processing: u00057s00001_hw00005.svc Completed in 1.2s (MAPE: 1.74%)
# Processing: u00057s00001_hw00006.svc Completed in 1.3s (MAPE: 8.24%)
# Processing: u00057s00001_hw00007.svc Completed in 1.4s (MAPE: 9.11%)
# Processing: u00058s00001_hw00001.svc Completed in 1.3s (MAPE: 6.44%)
# Processing: u00058s00001_hw00002.svc Completed in 1.5s (MAPE: 6.60%)
# Processing: u00058s00001_hw00003.svc Completed in 1.4s (MAPE: 11.86%)
# Processing: u00058s00001_hw00004.svc Completed in 1.0s (MAPE: 1.96%)
# Processing: u00058s00001_hw00005.svc Completed in 1.1s (MAPE: 1.64%)
# Processing: u00058s00001_hw00006.svc Completed in 1.4s (MAPE: 11.14%)
# Processing: u00058s00001_hw00007.svc Completed in 1.5s (MAPE: 11.97%)
# Processing: u00059s00001_hw00001.svc Completed in 1.1s (MAPE: 8.23%)
# Processing: u00059s00001_hw00002.svc Completed in 1.2s (MAPE: 8.52%)
# Processing: u00059s00001_hw00003.svc Completed in 1.4s (MAPE: 9.68%)
# Processing: u00059s00001_hw00004.svc Completed in 1.0s (MAPE: 5.10%)
# Processing: u00059s00001_hw00005.svc Completed in 1.3s (MAPE: 2.60%)
# Processing: u00059s00001_hw00006.svc Completed in 1.2s (MAPE: 11.30%)
# Processing: u00059s00001_hw00007.svc Completed in 1.4s (MAPE: 8.17%)
# Processing: u00060s00001_hw00001.svc Completed in 1.4s (MAPE: 9.75%)
# Processing: u00060s00001_hw00002.svc Completed in 1.6s (MAPE: 10.09%)
# Processing: u00060s00001_hw00003.svc Completed in 1.5s (MAPE: 11.55%)
# Processing: u00060s00001_hw00004.svc Completed in 1.1s (MAPE: 2.33%)
# Processing: u00060s00001_hw00005.svc Completed in 1.1s (MAPE: 2.90%)
# Processing: u00060s00001_hw00006.svc Completed in 1.5s (MAPE: 8.17%)
# Processing: u00060s00001_hw00007.svc Completed in 1.4s (MAPE: 9.53%)
# Processing: u00061s00001_hw00001.svc Completed in 1.2s (MAPE: 5.51%)
# Processing: u00061s00001_hw00002.svc Completed in 1.4s (MAPE: 7.22%)
# Processing: u00061s00001_hw00003.svc Completed in 1.4s (MAPE: 10.64%)
# Processing: u00061s00001_hw00004.svc Completed in 1.0s (MAPE: 1.72%)
# Processing: u00061s00001_hw00005.svc Completed in 1.0s (MAPE: 1.22%)
# Processing: u00061s00001_hw00006.svc Completed in 1.4s (MAPE: 10.22%)
# Processing: u00061s00001_hw00007.svc Completed in 1.4s (MAPE: 9.02%)
# Processing: u00062s00001_hw00001.svc Completed in 1.3s (MAPE: 5.25%)
# Processing: u00062s00001_hw00002.svc Completed in 1.4s (MAPE: 8.58%)
# Processing: u00062s00001_hw00003.svc Completed in 1.5s (MAPE: 10.39%)
# Processing: u00062s00001_hw00004.svc Completed in 1.1s (MAPE: 3.15%)
# Processing: u00062s00001_hw00005.svc Completed in 1.1s (MAPE: 1.54%)
# Processing: u00062s00001_hw00006.svc Completed in 1.4s (MAPE: 11.39%)
# Processing: u00062s00001_hw00007.svc Completed in 1.5s (MAPE: 10.39%)
# Processing: u00063s00001_hw00001.svc Completed in 1.3s (MAPE: 3.62%)
# Processing: u00063s00001_hw00002.svc Completed in 1.4s (MAPE: 7.84%)
# Processing: u00063s00001_hw00003.svc Completed in 1.4s (MAPE: 11.47%)
# Processing: u00063s00001_hw00004.svc Completed in 1.1s (MAPE: 0.67%)
# Processing: u00063s00001_hw00005.svc Completed in 1.2s (MAPE: 1.13%)
# Processing: u00063s00001_hw00006.svc Completed in 1.6s (MAPE: 9.84%)
# Processing: u00063s00001_hw00007.svc Completed in 1.4s (MAPE: 9.39%)
# Processing: u00064s00001_hw00001.svc Completed in 1.1s (MAPE: 2.81%)
# Processing: u00064s00001_hw00002.svc Completed in 1.4s (MAPE: 6.01%)
# Processing: u00064s00001_hw00003.svc Completed in 1.5s (MAPE: 10.91%)
# Processing: u00064s00001_hw00004.svc Completed in 1.1s (MAPE: 0.95%)
# Processing: u00064s00001_hw00005.svc Completed in 1.1s (MAPE: 0.93%)
# Processing: u00064s00001_hw00006.svc Completed in 1.5s (MAPE: 8.50%)
# Processing: u00064s00001_hw00007.svc Completed in 1.5s (MAPE: 10.96%)
# Processing: u00065s00001_hw00001.svc Completed in 1.8s (MAPE: 5.56%)
# Processing: u00065s00001_hw00002.svc Completed in 1.9s (MAPE: 5.48%)
# Processing: u00065s00001_hw00003.svc Completed in 1.6s (MAPE: 10.39%)
# Processing: u00065s00001_hw00004.svc Completed in 1.1s (MAPE: 2.95%)
# Processing: u00065s00001_hw00005.svc Completed in 1.1s (MAPE: 1.95%)
# Processing: u00065s00001_hw00006.svc Completed in 1.5s (MAPE: 6.75%)
# Processing: u00065s00001_hw00007.svc Completed in 1.4s (MAPE: 7.98%)
# Processing: u00066s00001_hw00001.svc Completed in 1.4s (MAPE: 4.19%)
# Processing: u00066s00001_hw00002.svc Completed in 1.6s (MAPE: 6.43%)
# Processing: u00066s00001_hw00003.svc Completed in 1.6s (MAPE: 10.52%)
# Processing: u00066s00001_hw00004.svc Completed in 1.0s (MAPE: 1.47%)
# Processing: u00066s00001_hw00005.svc Completed in 1.0s (MAPE: 2.13%)
# Processing: u00066s00001_hw00006.svc Completed in 1.6s (MAPE: 7.45%)
# Processing: u00066s00001_hw00007.svc Completed in 1.7s (MAPE: 10.88%)
# Processing: u00067s00001_hw00001.svc Completed in 1.1s (MAPE: 4.68%)
# Processing: u00067s00001_hw00002.svc Completed in 1.7s (MAPE: 3.89%)
# Processing: u00067s00001_hw00003.svc Completed in 1.5s (MAPE: 10.02%)
# Processing: u00067s00001_hw00004.svc Completed in 1.0s (MAPE: 2.17%)
# Processing: u00067s00001_hw00005.svc Completed in 1.0s (MAPE: 1.51%)
# Processing: u00067s00001_hw00006.svc Completed in 1.6s (MAPE: 6.40%)
# Processing: u00067s00001_hw00007.svc Completed in 1.4s (MAPE: 7.04%)
# Processing: u00068s00001_hw00001.svc Completed in 1.3s (MAPE: 5.40%)
# Processing: u00068s00001_hw00002.svc Completed in 1.5s (MAPE: 6.65%)
# Processing: u00068s00001_hw00003.svc Completed in 1.5s (MAPE: 12.48%)
# Processing: u00068s00001_hw00004.svc Completed in 1.0s (MAPE: 3.71%)
# Processing: u00068s00001_hw00005.svc Completed in 1.0s (MAPE: 0.63%)
# Processing: u00068s00001_hw00006.svc Completed in 1.4s (MAPE: 6.28%)
# Processing: u00068s00001_hw00007.svc Completed in 1.7s (MAPE: 9.87%)
# Processing: u00069s00001_hw00001.svc Completed in 1.2s (MAPE: 3.69%)
# Processing: u00069s00001_hw00002.svc Completed in 1.4s (MAPE: 5.84%)
# Processing: u00069s00001_hw00003.svc Completed in 1.6s (MAPE: 9.05%)
# Processing: u00069s00001_hw00004.svc Completed in 1.1s (MAPE: 13.41%)
# Processing: u00069s00001_hw00005.svc Completed in 0.9s (MAPE: 1.16%)
# Processing: u00069s00001_hw00006.svc Completed in 1.4s (MAPE: 9.02%)
# Processing: u00069s00001_hw00007.svc Completed in 1.6s (MAPE: 7.53%)
# Processing: u00070s00001_hw00001.svc Completed in 1.2s (MAPE: 6.29%)
# Processing: u00070s00001_hw00002.svc Completed in 1.4s (MAPE: 9.25%)
# Processing: u00070s00001_hw00003.svc Completed in 1.6s (MAPE: 11.24%)
# Processing: u00070s00001_hw00004.svc Completed in 1.1s (MAPE: 4.52%)
# Processing: u00070s00001_hw00005.svc Completed in 1.0s (MAPE: 2.35%)
# Processing: u00070s00001_hw00006.svc Completed in 1.5s (MAPE: 8.35%)
# Processing: u00070s00001_hw00007.svc Completed in 1.4s (MAPE: 9.39%)
# Processing: u00071s00001_hw00001.svc Completed in 1.4s (MAPE: 3.51%)
# Processing: u00071s00001_hw00002.svc Completed in 1.8s (MAPE: 5.21%)
# Processing: u00071s00001_hw00003.svc Completed in 1.5s (MAPE: 11.67%)
# Processing: u00071s00001_hw00004.svc Completed in 1.0s (MAPE: 3.70%)
# Processing: u00071s00001_hw00005.svc Completed in 1.0s (MAPE: 2.02%)
# Processing: u00071s00001_hw00006.svc Completed in 2.1s (MAPE: 8.22%)
# Processing: u00071s00001_hw00007.svc Completed in 1.6s (MAPE: 8.83%)
# Processing: u00072s00001_hw00001.svc Completed in 1.1s (MAPE: 5.41%)
# Processing: u00072s00001_hw00002.svc Completed in 1.6s (MAPE: 4.78%)
# Processing: u00072s00001_hw00003.svc Completed in 1.6s (MAPE: 10.37%)
# Processing: u00072s00001_hw00004.svc Completed in 1.1s (MAPE: 2.25%)
# Processing: u00072s00001_hw00005.svc Completed in 1.0s (MAPE: 1.39%)
# Processing: u00072s00001_hw00006.svc Completed in 1.4s (MAPE: 9.16%)
# Processing: u00072s00001_hw00007.svc Completed in 1.4s (MAPE: 8.64%)
# Processing: u00073s00001_hw00001.svc Completed in 1.1s (MAPE: 2.78%)
# Processing: u00073s00001_hw00002.svc Completed in 1.4s (MAPE: 4.45%)
# Processing: u00073s00001_hw00003.svc Completed in 1.4s (MAPE: 10.81%)
# Processing: u00073s00001_hw00004.svc Completed in 1.0s (MAPE: 1.64%)
# Processing: u00073s00001_hw00005.svc Completed in 1.0s (MAPE: 0.59%)
# Processing: u00073s00001_hw00006.svc Completed in 1.4s (MAPE: 12.11%)
# Processing: u00073s00001_hw00007.svc Completed in 1.5s (MAPE: 8.91%)
# Processing: u00074s00001_hw00001.svc Completed in 1.1s (MAPE: 13.52%)
# Processing: u00074s00001_hw00002.svc Completed in 1.4s (MAPE: 12.18%)
# Processing: u00074s00001_hw00003.svc Completed in 1.4s (MAPE: 9.84%)
# Processing: u00074s00001_hw00004.svc Completed in 1.1s (MAPE: 5.56%)
# Processing: u00074s00001_hw00005.svc Completed in 1.0s (MAPE: 1.90%)
# Processing: u00074s00001_hw00006.svc Completed in 1.4s (MAPE: 10.40%)
# Processing: u00074s00001_hw00007.svc Completed in 1.4s (MAPE: 10.19%)
# Processing: u00075s00001_hw00001.svc Completed in 1.5s (MAPE: 2.29%)
# Processing: u00075s00001_hw00002.svc Completed in 1.6s (MAPE: 5.23%)
# Processing: u00075s00001_hw00003.svc Completed in 1.6s (MAPE: 10.08%)
# Processing: u00075s00001_hw00004.svc Completed in 1.1s (MAPE: 7.33%)
# Processing: u00075s00001_hw00005.svc Completed in 1.0s (MAPE: 1.51%)
# Processing: u00075s00001_hw00006.svc Completed in 1.4s (MAPE: 8.48%)
# Processing: u00075s00001_hw00007.svc Completed in 1.5s (MAPE: 7.94%)
# Processing: u00076s00001_hw00001.svc Completed in 1.2s (MAPE: 6.94%)
# Processing: u00076s00001_hw00002.svc Completed in 1.5s (MAPE: 5.70%)
# Processing: u00076s00001_hw00003.svc Completed in 1.4s (MAPE: 11.87%)
# Processing: u00076s00001_hw00004.svc Completed in 1.0s (MAPE: 1.08%)
# Processing: u00076s00001_hw00005.svc Completed in 1.0s (MAPE: 0.94%)
# Processing: u00076s00001_hw00006.svc Completed in 1.4s (MAPE: 10.73%)
# Processing: u00076s00001_hw00007.svc Completed in 1.4s (MAPE: 9.25%)
# Processing: u00077s00001_hw00001.svc Completed in 1.2s (MAPE: 8.07%)
# Processing: u00077s00001_hw00002.svc Completed in 1.5s (MAPE: 9.26%)
# Processing: u00077s00001_hw00003.svc Completed in 1.4s (MAPE: 10.12%)
# Processing: u00077s00001_hw00004.svc Completed in 1.0s (MAPE: 2.78%)
# Processing: u00077s00001_hw00005.svc Completed in 0.8s (MAPE: 2.22%)
# Processing: u00077s00001_hw00006.svc Completed in 1.7s (MAPE: 9.11%)
# Processing: u00077s00001_hw00007.svc Completed in 1.6s (MAPE: 8.02%)
# Processing: u00078s00001_hw00001.svc Completed in 0.9s (MAPE: 3.12%)
# Processing: u00078s00001_hw00002.svc Completed in 1.3s (MAPE: 6.88%)
# Processing: u00078s00001_hw00003.svc Completed in 1.4s (MAPE: 10.30%)
# Processing: u00078s00001_hw00004.svc Completed in 1.0s (MAPE: 2.12%)
# Processing: u00078s00001_hw00005.svc Completed in 1.0s (MAPE: 1.56%)
# Processing: u00078s00001_hw00006.svc Completed in 1.3s (MAPE: 6.17%)
# Processing: u00078s00001_hw00007.svc Completed in 1.4s (MAPE: 8.17%)
# Processing: u00079s00001_hw00001.svc Completed in 1.1s (MAPE: 4.22%)
# Processing: u00079s00001_hw00002.svc Completed in 1.3s (MAPE: 6.48%)
# Processing: u00079s00001_hw00003.svc Completed in 1.5s (MAPE: 10.98%)
# Processing: u00079s00001_hw00004.svc Completed in 1.1s (MAPE: 2.74%)
# Processing: u00079s00001_hw00005.svc Completed in 1.1s (MAPE: 0.58%)
# Processing: u00079s00001_hw00006.svc Completed in 1.3s (MAPE: 8.59%)
# Processing: u00079s00001_hw00007.svc Completed in 1.4s (MAPE: 9.31%)
# Processing: u00080s00001_hw00001.svc Completed in 1.2s (MAPE: 12.65%)
# Processing: u00080s00001_hw00002.svc Completed in 1.5s (MAPE: 9.80%)
# Processing: u00080s00001_hw00003.svc Completed in 1.8s (MAPE: 12.57%)
# Processing: u00080s00001_hw00004.svc Completed in 1.1s (MAPE: 1.87%)
# Processing: u00080s00001_hw00005.svc Completed in 1.1s (MAPE: 1.12%)
# Processing: u00080s00001_hw00006.svc Completed in 1.4s (MAPE: 9.62%)
# Processing: u00080s00001_hw00007.svc Completed in 1.5s (MAPE: 9.54%)
# Processing: u00081s00001_hw00001.svc Completed in 2.0s (MAPE: 2.39%)
# Processing: u00081s00001_hw00002.svc Completed in 2.2s (MAPE: 3.89%)
# Processing: u00081s00001_hw00003.svc Completed in 1.5s (MAPE: 10.60%)
# Processing: u00081s00001_hw00004.svc Completed in 1.6s (MAPE: 2.96%)
# Processing: u00081s00001_hw00005.svc Completed in 1.9s (MAPE: 1.32%)
# Processing: u00081s00001_hw00006.svc Completed in 3.5s (MAPE: 6.25%)
# Processing: u00081s00001_hw00007.svc Completed in 2.9s (MAPE: 9.62%)
# Processing: u00082s00001_hw00001.svc Completed in 2.1s (MAPE: 3.68%)
# Processing: u00082s00001_hw00002.svc Completed in 2.3s (MAPE: 4.74%)
# Processing: u00082s00001_hw00003.svc Completed in 2.0s (MAPE: 9.22%)
# Processing: u00082s00001_hw00004.svc Completed in 1.0s (MAPE: 1.54%)
# Processing: u00082s00001_hw00005.svc Completed in 1.0s (MAPE: 0.90%)
# Processing: u00082s00001_hw00006.svc Completed in 1.7s (MAPE: 5.69%)
# Processing: u00082s00001_hw00007.svc Completed in 1.5s (MAPE: 10.43%)
# Processing: u00083s00001_hw00001.svc Completed in 1.4s (MAPE: 8.81%)
# Processing: u00083s00001_hw00002.svc Completed in 1.6s (MAPE: 6.53%)
# Processing: u00083s00001_hw00003.svc Completed in 1.5s (MAPE: 10.61%)
# Processing: u00083s00001_hw00004.svc Completed in 1.1s (MAPE: 3.12%)
# Processing: u00083s00001_hw00005.svc Completed in 0.9s (MAPE: 1.22%)
# Processing: u00083s00001_hw00006.svc Completed in 1.8s (MAPE: 7.47%)
# Processing: u00083s00001_hw00007.svc Completed in 1.4s (MAPE: 6.58%)
# Processing: u00084s00001_hw00001.svc Completed in 1.0s (MAPE: 2.67%)
# Processing: u00084s00001_hw00002.svc Completed in 1.4s (MAPE: 5.62%)
# Processing: u00084s00001_hw00003.svc Completed in 1.6s (MAPE: 10.70%)
# Processing: u00084s00001_hw00004.svc Completed in 1.0s (MAPE: 2.07%)
# Processing: u00084s00001_hw00005.svc Completed in 1.1s (MAPE: 1.60%)
# Processing: u00084s00001_hw00006.svc Completed in 1.4s (MAPE: 8.39%)
# Processing: u00084s00001_hw00007.svc Completed in 1.4s (MAPE: 8.53%)
# ----------------------------------------
# Overall Results:
# Average MAPE: 6.11%, Standard Deviation: 3.52%
